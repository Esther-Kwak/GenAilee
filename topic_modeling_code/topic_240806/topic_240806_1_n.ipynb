# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import re

from konlpy.tag import *

# %%
from konlpy.tag import Mecab

m = Mecab(dicpath = 'C:/mecab/mecab-ko-dic')
m.nouns('A타입도 좋고, PD충전 되는 것도 좋아요. C타입 여러개 있어서 좋습니다')
# Out:
# ['A타입', 'PD충전', '것', 'C타입', '개']

# %%
product = pd.read_csv("C:/Users/songy/Desktop/Data/product.csv", index_col = 0)
product
# Out:
#                              add_rule_based_split_review
# 3                               금액 차이 얼마 안 나는데 기능은 더 좋아요
# 4                             콤팩트한 디자인과 실용성에 높은 점수 주었습니다
# 8                                      전면 스크래치가 많아서 아쉽네요
# 15                               말 그대로 멀티어댑터에요 해외여행 필수 탬
# 19                                            작아서 휴대도 굿굿
# ...                                                  ...
# 18645                                       가볍고 휴대하기 좋아요
# 18646  C타입 충전이 없어서 구매를 망설이긴 했지만 좀 큰 변압기는 쳐져서 충전이 잘 안되...
# 18647                                        요 사이즈가 딱이네요
# 18649                                   켔써요 노란색이 너무 귀엽군요
# 18652           한 손에 쏙 들어오고 색이 쨍해서 여행 가서 잃어버릴 일 없을 거 같아요
#
# [8102 rows x 1 columns]

# %%
def upper_text(text):
    text = text.upper()
    return text

# %%
product['add_rule_based_split_review'] = product['add_rule_based_split_review'].apply(upper_text)

# %%
def replace_text(text):
  text = str(text)
  text = text.replace('쌈ㅎ','저렴해요')
  text = text.replace('안되는...','안됩니다')
  text = text.replace('ㅎ','')
  text = text.replace('ㅋ','')
  text = text.replace('루♡','')
  text = text.replace('♡','')
  text = text.replace('굳','굿')
  text = text.replace('ㅜ','')
  text = text.replace('중입니다)','중 입니다')
  text = text.replace('하나에요','하나예요')
  text = text.replace('있었어요','있어요')
  text = text.replace('욥','요')
  text = text.replace('오겠씀다~~ㅎㅎ/','오겠습니다')
  text = text.replace('후에~','')
  text = text.replace('개용','개요')
  text = text.replace('ㅅ','')
  text = text.replace('오ㅡ','')
  text = text.replace('여행가고싶어지네요ㅋㅋ','여행 가고 싶어지네요')
  text = text.replace('좋습니다!!!!','좋습니다')
  text = text.replace('구매확정해요','구매 확정해요')
  text = text.replace('완죤빨라요ㅋㅋ','완전 빨라요')
  text = text.replace('ㅡ','')
  text = text.replace('귀요미에요','귀여워요')
  text = text.replace('최고여요','최고예요')
  text = text.replace('사랑하여','사랑해요')
  text = text.replace('배송되었습니다','배송 되었습니다')
  text = text.replace('좋아요ㅔ','좋아요')
  text = text.replace('아니에요.','아니예요')
  text = text.replace('구매확정했습니다','구매 확정했습니다')
  text = text.replace('bbb','굿')
  text = text.replace('쓸ㄲ너ㅣㅇ르','')
  text = text.replace('같고요','같아요')
  text = text.replace('같네요','같아요')
  text = text.replace('씁니다','습니다')
  text = text.replace('넘좋와여','너무 좋아요')
  text = text.replace('굿입니다','굿')
  text = text.replace('목배게최고에요','목배게 최고예요')
  text = text.replace('감동이에요','감동이예요')
  text = text.replace('아이디어템','아이디어 탬')
  text = text.replace(':D','')
  text = text.replace('감사핮니다','감사합니다')
  text = text.replace('템','탬')
  text = text.replace('든든 합니다','든든합니다')
  text = text.replace('받아보았어요','받아봤어요')
  text = text.replace('가타용','같아요')
  text = text.replace('바랍니아','바랍니다')
  text = text.replace('사업번창하세요','사업 번창하세요')
  text = text.replace('쓸겠습니다','쓰겠습니다')
  text = text.replace('구매완료입니다','구매완료')
  text = text.replace('짱빠름','짱 빠름')
  text = text.replace('됩니닽','됩니다')
  text = text.replace('닙니다ㅛ','닙니다')
  text = text.replace('잘한듯해요','잘한듯')
  text = text.replace('가세여','가세요')
  text = text.replace('잘샀다템','잘샀어요')
  text = text.replace('좋아요좋아요좋오ㅓㅗㅇ좋아요','좋아요 좋아요')
  text = text.replace('써봐겠ㅆ네요','써봐야겠네요')
  text = text.replace('만족이에요','만족이예요')
  text = text.replace('아까워요.','아까워요')
  text = text.replace('ajjqjahaja','')
  text = text.replace('잚슬겡ㅎ','잘쓸게요')
  text = text.replace('잘했아요','잘했어요')
  text = text.replace('괜찬ㅍ아요','괜찮아요')
  text = text.replace('예쁨','예뻐요')
  text = text.replace('편하쥬','편해요')
  text = text.replace('감사함다','감사합니다')
  text = text.replace('핳핳','')
  text = text.replace('굿입니다','굿')
  text = text.replace('으흐흐','')
  text = text.replace('빨라요ㅗ','빨라요')
  text = text.replace('이븜','이쁨')
  text = text.replace('ㄹㅇ','')
  text = text.replace('되매요','되네요')
  text = text.replace('믿어보겠음다','믿어보겠습니다')
  text = text.replace('아니에요','아니예요')
  text = text.replace('만족합니다.ㅣ','만족합니다')
  text = text.replace('되고요','됩니다')
  text = text.replace('딱입니딘','딱입니다')
  text = text.replace('기대되어요','기대됩니다')
  text = text.replace('왔습디다','왔습니다')
  text = text.replace('맀어용','랐어요')
  text = text.replace('강강히','')
  text = text.replace('만족이여','만족이요')
  text = text.replace('사용했니다.','사용했습니다')
  text = text.replace('충전빨리되구죻아요','충전 빨리되고 좋아요')
  text = text.replace('잘됩니다잉','잘됩니다')
  text = text.replace('사용했답니다','사용했어요')
  text = text.replace('가타요','같아요')
  text = text.replace('최곱니다','최고입니다')
  text = text.replace('빠르네요','빠릅니다')
  text = text.replace('기릉','기를')
  text = text.replace('받았습니아','받았습니다')
  text = text.replace('ok.','ok')
  text = text.replace('가져감','가져갑니다')
  text = text.replace('익니다','입니다')
  text = text.replace('수용되오ㅡ','수용되요')
  text = text.replace('맨죡','만족')
  text = text.replace('ㄹ','')
  text = text.replace('구매예정이에요','구매 예정이예요')
  text = text.replace('좋은듓','좋은듯')
  text = text.replace('매우저롐하게잘구매했어요감사하네여','매우 저렴하게 잘 구매했어요 감사해요')
  text = text.replace('만적합니다','만족합니다')
  text = text.replace('ㅈ번창하세요','번창하세요')
  text = text.replace('전이에요','전이예요')
  text = text.replace('조어요','좋아요')
  text = text.replace('젛아요','좋아요')
  text = text.replace('됩니더','됩니다')
  text = text.replace('굿입디다','굿')
  text = text.replace('갘아어요','')
  text = text.replace('ㄷ,','')
  text = text.replace('잘되겠쥬','잘되겠죠')
  text = text.replace('쓰게습니도','쓰겠습니다')
  text = text.replace('하고요','하고')
  text = text.replace('저뇽가방도있네요','전용가방도 있네요')
  text = text.replace('sjsjsjjsjs','') 
  text = text.replace('좋겠구먼요','좋겠네요')
  text = text.replace('좋아욫','좋아요')
  text = text.replace('반퓸합니다','반품합니다')
  text = text.replace('꿋꿋입니다','굿')
  text = text.replace('잘씅게용','잘쓸게요')
  text = text.replace('땡큐네요','감사합니다')
  text = text.replace('베릐굿','굿')
  text = text.replace('효오','')
  text = text.replace('☆','')
  text = text.replace('ᄒ','')
  text = text.replace('썼어ᄉ','썼어요')
  text = text.replace('사용시뉴용할듯욕','사용시 유용할 듯')
  text = text.replace('있아요','있어요')
  text = text.replace('아다아다아','')
  text = text.replace('아다 아다 아','')
  text = text.replace('감사합니다아','감사합니다')
  text = text.replace('goood','굿')
  text = text.replace('싱픔굿배소오쟈웁','상품 굿 배송')
  text = text.replace('쓸겡','쓸게요')
  text = text.replace('굿국국숙','굿굿굿')
  text = text.replace('졸아요','좋아요')
  text = text.replace('USC','USB')
  text = text.replace('A S','AS')
  text = text.replace(' ㅐ외','해외')
  text = text.replace('ᄆ','')
  text = text.replace('ᅳᄋ ᄋ','')
  text = text.replace('배슝','배송')
  text = text.replace('ᅲ','')
  text = text.replace('쓸ᄁ너ᅵᄋ르','쓸게요')
  text = text.replace(' ♥','')
  text = text.replace('ᄏ','')
  text = text.replace('강 추','강추')
  text = text.replace('★','')
  text = text.replace('■','')
  
  # text = text.replace('USB', '유에스비')
  text = text.replace('보관 백', '보관백')
  text = text.replace('TYPE', '타입')
  text = text.replace('C TO C', 'C타입')
  text = text.replace('CTOC', 'C타입')
  text = text.replace('C2C', 'C타입')
  text = text.replace('USB-C', 'USB포트 C타입')
  text = text.replace('USB-A', 'USB포트 A타입')
  text = text.replace('C TYPE', 'C타입')
  text = text.replace('C 타입','C타입')
  text = text.replace('씨타입','C타입')
  text = text.replace('씨 타입', 'C타입')
  text = text.replace('A 타입','A타입')
  text = text.replace('에이타입','A타입')
  text = text.replace('에이 타입', 'A타입')
  text = text.replace('PD 충전','PD충전')
  text = text.replace('PD 잭', 'PD잭')
  text = text.replace('급 속','급속')
  text = text.replace('포드','포트')
  text = text.replace('포드만','포트')
  text = text.replace('포드리','포트')
  text = text.replace('핸폰','핸드폰')
  text = text.replace('휴대폰', '핸드폰')
  text = text.replace('휴대전화', '핸드폰')
  text = text.replace('11볼트', '110V')
  text = text.replace('22볼트', '220V')
  text = text.replace('11V', '110V')
  text = text.replace('22V', '220V')
  # text = text.replace('35W', '35와트')
  # text = text.replace('45W', '45와트')
  # text = text.replace('65W', '65와트')
  text = text.replace('포터', '포트')
  # text = text.replace('USB', 'USB포트') 
  text = text.replace('USB 포트', 'USB포트')
  text = text.replace('동시 충전', '동시충전')
  text = text.replace('고속 충전', '고속충전')
  text = text.replace('동시 이용', '동시이용')
  text = text.replace('동시 사용', '동시사용')
  text = text.replace('여러 나라', '여러나라')
  text = text.replace('코넥터', '커넥터')
  # 1개짜리는 제외
  return text

# %%
product['add_rule_based_split_review'] = product['add_rule_based_split_review'].apply(replace_text)

# %%
def clean_text(text):
    if isinstance(text, str):
        return re.sub(r'[-=+,#/\?:^$.@*"※~&%ㆍ!』\\‘·|\(\)\[\]\<\>`\'…\"\“’]', '', text)
    else:
        return ""

# %%
product['add_rule_based_split_review'] = product['add_rule_based_split_review'].apply(clean_text)

# %%
from konlpy.tag import Mecab
m = Mecab(dicpath = 'C:/mecab/mecab-ko-dic')

# %%
def preprocess_reviews(reviews, stopwords_path, additional_stopwords=[]):
    # 불용어 파일 로드
    with open(stopwords_path, encoding='utf-8') as file:
        stopwords = file.read().splitlines()
    
    # 추가 불용어 합치기
    stopwords.extend(additional_stopwords)

    # 리뷰 전처리
    clean_sent = []
    for review in reviews:
        clean = re.sub(r'[-=+,#/\?:^$.@*"※~&%ㆍ!』\\‘·|\(\)\[\]\<\>`\'…\"\“’]', '', review)
        clean = clean.replace('\n', '').replace('\r', '')  # 줄바꿈 문자 제거
        clean_sent.append(clean)

    m = Mecab(dicpath = 'C:/mecab/mecab-ko-dic')
    
    word_list = []
    for sentences in clean_sent:
        # 정규화
        # sentences = m.normalize(sentences)
        # 토큰화
        # tokens = sentences.split()
        tokens = m.nouns(sentences)
        # tokens = okt.nouns(sentences)
        # 불용어 제거
        tokens = [token for token in tokens if token not in stopwords]
        word_list.append(tokens)
    
    return word_list

# %%
"""
stopwords_path = "C:/Users/songy/Desktop/Data/stopwords-ko.txt"
with open(stopwords_path, encoding='utf-8') as file:
    stopwords = file.read().splitlines()

print(stopwords)
"""
# Out:
# '\nstopwords_path = "C:/Users/songy/Desktop/Data/stopwords-ko.txt"\nwith open(stopwords_path, encoding=\'utf-8\') as file:\n    stopwords = file.read().splitlines()\n\nprint(stopwords)\n'

# %%
def compiled_morphs(texts, stopwords_path, additional_stopwords=[]):
    # 불용어 파일 로드
    with open(stopwords_path, encoding='utf-8') as file:
        stopwords = file.read().splitlines()

    # 추가 불용어 합치기
    stopwords.extend(additional_stopwords)

    # 리뷰 전처리
    clean = re.sub(r'[-=+,#/\?:^$.@*"※~&%ㆍ!』\\‘·|\(\)\[\]\<\>`\'…\"\“’]', '', texts)
    clean = clean.replace('\n','').replace('\r','')     # 줄바꿈 문자 제거

    # 형태소 분석기 추가
    m = Mecab(dicpath='C:/mecab/mecab-ko-dic')

    result = []
    for i in range(len(m.pos(clean))):
        word, pos = m.pos(clean)[i]
        # 형태소가 연결 어미인지 확인
        if pos in ['VA']:
            if i + 1 < len(m.pos(clean)):
                next_word, next_pos = m.pos(clean)[i + 1]
                if next_pos in ['EC', 'ETM']:           # 연결 어미 또는 관형형 전성 어미
                    result.append(word + next_word)
                else:
                    result.append(word + next_word)
        elif pos in ['NNG', 'NNP']:
            result.append(word) 
    
    # 불용어 처리
    results = [word for word in result if word not in stopwords]
    
    return results

# %%
def compiled_morphs_noun(texts, stopwords_path, additional_stopwords=[]):
    # 불용어 파일 로드
    with open(stopwords_path, encoding='utf-8') as file:
        stopwords = file.read().splitlines()

    # 추가 불용어 합치기
    stopwords.extend(additional_stopwords)

    # 리뷰 전처리
    clean = re.sub(r'[-=+,#/\?:^$.@*"※~&%ㆍ!』\\‘·|\(\)\[\]\<\>`\'…\"\“’]', '', texts)
    clean = clean.replace('\n','').replace('\r','')     # 줄바꿈 문자 제거

    # 형태소 분석기 추가
    m = Mecab(dicpath='C:/mecab/mecab-ko-dic')

    result = []
    for i in range(len(m.pos(clean))):
        word, pos = m.pos(clean)[i]
        if pos in ['NNG', 'NNP']:
            result.append(word) 
    
    # 불용어 처리
    results = [word for word in result if word not in stopwords]
    
    return results

# %%
example_sent = "퓨즈 교체가 자동이라서 신경 쓸 일이 하나 줄은 것도 장점이고요"

# %%
def find_morphs(text):
    """
    명사, 형태소 추출 함수 (형용사의 연결 어미를 반영해 추출)
    """
    result = []

    for i in range(len(m.pos(text))):
        word, pos = m.pos(text)[i]
        # 형태소가 연결 어미인지 확인
        if pos in ['VA']:
            if i + 1 < len(m.pos(text)):
                next_word, next_pos = m.pos(text)[i + 1]
                if next_pos in ['EC', 'ETM']:           # 연결 어미 또는 관형형 전성 어미
                    result.append(word + next_word)
                else:
                    #result.append(word + next_word)
                    result.append(word)
        elif pos in ['NNG', 'NNP']:                     # 명사 
            result.append(word)

    return result

# %%
find_morphs("튼튼한 것 견고한 컴팩트 케이스 테스트")
# Out:
# ['컴팩트', '케이스', '테스트']

# %%
compiled_morphs("C타입까지 USB 튼튼한 것 견고한 컴팩트 케이스 테스트 칰 USB", stopwords_path="C:/Users/songy/Desktop/Data/stopwords-ko.txt")
# Out:
# ['C타입', '컴팩트', '케이스', '테스트']

# %%
compiled_morphs_noun("C타입까지 USB 튼튼한 것 견고한 컴팩트 케이스 테스트 칰 USB", stopwords_path="C:/Users/songy/Desktop/Data/stopwords-ko.txt")
# Out:
# ['C타입', '컴팩트', '케이스', '테스트']

# %%
#compiled_morphs("", stopwords_path="C:/Users/songy/Desktop/Data/stopwords-ko.txt")

# %%
#product['changed_text'] = product['add_rule_based_split_review'].apply(find_morphs)
reviews = product['add_rule_based_split_review']  # 리뷰 데이터
stopwords_path = "C:/Users/songy/Desktop/Data/stopwords-ko.txt"

additional_stopwords = ['가', '가격', '가운데', '가족', '간', '감', '감비', '감사', '값', '강추', '같고', '같습니다', '같아', '같아서', '같아요', '겉'
                        '같은', '결제', '같은데', '개', '거', '거랑', '걱정', '검색', '것', '겉', '게', '게요', '결과', '결재', '경우', '고', '금액', '차이',
                        '고려', '고만', '고민', '곳', '과', '괜찮아요', '구리고', '구매', '구매평', '구비', '구성', '구입', '군더더기', '굿', '귀찮게',
                        '귀찮고', '글', '급하게', '기대', '기존', '기준', '길', '김기', '깊질', '까지', '끝', '나라', '나중', '날', '남편',
                        '냐짱', '너무', '네이버', '노브', '눈', '느낌', '느리네요', '는', '다', '다르게', '다르고', '다양', '다이소', '다행', '달',
                        '담', '답변', '대부분', '대비', '대신', '덕분', '덜렁', '도', '도착', '돈', '동봉', '동생', '동일', '돼다', '되다',
                        '되어다', '두면', '뒤', '들', '등', '디', '딸', '때', '땡', '뛰어나다', '라', '라고', '래빗', '레이', '로', 
                        '를', '리뷰', '마', '마련', '마음', '만', '만족', '많고', '많아서', '많았었', '많지만', '말', '맘', '맛', '멀티',
                        '멜리', '면', '못', '무료', '문', '문제', '물', '물건', '미', '및', '밑', '며칠', '바이', '박스', '반', '받다',
                        '발', '발송', '배', '배송', '번', '번개', '벽', '변', '별도', '별점', '보관', '복', '봉', '부분', '브레',
                        '비선', '비싸지', '비싸지만', '빌', '사나', '사서', '사실', '사요', '사용', '사장', '사진', '생각', '서', '선물', '선택',
                        '설치', '세상', '쇼퍼', '숍', '수', '숙소', '스타', '스티커', '스펙', '시', '시기', '시대', '시험', '식겁', '신랑',
                        '신행', '실사', '실사용자', '싸게', '싸구려', '싸는데', '싸진', '쌀', '써다', '쏙', '쓸모', '아들', '아무것', '아쉽네요', '아쉽습니다',
                        '아주', '아직', '안', '않다', '알차게', '앞', '애', '야지', '얇아요', '얘기', '어렵더라고요', '어머니', '언니', '언스', '엄마',
                        '업', '없겠', '없고', '없나', '없네요', '없는', '없어서', '없어요', '없었', '없으니까요', '없지만', '에', '에서', '엔', '엔코',
                        '여분', '여유', '여행', '역할', '연락', '연휴', '옆', '예비', '예전', '옛날', '오다', '오랫동안', '오전', '오케이', '오후',
                        '와', '와이프', '요', '요새', '요즘', '용', '운', '워홀', '원', '원래', '유용', '으로', '은', '을', '의',
                        '이', '이거', '이다', '이라', '이랑', '이번', '이외', '이용', '이유', '이전', '인', '인터넷', '일행', '있고', '있군요',
                        '있긴', '있네요', '있는', '있는대도', '있다', '있다는', '있던데', '있어', '있어서', '있었', '있을', '있지만', '자', '자다', '자체',
                        '잔', '잘', '장만', '잦은데', '저렴', '저번', '전', '전용', '전이', '전체', '점', '정', '정도', '제', '제공',
                        '제품', '종결', '종류', '좋겠', '좋고', '좋네요', '좋더라구요', '좋습니다', '좋아서', '좋아요', '좋았', '좋은', '좋은데요', '좋을', '주', '좋',
                        '주니', '주문', '주파', '준비', '중요', '지난번', '지네', '지원', '지인', '집', '차', '차지', '처리', '처음', '첨부',
                        '추천', '추후', '출국', '출장', '친구', '친절', '커피', '코', '크게', '크지', '큰일', '테스트', '퇴원', '튀', '트',
                        '티', '판매', '편리', '편하게', '편하고', '평', '평생', '포장', '포함', '표', '프리', '필', '필수탬', '필요', '하고', '필수', '이거', '아쉽더라구요', 
                        '하다', '하머', '하우스', '한', '한국', '한큐', '해', '형', '호텔', '확인', '활용', '회사', '효', '후', '후기', '같', '없', '당황', '목', '탬', '높은',
                        '흠', '히', '힘', '하루','단','역시','음','지고','이기','이제','무거워서','주려','하나라','가능','가성비','배변','패드','견','강아지']

# 추가 불용어 : '가성비','배변','패드','견','강아지'

product['changed_text'] = product['add_rule_based_split_review'].apply(lambda texts : compiled_morphs(texts, stopwords_path, additional_stopwords))

# %%
len(product)
# Out:
# 8102

# %%
product.head(3)
# Out:
#   add_rule_based_split_review    changed_text
# 3    금액 차이 얼마 안 나는데 기능은 더 좋아요            [기능]
# 4  콤팩트한 디자인과 실용성에 높은 점수 주었습니다  [콤팩트, 디자인, 실용]
# 8           전면 스크래치가 많아서 아쉽네요      [전면, 스크래치]

# %%
product.head(3)
# Out:
#   add_rule_based_split_review    changed_text
# 3    금액 차이 얼마 안 나는데 기능은 더 좋아요            [기능]
# 4  콤팩트한 디자인과 실용성에 높은 점수 주었습니다  [콤팩트, 디자인, 실용]
# 8           전면 스크래치가 많아서 아쉽네요      [전면, 스크래치]

# %%
def list_convert_comma(lst):
    return ', '.join(lst)

def list_convert_space(lst):
    return ' '.join(lst)

# %%
product['Tokenized_sentence'] = product['changed_text'].apply(list_convert_comma)
product['Tokenized_morphs'] = product['changed_text'].apply(list_convert_space)
product.head(3)
# Out:
#   add_rule_based_split_review    changed_text Tokenized_sentence  \
# 3    금액 차이 얼마 안 나는데 기능은 더 좋아요            [기능]                 기능
# 4  콤팩트한 디자인과 실용성에 높은 점수 주었습니다  [콤팩트, 디자인, 실용]       콤팩트, 디자인, 실용
# 8           전면 스크래치가 많아서 아쉽네요      [전면, 스크래치]           전면, 스크래치
#
#   Tokenized_morphs
# 3               기능
# 4       콤팩트 디자인 실용
# 8          전면 스크래치

# %%
product.rename(columns={'changed_text':'Tokenized_sentence',
                        'Tokenized_sentence':'Tokenized_sentence_list'}, inplace=True)

# %%
#product.to_csv('C:/Users/songy/Desktop/Data/product_morphs.csv', encoding='utf-8-sig')

# %% [markdown]
# - 앞 전처리 (replace) 부분에서 처리 방식이 상이한 부분이 있어 추후 통일 예정
# - 우선 통일화 위해 공유 받은 데이터로 결과값 추출 진행 (product_pos)

# %%
#product_pos = pd.read_csv('C:/Users/songy/Desktop/Data/product_pos.csv', encoding='utf-8-sig', index_col = 0)
#product_pos.head(3)

# %%
# 오류에 따라 리스트 아닌 행 추출
#non_list_items = product_pos[~product_pos['Tokenized_sentence'].apply(lambda x: isinstance(x, list))]
#non_list_items

# %%
"""
# 오류에 따라 str이 아닌 리스트로 인식하게 하는 함수
def str_to_list(text):
    if isinstance(text, str):
        try:
            return eval(text)
        except:
            return text
    return text
"""
# Out:
# '\n# 오류에 따라 str이 아닌 리스트로 인식하게 하는 함수\ndef str_to_list(text):\n    if isinstance(text, str):\n        try:\n            return eval(text)\n        except:\n            return text\n    return text\n'

# %%
product
# Out:
#                              add_rule_based_split_review  Tokenized_sentence  \
# 3                               금액 차이 얼마 안 나는데 기능은 더 좋아요                [기능]
# 4                             콤팩트한 디자인과 실용성에 높은 점수 주었습니다      [콤팩트, 디자인, 실용]
# 8                                      전면 스크래치가 많아서 아쉽네요          [전면, 스크래치]
# 15                               말 그대로 멀티어댑터에요 해외여행 필수 탬       [멀티어댑터, 해외여행]
# 19                                            작아서 휴대도 굿굿           [작아서, 휴대]
# ...                                                  ...                 ...
# 18645                                       가볍고 휴대하기 좋아요           [가볍고, 휴대]
# 18646  C타입 충전이 없어서 구매를 망설이긴 했지만 좀 큰 변압기는 쳐져서 충전이 잘 안되...  [C타입, 충전, 변압기, 충전]
# 18647                                        요 사이즈가 딱이네요               [사이즈]
# 18649                                   켔써요 노란색이 너무 귀엽군요         [노란색, 귀엽군요]
# 18652           한 손에 쏙 들어오고 색이 쨍해서 여행 가서 잃어버릴 일 없을 거 같아요          [손, 색, 없을]
#
#       Tokenized_sentence_list Tokenized_morphs
# 3                          기능               기능
# 4                콤팩트, 디자인, 실용       콤팩트 디자인 실용
# 8                    전면, 스크래치          전면 스크래치
# 15                멀티어댑터, 해외여행       멀티어댑터 해외여행
# 19                    작아서, 휴대           작아서 휴대
# ...                       ...              ...
# 18645                 가볍고, 휴대           가볍고 휴대
# 18646        C타입, 충전, 변압기, 충전    C타입 충전 변압기 충전
# 18647                     사이즈              사이즈
# 18649               노란색, 귀엽군요         노란색 귀엽군요
# 18652                손, 색, 없을           손 색 없을
#
# [8102 rows x 4 columns]

# %%
# 위 함수 적용
#product['Tokenized_sentence'] = product['Tokenized_sentence'].apply(str_to_list)

# %%
remove_stopwords2 = sum(product['Tokenized_sentence'],[])
remove_stopwords2
# Out:
# ['기능',
#  '콤팩트',
#  '디자인',
#  '실용',
#  '전면',
#  '스크래치',
#  '멀티어댑터',
#  '해외여행',
#  '작아서',
#  '휴대',
#  '품질',
#  'USB형',
#  'USB형',
#  '전압',
#  '충전',
#  '느리게',
#  '충전',
#  '충전',
#  '코드',
#  '불편',
#  '파우치',
#  '같은',
#  '호환',
#  '불편',
#  '없으며',
#  '마감',
#  '아쉬우나',
#  '유럽',
#  '유럽',
#  '단자',
#  '불량',
#  'USB형',
#  '없길',
#  '성능',
#  '착하네요',
#  '콘센트',
#  '기능',
#  '일반형',
#  'USB형',
#  '좋음',
#  '겸용',
#  '충전',
#  '느리편',
#  '유럽',
#  '본체',
#  '콘센트',
#  '포트',
#  '추가',
#  '불량',
#  '포트',
#  '작동',
#  '불편',
#  '고정',
#  '무용지물',
#  '해결',
#  '불량',
#  '정상',
#  '플러그',
#  '품질',
#  '파우치',
#  '연결',
#  '연결',
#  '고장',
#  '콘센트',
#  '지장',
#  '없긴',
#  '코드',
#  '괜찮은',
#  '콘센트',
#  '정상',
#  '동작',
#  '국내',
#  '기능',
#  '국가',
#  '콘센트',
#  '많은',
#  '기능',
#  'EU타입',
#  '콘센트',
#  '전원',
#  '고정',
#  'EU타입',
#  '콘센트',
#  '전원',
#  '고정',
#  '여러나라',
#  '플러그',
#  '모양',
#  '품질',
#  '버튼',
#  '많네요',
#  '유럽',
#  '어댑터',
#  '국가',
#  '퀄리티',
#  '작고',
#  '파우치',
#  '휴대',
#  '대만',
#  '충전',
#  '타입',
#  '충전',
#  '일본',
#  '돼지코',
#  '연결',
#  '멀티탭',
#  'C타입',
#  '충전',
#  '돼지코',
#  'C타입',
#  '충전기',
#  '케이블',
#  '짐',
#  '자국',
#  '마감',
#  '대만',
#  '고속충전',
#  '미국',
#  '가볍고',
#  '파우치',
#  '캐리어',
#  '유선',
#  '칸',
#  '충전',
#  '장점',
#  '있어요',
#  '상품',
#  '품질',
#  '마감',
#  '실물',
#  '여행용',
#  '멀티어댑터',
#  '해외여행',
#  '타입',
#  '휴대',
#  '멀티어댑터',
#  '디자인',
#  '파우치',
#  '충전',
#  '속도',
#  '기능',
#  '타입',
#  'C타입',
#  '멀티탭',
#  '타입',
#  '타입',
#  'A타입',
#  'C타입',
#  '와이파이',
#  '도시락',
#  '핸드폰',
#  '보조배터리',
#  '충전',
#  '핸드폰',
#  '충전',
#  '속도',
#  '고속충전',
#  '충전기',
#  '디자인',
#  '한몫',
#  '파우치',
#  '좋고요',
#  '케이스',
#  '휴대',
#  '퀄리티',
#  '파우치',
#  '휴대',
#  '일본',
#  '불편',
#  '전기',
#  '케이스',
#  '케이스',
#  '쿠션',
#  '같은',
#  '콘센트',
#  '구멍',
#  '크기',
#  '모양',
#  '멀티어댑터',
#  '케이스',
#  '충전',
#  '파우치',
#  '디자인',
#  '파우치',
#  '성능',
#  '기능',
#  '돼지코',
#  '어댑터',
#  '작동',
#  '유럽',
#  '콘센트',
#  '좋더라고요',
#  '외국',
#  '고장',
#  '어댑터',
#  '충전',
#  '유럽',
#  '흰색',
#  '이쁘고',
#  '작고',
#  '케이스',
#  '디자인',
#  '파우치',
#  '자리',
#  '충전',
#  '파우치',
#  '일본',
#  '요고',
#  '해결',
#  'C타입',
#  '고속충전',
#  '파우치',
#  'USB포트',
#  '작동',
#  '케이스',
#  '고급',
#  '동유럽',
#  '보조배터리',
#  '충전',
#  '파우치',
#  '여러나라',
#  '부모',
#  '가실',
#  '성능',
#  '좋으면',
#  '연결',
#  '케이스',
#  '세계',
#  '돼지코',
#  '돼지코',
#  '파우치',
#  '안심',
#  '어댑터',
#  '냄새',
#  '미국',
#  '파우치',
#  '품질',
#  'C타입',
#  '내구',
#  '안정',
#  '사은품',
#  '파우치',
#  '이동',
#  '파손',
#  '우려',
#  'PD충전',
#  'C타입',
#  '충전',
#  'USB포트',
#  '충전기',
#  '실용',
#  '파우치',
#  'USB포트',
#  'C타입',
#  '작동',
#  '지역',
#  '구성품',
#  '멀티탭',
#  '일본',
#  '핸드폰',
#  '보조배터리',
#  '보조배터리',
#  '충전',
#  '야무지게',
#  '충전',
#  '유선',
#  '멀티탭',
#  '국가',
#  '무게',
#  '가볍고',
#  '휴대',
#  '파우치',
#  '휴대',
#  '속',
#  '멀티탭',
#  '충전',
#  '케이블',
#  '충전기',
#  '무게',
#  'C타입',
#  '케이블',
#  '어댑터',
#  '무게',
#  '충전',
#  'C타입',
#  '타입',
#  '실용',
#  '110V',
#  '구멍',
#  '여행지',
#  '고데기',
#  '렴',
#  '돼지코',
#  '파우치',
#  '멀티탭',
#  '고데기',
#  '어댑터',
#  '연결',
#  '돼지코',
#  '여러나라',
#  '어댑터',
#  '220V',
#  'C타입',
#  '케이스',
#  '성능',
#  '무게',
#  '사이즈',
#  '커버',
#  '디자인',
#  '이쁘고',
#  '케이스',
#  '디자인',
#  '케이스',
#  '케이스',
#  '해외',
#  'USB포트',
#  '핸드폰',
#  '충전',
#  '속도',
#  '빠르지',
#  '핸드폰',
#  '충전',
#  'USB포트',
#  '디자인',
#  '돼지코',
#  '고장',
#  '케이스',
#  '품질',
#  '케이스',
#  '어댑터',
#  '디자인',
#  '콘센트',
#  '대박',
#  '상품',
#  '충전',
#  '핸드폰',
#  '충전',
#  '멀티탭',
#  '연결',
#  '해외여행',
#  '영국',
#  'C타입',
#  '견고',
#  '콘센트',
#  '콘센트',
#  '충전',
#  '색',
#  '케이스',
#  '케이스',
#  '케이스',
#  '충전',
#  '선',
#  '충전',
#  '해외여행',
#  '크긴',
#  '문제없었',
#  '퓨즈',
#  '해외',
#  '퓨즈',
#  '퓨즈',
#  '작동',
#  '파우치',
#  '케이스',
#  '사은품',
#  '케이스',
#  '어댑터',
#  '충전',
#  '파우치',
#  '케이스',
#  '해외여행',
#  '어댑터',
#  '국내',
#  '불량',
#  '단점',
#  '불량',
#  '충전',
#  '충전',
#  '속도',
#  '느리지',
#  '워치',
#  '핸드폰',
#  '보조배터리',
#  '충전',
#  '있으면',
#  '해외',
#  '없습니다',
#  '충전',
#  '포트',
#  '고데기',
#  '고데기',
#  '볼트',
#  '어댑터',
#  '애플워치',
#  '보조배터리',
#  '충전',
#  '케이스',
#  '품질',
#  '중국',
#  '타입',
#  '충전',
#  '멀티탭',
#  '기기',
#  '충전',
#  'C타입',
#  '외국',
#  '일본',
#  '고장',
#  '충전',
#  '개선',
#  '110V',
#  '충전',
#  '입구',
#  '220V',
#  '깊이',
#  '깊지',
#  '일본',
#  '많더군요',
#  '깊은',
#  '입구',
#  '안쪽',
#  '개선',
#  '마감',
#  '아이디어',
#  '실용',
#  '정리',
#  '구조',
#  '휴대',
#  '국내',
#  '평소',
#  '선',
#  '어댑터',
#  '파우치',
#  '미국',
#  '손상',
#  '국내외',
#  '케이스',
#  '사용법',
#  '작고',
#  '부담',
#  '크기',
#  '파우치',
#  '여러나라',
#  'C타입',
#  '케이블',
#  '케이블',
#  '만능',
#  '기업',
#  '데이트',
#  '파우치',
#  '충',
#  '사이즈',
#  '타입',
#  '케이',
#  '어댑터',
#  '후회',
#  '일본',
#  '견고',
#  '해외여행',
#  '충전기',
#  '없어',
#  'C타입',
#  '케이블',
#  '포트',
#  '선',
#  '동시충전',
#  '파우치',
#  '무게',
#  '가볍고',
#  '세계',
#  '유럽',
#  '콘센트',
#  '케이스',
#  '휴대',
#  '여행용',
#  '멀티어댑터',
#  '해외여행',
#  '콘센트',
#  '변환기',
#  '돼지코',
#  '기능',
#  '기기',
#  '동시',
#  '충전',
#  'PD',
#  'C타입',
#  '빠르고',
#  '안정',
#  '충전',
#  '여행용',
#  '멀티어댑터',
#  '계속',
#  '멀티어댑터',
#  '미국',
#  '멀티탭',
#  '멀티탭',
#  '기기',
#  '무리',
#  '해외여행',
#  '대만',
#  '케이스',
#  '유럽',
#  '핸드폰',
#  '보조배터리',
#  '충전',
#  '어댑터',
#  '가방',
#  '어댑터',
#  '충전',
#  '파우치',
#  '세계',
#  '일본',
#  '가방',
#  '휴대',
#  '일본',
#  '퓨즈',
#  '퓨즈',
#  '유에스비',
#  '포트',
#  '타입',
#  '포트',
#  '동시',
#  '충전',
#  '일본',
#  '충전',
#  '디자인',
#  '콘센트',
#  '해외',
#  '돼지코',
#  '해결',
#  '파우치',
#  '멀티탭',
#  '좋음',
#  '디자인',
#  '케이스',
#  '케이스',
#  '디자인',
#  '대만',
#  '낯설었',
#  '전기포트',
#  '해외',
#  '케이스',
#  '장점',
#  '케이스',
#  '케이스',
#  '충전',
#  '충전',
#  '여러나라',
#  '호환',
#  '케이스',
#  '본체',
#  '같은',
#  '불안감',
#  '연결',
#  '충전',
#  '빠르게',
#  '케이스',
#  '콤팩트',
#  '품질',
#  '마감',
#  '안전',
#  '충전',
#  '연결',
#  '실용',
#  '케이스',
#  '케이스',
#  '다이슨',
#  '각도',
#  '각도',
#  '조절',
#  '돼지코',
#  '고속충전',
#  '케이스',
#  '케이스',
#  '이쁘고',
#  '해외여행',
#  '일본',
#  '케이스',
#  '콘센트',
#  'C타입',
#  '단자',
#  '유에스비',
#  '단자',
#  '빠르게',
#  '멀티어댑터',
#  '불편',
#  '콘센트',
#  '부드럽게',
#  'C타입',
#  '충전',
#  '파우치',
#  '휴대',
#  '충전',
#  '해외',
#  '멀티어댑터',
#  '무게',
#  '콘센트',
#  '불편',
#  '유럽',
#  '인증',
#  '지역',
#  '커버',
#  '일본',
#  '기기',
#  '충전',
#  '전일',
#  '저녁',
#  '짐',
#  '일본',
#  '돼지코',
#  '세계',
#  '한국인',
#  '고속충전',
#  '고속충전',
#  '아이폰',
#  '갤럭시',
#  '연결',
#  '충전',
#  '대만',
#  '110V',
#  '전기',
#  '충전',
#  '충전',
#  'C타입',
#  '케이스',
#  '귀엽고',
#  '케이스',
#  '고급',
#  '드라이기',
#  'C타입',
#  '충전',
#  '파우치',
#  '어댑터',
#  '동시',
#  '충전',
#  '220V',
#  '코드',
#  '내구',
#  '국가',
#  '어댑터',
#  '충전',
#  '선',
#  '파우치',
#  '디자인',
#  '컬러',
#  '고급',
#  '작아서',
#  '휴대',
#  '해외여행',
#  '멀티어댑터',
#  '포트',
#  '연결',
#  '잭',
#  '해결',
#  '국가',
#  '해당',
#  '옵션',
#  '설명서',
#  '파우치',
#  '발리',
#  '신혼',
#  '다이슨',
#  '어댑터',
#  '다이슨',
#  '베개',
#  '고생',
#  '의자',
#  '의자',
#  '가이드',
#  '사람',
#  '대박',
#  'C타입',
#  '동시',
#  '해외',
#  '짐',
#  '가격대',
#  '퀄리티',
#  '장점',
#  '있으면',
#  '해외',
#  '빛',
#  '디자인',
#  '케이스',
#  '입',
#  '개꿀',
#  '멀티탭',
#  '없음',
#  '충전',
#  '편',
#  '멀티탭',
#  '충전',
#  '헐겁다고',
#  '핸드폰',
#  '충전',
#  '워치',
#  '충전',
#  '드라이기',
#  '좋더라고요',
#  '많은',
#  '충전',
#  '파우치',
#  '파우치',
#  '실용',
#  '퓨즈',
#  '충전',
#  '케이블',
#  '많다',
#  '예쁘게',
#  '충전',
#  '갤럭시',
#  '고속충전',
#  '충전',
#  '빠르고',
#  '연결',
#  '불안',
#  '일본',
#  '충전',
#  '불편',
#  '색상',
#  '흰색',
#  '그레이',
#  '포트',
#  'C타입',
#  '충전',
#  '케이스',
#  '충전',
#  '호환',
#  '불편',
#  '케이스',
#  '케이스',
#  '해외여행',
#  'C타입',
#  '최근',
#  '콘센트',
#  '자리',
#  '타입',
#  '국내',
#  '멀티탭',
#  '실용',
#  '멀티탭',
#  '연결',
#  '핸드폰',
#  '충전',
#  '품질',
#  '고급',
#  '케이스',
#  '어댑터',
#  '콘센트',
#  '일본',
#  '어댑터',
#  '상품',
#  '충전',
#  '충전',
#  '케이스',
#  '충전',
#  '하와이',
#  '다이슨',
#  '크기',
#  '파우치',
#  '최근',
#  '대만',
#  '태국',
#  '최고',
#  '효율',
#  '높았',
#  '소지품',
#  '고속충전',
#  '짱',
#  '충전',
#  '빠르고',
#  '접촉',
#  '불량',
#  '있다고',
#  '블로그',
#  '돼지코',
#  '동시',
#  '충전',
#  '충전',
#  '구성품',
#  '어댑터',
#  '본품',
#  '설명서',
#  '파우치',
#  '어댑터',
#  '비교',
#  '가격대',
#  '콘센트',
#  '현상',
#  'C타입',
#  '적은',
#  '디자인',
#  '여러',
#  '케이블',
#  '일반',
#  '일본',
#  '배터리',
#  '충전',
#  '볼트',
#  '고속충전',
#  '테두리',
#  '노란색',
#  '교환',
#  '멀티탭',
#  '대용',
#  '사이즈',
#  '랩',
#  '고장',
#  '견고',
#  '타입',
#  '충전',
#  '빠르고',
#  '무게',
#  '크기',
#  '케이스',
#  '고급',
#  '베개',
#  '센스',
#  '많은데',
#  '해결',
#  '미니',
#  '고데기',
#  '케이스',
#  '디자인',
#  '작은',
#  '파우치',
#  '견고',
#  '심플',
#  '충전',
#  '콘센트',
#  '파우치',
#  '포트',
#  '케이스',
#  '좋고요',
#  '콘센트',
#  '충전',
#  '동시',
#  '충전',
#  '최대',
#  '충전',
#  '시도',
#  '미국',
#  '디자인',
#  '마트',
#  '크기',
#  '작았',
#  '충전기',
#  '전기포트',
#  '방문',
#  '전기포트',
#  '어댑터',
#  '어댑터',
#  '불안',
#  '파우치',
#  '어댑터',
#  '충전',
#  '괜찮았',
#  '멀티탭',
#  '220V',
#  '코드',
#  '충전',
#  '포트',
#  '같아서요',
#  '작아서',
#  '휴대',
#  '유럽',
#  '파우치',
#  '마감',
#  'C타입',
#  '포트',
#  'C타입',
#  '포트',
#  '충전',
#  '35W',
#  '최대',
#  '유럽',
#  '충전',
#  '많은데',
#  '핸드폰',
#  '수신기',
#  '충전',
#  '편하네요',
#  '디자인',
#  'C타입',
#  '편지',
#  '사은품',
#  '호주',
#  '핸드폰',
#  '충전',
#  'USB포트',
#  'C타입',
#  'A타입',
#  '케이스',
#  '정리',
#  '핸드폰',
#  '워치',
#  '충전',
#  '간편',
#  '충전',
#  '속도',
#  '감동',
#  '케이스',
#  '빠르게',
#  '재송',
#  '케이스',
#  '견고',
#  '충전',
#  '이것저것',
#  '완성도',
#  '충전',
#  '해외여행',
#  '전기',
#  '코드',
#  '타입',
#  '핸드폰',
#  '충전',
#  '충전',
#  '빠르고',
#  '멀티탭',
#  '충전기',
#  '불편',
#  '핸드폰',
#  '보조배터리',
#  '동시충전',
#  '손',
#  '편지',
#  '박싱',
#  '기분',
#  '케이스',
#  '디자인',
#  '파우치',
#  '코드',
#  '체결',
#  '충전',
#  '디자인',
#  '충전',
#  '포트',
#  '충전',
#  '파우치',
#  '크기',
#  '포스트잇',
#  '의견',
#  '무게',
#  '알차서',
#  'C타입',
#  '최대',
#  '있으면',
#  '해외',
#  '충전기',
#  '퓨즈',
#  '파우치',
#  '밤새',
#  '충전',
#  '유럽',
#  '충전',
#  '선',
#  '충전',
#  '어댑터',
#  '홍콩',
#  '계획',
#  '콘센트',
#  '다르다고',
#  '지',
#  '멀티어댑터',
#  '필리핀',
#  '충전',
#  '보조배터리',
#  '충전',
#  '부족',
#  '국가',
#  '해외여행',
#  '배터리',
#  '없을',
#  '정성',
#  '메모',
#  '구성품',
#  '콘센트',
#  '작동',
#  '동시',
#  '충전',
#  '속도',
#  '빠르고',
#  '손',
#  '편지',
#  '감동',
#  '추가',
#  '구성품',
#  '파우치',
#  '선',
#  '정리',
#  '꽈배기',
#  '무게',
#  '콤팩트',
#  '사이즈',
#  '미국',
#  '유럽',
#  '국가',
#  '콘센트',
#  '지팅스',
#  '문자',
#  '물품',
#  '정리',
#  ...]

# %%
#remove_stopwords2 = sum(product['changed_text'],[])
#remove_stopwords2

# %%
from collections import Counter
remain_freq = Counter(remove_stopwords2).most_common()
df_remain_freq = pd.DataFrame(remain_freq, columns=['형태소', '빈도'])
df_remain_freq
# Out:
#        형태소    빈도
# 0       충전  1227
# 1      케이스   926
# 2      디자인   545
# 3      어댑터   381
# 4      콘센트   331
# ...    ...   ...
# 1369   그리스     1
# 1370    두께     1
# 1371  문제없어     1
# 1372    도어     1
# 1373  귀엽군요     1
#
# [1374 rows x 2 columns]

# %%
from pprint import pprint
print(df_remain_freq)
# Out:
#        형태소    빈도
# 0       충전  1227
# 1      케이스   926
# 2      디자인   545
# 3      어댑터   381
# 4      콘센트   331
# ...    ...   ...
# 1369   그리스     1
# 1370    두께     1
# 1371  문제없어     1
# 1372    도어     1
# 1373  귀엽군요     1
#
# [1374 rows x 2 columns]

# %%
df_remain_freq.to_csv('C:/Users/songy/Desktop/Data/product_keyword.csv', encoding = 'utf-8-sig')

# %%
df_remain_freq
# Out:
#        형태소    빈도
# 0       충전  1227
# 1      케이스   926
# 2      디자인   545
# 3      어댑터   381
# 4      콘센트   331
# ...    ...   ...
# 1369   그리스     1
# 1370    두께     1
# 1371  문제없어     1
# 1372    도어     1
# 1373  귀엽군요     1
#
# [1374 rows x 2 columns]

# %%
#df_remain_freq['빈도'].value_counts().to_frame().reset_index().sort_values(by='빈도', ascending=False)[:30]

# %%
plt.rc("font", family = "Malgun Gothic")
sns.set(font="Malgun Gothic", 
rc={"axes.unicode_minus":False}, style='white')

# %%
import seaborn as sns
plt.rc('font', size = 20)
ax = plt.subplots(figsize=(25,10))
plt.xticks(rotation=90)
sns.barplot(data=df_remain_freq[:70], x='형태소', y='빈도')
# Out:
# <Axes: xlabel='형태소', ylabel='빈도'>

# %% [markdown]
# - elbow 기반 : 어댑터까지

# %%
#df_remain_freq['퍼센트'] = round((df_remain_freq['빈도']/df_remain_freq['빈도'].sum())*100,2)
#df_remain_freq['cumsum'] = df_remain_freq['퍼센트'].cumsum()
#df_remain_freq

# %%
df_remain_freq
# Out:
#        형태소    빈도
# 0       충전  1227
# 1      케이스   926
# 2      디자인   545
# 3      어댑터   381
# 4      콘센트   331
# ...    ...   ...
# 1369   그리스     1
# 1370    두께     1
# 1371  문제없어     1
# 1372    도어     1
# 1373  귀엽군요     1
#
# [1374 rows x 2 columns]

# %%
for i in range(5):
    print(df_remain_freq['빈도'][i])
# Out:
# 1227
# 926
# 545
# 381
# 331

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
def get_pos_tag(word):
    "명사만 추출하기 위해"
    if isinstance(word, str):  # 입력이 문자열인지 확인
        pos_tags = m.pos(word)
        return pos_tags[0][1] if pos_tags else 'Unknown'
    else:
        return 'Unknown'

df_remain_freq['pos'] = df_remain_freq['형태소'].apply(get_pos_tag)
df_remain_freq.head(3)
# Out:
#    형태소    빈도  pos
# 0   충전  1227  NNG
# 1  케이스   926  NNG
# 2  디자인   545  NNG

# %%
df_remain_freq['pos'].value_counts().to_frame().reset_index()
# Out:
#       pos  count
# 0     NNG    807
# 1      VA    404
# 2     NNP    151
# 3     MAG      3
# 4      MM      3
# 5      VV      2
# 6  VV+ETM      1
# 7      XR      1
# 8      NP      1
# 9   VV+EF      1

# %%
# Test
#df_remain_freq[(df_remain_freq['pos']=='NNG') | (df_remain_freq['pos']=='NNP')].reset_index()[['형태소','빈도','pos']]

# %% [markdown]
# ## 방법론2 > H0: 비슷한 속성이 많을수록 중요한 속성이다.

# %% [markdown]
# - 방법론1과 다르게 자기 자신을 포함해 진행 (제외 부분 제거 필요)

# %%
# 명사만 추출하는 부분
df_remain_freq = df_remain_freq[(df_remain_freq['pos']=='NNG') | (df_remain_freq['pos']=='NNP')].reset_index()[['형태소','빈도','pos']]

# 변화량 및 변화량/총변화량 도출 부분
df_remain_freq['변화량'] = 0

for i in range(len(df_remain_freq)):
    if i == 0:
        df_remain_freq['변화량'][i] = 0
    else:
        # ascending 되어 있어 증가하는 것은 없기 때문에 제곱근은 배제 
        df_remain_freq['변화량'][i] = df_remain_freq['빈도'][i-1] - df_remain_freq['빈도'][i]
    
    
    changed_sum = df_remain_freq['변화량'].sum()

# 퍼센트 계산으로 100을 곱하는 것 > 의미 있는 결과를 위해 round를 먼저 취해주고 100 곱함 
df_remain_freq['변화량/총변화량'] =round((df_remain_freq['변화량']/changed_sum),2)*100

# 두번째 minima 찾는 부분 (변화량/총변화량 = 0인 두번째 부분)
# 0행이 0으로 시작함에 따라 2번째 변곡점인 2로 진행
second_zero_index = df_remain_freq[df_remain_freq['변화량/총변화량']==0].index[2]
x_labels = df_remain_freq['형태소'][:second_zero_index+10]
print(f'minima is : {x_labels[second_zero_index]}, {second_zero_index}번째')

# 그래프 부분
fig1 = plt.figure(figsize=(25,8))
fig1.gca().spines['right'].set_visible(False)   # 오른쪽 테두리 제거
fig1.gca().spines['top'].set_visible(False)     # 위 테두리 제거
area1 = fig1.add_subplot(1,1,1)
ax1 = sns.lineplot(df_remain_freq['변화량/총변화량'][:second_zero_index+10], linewidth=3, ax=area1)   # ax=area1
plt.axvline(x=df_remain_freq[df_remain_freq['변화량/총변화량']==0.00].index[1], color='gray', linestyle='--', linewidth=1.5, alpha=0.7)
plt.axvline(x=second_zero_index, color='r', linestyle='--', linewidth=1.5, alpha=0.7)
plt.xticks(ticks=range(len(x_labels)), labels=x_labels, rotation=90)
ax1.set_title('Finding Minima', fontsize=24)    #position=(0.5, 5)
# Out:
# minima is : 멀티어댑터, 11번째
# Text(0.5, 1.0, 'Finding Minima')

# %%
df_remain_freq
# Out:
#       형태소    빈도  pos  변화량  변화량/총변화량
# 0      충전  1227  NNG    0       0.0
# 1     케이스   926  NNG  301      25.0
# 2     디자인   545  NNG  381      31.0
# 3     어댑터   381  NNG  164      13.0
# 4     콘센트   331  NNG   50       4.0
# ..    ...   ...  ...  ...       ...
# 953     링     1  NNG    0       0.0
# 954   그리스     1  NNP    0       0.0
# 955    두께     1  NNG    0       0.0
# 956  문제없어     1  NNG    0       0.0
# 957    도어     1  NNG    0       0.0
#
# [958 rows x 5 columns]

# %%
#df_remain_freq[df_remain_freq['변화량/총변화량']==0]

# %% [markdown]
# ### 키워드별 속성 추출 알고리즘 구축

# %%
product.head(3)
# Out:
#   add_rule_based_split_review Tokenized_sentence Tokenized_sentence_list  \
# 3    금액 차이 얼마 안 나는데 기능은 더 좋아요               [기능]                      기능
# 4  콤팩트한 디자인과 실용성에 높은 점수 주었습니다     [콤팩트, 디자인, 실용]            콤팩트, 디자인, 실용
# 8           전면 스크래치가 많아서 아쉽네요         [전면, 스크래치]                전면, 스크래치
#
#   Tokenized_morphs
# 3               기능
# 4       콤팩트 디자인 실용
# 8          전면 스크래치

# %%
# 마지막에 해당 코드 코드화하기 (누적 퍼센트, TopN개 파라미터 포함)
exclude_list = []   # 여기엔 앞에 등장한 키워드들 10개 포함해 누적 저장됨
list_all = []
subset_list = []

for i in range(second_zero_index):
    # A : 형태소 키워드 index 5번 (어댑터)까지 확인 
    # i번째 형태소가 명사에 해당할 경우만 

    # 동적 변수명 생성해 데이터프레임 구성 
    morphs_target = df_remain_freq['형태소'][i]
    var_name = f'df_{morphs_target}'
    globals()[var_name] = product[product['add_rule_based_split_review'].str.contains(f'{df_remain_freq["형태소"][i]}')]


    # 키워드별 형태소 키워드 분석
    var_name2 = f'keyword_freq_{morphs_target}'
    globals()[var_name2] = pd.DataFrame(Counter(sum(globals()[var_name]['Tokenized_sentence'],[])).most_common(), columns=['형태소', '빈도'])
    ### 앞단 키워드 상위 10개 제외 리스트 저장 (회의 반영 : 중복과정 제거)
    ### 제외한 키워드들만 형태소 feature에 반영될 수 있게, 퍼센트 뽑기 전에 키워드 루프

    globals()[var_name2] = globals()[var_name2][~globals()[var_name2]['형태소'].isin(exclude_list)]
    #exclude_list.extend(list(globals()[var_name2]['형태소'][:10]))
    exclude_list.extend(list(globals()[var_name2]['형태소'][:0]))

    #print(exclude_list)

    # 자기 자신은 제외하는 부분 (순서 변경)
    #globals()[var_name2] = globals()[var_name2][globals()[var_name2]['형태소']!=morphs_target]
        
    # 퍼센트, 누적 퍼센트 feature 추가 
    globals()[var_name2]['퍼센트'] = round((globals()[var_name2]['빈도']/globals()[var_name2]['빈도'].sum())*100,2)
    globals()[var_name2]['누적_퍼센트'] = globals()[var_name2]['퍼센트'].cumsum()

    # 누적 퍼센트에 따른 키워드 데이터프레임 추출
    c_value = 50                                        # 누적_퍼센트 파라미터 설정 / 누적 파라미터 이하인 데이터만 추출됨 
    var_name3 = f'cumsum_keyword_{morphs_target}'
    #globals()[var_name3] = globals()[var_name2][(globals()[var_name2]['누적_퍼센트']<c_value)]  # 자기 자신 제외 부분 앞단 (globals()[var_name2]['형태소']!=morphs_target) >> 방법론2에서는 제거
    globals()[var_name3] = globals()[var_name2][(globals()[var_name2]['누적_퍼센트']<c_value)]  # 자기 자신 제외 부분 앞단 (globals()[var_name2]['형태소']!=morphs_target) >> 방법론2에서는 제거

    # subset set으로 저장 (추후 겹치는 퍼센트에 따라 적합성 판단)
    var_name4 = f'subset_{morphs_target}'
    globals()[var_name4] = set(globals()[var_name3]['형태소'])

    # 전체 리스트 확인 & 전체 리스트가 전체 형태소중에 얼만큼의 비율을 차지하는지 
    list_all.extend(list(globals()[var_name3]['형태소']))
    list_set = set(list_all)
    #print(f'{i}번째 리스트 : \n{list_all}\n')

    #### subset끼리 계산 (i개씩 비교)
    subset_list.append(var_name4)       # 루프당 존재하는 subset 집합
    print(subset_list)
    subset_number = len(subset_list)    # subset 개수

#print(subset_list)
print('')

# print(list_all) # 전체 형태소 뽑고 싶을 때 
print(f'세부 고유 키워드가 전체 형태소 결과 포함 비율 : {round((len(list_set) / len(df_remain_freq.형태소))*100,2)} %')

sub_result_sum = df_remain_freq[df_remain_freq['형태소'].isin(list_all)]['빈도'].sum()
all_result_sum = df_remain_freq['빈도'].sum()
print(f'세부 키워드가 전체 키워드 내 차지하는 비율    : {round((sub_result_sum/all_result_sum)*100,2)} %')

print(f'\n현재 존재하는 subset의 개수는 {subset_number}')
# Out:
# ['subset_충전']
# ['subset_충전', 'subset_케이스']
# ['subset_충전', 'subset_케이스', 'subset_디자인']
# ['subset_충전', 'subset_케이스', 'subset_디자인', 'subset_어댑터']
# ['subset_충전', 'subset_케이스', 'subset_디자인', 'subset_어댑터', 'subset_콘센트']
# ['subset_충전', 'subset_케이스', 'subset_디자인', 'subset_어댑터', 'subset_콘센트', 'subset_파우치']
# ['subset_충전', 'subset_케이스', 'subset_디자인', 'subset_어댑터', 'subset_콘센트', 'subset_파우치', 'subset_포트']
# ['subset_충전', 'subset_케이스', 'subset_디자인', 'subset_어댑터', 'subset_콘센트', 'subset_파우치', 'subset_포트', 'subset_C타입']
# ['subset_충전', 'subset_케이스', 'subset_디자인', 'subset_어댑터', 'subset_콘센트', 'subset_파우치', 'subset_포트', 'subset_C타입', 'subset_고속충전']
# ['subset_충전', 'subset_케이스', 'subset_디자인', 'subset_어댑터', 'subset_콘센트', 'subset_파우치', 'subset_포트', 'subset_C타입', 'subset_고속충전', 'subset_멀티탭']
# ['subset_충전', 'subset_케이스', 'subset_디자인', 'subset_어댑터', 'subset_콘센트', 'subset_파우치', 'subset_포트', 'subset_C타입', 'subset_고속충전', 'subset_멀티탭', 'subset_충전기']
#
# 세부 고유 키워드가 전체 형태소 결과 포함 비율 : 3.34 %
# 세부 키워드가 전체 키워드 내 차지하는 비율    : 49.72 %
#
# 현재 존재하는 subset의 개수는 11

# %%
subset_충전
# Out:
# {'C타입', '고속충전', '기기', '동시', '일본', '충전', '충전기', '포트', '핸드폰'}

# %%
import itertools

def get_set_by_name(name):
    return globals()[name]

def find_intersections(sets_names):
    sets = [get_set_by_name(name) for name in sets_names]
    n = len(sets)
    results = []

    # 모든 가능한 부분집합에 대해 겹치는 요소 찾기
    for r in range(n + 1):
        for combo in itertools.combinations(range(n), r):
            if combo:  # 공집합은 생략
                intersection = sets[combo[0]]
                for i in combo[1:]:
                    intersection = intersection.intersection(sets[i])
                results.append({"Set Combination": tuple(sets_names[i] for i in combo), "Intersection": intersection})
            else:
                results.append({"Set Combination": combo, "Intersection": set()})
    return results

def intersection_to_df(sets_names):
    intersections = find_intersections(sets_names)
    # 데이터프레임으로 변환
    df = pd.DataFrame(intersections)
    # 결과 출력
    return df

def count_subset_num(sets):
    return len(sets)

# 필터링 되는지 확인
#df_sample[df_sample['Intersection'].apply(lambda x: len(x) < 1)]['Intersection'].value_counts()

# 예시 실행
df_sample = intersection_to_df(subset_list)
df_sample['set_number'] = df_sample['Set Combination'].apply(count_subset_num)
df_sample = df_sample[df_sample['Intersection'].apply(lambda x: len(x) > 1)]
df_sample
# Out:
#                                         Set Combination  \
# 1                                          (subset_충전,)
# 3                                         (subset_디자인,)
# 4                                         (subset_어댑터,)
# 5                                         (subset_콘센트,)
# 7                                          (subset_포트,)
# ...                                                 ...
# 728   (subset_충전, subset_어댑터, subset_포트, subset_C타입,...
# 729   (subset_충전, subset_어댑터, subset_포트, subset_C타입,...
# 748   (subset_충전, subset_콘센트, subset_포트, subset_C타입,...
# 979   (subset_어댑터, subset_콘센트, subset_포트, subset_C타입...
# 1231  (subset_충전, subset_어댑터, subset_콘센트, subset_포트,...
#
#                                            Intersection  set_number
# 1             {고속충전, 동시, C타입, 기기, 일본, 충전기, 포트, 충전, 핸드폰}           1
# 3                                            {디자인, 케이스}           1
# 4     {C타입, 해외여행, 플러그, 일본, 충전기, 포트, 어댑터, 충전, 콘센트, 케이...           1
# 5     {연결, 플러그, 일본, 고정, 국가, 작동, 유럽, 무게, 포트, 불편, 충전기,...           1
# 7                                  {USB포트, 충전, C타입, 포트}           1
# ...                                                 ...         ...
# 728                                            {충전, 포트}           5
# 729                                           {충전, C타입}           5
# 748                                            {충전, 포트}           5
# 979                                            {충전, 포트}           5
# 1231                                           {충전, 포트}           6
#
# [110 rows x 3 columns]

# %%
df_sample.to_csv('C:/Users/songy/Desktop/Data/combination_result_240806.csv', encoding='utf-8-sig')

# %%
subset_list
# Out:
# ['subset_충전',
#  'subset_케이스',
#  'subset_디자인',
#  'subset_어댑터',
#  'subset_콘센트',
#  'subset_파우치',
#  'subset_포트',
#  'subset_C타입',
#  'subset_고속충전',
#  'subset_멀티탭',
#  'subset_충전기']

# %%
df_sample['Intersection'] = df_sample['Intersection'].apply(lambda x: list(x))

# %%
def add_quotes(value):
    return f'"{value}"'

# %%
#df_sample['Intersection'] = df_sample['Intersection'].apply(lambda x: f'{x}')
#df_sample.head()

# %%
def percent_subset(list_name):
    x = df_remain_freq[df_remain_freq['형태소'].isin(list_name)]
    x2 = (x['빈도'].sum() / df_remain_freq['빈도'].sum())*100
    x2 = round(x2, 2)
    return x2

# %%
#df_sample.to_csv('C:/Users/songy/Desktop/Data/result_way2.csv', encoding='utf-8-sig')

# %%
df_sample['word_percent'] = df_sample['Intersection'].apply(percent_subset)
df_sample.head()
# Out:
#   Set Combination                                       Intersection  \
# 1    (subset_충전,)          [고속충전, 동시, C타입, 기기, 일본, 충전기, 포트, 충전, 핸드폰]
# 3   (subset_디자인,)                                         [디자인, 케이스]
# 4   (subset_어댑터,)  [C타입, 해외여행, 플러그, 일본, 충전기, 포트, 어댑터, 충전, 콘센트, 케이...
# 5   (subset_콘센트,)  [연결, 플러그, 일본, 고정, 국가, 작동, 유럽, 무게, 포트, 불편, 충전기,...
# 7    (subset_포트,)                               [USB포트, 충전, C타입, 포트]
#
#    set_number  word_percent
# 1           1         19.52
# 3           1         10.53
# 4           1         31.12
# 5           1         25.33
# 7           1         14.17

# %%
df_sample[df_sample['set_number'] == 1]
# Out:
#    Set Combination                                       Intersection  \
# 1     (subset_충전,)          [고속충전, 동시, C타입, 기기, 일본, 충전기, 포트, 충전, 핸드폰]
# 3    (subset_디자인,)                                         [디자인, 케이스]
# 4    (subset_어댑터,)  [C타입, 해외여행, 플러그, 일본, 충전기, 포트, 어댑터, 충전, 콘센트, 케이...
# 5    (subset_콘센트,)  [연결, 플러그, 일본, 고정, 국가, 작동, 유럽, 무게, 포트, 불편, 충전기,...
# 7     (subset_포트,)                               [USB포트, 충전, C타입, 포트]
# 8    (subset_C타입,)                                  [충전, 타입, C타입, 포트]
# 9   (subset_고속충전,)                                    [고속충전, C타입, 포트]
# 10   (subset_멀티탭,)          [연결, 해외여행, 충전기, 포트, 어댑터, 충전, 멀티탭, 해외, 코드]
# 11   (subset_충전기,)               [고속충전, C타입, 충전기, 짐, 선, 어댑터, 충전, 멀티탭]
#
#     set_number  word_percent
# 1            1         19.52
# 3            1         10.53
# 4            1         31.12
# 5            1         25.33
# 7            1         14.17
# 8            1         13.73
# 9            1          6.07
# 10           1         19.58
# 11           1         18.71

# %%
set_count_df = df_sample['set_number'].value_counts().to_frame().reset_index().sort_values(by='set_number', ascending=True)
set_count_df
# Out:
#    set_number  count
# 3           1      9
# 2           2     26
# 0           3     38
# 1           4     27
# 4           5      9
# 5           6      1

# %%
sns.barplot(set_count_df, x='set_number', y='count')
# Out:
# <Axes: xlabel='set_number', ylabel='count'>

# %%
sns.scatterplot(data=df_sample, x='set_number', y='word_percent', hue='set_number')
# Out:
# <Axes: xlabel='set_number', ylabel='word_percent'>

# %%
# 추후 합계까지 함수화 가능 할 듯 
print(f'1번 겹치는 경우 : 전체 경우의 {round(((df_sample[df_sample.set_number == 1].word_percent.sum())/(len(df_sample)*100))*100,2)} %')
print(f'2번 겹치는 경우 : 전체 경우의 {round(((df_sample[df_sample.set_number == 2].word_percent.sum())/(len(df_sample)*100))*100,2)} %')
print(f'3번 겹치는 경우 : 전체 경우의 {round(((df_sample[df_sample.set_number == 3].word_percent.sum())/(len(df_sample)*100))*100,2)} %')
print(f'4번 겹치는 경우 : 전체 경우의 {round(((df_sample[df_sample.set_number == 4].word_percent.sum())/(len(df_sample)*100))*100,2)} %')
print(f'5번 겹치는 경우 : 전체 경우의 {round(((df_sample[df_sample.set_number == 5].word_percent.sum())/(len(df_sample)*100))*100,2)} %')
print(f'6번 겹치는 경우 : 전체 경우의 {round(((df_sample[df_sample.set_number == 6].word_percent.sum())/(len(df_sample)*100))*100,2)} %')
# Out:
# 1번 겹치는 경우 : 전체 경우의 1.44 %
# 2번 겹치는 경우 : 전체 경우의 2.78 %
# 3번 겹치는 경우 : 전체 경우의 3.57 %
# 4번 겹치는 경우 : 전체 경우의 2.47 %
# 5번 겹치는 경우 : 전체 경우의 0.83 %
# 6번 겹치는 경우 : 전체 경우의 0.1 %

# %%
df_sample[(df_sample['set_number']==6)]
# Out:
#                                         Set Combination Intersection  \
# 1231  (subset_충전, subset_어댑터, subset_콘센트, subset_포트,...     [충전, 포트]
#
#       set_number  word_percent
# 1231           6          11.0

# %%
def check_not_in_intersection(row):
    "subset_ 이 없는 경우 False로 반환"
    set_combination = row['Set Combination']
    intersection_list = row['Intersection']

    not_in_list = []
    for w in set_combination:
        if w.startswith('subset_'):
            subset_word = w[len('subset_'):]
            if subset_word not in intersection_list:
                not_in_list.append(subset_word)

    return not_in_list

df_sample['not_in_intersection'] = df_sample.apply(check_not_in_intersection, axis=1)
df_sample.head(3)
# Out:
#   Set Combination                                       Intersection  \
# 1    (subset_충전,)          [고속충전, 동시, C타입, 기기, 일본, 충전기, 포트, 충전, 핸드폰]
# 3   (subset_디자인,)                                         [디자인, 케이스]
# 4   (subset_어댑터,)  [C타입, 해외여행, 플러그, 일본, 충전기, 포트, 어댑터, 충전, 콘센트, 케이...
#
#    set_number  word_percent not_in_intersection
# 1           1         19.52                  []
# 3           1         10.53                  []
# 4           1         31.12                  []

# %%
df_sample['concated_word_list'] = df_sample['Intersection'] + df_sample['not_in_intersection']
df_sample.head()
# Out:
#   Set Combination                                       Intersection  \
# 1    (subset_충전,)          [고속충전, 동시, C타입, 기기, 일본, 충전기, 포트, 충전, 핸드폰]
# 3   (subset_디자인,)                                         [디자인, 케이스]
# 4   (subset_어댑터,)  [C타입, 해외여행, 플러그, 일본, 충전기, 포트, 어댑터, 충전, 콘센트, 케이...
# 5   (subset_콘센트,)  [연결, 플러그, 일본, 고정, 국가, 작동, 유럽, 무게, 포트, 불편, 충전기,...
# 7    (subset_포트,)                               [USB포트, 충전, C타입, 포트]
#
#    set_number  word_percent not_in_intersection  \
# 1           1         19.52                  []
# 3           1         10.53                  []
# 4           1         31.12                  []
# 5           1         25.33                  []
# 7           1         14.17                  []
#
#                                   concated_word_list
# 1          [고속충전, 동시, C타입, 기기, 일본, 충전기, 포트, 충전, 핸드폰]
# 3                                         [디자인, 케이스]
# 4  [C타입, 해외여행, 플러그, 일본, 충전기, 포트, 어댑터, 충전, 콘센트, 케이...
# 5  [연결, 플러그, 일본, 고정, 국가, 작동, 유럽, 무게, 포트, 불편, 충전기,...
# 7                               [USB포트, 충전, C타입, 포트]

# %%
df_sample['word_percent_concated'] = df_sample['concated_word_list'].apply(percent_subset)
df_sample.head()
# Out:
#   Set Combination                                       Intersection  \
# 1    (subset_충전,)          [고속충전, 동시, C타입, 기기, 일본, 충전기, 포트, 충전, 핸드폰]
# 3   (subset_디자인,)                                         [디자인, 케이스]
# 4   (subset_어댑터,)  [C타입, 해외여행, 플러그, 일본, 충전기, 포트, 어댑터, 충전, 콘센트, 케이...
# 5   (subset_콘센트,)  [연결, 플러그, 일본, 고정, 국가, 작동, 유럽, 무게, 포트, 불편, 충전기,...
# 7    (subset_포트,)                               [USB포트, 충전, C타입, 포트]
#
#    set_number  word_percent not_in_intersection  \
# 1           1         19.52                  []
# 3           1         10.53                  []
# 4           1         31.12                  []
# 5           1         25.33                  []
# 7           1         14.17                  []
#
#                                   concated_word_list  word_percent_concated
# 1          [고속충전, 동시, C타입, 기기, 일본, 충전기, 포트, 충전, 핸드폰]                  19.52
# 3                                         [디자인, 케이스]                  10.53
# 4  [C타입, 해외여행, 플러그, 일본, 충전기, 포트, 어댑터, 충전, 콘센트, 케이...                  31.12
# 5  [연결, 플러그, 일본, 고정, 국가, 작동, 유럽, 무게, 포트, 불편, 충전기,...                  25.33
# 7                               [USB포트, 충전, C타입, 포트]                  14.17

# %%
sns.scatterplot(data=df_sample, x='set_number', y='word_percent_concated', hue='set_number')
# Out:
# <Axes: xlabel='set_number', ylabel='word_percent_concated'>

# %%
df_sample.head(3)
# Out:
#   Set Combination                                       Intersection  \
# 1    (subset_충전,)          [고속충전, 동시, C타입, 기기, 일본, 충전기, 포트, 충전, 핸드폰]
# 3   (subset_디자인,)                                         [디자인, 케이스]
# 4   (subset_어댑터,)  [C타입, 해외여행, 플러그, 일본, 충전기, 포트, 어댑터, 충전, 콘센트, 케이...
#
#    set_number  word_percent not_in_intersection  \
# 1           1         19.52                  []
# 3           1         10.53                  []
# 4           1         31.12                  []
#
#                                   concated_word_list  word_percent_concated
# 1          [고속충전, 동시, C타입, 기기, 일본, 충전기, 포트, 충전, 핸드폰]                  19.52
# 3                                         [디자인, 케이스]                  10.53
# 4  [C타입, 해외여행, 플러그, 일본, 충전기, 포트, 어댑터, 충전, 콘센트, 케이...                  31.12

# %%
df_remain_freq['빈도'].sum()
# Out:
# 13970

# %%
df_remain_freq
# Out:
#       형태소    빈도  pos  변화량  변화량/총변화량
# 0      충전  1227  NNG    0       0.0
# 1     케이스   926  NNG  301      25.0
# 2     디자인   545  NNG  381      31.0
# 3     어댑터   381  NNG  164      13.0
# 4     콘센트   331  NNG   50       4.0
# ..    ...   ...  ...  ...       ...
# 953     링     1  NNG    0       0.0
# 954   그리스     1  NNP    0       0.0
# 955    두께     1  NNG    0       0.0
# 956  문제없어     1  NNG    0       0.0
# 957    도어     1  NNG    0       0.0
#
# [958 rows x 5 columns]

# %%
len(subset_충전)
# Out:
# 9

# %%
def word_percent_fuction(df_remain_freq, subset):
    """
    subset 안 요소 있는 행 추출하고, 빈도의 합 / 전체 빈도의 합
    """
    df_remain_freq['형태소'].

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
import matplotlib.pyplot as plt
import ast

# Set Combination에 들어있는 고유 집합들을 unqique_subsets에 저장
unique_subsets = set()
for combination in df_sample['Set Combination']:
    unique_subsets.update(eval(combination) if isinstance(combination, str) else combination)

unique_subsets = list(unique_subsets)
#print(unique_subsets)

# 집합(행)별로 set combination 포함 여부에 따라 1 또는 0으로 저장
binary_matrix = []
for subset in unique_subsets:
    row = []
    word_percent = []
    for combination in df_sample['Set Combination']:
        combination = eval(combination) if isinstance(combination, str) else combination  
        #row.append(1 if subset in combination else 0)
        # percent로 삽입하는 부분
        word_percent.append("subset이 차지하는 비율" if subset in combination else 0)   # 1 대신에 퍼센트로 삽입할 수 있다면? 대표 속성의 subset가 차지하는 비율로?
    #binary_matrix.append(row)
    binary_matrix.append(word_percent)

# combination 포함 결과 numpy 저장
binary_matrix = np.array(binary_matrix)

# 계층적 군집화에 combination 포함 결과 반영 수행
Z = linkage(binary_matrix, method='ward')

# 시각화 
plt.figure(figsize=(25, 7))
dendro = dendrogram(Z, labels=unique_subsets, leaf_rotation=90) 
plt.title('Hierarchical Clustering Dendrogram for Subsets')
plt.xlabel('Subsets')
plt.ylabel('Distance')
plt.show()

# %%
unique_subsets
# Out:
# ['subset_콘센트',
#  'subset_고속충전',
#  'subset_멀티탭',
#  'subset_어댑터',
#  'subset_C타입',
#  'subset_충전',
#  'subset_디자인',
#  'subset_충전기',
#  'subset_포트']

# %%
# Out:
#                              add_rule_based_split_review  \
# 83                                      멀티콘센트 요긴하게 잘 쓸게요
# 114          유럽 가서 쓰려고 샀는데 본체가 무거워서 콘센트에 꽂아도 자꾸 기울어 빠집니다
# 185    콘센트에 딱 맞게 끼워지는 느낌은 아니긴 했는데 그래도 그럭저럭 사용엔 지장 없긴 ...
# 210                          USB가 잘 꽂히고 콘센트도 락언락이 정상 동작함
# 211           국내 용이 아니라 기능 확인은 안되지만 국가별 콘센트는 잘 나오고 들어가네요
# ...                                                  ...
# 18586                      이거 하나 장만해 놓으니 해외여행 콘센트 걱정 없네요
# 18589       한국에서 먼저 테스트해 봤는데 기본 콘센트 부분과 USB랑 C 부분 다 잘 돼요
# 18602                콘센트 안 빠져서 내 핸드폰 충전기도 망가지고 난리도 아니었어요
# 18618                    색감이 너무 이쁘고 콘센트를 밀어봤는데 부드럽게 나가네요
# 18634  다이소에도 돼지코가 있지만 앞으로의 해외여행을 생각한다면 다양한 콘센트 호환이 가능...
#
#                 Tokenized_sentence    Tokenized_sentence_list  \
# 83                           [콘센트]                        콘센트
# 114                  [유럽, 본체, 콘센트]                유럽, 본체, 콘센트
# 185                  [콘센트, 지장, 없긴]                콘센트, 지장, 없긴
# 210                  [콘센트, 정상, 동작]                콘센트, 정상, 동작
# 211              [국내, 기능, 국가, 콘센트]            국내, 기능, 국가, 콘센트
# ...                            ...                        ...
# 18586                  [해외여행, 콘센트]                  해외여행, 콘센트
# 18589                    [기본, 콘센트]                    기본, 콘센트
# 18602              [콘센트, 핸드폰, 충전기]              콘센트, 핸드폰, 충전기
# 18618         [색감, 이쁘고, 콘센트, 부드럽게]         색감, 이쁘고, 콘센트, 부드럽게
# 18634  [돼지코, 해외여행, 콘센트, 호환, 멀티어댑터]  돼지코, 해외여행, 콘센트, 호환, 멀티어댑터
#
#             Tokenized_morphs
# 83                       콘센트
# 114                유럽 본체 콘센트
# 185                콘센트 지장 없긴
# 210                콘센트 정상 동작
# 211             국내 기능 국가 콘센트
# ...                      ...
# 18586               해외여행 콘센트
# 18589                 기본 콘센트
# 18602            콘센트 핸드폰 충전기
# 18618        색감 이쁘고 콘센트 부드럽게
# 18634  돼지코 해외여행 콘센트 호환 멀티어댑터
#
# [314 rows x 4 columns]

# %%
subset_콘센트
# Out:
# {'고정',
#  '국가',
#  '멀티어댑터',
#  '무게',
#  '불편',
#  '어댑터',
#  '연결',
#  '유럽',
#  '일본',
#  '작동',
#  '충전',
#  '충전기',
#  '콘센트',
#  '포트',
#  '플러그',
#  '해외',
#  '호주'}

# %%
#### 노드 색상별 추출하는 방법 
from scipy.cluster.hierarchy import fcluster

# 덴드로그램의 color_list 정보를 사용하여 클러스터링
color_list = dendro['color_list']
icoord = np.array(dendro['icoord'])
dleaf_colors = np.array([dendro['leaves_color_list'][i] for i in range(len(unique_subsets))])
dleaf_labels = np.array(dendro['ivl'])

# 고유 색상 추출
unique_colors = np.unique(dleaf_colors)

# 클러스터별 집합 도출
cluster_dict = {}
for color in unique_colors:
    cluster_dict[color] = dleaf_labels[dleaf_colors == color].tolist()

def subword_total(st):
    "클러스터별 속성을 도출하기 위한 함수"
    set_all = set()
    for i in st:
        set_all.update(globals()[i])
    return set_all

#result_cluster = pd.DataFrame([(k,v) for k, vs in cluster_dict.items() for v in vs], columns=['cluster','set_list'])

# 클러스터별 집합 출력
for color, subsets in cluster_dict.items():
    print(f"Cluster color {color}: {subsets}")
    print(f"결과 속성은 아래와 같습니다. \n{subword_total(subsets)}\n\n")
# Out:
# Cluster color C0: ['subset_충전기', 'subset_C타입', 'subset_포트', 'subset_어댑터', 'subset_충전']
# 결과 속성은 아래와 같습니다.
# {'타입', 'C타입', '플러그', 'USB포트', '충전기', '짐', '어댑터', '충전', '멀티탭', '멀티어댑터', '해외', '핸드폰', '고속충전', '해외여행', '일본', '기기', '포트', '선', '콘센트', '케이스', '동시'}
#
#
# Cluster color C1: ['subset_고속충전', 'subset_디자인']
# 결과 속성은 아래와 같습니다.
# {'고속충전', 'C타입', '디자인', '케이스', '포트'}
#
#
# Cluster color C2: ['subset_콘센트', 'subset_멀티탭']
# 결과 속성은 아래와 같습니다.
# {'플러그', '국가', '고정', '무게', '충전기', '유럽', '불편', '어댑터', '충전', '멀티탭', '멀티어댑터', '해외', '호주', '연결', '해외여행', '일본', '작동', '포트', '콘센트', '코드'}

# %%
cluster_dict
# Out:
# {'C0': ['subset_충전기', 'subset_C타입', 'subset_포트', 'subset_어댑터', 'subset_충전'],
#  'C1': ['subset_고속충전', 'subset_디자인'],
#  'C2': ['subset_콘센트', 'subset_멀티탭']}

# %%
unique_colors
# Out:
# array(['C0', 'C1', 'C2'], dtype='<U2')

# %%
result_cluster = pd.DataFrame([(k,v) for k, vs in cluster_dict.items() for v in vs], columns=['cluster','set_list'])
result_cluster = result_cluster.groupby('cluster').apply(lambda x : x.assign(set_list=[cluster_dict[x.name]]*len(x))).reset_index(drop=True).drop_duplicates(['cluster'])
result_cluster['subword'] = result_cluster['set_list'].apply(subword_total)
result_cluster
# Out:
#   cluster                                           set_list  \
# 0      C0  [subset_충전기, subset_C타입, subset_포트, subset_어댑터...
# 5      C1                          [subset_고속충전, subset_디자인]
# 7      C2                           [subset_콘센트, subset_멀티탭]
#
#                                              subword
# 0  {타입, C타입, 플러그, USB포트, 충전기, 짐, 어댑터, 충전, 멀티탭, 멀티...
# 5                          {고속충전, C타입, 디자인, 케이스, 포트}
# 7  {플러그, 국가, 고정, 무게, 충전기, 유럽, 불편, 어댑터, 충전, 멀티탭, 멀...

# %%
cumsum_keyword_충전['빈도'].sum() / df_remain_freq
# Out:
#     형태소    빈도    퍼센트  누적_퍼센트
# 0    충전  1227  28.32   28.32
# 1  고속충전   239   5.52   33.84
# 2   충전기   165   3.81   37.65
# 3    포트   115   2.65   40.30
# 4   핸드폰   108   2.49   42.79
# 5   C타입   105   2.42   45.21
# 6    기기    67   1.55   46.76
# 7    동시    65   1.50   48.26
# 8    일본    64   1.48   49.74

# %%
df_remain_freq[df_remain_freq['형태소']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 df_remain_freq[df_remain_freq['형태소']]
#
# File c:\Users\songy\anaconda\envs\mecab\lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\songy\anaconda\envs\mecab\lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File c:\Users\songy\anaconda\envs\mecab\lib\site-packages\pandas\core\indexes\base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6247 if nmissing:
#    6248     if nmissing == len(indexer):
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6252     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['충전', '케이스', '디자인', '어댑터', '콘센트', '파우치', '포트', 'C타입', '고속충전', '멀티탭',\n       ...\n       '주황색', '툴', '정작', '변색', '키', '링', '그리스', '두께', '문제없어', '도어'],\n      dtype='object', length=958)] are in the [columns]"

# %%
# intersection에 대표 속성 포함된 경우
append_keyword_df = df_sample[df_sample['word_percent']!=df_sample['word_percent_concated']]

# intersection에 대표 속성이 포함되지 않은 경우
not_appended_keyword_df = df_sample[df_sample['word_percent']==df_sample['word_percent_concated']]

# %%
append_keyword_df.head(3)
# Out:
#              Set Combination            Intersection  set_number  \
# 14   (subset_충전, subset_어댑터)  [C타입, 포트, 충전, 일본, 충전기]           2
# 15   (subset_충전, subset_콘센트)       [일본, 포트, 충전기, 충전]           2
# 19  (subset_충전, subset_고속충전)         [포트, 고속충전, C타입]           2
#
#     word_percent not_in_intersection           concated_word_list  \
# 14         15.43               [어댑터]  [C타입, 포트, 충전, 일본, 충전기, 어댑터]
# 15         13.29               [콘센트]       [일본, 포트, 충전기, 충전, 콘센트]
# 19          6.06                [충전]          [포트, 고속충전, C타입, 충전]
#
#     word_percent_concated
# 14                  18.15
# 15                  15.66
# 19                  14.83

# %%
len(append_keyword_df)
# Out:
# 93

# %%
sns.scatterplot(append_keyword_df, x='word_percent', y='word_percent_concated', hue='set_number')
# Out:
# <Axes: xlabel='word_percent', ylabel='word_percent_concated'>

# %%
sns.scatterplot(not_appended_keyword_df, x='word_percent', y='word_percent_concated', hue='set_number')
# Out:
# <Axes: xlabel='word_percent', ylabel='word_percent_concated'>

# %%
sns.scatterplot(append_keyword_df, x='word_percent', y='word_percent_concated', color='blue', alpha=0.7)
sns.scatterplot(not_appended_keyword_df, x='word_percent', y='word_percent_concated', color='red',alpha=0.6)
plt.legend(labels=['exclude','include'], bbox_to_anchor=(1,1))

# %%
append_keyword_df.head(3)
# Out:
#              Set Combination            Intersection  set_number  \
# 14   (subset_충전, subset_어댑터)  [C타입, 포트, 충전, 일본, 충전기]           2
# 15   (subset_충전, subset_콘센트)       [일본, 포트, 충전기, 충전]           2
# 19  (subset_충전, subset_고속충전)         [포트, 고속충전, C타입]           2
#
#     word_percent not_in_intersection           concated_word_list  \
# 14         15.43               [어댑터]  [C타입, 포트, 충전, 일본, 충전기, 어댑터]
# 15         13.29               [콘센트]       [일본, 포트, 충전기, 충전, 콘센트]
# 19          6.06                [충전]          [포트, 고속충전, C타입, 충전]
#
#     word_percent_concated
# 14                  18.15
# 15                  15.66
# 19                  14.83

# %%
# 자기 자신을 포함하지 않는 경우(모든 데이터) 전체 형태소에서 차지하는 비율
df_sample[['set_number','word_percent']].corr()
# Out:
#               set_number  word_percent
# set_number      1.000000     -0.355131
# word_percent   -0.355131      1.000000

# %%
# 자기 자신 포함한 경우
df_sample[['set_number','word_percent_concated']].corr()
# Out:
#                        set_number  word_percent_concated
# set_number               1.000000               0.165606
# word_percent_concated    0.165606               1.000000

# %%
not_appended_keyword_df[['set_number','word_percent']].corr()
# Out:
#               set_number  word_percent
# set_number       1.00000      -0.27339
# word_percent    -0.27339       1.00000

# %%
append_keyword_df[['set_number','word_percent_concated']].corr()
# Out:
#                        set_number  word_percent_concated
# set_number               1.000000               0.429859
# word_percent_concated    0.429859               1.000000

# %%
append_keyword_df[['set_number','word_percent']].corr()
# Out:
#               set_number  word_percent
# set_number      1.000000     -0.048743
# word_percent   -0.048743      1.000000

# %%
s2 = sum(append_keyword_df[append_keyword_df['set_number']==2]['not_in_intersection'],[])
unique_s2 = set(s2)
unique_s2
# Out:
# {'C타입', '고속충전', '멀티탭', '어댑터', '충전', '충전기', '콘센트', '포트'}

# %%
print(f"가능     : {s2.count('가능')}")
print(f"고속충전 : {s2.count('고속충전')}")
print(f"멀티탭   : {s2.count('멀티탭')}")
print(f"어댑터   : {s2.count('어댑터')}")
print(f"충전기   : {s2.count('충전기')}")
print(f"콘센트   : {s2.count('콘센트')}")
print(f"포트     : {s2.count('포트')}")
# Out:
# 가능     : 0
# 고속충전 : 3
# 멀티탭   : 5
# 어댑터   : 4
# 충전기   : 3
# 콘센트   : 5
# 포트     : 1

# %%
s3 = sum(append_keyword_df[append_keyword_df['set_number']==3]['not_in_intersection'],[])
unique_s3 = set(s3)
unique_s3
# Out:
# {'C타입', '고속충전', '멀티탭', '어댑터', '충전', '충전기', '콘센트', '포트'}

# %%
print(f"가능     : {s3.count('가능')}")
print(f"고속충전 : {s3.count('고속충전')}")
print(f"멀티탭   : {s3.count('멀티탭')}")
print(f"어댑터   : {s3.count('어댑터')}")
print(f"충전기   : {s3.count('충전기')}")
print(f"콘센트   : {s3.count('콘센트')}")
print(f"포트     : {s3.count('포트')}")
# Out:
# 가능     : 0
# 고속충전 : 6
# 멀티탭   : 13
# 어댑터   : 15
# 충전기   : 6
# 콘센트   : 13
# 포트     : 3

# %%
s4 = sum(append_keyword_df[append_keyword_df['set_number']==4]['not_in_intersection'],[])
unique_s4 = set(s4)
unique_s4
# Out:
# {'C타입', '고속충전', '멀티탭', '어댑터', '충전', '충전기', '콘센트', '포트'}

# %%
print(f"가능     : {s4.count('가능')}")
print(f"고속충전 : {s4.count('고속충전')}")
print(f"멀티탭   : {s4.count('멀티탭')}")
print(f"어댑터   : {s4.count('어댑터')}")
print(f"충전기   : {s4.count('충전기')}")
print(f"콘센트   : {s4.count('콘센트')}")
print(f"포트     : {s4.count('포트')}")
# Out:
# 가능     : 0
# 고속충전 : 4
# 멀티탭   : 13
# 어댑터   : 18
# 충전기   : 4
# 콘센트   : 13
# 포트     : 3

# %%
s5 = sum(append_keyword_df[append_keyword_df['set_number']==5]['not_in_intersection'],[])
unique_s5 = set(s5)
unique_s5
# Out:
# {'C타입', '고속충전', '멀티탭', '어댑터', '충전', '충전기', '콘센트', '포트'}

# %%
print(f"가능     : {s5.count('가능')}")
print(f"고속충전 : {s5.count('고속충전')}")
print(f"멀티탭   : {s5.count('멀티탭')}")
print(f"어댑터   : {s5.count('어댑터')}")
print(f"충전기   : {s5.count('충전기')}")
print(f"콘센트   : {s5.count('콘센트')}")
print(f"포트     : {s5.count('포트')}")
# Out:
# 가능     : 0
# 고속충전 : 1
# 멀티탭   : 6
# 어댑터   : 8
# 충전기   : 1
# 콘센트   : 6
# 포트     : 1

# %%
s6 = sum(append_keyword_df[append_keyword_df['set_number']==6]['not_in_intersection'],[])
unique_s6 = set(s6)
unique_s6
# Out:
# {'C타입', '멀티탭', '어댑터', '콘센트'}

# %%
print(f"가능     : {s6.count('가능')}")
print(f"고속충전 : {s6.count('고속충전')}")
print(f"멀티탭   : {s6.count('멀티탭')}")
print(f"어댑터   : {s6.count('어댑터')}")
print(f"충전기   : {s6.count('충전기')}")
print(f"콘센트   : {s6.count('콘센트')}")
print(f"포트     : {s6.count('포트')}")
# Out:
# 가능     : 0
# 고속충전 : 0
# 멀티탭   : 1
# 어댑터   : 1
# 충전기   : 0
# 콘센트   : 1
# 포트     : 0

# %%
# 대표 속성이 공통 집합에 포함되지 않은 경우 도출되는 키워드 (겹치는 개수별)
append_keyword_df.head()
# Out:
#              Set Combination            Intersection  set_number  \
# 14   (subset_충전, subset_어댑터)  [C타입, 포트, 충전, 일본, 충전기]           2
# 15   (subset_충전, subset_콘센트)       [일본, 포트, 충전기, 충전]           2
# 19  (subset_충전, subset_고속충전)         [포트, 고속충전, C타입]           2
# 20   (subset_충전, subset_멀티탭)           [포트, 충전기, 충전]           2
# 41   (subset_어댑터, subset_포트)           [포트, 충전, C타입]           2
#
#     word_percent not_in_intersection           concated_word_list  \
# 14         15.43               [어댑터]  [C타입, 포트, 충전, 일본, 충전기, 어댑터]
# 15         13.29               [콘센트]       [일본, 포트, 충전기, 충전, 콘센트]
# 19          6.06                [충전]          [포트, 고속충전, C타입, 충전]
# 20         12.16               [멀티탭]           [포트, 충전기, 충전, 멀티탭]
# 41         13.12               [어댑터]           [포트, 충전, C타입, 어댑터]
#
#     word_percent_concated
# 14                  18.15
# 15                  15.66
# 19                  14.83
# 20                  13.46
# 41                  15.84

# %%
cumsum_keyword_충전.to_csv('C:/Users/songy/Desktop/Data/keyword_result/keyword_충전.csv', encoding='utf-8-sig')
cumsum_keyword_케이스.to_csv('C:/Users/songy/Desktop/Data/keyword_result/keyword_케이스.csv', encoding='utf-8-sig')
cumsum_keyword_여행.to_csv('C:/Users/songy/Desktop/Data/keyword_result/keyword_여행.csv', encoding='utf-8-sig')
cumsum_keyword_디자인.to_csv('C:/Users/songy/Desktop/Data/keyword_result/keyword_디자인.csv', encoding='utf-8-sig')
cumsum_keyword_어댑터.to_csv('C:/Users/songy/Desktop/Data/keyword_result/keyword_어댑터.csv', encoding='utf-8-sig')
#cumsum_keyword_콘센트.to_csv('C:/Users/songy/Desktop/Data/keyword_result/keyword_콘센트.csv', encoding='utf-8-sig')
#cumsum_keyword_파우치.to_csv('C:/Users/songy/Desktop/Data/keyword_result/keyword_파우치.csv', encoding='utf-8-sig')
#cumsum_keyword_포트.to_csv('C:/Users/songy/Desktop/Data/keyword_result/keyword_포트.csv', encoding='utf-8-sig')
#cumsum_keyword_C타입.to_csv('C:/Users/songy/Desktop/Data/keyword_result/keyword_C타입.csv', encoding='utf-8-sig')
#cumsum_keyword_가능.to_csv('C:/Users/songy/Desktop/Data/keyword_result/keyword_가능.csv', encoding='utf-8-sig')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[101], line 3
#       1 cumsum_keyword_충전.to_csv('C:/Users/songy/Desktop/Data/keyword_result/keyword_충전.csv', encoding='utf-8-sig')
#       2 cumsum_keyword_케이스.to_csv('C:/Users/songy/Desktop/Data/keyword_result/keyword_케이스.csv', encoding='utf-8-sig')
# ----> 3 cumsum_keyword_여행.to_csv('C:/Users/songy/Desktop/Data/keyword_result/keyword_여행.csv', encoding='utf-8-sig')
#       4 cumsum_keyword_디자인.to_csv('C:/Users/songy/Desktop/Data/keyword_result/keyword_디자인.csv', encoding='utf-8-sig')
#       5 cumsum_keyword_어댑터.to_csv('C:/Users/songy/Desktop/Data/keyword_result/keyword_어댑터.csv', encoding='utf-8-sig')
#
# NameError: name 'cumsum_keyword_여행' is not defined

# %%
def subset_merging_percent(subset_a, subset_b):
    subset_intersection = len(subset_a.intersection(subset_b))
    subset_union = len(subset_a.union(subset_b))
    result = round((subset_intersection / subset_union)*100,2)
    return result

# %% [markdown]
# subset_충전
# subset_케이스
# subset_여행
# subset_디자인
# subset_어댑터
# subset_콘센트
# subset_파우치
# subset_포트
# subset_C타입
# subset_가능
# subset_고속충전
# subset_멀티탭
# subset_충전기

# %%
print(subset_어댑터)
# Out:
# {'충전', '가능', '여행', '멀티탭', '해외', '연결', '플러그', '돼지코', '디자인', '여러나라', '충전기', 'USB포트', '콘센트', 'C타입', '기능', '여행용', '일본', '멀티어댑터', '해외여행', '케이스', '선', '포트'}

# %%
print(f'충전   &  케이스 겹치는 비율 : {subset_merging_percent(subset_충전,subset_케이스)} %')
print(f'충전   &  여행   겹치는 비율 : {subset_merging_percent(subset_충전,subset_여행)} %')
print(f'충전   &  디자인 겹치는 비율 : {subset_merging_percent(subset_충전,subset_디자인)} %')
print(f'충전   &  어댑터 겹치는 비율 : {subset_merging_percent(subset_충전,subset_어댑터)} %')
print(f'케이스 &  여행   겹치는 비율 : {subset_merging_percent(subset_케이스,subset_여행)} %')
print(f'케이스 &  디자인 겹치는 비율 : {subset_merging_percent(subset_케이스,subset_디자인)} %')
print(f'케이스 &  어댑터 겹치는 비율 : {subset_merging_percent(subset_케이스,subset_어댑터)} %')
print(f'여행   &  디자인 겹치는 비율 : {subset_merging_percent(subset_여행,subset_디자인)} %')
print(f'여행   &  어댑터 겹치는 비율 : {subset_merging_percent(subset_여행,subset_어댑터)} %')
# Out:
# 충전   &  케이스 겹치는 비율 : 10.0 %
# 충전   &  여행   겹치는 비율 : 27.27 %
# 충전   &  디자인 겹치는 비율 : 6.06 %
# 충전   &  어댑터 겹치는 비율 : 31.25 %
# 케이스 &  여행   겹치는 비율 : 24.32 %
# 케이스 &  디자인 겹치는 비율 : 30.0 %
# 케이스 &  어댑터 겹치는 비율 : 15.0 %
# 여행   &  디자인 겹치는 비율 : 19.35 %
# 여행   &  어댑터 겹치는 비율 : 51.72 %

# %%
def intersection_list(subset_a, subset_b):
    return subset_a.intersection(subset_b)

# %%
def set_only_list(subset_a, subset_b):
    a_result = subset_a - subset_b
    b_result = subset_b - subset_a
    return print(a_result), print(b_result)

# %%
print(intersection_list(subset_여행, subset_어댑터))
# Out:
# {'일본', '멀티어댑터', '해외여행', '충전', '가능', '멀티탭', '케이스', '충전기', 'C타입', '플러그', '여행용', '포트', '콘센트', '돼지코', '디자인'}

# %%
set_only_list(subset_여행, subset_어댑터)
# Out:
# {'고속충전', '유럽', '핸드폰', '휴대', '어댑터', '파우치', '사이즈'}
# {'여행', '여러나라', '연결', '해외', 'USB포트', '기능', '선'}
# (None, None)

# %%
print(subset_충전)
# Out:
# {'가능', '여행', '속도', '연결', '해외', '케이블', '핸드폰', '충전기', '어댑터', 'USB포트', '보조배터리', '기기', '빠르고', '콘센트', '고속충전', '빠르게', 'C타입', '동시', '일본', '포트'}

# %%
def subset_result(subset):
    subset

# %%
subset_충전.intersection(subset_케이스)
# Out:
# {'가능', '어댑터', '여행', '포트'}

# %%
cumsum_keyword_케이스
# Out:
#      형태소  빈도   퍼센트  누적_퍼센트
# 1     여행  80  8.38    8.38
# 2    디자인  61  6.39   14.77
# 3     고급  40  4.19   18.96
# 4    이쁘고  34  3.56   22.52
# 5     휴대  31  3.25   25.77
# 6    예쁘고  27  2.83   28.60
# 7     충전  23  2.41   31.01
# 8    어댑터  17  1.78   32.79
# 9     색상  17  1.78   34.57
# 10    하드  14  1.47   36.04
# 11   사이즈  12  1.26   37.30
# 12   가볍고  11  1.15   38.45
# 13  해외여행  10  1.05   39.50
# 14   귀엽고  10  1.05   40.55
# 15    가능  10  1.05   41.60
# 16    유럽   9  0.94   42.54
# 17    작고   9  0.94   43.48
# 18    견고   9  0.94   44.42
# 19     색   8  0.84   45.26
# 20    안심   8  0.84   46.10
# 21    상품   8  0.84   46.94
# 22    먼지   8  0.84   47.78
# 23    포트   8  0.84   48.62
# 24    여권   8  0.84   49.46

# %%
plt.rc('font', size = 25)
ax = plt.subplots(figsize=(25,10))
plt.title('충전 속성 결과', fontsize=20)
plt.xticks(rotation=90)
sns.barplot(data=cumsum_keyword_충전, x='형태소', y='빈도')
# Out:
# <Axes: title={'center': '충전 속성 결과'}, xlabel='형태소', ylabel='빈도'>

# %% [markdown]
# local minima 고도화 적용

# %%
cumsum_keyword_케이스
# Out:
#      형태소  빈도   퍼센트  누적_퍼센트
# 1     여행  80  8.38    8.38
# 2    디자인  61  6.39   14.77
# 3     고급  40  4.19   18.96
# 4    이쁘고  34  3.56   22.52
# 5     휴대  31  3.25   25.77
# 6    예쁘고  27  2.83   28.60
# 7     충전  23  2.41   31.01
# 8    어댑터  17  1.78   32.79
# 9     색상  17  1.78   34.57
# 10    하드  14  1.47   36.04
# 11   사이즈  12  1.26   37.30
# 12   가볍고  11  1.15   38.45
# 13  해외여행  10  1.05   39.50
# 14   귀엽고  10  1.05   40.55
# 15    가능  10  1.05   41.60
# 16    유럽   9  0.94   42.54
# 17    작고   9  0.94   43.48
# 18    견고   9  0.94   44.42
# 19     색   8  0.84   45.26
# 20    안심   8  0.84   46.10
# 21    상품   8  0.84   46.94
# 22    먼지   8  0.84   47.78
# 23    포트   8  0.84   48.62
# 24    여권   8  0.84   49.46

# %%
plt.rc('font', size = 25)
ax = plt.subplots(figsize=(25,10))
plt.title('케이스 속성 결과', fontsize=20)
plt.xticks(rotation=90)
sns.barplot(data=cumsum_keyword_케이스, x='형태소', y='빈도')
# Out:
# <Axes: title={'center': '케이스 속성 결과'}, xlabel='형태소', ylabel='빈도'>

# %%
cumsum_keyword_여행.head(50)
# Out:
#       형태소   빈도   퍼센트  누적_퍼센트
# 1      충전  186  7.56    7.56
# 2    해외여행  151  6.14   13.70
# 3     어댑터  112  4.55   18.25
# 4      일본   91  3.70   21.95
# 5     케이스   90  3.66   25.61
# 6   멀티어댑터   75  3.05   28.66
# 7     멀티탭   49  1.99   30.65
# 8      유럽   47  1.91   32.56
# 9     디자인   47  1.91   34.47
# 10    콘센트   44  1.79   36.26
# 11    돼지코   34  1.38   37.64
# 12    충전기   34  1.38   39.02
# 13   고속충전   32  1.30   40.32
# 14    파우치   31  1.26   41.58
# 15    핸드폰   31  1.26   42.84
# 16     포트   29  1.18   44.02
# 17    C타입   25  1.02   45.04
# 18     휴대   24  0.98   46.02
# 19    사이즈   24  0.98   47.00
# 20    여행용   23  0.94   47.94
# 21    플러그   23  0.94   48.88
# 22     가능   22  0.89   49.77

# %%
plt.rc('font', size = 25)
ax = plt.subplots(figsize=(25,10))
plt.title('여행 속성 결과', fontsize=20)
plt.xticks(rotation=90)
sns.barplot(data=cumsum_keyword_여행, x='형태소', y='빈도')
# Out:
# <Axes: title={'center': '여행 속성 결과'}, xlabel='형태소', ylabel='빈도'>

# %%
cumsum_keyword_디자인
# Out:
#      형태소  빈도   퍼센트  누적_퍼센트
# 1    케이스  60  7.39    7.39
# 2    이쁘고  58  7.14   14.53
# 3    예쁘고  57  7.02   21.55
# 4     여행  38  4.68   26.23
# 5    파우치  23  2.83   29.06
# 6     충전  22  2.71   31.77
# 7     기능  21  2.59   34.36
# 8     색상  21  2.59   36.95
# 9     고급  20  2.46   39.41
# 10    실용  18  2.22   41.63
# 11    성능  17  2.09   43.72
# 12   콤팩트  12  1.48   45.20
# 13    휴대  11  1.35   46.55
# 14  해외여행  10  1.23   47.78
# 15    포트  10  1.23   49.01

# %%
plt.rc('font', size = 25)
ax = plt.subplots(figsize=(25,10))
plt.title('디자인 속성 결과', fontsize=20)
plt.xticks(rotation=90)
sns.barplot(data=cumsum_keyword_디자인, x='형태소', y='빈도')
# Out:
# <Axes: title={'center': '디자인 속성 결과'}, xlabel='형태소', ylabel='빈도'>

# %%
cumsum_keyword_어댑터
# Out:
#       형태소   빈도    퍼센트  누적_퍼센트
# 1   멀티어댑터  162  11.10   11.10
# 2      여행  123   8.42   19.52
# 3      충전   65   4.45   23.97
# 4    해외여행   48   3.29   27.26
# 5     콘센트   32   2.19   29.45
# 6      해외   29   1.99   31.44
# 7     플러그   24   1.64   33.08
# 8      가능   22   1.51   34.59
# 9     충전기   22   1.51   36.10
# 10     일본   21   1.44   37.54
# 11     포트   21   1.44   38.98
# 12    C타입   20   1.37   40.35
# 13    케이스   19   1.30   41.65
# 14    여행용   17   1.16   42.81
# 15     연결   14   0.96   43.77
# 16      선   14   0.96   44.73
# 17  USB포트   13   0.89   45.62
# 18    돼지코   12   0.82   46.44
# 19    디자인   11   0.75   47.19
# 20     기능   11   0.75   47.94
# 21    멀티탭   11   0.75   48.69
# 22   여러나라   10   0.68   49.37

# %%
plt.rc('font', size = 25)
ax = plt.subplots(figsize=(25,10))
plt.title('어댑터 속성 결과', fontsize=20)
plt.xticks(rotation=90)
sns.barplot(data=cumsum_keyword_어댑터, x='형태소', y='빈도')
# Out:
# <Axes: title={'center': '어댑터 속성 결과'}, xlabel='형태소', ylabel='빈도'>

# %% [markdown]
# ### 실험 과정

# %%
df_remain_freq
# Out:
#       형태소    빈도  pos  변화량  변화량/총변화량
# 0      충전  1227  NNG    0       0.0
# 1     케이스   926  NNG  301      25.0
# 2      여행   776  NNG  150      12.0
# 3     디자인   545  NNG  231      19.0
# 4     어댑터   381  NNG  164      13.0
# ..    ...   ...  ...  ...       ...
# 961     링     1  NNG    0       0.0
# 962   그리스     1  NNP    0       0.0
# 963    두께     1  NNG    0       0.0
# 964  문제없어     1  NNG    0       0.0
# 965    도어     1  NNG    0       0.0
#
# [966 rows x 5 columns]

# %% [markdown]
# Test
