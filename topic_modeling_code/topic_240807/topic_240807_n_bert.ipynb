# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import re

from konlpy.tag import *

# %%
from konlpy.tag import Mecab

m = Mecab(dicpath = 'C:/mecab/mecab-ko-dic')
m.nouns('A타입도 좋고, PD충전 되는 것도 좋아요. C타입 여러개 있어서 좋습니다')
# Out:
# ['A타입', 'PD충전', '것', 'C타입', '개']

# %%
#product = pd.read_csv("C:/Users/songy/Desktop/Data/product.csv", index_col = 0)
product = pd.read_csv('C:/Users/songy/Desktop/Data/product.csv', index_col=0)
product
# Out:
#                              add_rule_based_split_review
# 3                               금액 차이 얼마 안 나는데 기능은 더 좋아요
# 4                             콤팩트한 디자인과 실용성에 높은 점수 주었습니다
# 8                                      전면 스크래치가 많아서 아쉽네요
# 15                               말 그대로 멀티어댑터에요 해외여행 필수 탬
# 19                                            작아서 휴대도 굿굿
# ...                                                  ...
# 18645                                       가볍고 휴대하기 좋아요
# 18646  C타입 충전이 없어서 구매를 망설이긴 했지만 좀 큰 변압기는 쳐져서 충전이 잘 안되...
# 18647                                        요 사이즈가 딱이네요
# 18649                                   켔써요 노란색이 너무 귀엽군요
# 18652           한 손에 쏙 들어오고 색이 쨍해서 여행 가서 잃어버릴 일 없을 거 같아요
#
# [8102 rows x 1 columns]

# %%
def upper_text(text):
    text = text.upper()
    return text

# %%
product['add_rule_based_split_review'] = product['add_rule_based_split_review'].apply(upper_text)

# %%
def replace_text(text):
  text = str(text)
  text = text.replace('쌈ㅎ','저렴해요')
  text = text.replace('안되는...','안됩니다')
  text = text.replace('ㅎ','')
  text = text.replace('ㅋ','')
  text = text.replace('루♡','')
  text = text.replace('♡','')
  text = text.replace('굳','굿')
  text = text.replace('ㅜ','')
  text = text.replace('중입니다)','중 입니다')
  text = text.replace('하나에요','하나예요')
  text = text.replace('있었어요','있어요')
  text = text.replace('욥','요')
  text = text.replace('오겠씀다~~ㅎㅎ/','오겠습니다')
  text = text.replace('후에~','')
  text = text.replace('개용','개요')
  text = text.replace('ㅅ','')
  text = text.replace('오ㅡ','')
  text = text.replace('여행가고싶어지네요ㅋㅋ','여행 가고 싶어지네요')
  text = text.replace('좋습니다!!!!','좋습니다')
  text = text.replace('구매확정해요','구매 확정해요')
  text = text.replace('완죤빨라요ㅋㅋ','완전 빨라요')
  text = text.replace('ㅡ','')
  text = text.replace('귀요미에요','귀여워요')
  text = text.replace('최고여요','최고예요')
  text = text.replace('사랑하여','사랑해요')
  text = text.replace('배송되었습니다','배송 되었습니다')
  text = text.replace('좋아요ㅔ','좋아요')
  text = text.replace('아니에요.','아니예요')
  text = text.replace('구매확정했습니다','구매 확정했습니다')
  text = text.replace('bbb','굿')
  text = text.replace('쓸ㄲ너ㅣㅇ르','')
  text = text.replace('같고요','같아요')
  text = text.replace('같네요','같아요')
  text = text.replace('씁니다','습니다')
  text = text.replace('넘좋와여','너무 좋아요')
  text = text.replace('굿입니다','굿')
  text = text.replace('목배게최고에요','목배게 최고예요')
  text = text.replace('감동이에요','감동이예요')
  text = text.replace('아이디어템','아이디어 탬')
  text = text.replace(':D','')
  text = text.replace('감사핮니다','감사합니다')
  text = text.replace('템','탬')
  text = text.replace('든든 합니다','든든합니다')
  text = text.replace('받아보았어요','받아봤어요')
  text = text.replace('가타용','같아요')
  text = text.replace('바랍니아','바랍니다')
  text = text.replace('사업번창하세요','사업 번창하세요')
  text = text.replace('쓸겠습니다','쓰겠습니다')
  text = text.replace('구매완료입니다','구매완료')
  text = text.replace('짱빠름','짱 빠름')
  text = text.replace('됩니닽','됩니다')
  text = text.replace('닙니다ㅛ','닙니다')
  text = text.replace('잘한듯해요','잘한듯')
  text = text.replace('가세여','가세요')
  text = text.replace('잘샀다템','잘샀어요')
  text = text.replace('좋아요좋아요좋오ㅓㅗㅇ좋아요','좋아요 좋아요')
  text = text.replace('써봐겠ㅆ네요','써봐야겠네요')
  text = text.replace('만족이에요','만족이예요')
  text = text.replace('아까워요.','아까워요')
  text = text.replace('ajjqjahaja','')
  text = text.replace('잚슬겡ㅎ','잘쓸게요')
  text = text.replace('잘했아요','잘했어요')
  text = text.replace('괜찬ㅍ아요','괜찮아요')
  text = text.replace('예쁨','예뻐요')
  text = text.replace('편하쥬','편해요')
  text = text.replace('감사함다','감사합니다')
  text = text.replace('핳핳','')
  text = text.replace('굿입니다','굿')
  text = text.replace('으흐흐','')
  text = text.replace('빨라요ㅗ','빨라요')
  text = text.replace('이븜','이쁨')
  text = text.replace('ㄹㅇ','')
  text = text.replace('되매요','되네요')
  text = text.replace('믿어보겠음다','믿어보겠습니다')
  text = text.replace('아니에요','아니예요')
  text = text.replace('만족합니다.ㅣ','만족합니다')
  text = text.replace('되고요','됩니다')
  text = text.replace('딱입니딘','딱입니다')
  text = text.replace('기대되어요','기대됩니다')
  text = text.replace('왔습디다','왔습니다')
  text = text.replace('맀어용','랐어요')
  text = text.replace('강강히','')
  text = text.replace('만족이여','만족이요')
  text = text.replace('사용했니다.','사용했습니다')
  text = text.replace('충전빨리되구죻아요','충전 빨리되고 좋아요')
  text = text.replace('잘됩니다잉','잘됩니다')
  text = text.replace('사용했답니다','사용했어요')
  text = text.replace('가타요','같아요')
  text = text.replace('최곱니다','최고입니다')
  text = text.replace('빠르네요','빠릅니다')
  text = text.replace('기릉','기를')
  text = text.replace('받았습니아','받았습니다')
  text = text.replace('ok.','ok')
  text = text.replace('가져감','가져갑니다')
  text = text.replace('익니다','입니다')
  text = text.replace('수용되오ㅡ','수용되요')
  text = text.replace('맨죡','만족')
  text = text.replace('ㄹ','')
  text = text.replace('구매예정이에요','구매 예정이예요')
  text = text.replace('좋은듓','좋은듯')
  text = text.replace('매우저롐하게잘구매했어요감사하네여','매우 저렴하게 잘 구매했어요 감사해요')
  text = text.replace('만적합니다','만족합니다')
  text = text.replace('ㅈ번창하세요','번창하세요')
  text = text.replace('전이에요','전이예요')
  text = text.replace('조어요','좋아요')
  text = text.replace('젛아요','좋아요')
  text = text.replace('됩니더','됩니다')
  text = text.replace('굿입디다','굿')
  text = text.replace('갘아어요','')
  text = text.replace('ㄷ,','')
  text = text.replace('잘되겠쥬','잘되겠죠')
  text = text.replace('쓰게습니도','쓰겠습니다')
  text = text.replace('하고요','하고')
  text = text.replace('저뇽가방도있네요','전용가방도 있네요')
  text = text.replace('sjsjsjjsjs','') 
  text = text.replace('좋겠구먼요','좋겠네요')
  text = text.replace('좋아욫','좋아요')
  text = text.replace('반퓸합니다','반품합니다')
  text = text.replace('꿋꿋입니다','굿')
  text = text.replace('잘씅게용','잘쓸게요')
  text = text.replace('땡큐네요','감사합니다')
  text = text.replace('베릐굿','굿')
  text = text.replace('효오','')
  text = text.replace('☆','')
  text = text.replace('ᄒ','')
  text = text.replace('썼어ᄉ','썼어요')
  text = text.replace('사용시뉴용할듯욕','사용시 유용할 듯')
  text = text.replace('있아요','있어요')
  text = text.replace('아다아다아','')
  text = text.replace('아다 아다 아','')
  text = text.replace('감사합니다아','감사합니다')
  text = text.replace('goood','굿')
  text = text.replace('싱픔굿배소오쟈웁','상품 굿 배송')
  text = text.replace('쓸겡','쓸게요')
  text = text.replace('굿국국숙','굿굿굿')
  text = text.replace('졸아요','좋아요')
  text = text.replace('USC','USB')
  text = text.replace('A S','AS')
  text = text.replace(' ㅐ외','해외')
  text = text.replace('ᄆ','')
  text = text.replace('ᅳᄋ ᄋ','')
  text = text.replace('배슝','배송')
  text = text.replace('ᅲ','')
  text = text.replace('쓸ᄁ너ᅵᄋ르','쓸게요')
  text = text.replace(' ♥','')
  text = text.replace('ᄏ','')
  text = text.replace('강 추','강추')
  text = text.replace('★','')
  text = text.replace('■','')
  
  # text = text.replace('USB', '유에스비')
  text = text.replace('보관 백', '보관백')
  text = text.replace('TYPE', '타입')
  text = text.replace('C TO C', 'C타입')
  text = text.replace('CTOC', 'C타입')
  text = text.replace('C2C', 'C타입')
  text = text.replace('USB-C', 'USB포트 C타입')
  text = text.replace('USB-A', 'USB포트 A타입')
  text = text.replace('C TYPE', 'C타입')
  text = text.replace('C 타입','C타입')
  text = text.replace('씨타입','C타입')
  text = text.replace('씨 타입', 'C타입')
  text = text.replace('A 타입','A타입')
  text = text.replace('에이타입','A타입')
  text = text.replace('에이 타입', 'A타입')
  text = text.replace('PD 충전','PD충전')
  text = text.replace('PD 잭', 'PD잭')
  text = text.replace('급 속','급속')
  text = text.replace('포드','포트')
  text = text.replace('포드만','포트')
  text = text.replace('포드리','포트')
  text = text.replace('핸폰','핸드폰')
  text = text.replace('휴대폰', '핸드폰')
  text = text.replace('휴대전화', '핸드폰')
  text = text.replace('11볼트', '110V')
  text = text.replace('22볼트', '220V')
  text = text.replace('11V', '110V')
  text = text.replace('22V', '220V')
  # text = text.replace('35W', '35와트')
  # text = text.replace('45W', '45와트')
  # text = text.replace('65W', '65와트')
  text = text.replace('포터', '포트')
  # text = text.replace('USB', 'USB포트') 
  text = text.replace('USB 포트', 'USB포트')
  text = text.replace('동시 충전', '동시충전')
  text = text.replace('고속 충전', '고속충전')
  text = text.replace('동시 이용', '동시이용')
  text = text.replace('동시 사용', '동시사용')
  text = text.replace('여러 나라', '여러나라')
  text = text.replace('코넥터', '커넥터')
  # 1개짜리는 제외
  return text

# %%
product['add_rule_based_split_review'] = product['add_rule_based_split_review'].apply(replace_text)

# %%
def clean_text(text):
    if isinstance(text, str):
        return re.sub(r'[-=+,#/\?:^$.@*"※~&%ㆍ!』\\‘·|\(\)\[\]\<\>`\'…\"\“’]', '', text)
    else:
        return ""

# %%
product['add_rule_based_split_review'] = product['add_rule_based_split_review'].apply(clean_text)

# %%
from konlpy.tag import Mecab
m = Mecab(dicpath = 'C:/mecab/mecab-ko-dic')

# %%
def preprocess_reviews(reviews, stopwords_path, additional_stopwords=[]):
    # 불용어 파일 로드
    with open(stopwords_path, encoding='utf-8') as file:
        stopwords = file.read().splitlines()
    
    # 추가 불용어 합치기
    stopwords.extend(additional_stopwords)

    # 리뷰 전처리
    clean_sent = []
    for review in reviews:
        clean = re.sub(r'[-=+,#/\?:^$.@*"※~&%ㆍ!』\\‘·|\(\)\[\]\<\>`\'…\"\“’]', '', review)
        clean = clean.replace('\n', '').replace('\r', '')  # 줄바꿈 문자 제거
        clean_sent.append(clean)

    m = Mecab(dicpath = 'C:/mecab/mecab-ko-dic')
    
    word_list = []
    for sentences in clean_sent:
        # 정규화
        # sentences = m.normalize(sentences)
        # 토큰화
        # tokens = sentences.split()
        tokens = m.nouns(sentences)
        # tokens = okt.nouns(sentences)
        # 불용어 제거
        tokens = [token for token in tokens if token not in stopwords]
        word_list.append(tokens)
    
    return word_list

# %%
"""
stopwords_path = "C:/Users/songy/Desktop/Data/stopwords-ko.txt"
with open(stopwords_path, encoding='utf-8') as file:
    stopwords = file.read().splitlines()

stopwords.extend(additional_stopwords)
print(stopwords)
"""
# Out:
# '\nstopwords_path = "C:/Users/songy/Desktop/Data/stopwords-ko.txt"\nwith open(stopwords_path, encoding=\'utf-8\') as file:\n    stopwords = file.read().splitlines()\n\nprint(stopwords)\n'

# %%
def compiled_morphs(texts, stopwords_path, additional_stopwords=[]):
    # 불용어 파일 로드
    with open(stopwords_path, encoding='utf-8') as file:
        stopwords = file.read().splitlines()

    # 추가 불용어 합치기
    stopwords.extend(additional_stopwords)

    # 리뷰 전처리
    clean = re.sub(r'[-=+,#/\?:^$.@*"※~&%ㆍ!』\\‘·|\(\)\[\]\<\>`\'…\"\“’]', '', texts)
    clean = clean.replace('\n','').replace('\r','')     # 줄바꿈 문자 제거

    # 형태소 분석기 추가
    m = Mecab(dicpath='C:/mecab/mecab-ko-dic')

    result = []
    for i in range(len(m.pos(clean))):
        word, pos = m.pos(clean)[i]
        # 형태소가 연결 어미인지 확인
        if pos in ['VA']:
            if i + 1 < len(m.pos(clean)):
                next_word, next_pos = m.pos(clean)[i + 1]
                if next_pos in ['EC', 'ETM']:           # 연결 어미 또는 관형형 전성 어미
                    result.append(word + next_word)
                else:
                    result.append(word + next_word)
        elif pos in ['NNG', 'NNP']:
            result.append(word) 
    
    # 불용어 처리
    results = [word for word in result if word not in stopwords]
    
    return results

# %%
def compiled_morphs_noun(texts, stopwords_path, additional_stopwords=[]):
    # 불용어 파일 로드
    with open(stopwords_path, encoding='utf-8') as file:
        stopwords = file.read().splitlines()

    # 추가 불용어 합치기
    stopwords.extend(additional_stopwords)

    # 리뷰 전처리
    clean = re.sub(r'[-=+,#/\?:^$.@*"※~&%ㆍ!』\\‘·|\(\)\[\]\<\>`\'…\"\“’]', '', texts)
    clean = clean.replace('\n','').replace('\r','')     # 줄바꿈 문자 제거

    # 형태소 분석기 추가
    m = Mecab(dicpath='C:/mecab/mecab-ko-dic')

    result = []
    for i in range(len(m.pos(clean))):
        word, pos = m.pos(clean)[i]
        if pos in ['NNG', 'NNP']:
            result.append(word) 
    
    # 불용어 처리
    results = [word for word in result if word not in stopwords]
    
    return results

# %%
example_sent = "퓨즈 교체가 자동이라서 신경 쓸 일이 하나 줄은 것도 장점이고요"

# %%
def find_morphs(text):
    """
    명사, 형태소 추출 함수 (형용사의 연결 어미를 반영해 추출)
    """
    result = []

    for i in range(len(m.pos(text))):
        word, pos = m.pos(text)[i]
        # 형태소가 연결 어미인지 확인
        if pos in ['VA']:
            if i + 1 < len(m.pos(text)):
                next_word, next_pos = m.pos(text)[i + 1]
                if next_pos in ['EC', 'ETM']:           # 연결 어미 또는 관형형 전성 어미
                    result.append(word + next_word)
                else:
                    #result.append(word + next_word)
                    result.append(word)
        elif pos in ['NNG', 'NNP']:                     # 명사 
            result.append(word)

    return result

# %%
find_morphs("튼튼한 것 견고한 컴팩트 케이스 테스트")
# Out:
# ['컴팩트', '케이스', '테스트']

# %%
compiled_morphs("C타입까지 USB 튼튼한 것 견고한 컴팩트 케이스 테스트 칰 USB", stopwords_path="C:/Users/songy/Desktop/Data/stopwords-ko.txt")
# Out:
# ['C타입', '컴팩트', '케이스', '테스트']

# %%
compiled_morphs_noun("C타입까지 USB 튼튼한 것 견고한 컴팩트 케이스 테스트 칰 USB", stopwords_path="C:/Users/songy/Desktop/Data/stopwords-ko.txt")
# Out:
# ['C타입', '컴팩트', '케이스', '테스트']

# %%
#compiled_morphs("", stopwords_path="C:/Users/songy/Desktop/Data/stopwords-ko.txt")

# %%
#product['changed_text'] = product['add_rule_based_split_review'].apply(find_morphs)
reviews = product['add_rule_based_split_review']  # 리뷰 데이터
stopwords_path = "C:/Users/songy/Desktop/Data/stopwords-ko.txt"

additional_stopwords = ['가', '가격', '가운데', '가족', '간', '감', '감비', '감사', '값', '강추', '같고', '같습니다', '같아', '같아서', '같아요', '겉'
                        '같은', '결제', '같은데', '개', '거', '거랑', '걱정', '검색', '것', '겉', '게', '게요', '결과', '결재', '경우', '고', '금액', '차이',
                        '고려', '고만', '고민', '곳', '과', '괜찮아요', '구리고', '구매', '구매평', '구비', '구성', '구입', '군더더기', '굿', '귀찮게',
                        '귀찮고', '글', '급하게', '기대', '기존', '기준', '길', '김기', '깊질', '까지', '끝', '나라', '나중', '날', '남편',
                        '냐짱', '너무', '네이버', '노브', '눈', '느낌', '느리네요', '는', '다', '다르게', '다르고', '다양', '다이소', '다행', '달',
                        '담', '답변', '대부분', '대비', '대신', '덕분', '덜렁', '도', '도착', '돈', '동봉', '동생', '동일', '돼다', '되다',
                        '되어다', '두면', '뒤', '들', '등', '디', '딸', '때', '땡', '뛰어나다', '라', '라고', '래빗', '레이', '로', 
                        '를', '리뷰', '마', '마련', '마음', '만', '만족', '많고', '많아서', '많았었', '많지만', '말', '맘', '맛', '멀티',
                        '멜리', '면', '못', '무료', '문', '문제', '물', '물건', '미', '및', '밑', '며칠', '바이', '박스', '반', '받다',
                        '발', '발송', '배', '배송', '번', '번개', '벽', '변', '별도', '별점', '보관', '복', '봉', '부분', '브레',
                        '비선', '비싸지', '비싸지만', '빌', '사나', '사서', '사실', '사요', '사용', '사장', '사진', '생각', '서', '선물', '선택',
                        '설치', '세상', '쇼퍼', '숍', '수', '숙소', '스타', '스티커', '스펙', '시', '시기', '시대', '시험', '식겁', '신랑',
                        '신행', '실사', '실사용자', '싸게', '싸구려', '싸는데', '싸진', '쌀', '써다', '쏙', '쓸모', '아들', '아무것', '아쉽네요', '아쉽습니다',
                        '아주', '아직', '안', '않다', '알차게', '앞', '애', '야지', '얇아요', '얘기', '어렵더라고요', '어머니', '언니', '언스', '엄마',
                        '업', '없겠', '없고', '없나', '없네요', '없는', '없어서', '없어요', '없었', '없으니까요', '없지만', '에', '에서', '엔', '엔코',
                        '여분', '여유', '여행', '역할', '연락', '연휴', '옆', '예비', '예전', '옛날', '오다', '오랫동안', '오전', '오케이', '오후',
                        '와', '와이프', '요', '요새', '요즘', '용', '운', '워홀', '원', '원래', '유용', '으로', '은', '을', '의',
                        '이', '이거', '이다', '이라', '이랑', '이번', '이외', '이용', '이유', '이전', '인', '인터넷', '일행', '있고', '있군요',
                        '있긴', '있네요', '있는', '있는대도', '있다', '있다는', '있던데', '있어', '있어서', '있었', '있을', '있지만', '자', '자다', '자체',
                        '잔', '잘', '장만', '잦은데', '저렴', '저번', '전', '전용', '전이', '전체', '점', '정', '정도', '제', '제공',
                        '제품', '종결', '종류', '좋겠', '좋고', '좋네요', '좋더라구요', '좋습니다', '좋아서', '좋아요', '좋았', '좋은', '좋은데요', '좋을', '주', '좋',
                        '주니', '주문', '주파', '준비', '중요', '지난번', '지네', '지원', '지인', '집', '차', '차지', '처리', '처음', '첨부',
                        '추천', '추후', '출국', '출장', '친구', '친절', '커피', '코', '크게', '크지', '큰일', '테스트', '퇴원', '튀', '트',
                        '티', '판매', '편리', '편하게', '편하고', '평', '평생', '포장', '포함', '표', '프리', '필', '필수탬', '필요', '하고', '필수', '이거', '아쉽더라구요', 
                        '하다', '하머', '하우스', '한', '한국', '한큐', '해', '형', '호텔', '확인', '활용', '회사', '효', '후', '후기', '같', '없', '당황', '목', '탬', '높은',
                        '흠', '히', '힘', '하루','단','역시','음','지고','이기','이제','무거워서','주려','하나라','가능','가성비','배변','패드','견','강아지',
                        '해외','여행','어댑터']

# 추가 불용어 : '가성비','배변','패드','견','강아지'

product['changed_text'] = product['add_rule_based_split_review'].apply(lambda texts : compiled_morphs_noun(texts, stopwords_path, additional_stopwords))

# %%
len(product)
# Out:
# 8102

# %%
product.head(3)
# Out:
#   add_rule_based_split_review    changed_text
# 3    금액 차이 얼마 안 나는데 기능은 더 좋아요            [기능]
# 4  콤팩트한 디자인과 실용성에 높은 점수 주었습니다  [콤팩트, 디자인, 실용]
# 8           전면 스크래치가 많아서 아쉽네요      [전면, 스크래치]

# %%
product.head(3)
# Out:
#   add_rule_based_split_review    changed_text
# 3    금액 차이 얼마 안 나는데 기능은 더 좋아요            [기능]
# 4  콤팩트한 디자인과 실용성에 높은 점수 주었습니다  [콤팩트, 디자인, 실용]
# 8           전면 스크래치가 많아서 아쉽네요      [전면, 스크래치]

# %%
def list_convert_comma(lst):
    return ', '.join(lst)

def list_convert_space(lst):
    return ' '.join(lst)

# %%
product['Tokenized_sentence'] = product['changed_text'].apply(list_convert_comma)
product['Tokenized_morphs'] = product['changed_text'].apply(list_convert_space)
product.head(3)
# Out:
#   add_rule_based_split_review    changed_text Tokenized_sentence  \
# 3    금액 차이 얼마 안 나는데 기능은 더 좋아요            [기능]                 기능
# 4  콤팩트한 디자인과 실용성에 높은 점수 주었습니다  [콤팩트, 디자인, 실용]       콤팩트, 디자인, 실용
# 8           전면 스크래치가 많아서 아쉽네요      [전면, 스크래치]           전면, 스크래치
#
#   Tokenized_morphs
# 3               기능
# 4       콤팩트 디자인 실용
# 8          전면 스크래치

# %%
product.rename(columns={'changed_text':'Tokenized_sentence',
                        'Tokenized_sentence':'Tokenized_sentence_list'}, inplace=True)

# %%
#product.to_csv('C:/Users/songy/Desktop/Data/product_morphs.csv', encoding='utf-8-sig')

# %% [markdown]
# - 앞 전처리 (replace) 부분에서 처리 방식이 상이한 부분이 있어 추후 통일 예정
# - 우선 통일화 위해 공유 받은 데이터로 결과값 추출 진행 (product_pos)

# %%
#product_pos = pd.read_csv('C:/Users/songy/Desktop/Data/product_pos.csv', encoding='utf-8-sig', index_col = 0)
#product_pos.head(3)

# %%
# 오류에 따라 리스트 아닌 행 추출
#non_list_items = product_pos[~product_pos['Tokenized_sentence'].apply(lambda x: isinstance(x, list))]
#non_list_items

# %%
"""
# 오류에 따라 str이 아닌 리스트로 인식하게 하는 함수
def str_to_list(text):
    if isinstance(text, str):
        try:
            return eval(text)
        except:
            return text
    return text
"""
# Out:
# '\n# 오류에 따라 str이 아닌 리스트로 인식하게 하는 함수\ndef str_to_list(text):\n    if isinstance(text, str):\n        try:\n            return eval(text)\n        except:\n            return text\n    return text\n'

# %%
product
# Out:
#                              add_rule_based_split_review  Tokenized_sentence  \
# 3                               금액 차이 얼마 안 나는데 기능은 더 좋아요                [기능]
# 4                             콤팩트한 디자인과 실용성에 높은 점수 주었습니다      [콤팩트, 디자인, 실용]
# 8                                      전면 스크래치가 많아서 아쉽네요          [전면, 스크래치]
# 15                               말 그대로 멀티어댑터에요 해외여행 필수 탬       [멀티어댑터, 해외여행]
# 19                                            작아서 휴대도 굿굿                [휴대]
# ...                                                  ...                 ...
# 18645                                       가볍고 휴대하기 좋아요                [휴대]
# 18646  C타입 충전이 없어서 구매를 망설이긴 했지만 좀 큰 변압기는 쳐져서 충전이 잘 안되...  [C타입, 충전, 변압기, 충전]
# 18647                                        요 사이즈가 딱이네요               [사이즈]
# 18649                                   켔써요 노란색이 너무 귀엽군요               [노란색]
# 18652           한 손에 쏙 들어오고 색이 쨍해서 여행 가서 잃어버릴 일 없을 거 같아요              [손, 색]
#
#       Tokenized_sentence_list Tokenized_morphs
# 3                          기능               기능
# 4                콤팩트, 디자인, 실용       콤팩트 디자인 실용
# 8                    전면, 스크래치          전면 스크래치
# 15                멀티어댑터, 해외여행       멀티어댑터 해외여행
# 19                         휴대               휴대
# ...                       ...              ...
# 18645                      휴대               휴대
# 18646        C타입, 충전, 변압기, 충전    C타입 충전 변압기 충전
# 18647                     사이즈              사이즈
# 18649                     노란색              노란색
# 18652                    손, 색              손 색
#
# [8102 rows x 4 columns]

# %%
# 위 함수 적용
#product['Tokenized_sentence'] = product['Tokenized_sentence'].apply(str_to_list)

# %%
remove_stopwords2 = sum(product['Tokenized_sentence'],[])
remove_stopwords2
# Out:
# ['기능',
#  '콤팩트',
#  '디자인',
#  '실용',
#  '전면',
#  '스크래치',
#  '멀티어댑터',
#  '해외여행',
#  '휴대',
#  '품질',
#  'USB형',
#  'USB형',
#  '전압',
#  '충전',
#  '충전',
#  '충전',
#  '코드',
#  '불편',
#  '파우치',
#  '호환',
#  '불편',
#  '마감',
#  '유럽',
#  '유럽',
#  '단자',
#  '불량',
#  'USB형',
#  '성능',
#  '콘센트',
#  '기능',
#  '일반형',
#  'USB형',
#  '겸용',
#  '충전',
#  '유럽',
#  '본체',
#  '콘센트',
#  '포트',
#  '추가',
#  '불량',
#  '포트',
#  '작동',
#  '불편',
#  '고정',
#  '무용지물',
#  '해결',
#  '불량',
#  '정상',
#  '플러그',
#  '품질',
#  '파우치',
#  '연결',
#  '연결',
#  '고장',
#  '콘센트',
#  '지장',
#  '코드',
#  '콘센트',
#  '정상',
#  '동작',
#  '국내',
#  '기능',
#  '국가',
#  '콘센트',
#  '기능',
#  'EU타입',
#  '콘센트',
#  '전원',
#  '고정',
#  'EU타입',
#  '콘센트',
#  '전원',
#  '고정',
#  '여러나라',
#  '플러그',
#  '모양',
#  '품질',
#  '버튼',
#  '유럽',
#  '국가',
#  '퀄리티',
#  '파우치',
#  '휴대',
#  '대만',
#  '충전',
#  '타입',
#  '충전',
#  '일본',
#  '돼지코',
#  '연결',
#  '멀티탭',
#  'C타입',
#  '충전',
#  '돼지코',
#  'C타입',
#  '충전기',
#  '케이블',
#  '짐',
#  '자국',
#  '마감',
#  '대만',
#  '고속충전',
#  '미국',
#  '파우치',
#  '캐리어',
#  '유선',
#  '칸',
#  '충전',
#  '장점',
#  '상품',
#  '품질',
#  '마감',
#  '실물',
#  '여행용',
#  '멀티어댑터',
#  '해외여행',
#  '타입',
#  '휴대',
#  '멀티어댑터',
#  '디자인',
#  '파우치',
#  '충전',
#  '속도',
#  '기능',
#  '타입',
#  'C타입',
#  '멀티탭',
#  '타입',
#  '타입',
#  'A타입',
#  'C타입',
#  '와이파이',
#  '도시락',
#  '핸드폰',
#  '보조배터리',
#  '충전',
#  '핸드폰',
#  '충전',
#  '속도',
#  '고속충전',
#  '충전기',
#  '디자인',
#  '한몫',
#  '파우치',
#  '케이스',
#  '휴대',
#  '퀄리티',
#  '파우치',
#  '휴대',
#  '일본',
#  '불편',
#  '전기',
#  '케이스',
#  '케이스',
#  '쿠션',
#  '콘센트',
#  '구멍',
#  '크기',
#  '모양',
#  '멀티어댑터',
#  '케이스',
#  '충전',
#  '파우치',
#  '디자인',
#  '파우치',
#  '성능',
#  '기능',
#  '돼지코',
#  '작동',
#  '유럽',
#  '콘센트',
#  '외국',
#  '고장',
#  '충전',
#  '유럽',
#  '흰색',
#  '케이스',
#  '디자인',
#  '파우치',
#  '자리',
#  '충전',
#  '파우치',
#  '일본',
#  '요고',
#  '해결',
#  'C타입',
#  '고속충전',
#  '파우치',
#  'USB포트',
#  '작동',
#  '케이스',
#  '고급',
#  '동유럽',
#  '보조배터리',
#  '충전',
#  '파우치',
#  '여러나라',
#  '부모',
#  '가실',
#  '성능',
#  '연결',
#  '케이스',
#  '세계',
#  '돼지코',
#  '돼지코',
#  '파우치',
#  '안심',
#  '냄새',
#  '미국',
#  '파우치',
#  '품질',
#  'C타입',
#  '내구',
#  '안정',
#  '사은품',
#  '파우치',
#  '이동',
#  '파손',
#  '우려',
#  'PD충전',
#  'C타입',
#  '충전',
#  'USB포트',
#  '충전기',
#  '실용',
#  '파우치',
#  'USB포트',
#  'C타입',
#  '작동',
#  '지역',
#  '구성품',
#  '멀티탭',
#  '일본',
#  '핸드폰',
#  '보조배터리',
#  '보조배터리',
#  '충전',
#  '충전',
#  '유선',
#  '멀티탭',
#  '국가',
#  '무게',
#  '휴대',
#  '파우치',
#  '휴대',
#  '속',
#  '멀티탭',
#  '충전',
#  '케이블',
#  '충전기',
#  '무게',
#  'C타입',
#  '케이블',
#  '무게',
#  '충전',
#  'C타입',
#  '타입',
#  '실용',
#  '110V',
#  '구멍',
#  '여행지',
#  '고데기',
#  '렴',
#  '돼지코',
#  '파우치',
#  '멀티탭',
#  '고데기',
#  '연결',
#  '돼지코',
#  '여러나라',
#  '220V',
#  'C타입',
#  '케이스',
#  '성능',
#  '무게',
#  '사이즈',
#  '커버',
#  '디자인',
#  '케이스',
#  '디자인',
#  '케이스',
#  '케이스',
#  'USB포트',
#  '핸드폰',
#  '충전',
#  '속도',
#  '핸드폰',
#  '충전',
#  'USB포트',
#  '디자인',
#  '돼지코',
#  '고장',
#  '케이스',
#  '품질',
#  '케이스',
#  '디자인',
#  '콘센트',
#  '대박',
#  '상품',
#  '충전',
#  '핸드폰',
#  '충전',
#  '멀티탭',
#  '연결',
#  '해외여행',
#  '영국',
#  'C타입',
#  '견고',
#  '콘센트',
#  '콘센트',
#  '충전',
#  '색',
#  '케이스',
#  '케이스',
#  '케이스',
#  '충전',
#  '선',
#  '충전',
#  '해외여행',
#  '퓨즈',
#  '퓨즈',
#  '퓨즈',
#  '작동',
#  '파우치',
#  '케이스',
#  '사은품',
#  '케이스',
#  '충전',
#  '파우치',
#  '케이스',
#  '해외여행',
#  '국내',
#  '불량',
#  '단점',
#  '불량',
#  '충전',
#  '충전',
#  '속도',
#  '워치',
#  '핸드폰',
#  '보조배터리',
#  '충전',
#  '충전',
#  '포트',
#  '고데기',
#  '고데기',
#  '볼트',
#  '애플워치',
#  '보조배터리',
#  '충전',
#  '케이스',
#  '품질',
#  '중국',
#  '타입',
#  '충전',
#  '멀티탭',
#  '기기',
#  '충전',
#  'C타입',
#  '외국',
#  '일본',
#  '고장',
#  '충전',
#  '개선',
#  '110V',
#  '충전',
#  '입구',
#  '220V',
#  '깊이',
#  '일본',
#  '입구',
#  '안쪽',
#  '개선',
#  '마감',
#  '아이디어',
#  '실용',
#  '정리',
#  '구조',
#  '휴대',
#  '국내',
#  '평소',
#  '선',
#  '파우치',
#  '미국',
#  '손상',
#  '국내외',
#  '케이스',
#  '사용법',
#  '부담',
#  '크기',
#  '파우치',
#  '여러나라',
#  'C타입',
#  '케이블',
#  '케이블',
#  '만능',
#  '기업',
#  '데이트',
#  '파우치',
#  '충',
#  '사이즈',
#  '타입',
#  '케이',
#  '후회',
#  '일본',
#  '견고',
#  '해외여행',
#  '충전기',
#  'C타입',
#  '케이블',
#  '포트',
#  '선',
#  '동시충전',
#  '파우치',
#  '무게',
#  '세계',
#  '유럽',
#  '콘센트',
#  '케이스',
#  '휴대',
#  '여행용',
#  '멀티어댑터',
#  '해외여행',
#  '콘센트',
#  '변환기',
#  '돼지코',
#  '기능',
#  '기기',
#  '동시',
#  '충전',
#  'PD',
#  'C타입',
#  '안정',
#  '충전',
#  '여행용',
#  '멀티어댑터',
#  '계속',
#  '멀티어댑터',
#  '미국',
#  '멀티탭',
#  '멀티탭',
#  '기기',
#  '무리',
#  '해외여행',
#  '대만',
#  '케이스',
#  '유럽',
#  '핸드폰',
#  '보조배터리',
#  '충전',
#  '가방',
#  '충전',
#  '파우치',
#  '세계',
#  '일본',
#  '가방',
#  '휴대',
#  '일본',
#  '퓨즈',
#  '퓨즈',
#  '유에스비',
#  '포트',
#  '타입',
#  '포트',
#  '동시',
#  '충전',
#  '일본',
#  '충전',
#  '디자인',
#  '콘센트',
#  '돼지코',
#  '해결',
#  '파우치',
#  '멀티탭',
#  '디자인',
#  '케이스',
#  '케이스',
#  '디자인',
#  '대만',
#  '전기포트',
#  '케이스',
#  '장점',
#  '케이스',
#  '케이스',
#  '충전',
#  '충전',
#  '여러나라',
#  '호환',
#  '케이스',
#  '본체',
#  '불안감',
#  '연결',
#  '충전',
#  '케이스',
#  '콤팩트',
#  '품질',
#  '마감',
#  '안전',
#  '충전',
#  '연결',
#  '실용',
#  '케이스',
#  '케이스',
#  '다이슨',
#  '각도',
#  '각도',
#  '조절',
#  '돼지코',
#  '고속충전',
#  '케이스',
#  '케이스',
#  '해외여행',
#  '일본',
#  '케이스',
#  '콘센트',
#  'C타입',
#  '단자',
#  '유에스비',
#  '단자',
#  '멀티어댑터',
#  '불편',
#  '콘센트',
#  'C타입',
#  '충전',
#  '파우치',
#  '휴대',
#  '충전',
#  '멀티어댑터',
#  '무게',
#  '콘센트',
#  '불편',
#  '유럽',
#  '인증',
#  '지역',
#  '커버',
#  '일본',
#  '기기',
#  '충전',
#  '전일',
#  '저녁',
#  '짐',
#  '일본',
#  '돼지코',
#  '세계',
#  '한국인',
#  '고속충전',
#  '고속충전',
#  '아이폰',
#  '갤럭시',
#  '연결',
#  '충전',
#  '대만',
#  '110V',
#  '전기',
#  '충전',
#  '충전',
#  'C타입',
#  '케이스',
#  '케이스',
#  '고급',
#  '드라이기',
#  'C타입',
#  '충전',
#  '파우치',
#  '동시',
#  '충전',
#  '220V',
#  '코드',
#  '내구',
#  '국가',
#  '충전',
#  '선',
#  '파우치',
#  '디자인',
#  '컬러',
#  '고급',
#  '휴대',
#  '해외여행',
#  '멀티어댑터',
#  '포트',
#  '연결',
#  '잭',
#  '해결',
#  '국가',
#  '해당',
#  '옵션',
#  '설명서',
#  '파우치',
#  '발리',
#  '신혼',
#  '다이슨',
#  '다이슨',
#  '베개',
#  '고생',
#  '의자',
#  '의자',
#  '가이드',
#  '사람',
#  '대박',
#  'C타입',
#  '동시',
#  '짐',
#  '가격대',
#  '퀄리티',
#  '장점',
#  '빛',
#  '디자인',
#  '케이스',
#  '입',
#  '개꿀',
#  '멀티탭',
#  '충전',
#  '편',
#  '멀티탭',
#  '충전',
#  '핸드폰',
#  '충전',
#  '워치',
#  '충전',
#  '드라이기',
#  '충전',
#  '파우치',
#  '파우치',
#  '실용',
#  '퓨즈',
#  '충전',
#  '케이블',
#  '충전',
#  '갤럭시',
#  '고속충전',
#  '충전',
#  '연결',
#  '불안',
#  '일본',
#  '충전',
#  '불편',
#  '색상',
#  '흰색',
#  '그레이',
#  '포트',
#  'C타입',
#  '충전',
#  '케이스',
#  '충전',
#  '호환',
#  '불편',
#  '케이스',
#  '케이스',
#  '해외여행',
#  'C타입',
#  '최근',
#  '콘센트',
#  '자리',
#  '타입',
#  '국내',
#  '멀티탭',
#  '실용',
#  '멀티탭',
#  '연결',
#  '핸드폰',
#  '충전',
#  '품질',
#  '고급',
#  '케이스',
#  '콘센트',
#  '일본',
#  '상품',
#  '충전',
#  '충전',
#  '케이스',
#  '충전',
#  '하와이',
#  '다이슨',
#  '크기',
#  '파우치',
#  '최근',
#  '대만',
#  '태국',
#  '최고',
#  '효율',
#  '소지품',
#  '고속충전',
#  '짱',
#  '충전',
#  '접촉',
#  '불량',
#  '블로그',
#  '돼지코',
#  '동시',
#  '충전',
#  '충전',
#  '구성품',
#  '본품',
#  '설명서',
#  '파우치',
#  '비교',
#  '가격대',
#  '콘센트',
#  '현상',
#  'C타입',
#  '디자인',
#  '여러',
#  '케이블',
#  '일반',
#  '일본',
#  '배터리',
#  '충전',
#  '볼트',
#  '고속충전',
#  '테두리',
#  '노란색',
#  '교환',
#  '멀티탭',
#  '대용',
#  '사이즈',
#  '랩',
#  '고장',
#  '견고',
#  '타입',
#  '충전',
#  '무게',
#  '크기',
#  '케이스',
#  '고급',
#  '베개',
#  '센스',
#  '해결',
#  '미니',
#  '고데기',
#  '케이스',
#  '디자인',
#  '파우치',
#  '견고',
#  '심플',
#  '충전',
#  '콘센트',
#  '파우치',
#  '포트',
#  '케이스',
#  '콘센트',
#  '충전',
#  '동시',
#  '충전',
#  '최대',
#  '충전',
#  '시도',
#  '미국',
#  '디자인',
#  '마트',
#  '크기',
#  '충전기',
#  '전기포트',
#  '방문',
#  '전기포트',
#  '불안',
#  '파우치',
#  '충전',
#  '멀티탭',
#  '220V',
#  '코드',
#  '충전',
#  '포트',
#  '휴대',
#  '유럽',
#  '파우치',
#  '마감',
#  'C타입',
#  '포트',
#  'C타입',
#  '포트',
#  '충전',
#  '35W',
#  '최대',
#  '유럽',
#  '충전',
#  '핸드폰',
#  '수신기',
#  '충전',
#  '디자인',
#  'C타입',
#  '편지',
#  '사은품',
#  '호주',
#  '핸드폰',
#  '충전',
#  'USB포트',
#  'C타입',
#  'A타입',
#  '케이스',
#  '정리',
#  '핸드폰',
#  '워치',
#  '충전',
#  '간편',
#  '충전',
#  '속도',
#  '감동',
#  '케이스',
#  '재송',
#  '케이스',
#  '견고',
#  '충전',
#  '이것저것',
#  '완성도',
#  '충전',
#  '해외여행',
#  '전기',
#  '코드',
#  '타입',
#  '핸드폰',
#  '충전',
#  '충전',
#  '멀티탭',
#  '충전기',
#  '불편',
#  '핸드폰',
#  '보조배터리',
#  '동시충전',
#  '손',
#  '편지',
#  '박싱',
#  '기분',
#  '케이스',
#  '디자인',
#  '파우치',
#  '코드',
#  '체결',
#  '충전',
#  '디자인',
#  '충전',
#  '포트',
#  '충전',
#  '파우치',
#  '크기',
#  '포스트잇',
#  '의견',
#  '무게',
#  'C타입',
#  '최대',
#  '충전기',
#  '퓨즈',
#  '파우치',
#  '밤새',
#  '충전',
#  '유럽',
#  '충전',
#  '선',
#  '충전',
#  '홍콩',
#  '계획',
#  '콘센트',
#  '지',
#  '멀티어댑터',
#  '필리핀',
#  '충전',
#  '보조배터리',
#  '충전',
#  '부족',
#  '국가',
#  '해외여행',
#  '배터리',
#  '정성',
#  '메모',
#  '구성품',
#  '콘센트',
#  '작동',
#  '동시',
#  '충전',
#  '속도',
#  '손',
#  '편지',
#  '감동',
#  '추가',
#  '구성품',
#  '파우치',
#  '선',
#  '정리',
#  '꽈배기',
#  '무게',
#  '콤팩트',
#  '사이즈',
#  '미국',
#  '유럽',
#  '국가',
#  '콘센트',
#  '지팅스',
#  '문자',
#  '물품',
#  '정리',
#  '토요일',
#  '연결',
#  '포기',
#  '헤어',
#  '드라이기',
#  '바람',
#  '전압',
#  '케이스',
#  '호환',
#  '충전',
#  '충전',
#  '속도',
#  '기능',
#  '세',
#  '충전',
#  '고속충전',
#  '케이스',
#  '손',
#  '편지',
#  '정성',
#  '파우치',
#  'USB포트',
#  '파우치',
#  '품질',
#  '캐나다',
#  '멀티어댑터',
#  '파우치',
#  '변환',
#  '손',
#  '디자인',
#  '기능',
#  '사은품',
#  '쪽지',
#  '기분',
#  '케이스',
#  '불량',
#  '불량',
#  '인증',
#  '영상',
#  '케이스',
#  '소형',
#  '세계',
#  '기기',
#  '케이스',
#  '전기',
#  '전기',
#  '상세',
#  '설명',
#  '전기',
#  '질문',
#  '설명',
#  '손',
#  '쪽지',
#  '동',
#  '케이스',
#  '멀티어댑터',
#  '메모',
#  '사은품',
#  '파우치',
#  '이것저것',
#  '방법',
#  '참고',
#  '정성',
#  '손',
#  '편지',
#  '감동',
#  '구멍',
#  '고정',
#  '파우치',
#  '서유럽',
#  '방법',
#  '전화',
#  '설명',
#  '핸드폰',
#  '전기',
#  '충전',
#  '해결',
#  '포스트잇',
#  '충전기',
#  '짐',
#  '충전기',
#  '초고속',
#  '일본',
#  '충전',
#  '충전',
#  '충전기',
#  '선',
#  '충전',
#  '첨',
#  '콘센트',
#  '깜놀',
#  '멀티탭',
#  'C타입',
#  '크기',
#  '휴대',
#  'USB포트',
#  'C타입',
#  '포트',
#  '고속충전',
#  '포트',
#  '용량',
#  '내장',
#  '퓨즈',
#  '퓨즈',
#  '체결',
#  '안전',
#  '성능',
#  '급속',
#  '충전',
#  '양호',
#  '파우치',
#  ...]

# %%
#remove_stopwords2 = sum(product['changed_text'],[])
#remove_stopwords2

# %%
from collections import Counter
remain_freq = Counter(remove_stopwords2).most_common()
df_remain_freq = pd.DataFrame(remain_freq, columns=['형태소', '빈도'])
df_remain_freq
# Out:
#      형태소    빈도
# 0     충전  1227
# 1    케이스   926
# 2    디자인   545
# 3    콘센트   331
# 4    파우치   313
# ..   ...   ...
# 949    키     1
# 950    링     1
# 951  그리스     1
# 952   두께     1
# 953   도어     1
#
# [954 rows x 2 columns]

# %%
from pprint import pprint
print(df_remain_freq)
# Out:
#      형태소    빈도
# 0     충전  1227
# 1    케이스   926
# 2    디자인   545
# 3    콘센트   331
# 4    파우치   313
# ..   ...   ...
# 949    키     1
# 950    링     1
# 951  그리스     1
# 952   두께     1
# 953   도어     1
#
# [954 rows x 2 columns]

# %%
df_remain_freq.to_csv('C:/Users/songy/Desktop/Data/product_keyword.csv', encoding = 'utf-8-sig')

# %%
df_remain_freq
# Out:
#      형태소    빈도
# 0     충전  1227
# 1    케이스   926
# 2    디자인   545
# 3    콘센트   331
# 4    파우치   313
# ..   ...   ...
# 949    키     1
# 950    링     1
# 951  그리스     1
# 952   두께     1
# 953   도어     1
#
# [954 rows x 2 columns]

# %%
#df_remain_freq['빈도'].value_counts().to_frame().reset_index().sort_values(by='빈도', ascending=False)[:30]

# %%
plt.rc("font", family = "Malgun Gothic")
sns.set(font="Malgun Gothic", 
rc={"axes.unicode_minus":False}, style='white')

# %%
import seaborn as sns
plt.rc('font', size = 20)
ax = plt.subplots(figsize=(25,10))
plt.xticks(rotation=90)
sns.barplot(data=df_remain_freq[:70], x='형태소', y='빈도')
# Out:
# <Axes: xlabel='형태소', ylabel='빈도'>

# %% [markdown]
# - elbow 기반 : 어댑터까지

# %%
#df_remain_freq['퍼센트'] = round((df_remain_freq['빈도']/df_remain_freq['빈도'].sum())*100,2)
#df_remain_freq['cumsum'] = df_remain_freq['퍼센트'].cumsum()
#df_remain_freq

# %%
df_remain_freq
# Out:
#      형태소    빈도
# 0     충전  1227
# 1    케이스   926
# 2    디자인   545
# 3    콘센트   331
# 4    파우치   313
# ..   ...   ...
# 949    키     1
# 950    링     1
# 951  그리스     1
# 952   두께     1
# 953   도어     1
#
# [954 rows x 2 columns]

# %%
for i in range(5):
    print(df_remain_freq['빈도'][i])
# Out:
# 1227
# 926
# 545
# 331
# 313

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
def get_pos_tag(word):
    "명사만 추출하기 위해"
    if isinstance(word, str):  # 입력이 문자열인지 확인
        pos_tags = m.pos(word)
        return pos_tags[0][1] if pos_tags else 'Unknown'
    else:
        return 'Unknown'

df_remain_freq['pos'] = df_remain_freq['형태소'].apply(get_pos_tag)
df_remain_freq.head(3)
# Out:
#    형태소    빈도  pos
# 0   충전  1227  NNG
# 1  케이스   926  NNG
# 2  디자인   545  NNG

# %%
df_remain_freq['pos'].value_counts().to_frame().reset_index()
# Out:
#       pos  count
# 0     NNG    793
# 1     NNP    151
# 2      MM      3
# 3     MAG      2
# 4      VV      2
# 5      VA      1
# 6  VV+ETM      1
# 7      NP      1

# %%
# Test
#df_remain_freq[(df_remain_freq['pos']=='NNG') | (df_remain_freq['pos']=='NNP')].reset_index()[['형태소','빈도','pos']]

# %% [markdown]
# ## 방법론2 > H0: 비슷한 속성이 많을수록 중요한 속성이다.

# %% [markdown]
# - 방법론1과 다르게 자기 자신을 포함해 진행 (제외 부분 제거 필요)

# %%
# 명사만 추출하는 부분
df_remain_freq = df_remain_freq[(df_remain_freq['pos']=='NNG') | (df_remain_freq['pos']=='NNP')].reset_index()[['형태소','빈도','pos']]

# 변화량 및 변화량/총변화량 도출 부분
df_remain_freq['변화량'] = 0

for i in range(len(df_remain_freq)):
    if i == 0:
        df_remain_freq['변화량'][i] = 0
    else:
        # ascending 되어 있어 증가하는 것은 없기 때문에 제곱근은 배제 
        df_remain_freq['변화량'][i] = df_remain_freq['빈도'][i-1] - df_remain_freq['빈도'][i]
    
    
    changed_sum = df_remain_freq['변화량'].sum()

# 퍼센트 계산으로 100을 곱하는 것 > 의미 있는 결과를 위해 round를 먼저 취해주고 100 곱함 
df_remain_freq['변화량/총변화량'] =round((df_remain_freq['변화량']/changed_sum),2)*100

# 두번째 minima 찾는 부분 (변화량/총변화량 = 0인 두번째 부분)
# 0행이 0으로 시작함에 따라 2번째 변곡점인 2로 진행
second_zero_index = df_remain_freq[df_remain_freq['변화량/총변화량']==0].index[2]
x_labels = df_remain_freq['형태소'][:second_zero_index+10]
print(f'minima is : {x_labels[second_zero_index]}, {second_zero_index}번째')

# 그래프 부분
fig1 = plt.figure(figsize=(25,8))
fig1.gca().spines['right'].set_visible(False)   # 오른쪽 테두리 제거
fig1.gca().spines['top'].set_visible(False)     # 위 테두리 제거
area1 = fig1.add_subplot(1,1,1)
ax1 = sns.lineplot(df_remain_freq['변화량/총변화량'][:second_zero_index+10], linewidth=3, ax=area1)   # ax=area1
plt.axvline(x=df_remain_freq[df_remain_freq['변화량/총변화량']==0.00].index[1], color='gray', linestyle='--', linewidth=1.5, alpha=0.7)
plt.axvline(x=second_zero_index, color='r', linestyle='--', linewidth=1.5, alpha=0.7)
plt.xticks(ticks=range(len(x_labels)), labels=x_labels, rotation=90)
ax1.set_title('Finding Minima', fontsize=24)    #position=(0.5, 5)
# Out:
# minima is : 멀티어댑터, 10번째
# Text(0.5, 1.0, 'Finding Minima')

# %%
df_remain_freq
# Out:
#      형태소    빈도  pos  변화량  변화량/총변화량
# 0     충전  1227  NNG    0       0.0
# 1    케이스   926  NNG  301      25.0
# 2    디자인   545  NNG  381      31.0
# 3    콘센트   331  NNG  214      17.0
# 4    파우치   313  NNP   18       1.0
# ..   ...   ...  ...  ...       ...
# 939    키     1  NNG    0       0.0
# 940    링     1  NNG    0       0.0
# 941  그리스     1  NNP    0       0.0
# 942   두께     1  NNG    0       0.0
# 943   도어     1  NNG    0       0.0
#
# [944 rows x 5 columns]

# %%
#df_remain_freq[df_remain_freq['변화량/총변화량']==0]

# %% [markdown]
# ### 키워드별 속성 추출 알고리즘 구축

# %%
product.head(3)
# Out:
#   add_rule_based_split_review Tokenized_sentence Tokenized_sentence_list  \
# 3    금액 차이 얼마 안 나는데 기능은 더 좋아요               [기능]                      기능
# 4  콤팩트한 디자인과 실용성에 높은 점수 주었습니다     [콤팩트, 디자인, 실용]            콤팩트, 디자인, 실용
# 8           전면 스크래치가 많아서 아쉽네요         [전면, 스크래치]                전면, 스크래치
#
#   Tokenized_morphs
# 3               기능
# 4       콤팩트 디자인 실용
# 8          전면 스크래치

# %%
# 마지막에 해당 코드 코드화하기 (누적 퍼센트, TopN개 파라미터 포함)
exclude_list = []   # 여기엔 앞에 등장한 키워드들 10개 포함해 누적 저장됨
list_all = []
subset_list = []

for i in range(second_zero_index):
    # A : 형태소 키워드 index 5번 (어댑터)까지 확인 
    # i번째 형태소가 명사에 해당할 경우만 

    # 동적 변수명 생성해 데이터프레임 구성 
    morphs_target = df_remain_freq['형태소'][i]
    var_name = f'df_{morphs_target}'
    globals()[var_name] = product[product['add_rule_based_split_review'].str.contains(f'{df_remain_freq["형태소"][i]}')]


    # 키워드별 형태소 키워드 분석
    var_name2 = f'keyword_freq_{morphs_target}'
    globals()[var_name2] = pd.DataFrame(Counter(sum(globals()[var_name]['Tokenized_sentence'],[])).most_common(), columns=['형태소', '빈도'])
    ### 앞단 키워드 상위 10개 제외 리스트 저장 (회의 반영 : 중복과정 제거)
    ### 제외한 키워드들만 형태소 feature에 반영될 수 있게, 퍼센트 뽑기 전에 키워드 루프

    globals()[var_name2] = globals()[var_name2][~globals()[var_name2]['형태소'].isin(exclude_list)]
    #exclude_list.extend(list(globals()[var_name2]['형태소'][:10]))
    exclude_list.extend(list(globals()[var_name2]['형태소'][:0]))

    #print(exclude_list)

    # 자기 자신은 제외하는 부분 (순서 변경)
    #globals()[var_name2] = globals()[var_name2][globals()[var_name2]['형태소']!=morphs_target]
        
    # 퍼센트, 누적 퍼센트 feature 추가 
    globals()[var_name2]['퍼센트'] = round((globals()[var_name2]['빈도']/globals()[var_name2]['빈도'].sum())*100,2)
    globals()[var_name2]['누적_퍼센트'] = globals()[var_name2]['퍼센트'].cumsum()

    # 누적 퍼센트에 따른 키워드 데이터프레임 추출
    c_value = 70                                        # 누적_퍼센트 파라미터 설정 / 누적 파라미터 이하인 데이터만 추출됨 
    var_name3 = f'cumsum_keyword_{morphs_target}'
    #globals()[var_name3] = globals()[var_name2][(globals()[var_name2]['누적_퍼센트']<c_value)]  # 자기 자신 제외 부분 앞단 (globals()[var_name2]['형태소']!=morphs_target) >> 방법론2에서는 제거
    globals()[var_name3] = globals()[var_name2][(globals()[var_name2]['누적_퍼센트']<c_value)]  # 자기 자신 제외 부분 앞단 (globals()[var_name2]['형태소']!=morphs_target) >> 방법론2에서는 제거

    # subset set으로 저장 (추후 겹치는 퍼센트에 따라 적합성 판단)
    var_name4 = f'subset_{morphs_target}'
    globals()[var_name4] = set(globals()[var_name3]['형태소'])

    # 전체 리스트 확인 & 전체 리스트가 전체 형태소중에 얼만큼의 비율을 차지하는지 
    list_all.extend(list(globals()[var_name3]['형태소']))
    list_set = set(list_all)
    #print(f'{i}번째 리스트 : \n{list_all}\n')

    #### subset끼리 계산 (i개씩 비교)
    subset_list.append(var_name4)       # 루프당 존재하는 subset 집합
    print(subset_list)
    subset_number = len(subset_list)    # subset 개수

#print(subset_list)
print('')

# print(list_all) # 전체 형태소 뽑고 싶을 때 
print(f'세부 고유 키워드가 전체 형태소 결과 포함 비율 : {round((len(list_set) / len(df_remain_freq.형태소))*100,2)} %')

sub_result_sum = df_remain_freq[df_remain_freq['형태소'].isin(list_all)]['빈도'].sum()
all_result_sum = df_remain_freq['빈도'].sum()
print(f'세부 키워드가 전체 키워드 내 차지하는 비율    : {round((sub_result_sum/all_result_sum)*100,2)} %')

print(f'\n현재 존재하는 subset의 개수는 {subset_number}')
# Out:
# ['subset_충전']
# ['subset_충전', 'subset_케이스']
# ['subset_충전', 'subset_케이스', 'subset_디자인']
# ['subset_충전', 'subset_케이스', 'subset_디자인', 'subset_콘센트']
# ['subset_충전', 'subset_케이스', 'subset_디자인', 'subset_콘센트', 'subset_파우치']
# ['subset_충전', 'subset_케이스', 'subset_디자인', 'subset_콘센트', 'subset_파우치', 'subset_포트']
# ['subset_충전', 'subset_케이스', 'subset_디자인', 'subset_콘센트', 'subset_파우치', 'subset_포트', 'subset_C타입']
# ['subset_충전', 'subset_케이스', 'subset_디자인', 'subset_콘센트', 'subset_파우치', 'subset_포트', 'subset_C타입', 'subset_고속충전']
# ['subset_충전', 'subset_케이스', 'subset_디자인', 'subset_콘센트', 'subset_파우치', 'subset_포트', 'subset_C타입', 'subset_고속충전', 'subset_멀티탭']
# ['subset_충전', 'subset_케이스', 'subset_디자인', 'subset_콘센트', 'subset_파우치', 'subset_포트', 'subset_C타입', 'subset_고속충전', 'subset_멀티탭', 'subset_충전기']
#
# 세부 고유 키워드가 전체 형태소 결과 포함 비율 : 8.47 %
# 세부 키워드가 전체 키워드 내 차지하는 비율    : 67.64 %
#
# 현재 존재하는 subset의 개수는 10

# %%
subset_충전
# Out:
# {'C타입',
#  'USB포트',
#  '고속충전',
#  '기기',
#  '노트북',
#  '동시',
#  '디자인',
#  '멀티어댑터',
#  '멀티탭',
#  '보조배터리',
#  '불편',
#  '선',
#  '속도',
#  '연결',
#  '일본',
#  '충전',
#  '충전기',
#  '케이블',
#  '케이스',
#  '콘센트',
#  '타입',
#  '포트',
#  '폰',
#  '해외여행',
#  '핸드폰'}

# %%
import itertools

def get_set_by_name(name):
    return globals()[name]

def find_intersections(sets_names):
    sets = [get_set_by_name(name) for name in sets_names]
    n = len(sets)
    results = []

    # 모든 가능한 부분집합에 대해 겹치는 요소 찾기
    for r in range(n + 1):
        for combo in itertools.combinations(range(n), r):
            if combo:  # 공집합은 생략
                intersection = sets[combo[0]]
                for i in combo[1:]:
                    intersection = intersection.intersection(sets[i])
                results.append({"Set Combination": tuple(sets_names[i] for i in combo), "Intersection": intersection})
            else:
                results.append({"Set Combination": combo, "Intersection": set()})
    return results

def intersection_to_df(sets_names):
    intersections = find_intersections(sets_names)
    # 데이터프레임으로 변환
    df = pd.DataFrame(intersections)
    # 결과 출력
    return df

def count_subset_num(sets):
    return len(sets)

# 필터링 되는지 확인
#df_sample[df_sample['Intersection'].apply(lambda x: len(x) < 1)]['Intersection'].value_counts()

# 예시 실행
df_sample = intersection_to_df(subset_list)
df_sample['set_number'] = df_sample['Set Combination'].apply(count_subset_num)
df_sample = df_sample[df_sample['Intersection'].apply(lambda x: len(x) > 1)]
df_sample
# Out:
#                                        Set Combination  \
# 1                                         (subset_충전,)
# 2                                        (subset_케이스,)
# 3                                        (subset_디자인,)
# 4                                        (subset_콘센트,)
# 5                                        (subset_파우치,)
# ..                                                 ...
# 886  (subset_충전, subset_케이스, subset_콘센트, subset_파우치...
# 907  (subset_충전, subset_디자인, subset_콘센트, subset_파우치...
# 930  (subset_충전, subset_콘센트, subset_포트, subset_C타입,...
# 935  (subset_케이스, subset_디자인, subset_콘센트, subset_파우...
# 971  (subset_충전, subset_케이스, subset_디자인, subset_콘센트...
#
#                                           Intersection  set_number
# 1    {불편, 핸드폰, C타입, 고속충전, 속도, 타입, 연결, 기기, 멀티어댑터, 멀티...           1
# 2                           {색상, 디자인, 고급, 케이스, 휴대, 충전}           1
# 3         {색상, 디자인, 고급, 파우치, 기능, 케이스, 성능, 실용, 콤팩트, 충전}           1
# 4    {불편, 안정, 동작, 무게, C타입, 전기, 전원, 유럽, 고속충전, 안심, 고정...           1
# 5    {디자인, 고급, 파우치, 색, 캐리어, 가방, 색깔, 크기, 휴대, 사은품, 작동...           1
# ..                                                 ...         ...
# 886                                          {디자인, 충전}           7
# 907                                          {디자인, 충전}           7
# 930         {연결, C타입, 멀티어댑터, USB포트, 충전기, 해외여행, 충전, 포트}           7
# 935                                          {디자인, 충전}           7
# 971                                          {디자인, 충전}           8
#
# [351 rows x 3 columns]

# %%
df_sample.to_csv('C:/Users/songy/Desktop/Data/combination_result_240806.csv', encoding='utf-8-sig')

# %%
subset_list
# Out:
# ['subset_충전',
#  'subset_케이스',
#  'subset_디자인',
#  'subset_콘센트',
#  'subset_파우치',
#  'subset_포트',
#  'subset_C타입',
#  'subset_고속충전',
#  'subset_멀티탭',
#  'subset_충전기']

# %%
df_sample['Intersection'] = df_sample['Intersection'].apply(lambda x: list(x))

# %%
def add_quotes(value):
    return f'"{value}"'

# %%
#df_sample['Intersection'] = df_sample['Intersection'].apply(lambda x: f'{x}')
#df_sample.head()

# %%
def percent_subset(list_name):
    x = df_remain_freq[df_remain_freq['형태소'].isin(list_name)]
    x2 = (x['빈도'].sum() / df_remain_freq['빈도'].sum())*100
    x2 = round(x2, 2)
    return x2

# %%
#df_sample.to_csv('C:/Users/songy/Desktop/Data/result_way2.csv', encoding='utf-8-sig')

# %%
df_sample['word_percent'] = df_sample['Intersection'].apply(percent_subset)
df_sample.head()
# Out:
#   Set Combination                                       Intersection  \
# 1    (subset_충전,)  [불편, 핸드폰, C타입, 고속충전, 속도, 타입, 연결, 기기, 멀티어댑터, 멀티...
# 2   (subset_케이스,)                         [색상, 디자인, 고급, 케이스, 휴대, 충전]
# 3   (subset_디자인,)       [색상, 디자인, 고급, 파우치, 기능, 케이스, 성능, 실용, 콤팩트, 충전]
# 4   (subset_콘센트,)  [불편, 안정, 동작, 무게, C타입, 전기, 전원, 유럽, 고속충전, 안심, 고정...
# 5   (subset_파우치,)  [디자인, 고급, 파우치, 색, 캐리어, 가방, 색깔, 크기, 휴대, 사은품, 작동...
#
#    set_number  word_percent
# 1           1         43.49
# 2           1         23.24
# 3           1         27.12
# 4           1         40.04
# 5           1         21.57

# %%
df_sample[df_sample['set_number'] == 1]
# Out:
#    Set Combination                                       Intersection  \
# 1     (subset_충전,)  [불편, 핸드폰, C타입, 고속충전, 속도, 타입, 연결, 기기, 멀티어댑터, 멀티...
# 2    (subset_케이스,)                         [색상, 디자인, 고급, 케이스, 휴대, 충전]
# 3    (subset_디자인,)       [색상, 디자인, 고급, 파우치, 기능, 케이스, 성능, 실용, 콤팩트, 충전]
# 4    (subset_콘센트,)  [불편, 안정, 동작, 무게, C타입, 전기, 전원, 유럽, 고속충전, 안심, 고정...
# 5    (subset_파우치,)  [디자인, 고급, 파우치, 색, 캐리어, 가방, 색깔, 크기, 휴대, 사은품, 작동...
# 6     (subset_포트,)  [핸드폰, C타입, 고속충전, 타입, 연결, 기기, 멀티어댑터, 멀티탭, USB포트...
# 7    (subset_C타입,)  [타입, 연결, 단자, 유에스비, C타입, 멀티어댑터, A타입, USB포트, 충전기...
# 8   (subset_고속충전,)  [단자, 핸드폰, C타입, 35W, 고속충전, 최고, 속도, 타입, 연결, 멀티어댑...
# 9    (subset_멀티탭,)  [불편, 핸드폰, C타입, 고속, 미국, 연결, 기기, 멀티어댑터, 멀티탭, 기능,...
# 10   (subset_충전기,)  [단자, 핸드폰, C타입, 고속충전, 속도, 타입, 연결, 해결, 멀티어댑터, 멀티...
#
#     set_number  word_percent
# 1            1         43.49
# 2            1         23.24
# 3            1         27.12
# 4            1         40.04
# 5            1         21.57
# 6            1         39.76
# 7            1         23.09
# 8            1         34.27
# 9            1         42.81
# 10           1         31.67

# %%
set_count_df = df_sample['set_number'].value_counts().to_frame().reset_index().sort_values(by='set_number', ascending=True)
set_count_df
# Out:
#    set_number  count
# 5           1     10
# 3           2     39
# 1           3     81
# 0           4    100
# 2           5     76
# 4           6     35
# 6           7      9
# 7           8      1

# %%
sns.barplot(set_count_df, x='set_number', y='count')
# Out:
# <Axes: xlabel='set_number', ylabel='count'>

# %%
sns.scatterplot(data=df_sample, x='set_number', y='word_percent', hue='set_number')
# Out:
# <Axes: xlabel='set_number', ylabel='word_percent'>

# %%
# 추후 합계까지 함수화 가능 할 듯 
print(f'1번 겹치는 경우 : 전체 경우의 {round(((df_sample[df_sample.set_number == 1].word_percent.sum())/(len(df_sample)*100))*100,2)} %')
print(f'2번 겹치는 경우 : 전체 경우의 {round(((df_sample[df_sample.set_number == 2].word_percent.sum())/(len(df_sample)*100))*100,2)} %')
print(f'3번 겹치는 경우 : 전체 경우의 {round(((df_sample[df_sample.set_number == 3].word_percent.sum())/(len(df_sample)*100))*100,2)} %')
print(f'4번 겹치는 경우 : 전체 경우의 {round(((df_sample[df_sample.set_number == 4].word_percent.sum())/(len(df_sample)*100))*100,2)} %')
print(f'5번 겹치는 경우 : 전체 경우의 {round(((df_sample[df_sample.set_number == 5].word_percent.sum())/(len(df_sample)*100))*100,2)} %')
print(f'6번 겹치는 경우 : 전체 경우의 {round(((df_sample[df_sample.set_number == 6].word_percent.sum())/(len(df_sample)*100))*100,2)} %')
# Out:
# 1번 겹치는 경우 : 전체 경우의 0.93 %
# 2번 겹치는 경우 : 전체 경우의 2.53 %
# 3번 겹치는 경우 : 전체 경우의 4.36 %
# 4번 겹치는 경우 : 전체 경우의 4.78 %
# 5번 겹치는 경우 : 전체 경우의 3.34 %
# 6번 겹치는 경우 : 전체 경우의 1.45 %

# %%
df_sample[(df_sample['set_number']==6)]
# Out:
#                                        Set Combination  \
# 638  (subset_충전, subset_케이스, subset_디자인, subset_콘센트...
# 640  (subset_충전, subset_케이스, subset_디자인, subset_콘센트...
# 641  (subset_충전, subset_케이스, subset_디자인, subset_콘센트...
# 644  (subset_충전, subset_케이스, subset_디자인, subset_콘센트...
# 645  (subset_충전, subset_케이스, subset_디자인, subset_콘센트...
# 650  (subset_충전, subset_케이스, subset_디자인, subset_콘센트...
# 654  (subset_충전, subset_케이스, subset_디자인, subset_파우치...
# 655  (subset_충전, subset_케이스, subset_디자인, subset_파우치...
# 660  (subset_충전, subset_케이스, subset_디자인, subset_파우치...
# 666  (subset_충전, subset_케이스, subset_디자인, subset_포트,...
# 674  (subset_충전, subset_케이스, subset_콘센트, subset_파우치...
# 675  (subset_충전, subset_케이스, subset_콘센트, subset_파우치...
# 680  (subset_충전, subset_케이스, subset_콘센트, subset_파우치...
# 686  (subset_충전, subset_케이스, subset_콘센트, subset_포트,...
# 696  (subset_충전, subset_케이스, subset_파우치, subset_포트,...
# 709  (subset_충전, subset_디자인, subset_콘센트, subset_파우치...
# 710  (subset_충전, subset_디자인, subset_콘센트, subset_파우치...
# 715  (subset_충전, subset_디자인, subset_콘센트, subset_파우치...
# 721  (subset_충전, subset_디자인, subset_콘센트, subset_포트,...
# 731  (subset_충전, subset_디자인, subset_파우치, subset_포트,...
# 746  (subset_충전, subset_콘센트, subset_파우치, subset_포트,...
# 753  (subset_충전, subset_콘센트, subset_포트, subset_C타입,...
# 754  (subset_충전, subset_콘센트, subset_포트, subset_C타입,...
# 755  (subset_충전, subset_콘센트, subset_포트, subset_C타입,...
# 756  (subset_충전, subset_콘센트, subset_포트, subset_고속충전...
# 757  (subset_충전, subset_콘센트, subset_C타입, subset_고속충...
# 763  (subset_충전, subset_포트, subset_C타입, subset_고속충전...
# 765  (subset_케이스, subset_디자인, subset_콘센트, subset_파우...
# 766  (subset_케이스, subset_디자인, subset_콘센트, subset_파우...
# 771  (subset_케이스, subset_디자인, subset_콘센트, subset_파우...
# 777  (subset_케이스, subset_디자인, subset_콘센트, subset_포트...
# 787  (subset_케이스, subset_디자인, subset_파우치, subset_포트...
# 802  (subset_케이스, subset_콘센트, subset_파우치, subset_포트...
# 823  (subset_디자인, subset_콘센트, subset_파우치, subset_포트...
# 846  (subset_콘센트, subset_포트, subset_C타입, subset_고속충...
#
#                                           Intersection  set_number  \
# 638                                          [디자인, 충전]           6
# 640                                          [디자인, 충전]           6
# 641                                          [디자인, 충전]           6
# 644                                          [디자인, 충전]           6
# 645                                          [디자인, 충전]           6
# 650                                          [디자인, 충전]           6
# 654                                          [디자인, 충전]           6
# 655                                          [디자인, 충전]           6
# 660                                          [디자인, 충전]           6
# 666                                          [디자인, 충전]           6
# 674                                          [디자인, 충전]           6
# 675                                          [디자인, 충전]           6
# 680                                          [디자인, 충전]           6
# 686                                          [디자인, 충전]           6
# 696                                          [디자인, 충전]           6
# 709                                          [디자인, 충전]           6
# 710                                          [디자인, 충전]           6
# 715                                          [디자인, 충전]           6
# 721                                          [디자인, 충전]           6
# 731                                          [디자인, 충전]           6
# 746                                          [디자인, 충전]           6
# 753         [연결, C타입, 멀티어댑터, USB포트, 충전기, 해외여행, 충전, 포트]           6
# 754  [타입, 연결, C타입, 멀티어댑터, USB포트, 충전기, 해외여행, 충전, 고속충...           6
# 755         [연결, C타입, 멀티어댑터, USB포트, 충전기, 해외여행, 충전, 포트]           6
# 756    [연결, 포트, C타입, 멀티어댑터, USB포트, 충전기, 해외여행, 충전, 콘센트]           6
# 757         [연결, C타입, 멀티어댑터, USB포트, 충전기, 해외여행, 충전, 포트]           6
# 763         [연결, C타입, 멀티어댑터, USB포트, 충전기, 해외여행, 충전, 포트]           6
# 765                                          [디자인, 충전]           6
# 766                                          [디자인, 충전]           6
# 771                                          [디자인, 충전]           6
# 777                                          [디자인, 충전]           6
# 787                                          [디자인, 충전]           6
# 802                                          [디자인, 충전]           6
# 823                                          [디자인, 충전]           6
# 846         [연결, C타입, 멀티어댑터, USB포트, 충전기, 해외여행, 충전, 포트]           6
#
#      word_percent
# 638         13.21
# 640         13.21
# 641         13.21
# 644         13.21
# 645         13.21
# 650         13.21
# 654         13.21
# 655         13.21
# 660         13.21
# 666         13.21
# 674         13.21
# 675         13.21
# 680         13.21
# 686         13.21
# 696         13.21
# 709         13.21
# 710         13.21
# 715         13.21
# 721         13.21
# 731         13.21
# 746         13.21
# 753         19.14
# 754         21.54
# 755         19.14
# 756         21.61
# 757         19.14
# 763         19.14
# 765         13.21
# 766         13.21
# 771         13.21
# 777         13.21
# 787         13.21
# 802         13.21
# 823         13.21
# 846         19.14

# %%
def check_not_in_intersection(row):
    "subset_ 이 없는 경우 False로 반환"
    set_combination = row['Set Combination']
    intersection_list = row['Intersection']

    not_in_list = []
    for w in set_combination:
        if w.startswith('subset_'):
            subset_word = w[len('subset_'):]
            if subset_word not in intersection_list:
                not_in_list.append(subset_word)

    return not_in_list

df_sample['not_in_intersection'] = df_sample.apply(check_not_in_intersection, axis=1)
df_sample.head(3)
# Out:
#   Set Combination                                       Intersection  \
# 1    (subset_충전,)  [불편, 핸드폰, C타입, 고속충전, 속도, 타입, 연결, 기기, 멀티어댑터, 멀티...
# 2   (subset_케이스,)                         [색상, 디자인, 고급, 케이스, 휴대, 충전]
# 3   (subset_디자인,)       [색상, 디자인, 고급, 파우치, 기능, 케이스, 성능, 실용, 콤팩트, 충전]
#
#    set_number  word_percent not_in_intersection
# 1           1         43.49                  []
# 2           1         23.24                  []
# 3           1         27.12                  []

# %%
df_sample['concated_word_list'] = df_sample['Intersection'] + df_sample['not_in_intersection']
df_sample.head()
# Out:
#   Set Combination                                       Intersection  \
# 1    (subset_충전,)  [불편, 핸드폰, C타입, 고속충전, 속도, 타입, 연결, 기기, 멀티어댑터, 멀티...
# 2   (subset_케이스,)                         [색상, 디자인, 고급, 케이스, 휴대, 충전]
# 3   (subset_디자인,)       [색상, 디자인, 고급, 파우치, 기능, 케이스, 성능, 실용, 콤팩트, 충전]
# 4   (subset_콘센트,)  [불편, 안정, 동작, 무게, C타입, 전기, 전원, 유럽, 고속충전, 안심, 고정...
# 5   (subset_파우치,)  [디자인, 고급, 파우치, 색, 캐리어, 가방, 색깔, 크기, 휴대, 사은품, 작동...
#
#    set_number  word_percent not_in_intersection  \
# 1           1         43.49                  []
# 2           1         23.24                  []
# 3           1         27.12                  []
# 4           1         40.04                  []
# 5           1         21.57                  []
#
#                                   concated_word_list
# 1  [불편, 핸드폰, C타입, 고속충전, 속도, 타입, 연결, 기기, 멀티어댑터, 멀티...
# 2                         [색상, 디자인, 고급, 케이스, 휴대, 충전]
# 3       [색상, 디자인, 고급, 파우치, 기능, 케이스, 성능, 실용, 콤팩트, 충전]
# 4  [불편, 안정, 동작, 무게, C타입, 전기, 전원, 유럽, 고속충전, 안심, 고정...
# 5  [디자인, 고급, 파우치, 색, 캐리어, 가방, 색깔, 크기, 휴대, 사은품, 작동...

# %%
df_sample['word_percent_concated'] = df_sample['concated_word_list'].apply(percent_subset)
df_sample.head()
# Out:
#   Set Combination                                       Intersection  \
# 1    (subset_충전,)  [불편, 핸드폰, C타입, 고속충전, 속도, 타입, 연결, 기기, 멀티어댑터, 멀티...
# 2   (subset_케이스,)                         [색상, 디자인, 고급, 케이스, 휴대, 충전]
# 3   (subset_디자인,)       [색상, 디자인, 고급, 파우치, 기능, 케이스, 성능, 실용, 콤팩트, 충전]
# 4   (subset_콘센트,)  [불편, 안정, 동작, 무게, C타입, 전기, 전원, 유럽, 고속충전, 안심, 고정...
# 5   (subset_파우치,)  [디자인, 고급, 파우치, 색, 캐리어, 가방, 색깔, 크기, 휴대, 사은품, 작동...
#
#    set_number  word_percent not_in_intersection  \
# 1           1         43.49                  []
# 2           1         23.24                  []
# 3           1         27.12                  []
# 4           1         40.04                  []
# 5           1         21.57                  []
#
#                                   concated_word_list  word_percent_concated
# 1  [불편, 핸드폰, C타입, 고속충전, 속도, 타입, 연결, 기기, 멀티어댑터, 멀티...                  43.49
# 2                         [색상, 디자인, 고급, 케이스, 휴대, 충전]                  23.24
# 3       [색상, 디자인, 고급, 파우치, 기능, 케이스, 성능, 실용, 콤팩트, 충전]                  27.12
# 4  [불편, 안정, 동작, 무게, C타입, 전기, 전원, 유럽, 고속충전, 안심, 고정...                  40.04
# 5  [디자인, 고급, 파우치, 색, 캐리어, 가방, 색깔, 크기, 휴대, 사은품, 작동...                  21.57

# %%
sns.scatterplot(data=df_sample, x='set_number', y='word_percent_concated', hue='set_number')
# Out:
# <Axes: xlabel='set_number', ylabel='word_percent_concated'>

# %%
df_sample.head(3)
# Out:
#   Set Combination                                       Intersection  \
# 1    (subset_충전,)  [불편, 핸드폰, C타입, 고속충전, 속도, 타입, 연결, 기기, 멀티어댑터, 멀티...
# 2   (subset_케이스,)                         [색상, 디자인, 고급, 케이스, 휴대, 충전]
# 3   (subset_디자인,)       [색상, 디자인, 고급, 파우치, 기능, 케이스, 성능, 실용, 콤팩트, 충전]
#
#    set_number  word_percent not_in_intersection  \
# 1           1         43.49                  []
# 2           1         23.24                  []
# 3           1         27.12                  []
#
#                                   concated_word_list  word_percent_concated
# 1  [불편, 핸드폰, C타입, 고속충전, 속도, 타입, 연결, 기기, 멀티어댑터, 멀티...                  43.49
# 2                         [색상, 디자인, 고급, 케이스, 휴대, 충전]                  23.24
# 3       [색상, 디자인, 고급, 파우치, 기능, 케이스, 성능, 실용, 콤팩트, 충전]                  27.12

# %%
df_remain_freq['빈도'].sum()
# Out:
# 13419

# %%
df_remain_freq
# Out:
#      형태소    빈도  pos  변화량  변화량/총변화량
# 0     충전  1227  NNG    0       0.0
# 1    케이스   926  NNG  301      25.0
# 2    디자인   545  NNG  381      31.0
# 3    콘센트   331  NNG  214      17.0
# 4    파우치   313  NNP   18       1.0
# ..   ...   ...  ...  ...       ...
# 939    키     1  NNG    0       0.0
# 940    링     1  NNG    0       0.0
# 941  그리스     1  NNP    0       0.0
# 942   두께     1  NNG    0       0.0
# 943   도어     1  NNG    0       0.0
#
# [944 rows x 5 columns]

# %%
len(subset_충전)
# Out:
# 25

# %%
"""
def word_percent_fuction(df_remain_freq, subset):
    "subset 안 요소 있는 행 추출하고, 빈도의 합 / 전체 빈도의 합"
    df_remain_freq['형태소'].
"""
# Out:
# '\ndef word_percent_fuction(df_remain_freq, subset):\n    "subset 안 요소 있는 행 추출하고, 빈도의 합 / 전체 빈도의 합"\n    df_remain_freq[\'형태소\'].\n'

# %%
df_sample.head(3)
# Out:
#   Set Combination                                       Intersection  \
# 1    (subset_충전,)  [불편, 핸드폰, C타입, 고속충전, 속도, 타입, 연결, 기기, 멀티어댑터, 멀티...
# 2   (subset_케이스,)                         [색상, 디자인, 고급, 케이스, 휴대, 충전]
# 3   (subset_디자인,)       [색상, 디자인, 고급, 파우치, 기능, 케이스, 성능, 실용, 콤팩트, 충전]
#
#    set_number  word_percent not_in_intersection  \
# 1           1         43.49                  []
# 2           1         23.24                  []
# 3           1         27.12                  []
#
#                                   concated_word_list  word_percent_concated
# 1  [불편, 핸드폰, C타입, 고속충전, 속도, 타입, 연결, 기기, 멀티어댑터, 멀티...                  43.49
# 2                         [색상, 디자인, 고급, 케이스, 휴대, 충전]                  23.24
# 3       [색상, 디자인, 고급, 파우치, 기능, 케이스, 성능, 실용, 콤팩트, 충전]                  27.12

# %%
"""
for combination in df_sample['Set Combination']:
    #print(combination)
    print(float(df_sample[df_sample['Set Combination']==combination]['word_percent']))
"""
# Out:
# "\nfor combination in df_sample['Set Combination']:\n    #print(combination)\n    print(float(df_sample[df_sample['Set Combination']==combination]['word_percent']))\n"

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from scipy.cluster.hierarchy import linkage, dendrogram, fcluster
import matplotlib.pyplot as plt
import ast

# Set Combination에 들어있는 고유 집합들을 unqique_subsets에 저장
unique_subsets = set()
for combination in df_sample['Set Combination']:
    unique_subsets.update(eval(combination) if isinstance(combination, str) else combination)

unique_subsets = list(unique_subsets)
#print(unique_subsets)

# 집합(행)별로 set combination 포함 여부에 따라 1 또는 0으로 저장
binary_matrix = []
for subset in unique_subsets:
    row = []
    word_percent = []
    for combination in df_sample['Set Combination']:
        combination = eval(combination) if isinstance(combination, str) else combination  
        #row.append(1 if subset in combination else 0)
        # percent로 삽입하는 부분
        word_percent.append(float(df_sample[df_sample['Set Combination']==combination]['word_percent']/100) if subset in combination else 0)  
    #binary_matrix.append(row)
    binary_matrix.append(word_percent)

# combination 포함 결과 numpy 저장
binary_matrix = np.array(binary_matrix)

# 계층적 군집화에 combination 포함 결과 반영 수행
Z = linkage(binary_matrix, method='ward')

# 시각화 
plt.figure(figsize=(25, 7))
dendro = dendrogram(Z, labels=unique_subsets, leaf_rotation=90) 
plt.title('Hierarchical Clustering Dendrogram for Subsets')
plt.xlabel('Subsets')
plt.ylabel('Distance')
plt.show()

# %%
#### 노드 색상별 추출하는 방법 
from scipy.cluster.hierarchy import fcluster

# 덴드로그램의 color_list 정보를 사용하여 클러스터링
color_list = dendro['color_list']
icoord = np.array(dendro['icoord'])
dleaf_colors = np.array([dendro['leaves_color_list'][i] for i in range(len(unique_subsets))])
dleaf_labels = np.array(dendro['ivl'])

# 고유 색상 추출
unique_colors = np.unique(dleaf_colors)

# 클러스터별 집합 도출
cluster_dict = {}
for color in unique_colors:
    cluster_dict[color] = dleaf_labels[dleaf_colors == color].tolist()

def subword_total(st):
    "클러스터별 속성을 도출하기 위한 함수"
    set_all = set()
    for i in st:
        set_all.update(globals()[i])
    return set_all

#result_cluster = pd.DataFrame([(k,v) for k, vs in cluster_dict.items() for v in vs], columns=['cluster','set_list'])

# 클러스터별 집합 출력
for color, subsets in cluster_dict.items():
    print(f"Cluster color {color}: {subsets}")
    print(f"결과 속성은 아래와 같습니다. \n{subword_total(subsets)}\n\n")
# Out:
# Cluster color C0: ['subset_고속충전', 'subset_콘센트', 'subset_충전', 'subset_포트', 'subset_멀티탭']
# 결과 속성은 아래와 같습니다.
# {'불편', '안정', '단자', '동작', '핸드폰', '고속', '미국', '전원', '고속충전', '안심', '고정', '구멍', '멀티어댑터', '기능', '충전', '상품', '케이블', '포트', '콘센트', '국가', '스위치', '케이스', '규격', '부피', '디자인', '부족', '모양', '일본', '퓨즈', '220V', '짐', '해외여행', '무게', 'C타입', '전기', '35W', '유럽', '최고', '속도', '타입', '연결', '기기', '해결', '본체', '접촉', '멀티탭', 'USB포트', '세계', '작동', '가방', '동시', '호주', '버튼', '돼지코', '공간', '보조배터리', '국내', '선', '노트북', '상태', '코드', '유에스비', '현지', '폰', '충전기', '플러그'}
#
#
# Cluster color C1: ['subset_파우치', 'subset_케이스', 'subset_디자인']
# 결과 속성은 아래와 같습니다.
# {'색상', '고급', '파우치', '색', '콤팩트', '케이스', '실용', '크기', '휴대', '색깔', '디자인', '캐리어', '사은품', '기능', '성능', '가방', '작동', '충전', '마감'}
#
#
# Cluster color C2: ['subset_충전기', 'subset_C타입']
# 결과 속성은 아래와 같습니다.
# {'돼지코', '단자', '핸드폰', 'C타입', '선', '고속충전', '속도', '타입', '연결', '유에스비', '해결', '멀티어댑터', '일본', 'A타입', '멀티탭', '짐', 'USB포트', '포트', '해외여행', '충전', '케이블', '콘센트', '충전기'}

# %%
cluster_dict
# Out:
# {'C0': ['subset_고속충전', 'subset_콘센트', 'subset_충전', 'subset_포트', 'subset_멀티탭'],
#  'C1': ['subset_파우치', 'subset_케이스', 'subset_디자인'],
#  'C2': ['subset_충전기', 'subset_C타입']}

# %%
unique_colors
# Out:
# array(['C0', 'C1', 'C2'], dtype='<U2')

# %%
result_cluster = pd.DataFrame([(k,v) for k, vs in cluster_dict.items() for v in vs], columns=['cluster','set_list'])
result_cluster = result_cluster.groupby('cluster').apply(lambda x : x.assign(set_list=[cluster_dict[x.name]]*len(x))).reset_index(drop=True).drop_duplicates(['cluster'])
result_cluster['subword'] = result_cluster['set_list'].apply(subword_total)
result_cluster
# Out:
#   cluster                                           set_list  \
# 0      C0  [subset_고속충전, subset_콘센트, subset_충전, subset_포트...
# 5      C1               [subset_파우치, subset_케이스, subset_디자인]
# 8      C2                           [subset_충전기, subset_C타입]
#
#                                              subword
# 0  {불편, 안정, 단자, 동작, 핸드폰, 고속, 미국, 전원, 고속충전, 안심, 고정...
# 5  {색상, 고급, 파우치, 색, 콤팩트, 케이스, 실용, 크기, 휴대, 색깔, 디자인...
# 8  {돼지코, 단자, 핸드폰, C타입, 선, 고속충전, 속도, 타입, 연결, 유에스비,...

# %% [markdown]
# ### BERT / KeyBERT 실험 진행

# %% [markdown]
# BERT

# %%
import torch
from transformers import BertTokenizer, BertModel
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import precision_recall_fscore_support, accuracy_score

# BERT 모델 및 토크나이저
model_name = 'bert-base-multilingual-cased'
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertModel.from_pretrained(model_name)

# %%
# review 데이터 하나의 Text로 저장
doc_review = ' '.join(product['add_rule_based_split_review'].to_list())
doc_review
# Out:
# '금액 차이 얼마 안 나는데 기능은 더 좋아요 콤팩트한 디자인과 실용성에 높은 점수 주었습니다 전면 스크래치가 많아서 아쉽네요 말 그대로 멀티어댑터에요 해외여행 필수 탬 작아서 휴대도 굿굿 빠른 배송 좋은 품질 감사합니다 USB형 후기 보고 안될까 봐 USB형이 사용하기가 훨씬 편해서 좋았어요 나라마다 전압이 틀려서 그런지 충전이 잘 되는 나라도 있고 느리게 충전되는 경우도 있고 충전 코드가 헐거워 불편한 호텔도 있어서 파우치 같은 걸로 밑에 받쳐 사용하심 될 거 같아요  호환되는 나라가 많아서 좋아요 유용하게 사용하고 있어요 사용하기에 큰 불편은 없으며 마감이 조금 아쉬우나 싼 맛에 써요 근데 하나는 바로 망가졌어요 유럽여행으로 많이 구매했는데 유럽은 우리나라 220보다 얇아요 USB 단자가 있어 유용할 듯 불량 없이 잘 사용되면 좋겠어요 USB형 저렴하게 잘 샀습니다 문제없길 바라요 성능 대비 가격이 무지 착하네요  물건도 꼼꼼하게 잘 왔어요 멀티콘센트 요긴하게 잘 쓸게요 필요한 기능만 있어서 좋았어요 일반형 1 USB형 1개 이렇게 구매하니 둘이 여행하기 딱 좋음 여러 가지 겸용이어서 두고두고 쓸 것 같아요 USB 충전은 좀 느리 편입니다 2개는 괜찮아요 유럽 가서 쓰려고 샀는데 본체가 무거워서 콘센트에 꽂아도 자꾸 기울어 빠집니다 결과적으로 전혀 못 쓰고 왔어요 내구성 편리성 모두 만족스럽습니다 한국 가서 왕창 사서 가지고 와서 써야겠네요 포트 있는 게 더 좋을 거 같아서 구매했어요 110볼트로 여행을 가게 되어 구매했습니다 몇 개 있지만 USB 있는 제품이라 추가 구매했어요 불량 있을까 봐 하나 더 구매했어요 포트가 많아서 활용도도 좋고 작동 잘하네요 제품 만족하고 사용 중입니다 제품에 문제 있는 거 아니니까 과감하게 사용하시길 이거 너무 불편합니다 고정이 안되어서 무용지물이었네요 ㅠㅠ 하나로 모두 해결되니 편리하고 가성비도 좋습니다 2개 주문했는데 하나가 불량이 왔습니다 그래도 하나는 정상이라 다행이네요 두 가지 다른 플러그 보내주셨어요 품질 좋습니다 보관 파우치와 함께 오고 USB 연결까지 하면 3개나 연결이 가능해서 편했어요 고장이 잘 날 거 같아서 2개 주문했었는데 하나만 주문해도 될듯했네요 콘센트에 딱 맞게 끼워지는 느낌은 아니긴 했는데 그래도 그럭저럭 사용엔 지장 없긴 했습니다 너무 만족하면서 사용 중이에요  꼭 구매하세요 코드를 꽂아보니 괜찮은 것 같아요 이외에 멀티로 사용할 수 있는 부분은 좋습니다 새 제품이라 그런 것 같아요 USB가 잘 꽂히고 콘센트도 락언락이 정상 동작함 국내 용이 아니라 기능 확인은 안되지만 국가별 콘센트는 잘 나오고 들어가네요 저렴한 가격에 많은 기능 만족합니다 흠 뭐가 안돼가지고 못썼네요 여행 시 꼭 필요한 물건 잘 구매했습니다 EU타입으로 집 콘센트에 넣어봤을 때 전원은 잘 들어오나 고정이 안됩니다 ㅠ EU타입으로 집 콘센트에 넣어봤을 때 전원은 들어오나 고정이 안됩니다 ㅠ 아주 만족스럽게 사용하고 있습니다 여러나라의 플러그 모양을 갖춰서 좋아요 한 번에 여러개 사서 지인들 나눠졌습니다 품질이 조금만 더 좋았으면 좋겠네요 버튼 누르는데 들어가고 안 들어가는 부분이 많네요 유럽여행 가서 어댑터 구입했는데 모든 국가에서 쓸 수 있어서 너무 편리하고 가격도 저렴해서 구매했어요 여행 가서 쓸 제품인데 퀄리티도 아주 좋네요 아직 사용 전이지만 작고 파우치가 있어서 휴대하기 편할 것 같아요 이번 대만 여행 때 가져갔는데 USB 충전 타입도 있어서 너무 좋았어요 충전도 잘 되고 좋아요 저번 일본 여행 때 싼 맛이 돼지코 챙겨갔다가 연결 제대로 안돼서 눈물 났는데요 이거랑 멀티탭 맘 있으면 걱정할 필요 업어요 하나로 C타입까지 충전할 수 있어서 좋았습니다 기존에 쓰던 돼지코가 아쉬워서 새로 구매했습니다  특히나 C타입 꽂는 부분도 있어서 너무 좋네요 별도 충전기 없이 케이블만 챙겨가서 짐도 줄었네요 긁히면 자국이 남고 마감이 살짝 아쉽네요 하나 쟁여놓으면 계속 쓸듯 굿 저도 대만 가서 고속충전으로 잘 썼고 동생도 미국 출장 중에 잘 쓰고 있다고 연락 왔어요 일단 가볍고 전용 파우치에 넣으니까 보관에 용이하고 캐리어에 가지고 다니기 좋아요 그리고 유선 줄 꼽는 칸이 많아서 한 번에 충전을 많이 할 수 있는 장점이 있어요 상품 품질 및 마감 등 실물이 더 좋네요 감비 앤코 여행용 멀티어댑터 해외여행 타입이 다양하게 있어서 오래오래 다양하게 쓸 수 있을 거 같아요 휴대성도 편리해요 동일 스펙 멀티어댑터 중 디자인이 가장 예뻐요 파우치도 있고 충전 속도도 빨라 여행 가서 잘 썼어요 하나로 여러 기능을 쓸 수 있어서 편리하네요 USB 타입과 C타입 모두 있어서 너무 유용했어요 번거로운 멀티탭 대신 여행 필수 탬 강추 물건이 견고하고 사진과 같이 좋습니다 이게 USB 타입 C타입이 가능해서 사게 되었는데 솔직히 가격 빼면 좋은 거 같습니다 A타입이랑 C타입이 적절하게 있어서 유용하게 사용했어요 매우 만족하고 사용하고 있어요  와이파이 도시락  핸드폰  보조배터리 등등 한 번에 충전할 수 있어서 너무 좋았어요 핸드폰은 충전 속도도 고속충전이라서 정말 잘 사용했네요 무엇보다 다 충전기보다 간지가 나서 좋았고  깔끔한 디자인에 묵직함도 한몫했다고 생각합니다 여행 갈 때 가지고 가기 좋네요 파우치까지 있어서 보관도 좋고요 케이스가 있어서 휴대하기 좋아서 어느 여행이나 꼭 챙겨서 잘 사용할 수 있을 것 같습니다  퀄리티 정말 좋아요 파우치도 줘서 좋아요 한 달 구매평 남기겠습니다 휴대 편하고 일본에서 불편함이 업이 잘 사용했습니다 별점을 하나 뺀 이유는 전기제품 배송인데 뽁뽁이도 없이 그냥 왔기 때문입니다 케이스 주신 것은 정말 감사하지만  케이스 안에도 쿠션은 없고  박스에 던지지 마시오 같은 스티커도 없이 왔어요 출국 전에 물건을 테스트해보고 싶은데 한국의 콘센트 구멍이랑 크기나 모양이 달라서 섣불리 꽂아봐도 될지 모르겠네요 튼튼하고 멀티어댑터로 사용할 수 있다는 점이 너무 좋아요 케이스도 맘에 듭니다 열심히 충전한 덕분에 이런 멋진 사진도 찍을 수 있었네요 내일 가는데 다행히 오늘 받았어요 망가짐 없이 여행 다녀오는 동안 너무 편하게 잘 사용했고 일단 다시 보관할 수 있는 파우치 있는 게 제일 좋아요 깔끔한 디자인에 파우치까지 있어 마음에 들어요 아직 여행 전이라 성능은 잘 모르겠지만 잘 되리라 믿어요 이 기능을 다 쓸 수 있게 다양한 나라를 여행하고 싶네요  오히려 여분으로 챙겨간 돼지코가 없었으면 큰일 날 정도로 이 어댑터가 작동을 인하더라고요 ㅠㅠ 이번 유럽여행 시 가장 탁월하게 이용한 제품 중 하나입니다 콘센트에서 안 빠지고 좋더라고요 외국 나가서 쓰기 너무 편할 것 같아요 10년 써도 고장 안 날 거 같아요 신행 준비로 샀는데 어댑터가 잘 됐으면 좋겠어요 여러개 한 번에 충전할 수 있어서 좋아요 유럽 여행 갈 때 쓰려고 샀는데 흰색이라 이쁘고 작고 케이스도 있어서 너무 좋아요 리뷰 보고 구매했는데 디자인도 맘에 들고 좋아요 파우치 있으니 좋아요 자리 차지도 많이 안 하고 충전도 잘 돼요 여행 갈 일이 있어서 샀는데 단단하고 파우치까지 있어서 좋아요 일본 여행 때 요고 하나로 해결했어요 C타입 고속충전 너무 맘에 들어요 파우치에 넣을 수 있어서 좋아요 USB포트도 3개나 되고 만족합니다 잘 작동하고 같이 주신 케이스도 너무 고급스러워요 사실 동유럽이라 필요는 없었지만 보조배터리 충전으로 잘 사용함 파우치 줘서 좋아요 하나로 여러나라에서 사용할 수 있어서 좋은 거 같아요 부모님 여행 가실 때 쓰시라고 사드렸는데 성능이 좋으면 좋겠어요 여러개 연결할 수 있어서 좋았어요 케이스까지 있어서 깔끔하고 보관도 용이합니다 예전보다 훨씬 간편해지고 이것만 구매하면 세계 어디든 사용할 수 있어요 돼지코는 따로 준비해야 하는 듯 요 돼지코 없었음 파우치에 넣어서 갖고 다니니 안심이 됐고  같이 여행 간 언니 어댑터는 저렴한 제품으로 구매했다고 했는데 타는 냄새가 나더라고요 미국 출장차 급하게 구입했는데 파우치도 마음에 들고 다른 후기들과 달리 품질 문제 전혀 없이 잘 사용 중입니다 생각보다 묵직한 게 내 구정이 좋아 보이네요 C타입과 USB 같이 있는 게 좋네요 이거 하나로 끝날듯해요 튼튼한 내구성을 가져 안정 ...

# %%
stopwords_path = "C:/Users/songy/Desktop/Data/stopwords-ko.txt"
with open(stopwords_path, encoding='utf-8') as file:
    stopwords = file.read().splitlines()

stopwords.extend(additional_stopwords)
print(stopwords)
# Out:
# ['!', '"', '$', '%', '&', "'", '(', ')', '*', '+', ',', '-', '.', '...', ';', '<', '=', '>', '?', '@', '\\', '^', '_', '`', '|', '~', '·', '—', '——', '‘', '’', '“', '”', '…', '、', '。', '〈', '〉', '《', '》', '가', '가까스로', '가령', '각', '각각', '각자', '각종', '갖고말하자면', '같다', '같이', '개의치않고', '거니와', '거바', '거의', '것', '것과 같이', '것들', '게다가', '게우다', '겨우', '견지에서', '결과에 이르다', '결국', '결론을 낼 수 있다', '겸사겸사', '고려하면', '고로', '곧', '공동으로', '과', '과연', '관계가 있다', '관계없이', '관련이 있다', '관하여', '관한', '관해서는', '구', '구체적으로', '구토하다', '그', '그들', '그때', '그래', '그래도', '그래서', '그러나', '그러니', '그러니까', '그러면', '그러므로', '그러한즉', '그런 까닭에', '그런데', '그런즉', '그럼', '그럼에도 불구하고', '그렇게 함으로써', '그렇지', '그렇지 않다면', '그렇지 않으면', '그렇지만', '그렇지않으면', '그리고', '그리하여', '그만이다', '그에 따르는', '그위에', '그저', '그중에서', '그치지 않다', '근거로', '근거하여', '기대여', '기점으로', '기준으로', '기타', '까닭으로', '까악', '까지', '까지 미치다', '까지도', '꽈당', '끙끙', '끼익', '나', '나머지는', '남들', '남짓', '너', '너희', '너희들', '네', '넷', '년', '논하지 않다', '놀라다', '누가 알겠는가', '누구', '다른', '다른 방면으로', '다만', '다섯', '다소', '다수', '다시 말하자면', '다시말하면', '다음', '다음에', '다음으로', '단지', '답다', '당신', '당장', '대로 하다', '대하면', '대하여', '대해 말하자면', '대해서', '댕그', '더구나', '더군다나', '더라도', '더불어', '더욱더', '더욱이는', '도달하다', '도착하다', '동시에', '동안', '된바에야', '된이상', '두번째로', '둘', '둥둥', '뒤따라', '뒤이어', '든간에', '들', '등', '등등', '딩동', '따라', '따라서', '따위', '따지지 않다', '딱', '때', '때가 되어', '때문에', '또', '또한', '뚝뚝', '라 해도', '령', '로', '로 인하여', '로부터', '로써', '륙', '를', '마음대로', '마저', '마저도', '마치', '막론하고', '만 못하다', '만약', '만약에', '만은 아니다', '만이 아니다', '만일', '만큼', '말하자면', '말할것도 없고', '매', '매번', '메쓰겁다', '몇', '모', '모두', '무렵', '무릎쓰고', '무슨', '무엇', '무엇때문에', '물론', '및', '바꾸어말하면', '바꾸어말하자면', '바꾸어서 말하면', '바꾸어서 한다면', '바꿔 말하면', '바로', '바와같이', '밖에 안된다', '반대로', '반대로 말하자면', '반드시', '버금', '보는데서', '보다더', '보드득', '본대로', '봐', '봐라', '부류의 사람들', '부터', '불구하고', '불문하고', '붕붕', '비걱거리다', '비교적', '비길수 없다', '비로소', '비록', '비슷하다', '비추어 보아', '비하면', '뿐만 아니라', '뿐만아니라', '뿐이다', '삐걱', '삐걱거리다', '사', '삼', '상대적으로 말하자면', '생각한대로', '설령', '설마', '설사', '셋', '소생', '소인', '솨', '쉿', '습니까', '습니다', '시각', '시간', '시작하여', '시초에', '시키다', '실로', '심지어', '아', '아니', '아니나다를가', '아니라면', '아니면', '아니었다면', '아래윗', '아무거나', '아무도', '아야', '아울러', '아이', '아이고', '아이구', '아이야', '아이쿠', '아하', '아홉', '안 그러면', '않기 위하여', '않기 위해서', '알 수 있다', '알았어', '앗', '앞에서', '앞의것', '야', '약간', '양자', '어', '어기여차', '어느', '어느 년도', '어느것', '어느곳', '어느때', '어느쪽', '어느해', '어디', '어때', '어떠한', '어떤', '어떤것', '어떤것들', '어떻게', '어떻해', '어이', '어째서', '어쨋든', '어쩔수 없다', '어찌', '어찌됏든', '어찌됏어', '어찌하든지', '어찌하여', '언제', '언젠가', '얼마', '얼마 안 되는 것', '얼마간', '얼마나', '얼마든지', '얼마만큼', '얼마큼', '엉엉', '에', '에 가서', '에 달려 있다', '에 대해', '에 있다', '에 한하다', '에게', '에서', '여', '여기', '여덟', '여러분', '여보시오', '여부', '여섯', '여전히', '여차', '연관되다', '연이서', '영', '영차', '옆사람', '예', '예를 들면', '예를 들자면', '예컨대', '예하면', '오', '오로지', '오르다', '오자마자', '오직', '오호', '오히려', '와', '와 같은 사람들', '와르르', '와아', '왜', '왜냐하면', '외에도', '요만큼', '요만한 것', '요만한걸', '요컨대', '우르르', '우리', '우리들', '우선', '우에 종합한것과같이', '운운', '월', '위에서 서술한바와같이', '위하여', '위해서', '윙윙', '육', '으로', '으로 인하여', '으로서', '으로써', '을', '응', '응당', '의', '의거하여', '의지하여', '의해', '의해되다', '의해서', '이', '이 되다', '이 때문에', '이 밖에', '이 외에', '이 정도의', '이것', '이곳', '이때', '이라면', '이래', '이러이러하다', '이러한', '이런', '이럴정도로', '이렇게 많은 것', '이렇게되면', '이렇게말하자면', '이렇구나', '이로 인하여', '이르기까지', '이리하여', '이만큼', '이번', '이봐', '이상', '이어서', '이었다', '이와 같다', '이와 같은', '이와 반대로', '이와같다면', '이외에도', '이용하여', '이유만으로', '이젠', '이지만', '이쪽', '이천구', '이천육', '이천칠', '이천팔', '인 듯하다', '인젠', '일', '일것이다', '일곱', '일단', '일때', '일반적으로', '일지라도', '임에 틀림없다', '입각하여', '입장에서', '잇따라', '있다', '자', '자기', '자기집', '자마자', '자신', '잠깐', '잠시', '저', '저것', '저것만큼', '저기', '저쪽', '저희', '전부', '전자', '전후', '점에서 보아', '정도에 이르다', '제', '제각기', '제외하고', '조금', '조차', '조차도', '졸졸', '좀', '좋아', '좍좍', '주룩주룩', '주저하지 않고', '줄은 몰랏다', '줄은모른다', '중에서', '중의하나', '즈음하여', '즉', '즉시', '지든지', '지만', '지말고', '진짜로', '쪽으로', '차라리', '참', '참나', '첫번째로', '쳇', '총적으로', '총적으로 말하면', '총적으로 보면', '칠', '콸콸', '쾅쾅', '쿵', '타다', '타인', '탕탕', '토하다', '통하여', '툭', '퉤', '틈타', '팍', '팔', '퍽', '펄렁', '하', '하게될것이다', '하게하다', '하겠는가', '하고 있다', '하고있었다', '하곤하였다', '하구나', '하기 때문에', '하기 위하여', '하기는한데', '하기만 하면', '하기보다는', '하기에', '하나', '하느니', '하는 김에', '하는 편이 낫다', '하는것도', '하는것만 못하다', '하는것이 낫다', '하는 ...

# %%
def get_embedding(text, tokenizer, model):
  inputs = tokenizer(text, return_tensors='pt', padding=True, truncation=True)
  outputs = model(**inputs)
  embedding = outputs.last_hidden_state
  return embedding, inputs

def extract_keywords(text, tokenizer, model, top_n=5):
  # 텍스트에서 명사 추출
  nouns = [word for word in m.nouns(text) if word not in stopwords]
  if len(nouns)==0:
    return []

  # BERT 임베딩 생성
  embedding, inputs = get_embedding(text, tokenizer, model)
  token_embeddings = embedding[0]    # (sequence_length, hidden_size)
  cls_embedding = token_embeddings[0] # [CLS] 토큰 임베딩

  # 토큰 중요도 계산 ([CLS] 토큰과 코사인 유사도)
  token_importance = cosine_similarity(cls_embedding.detach().numpy().reshape(1,-1),
                                       token_embeddings.detach().numpy())

  # 토큰과 중요도 매핑
  tokens = tokenizer.convert_ids_to_tokens(inputs['input_ids'][0])
  token_scores = list(zip(tokens, token_importance))

  # 상위 N개 키워드 추출
  token_scores = sorted(token_scores, key=lambda x: x[1], reverse=True)
  keywords = [token for token, score in token_scores if token not in ['[CLS]', '[SEP]']][:top_n]

  # 명사만 추출된 키워드 리스트
  keywords = [word for word in keywords if word in nouns]

  return keywords

# %%
extract_keywords(doc_review, tokenizer, model, top_n=5)
# Out:
# []

# %% [markdown]
# KeyBERT

# %%
#!pip install keybert

# %%
from keybert import KeyBERT

# 경량화된 모델로 빠른 연산 속도
kw_model = KeyBERT(model='sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2')

# distilBERT 기반 더 작은 사이즈의 경량화 모델
kw_distil_model = KeyBERT(model='sentence-transformers/distilbert-base-nli-mean-tokens')

# 다국어 지원 모델
kw_multi_model = KeyBERT(model='sentence-transformers/xlm-r-bert-base-nli-stsb-mean-tokens')

# RoBERTa 기반 문장 임제딩 모델
kw_roberta_model = KeyBERT(model='sentence-transformers/roberta-base-nli-stsb-mean-tokens')

# %%
def keybert_extract_keyword(text, model, top_n=5):
  keywords = model.extract_keywords(text, keyphrase_ngram_range=(1,1), stop_words=stopwords, top_n=top_n)
  return [keyword for keyword, score in keywords]

# %%
def exract_nouns(text, stopwords):
  nouns = [word for word in m.nouns(text) if word not in stopwords]
  return ' '.join(nouns)

# %%
# 명사만 추출 
#noun_text = compiled_morphs_noun(doc_review, stopwords_path, additional_stopwords)
noun_text = exract_nouns(doc_review, stopwords)

# %%
noun_text
# Out:
# '기능 콤팩트 디자인 실용 전면 스크래치 멀티어댑터 해외여행 휴대 품질 USB형 전압 충전 충전 충전 코드 불편 파우치 걸로 호환 불편 마감 유럽 유럽 단자 듯 불량 USB형 성능 콘센트 기능 일반형 USB형 가지 겸용 충전 편 유럽 본체 콘센트 내 포트 볼트 추가 불량 포트 작동 중 불편 고정 무용지물 해결 불량 정상 가지 플러그 품질 파우치 연결 연결 고장 듯 콘센트 지장 중 코드 콘센트 정상 동작 국내 기능 국가 콘센트 기능 뭐 타입 콘센트 전원 고정 EU타입 콘센트 전원 고정 여러나라 플러그 모양 품질 버튼 데 유럽 국가 퀄리티 파우치 휴대 대만 충전 타입 충전 일본 돼지코 연결 멀티탭 C타입 충전 돼지코 C타입 충전기 케이블 짐 자국 마감 듯 대만 고속충전 미국 중 파우치 캐리어 유선 줄 칸 충전 장점 상품 품질 마감 실물 앤 여행용 멀티어댑터 해외여행 타입 휴대 멀티어댑터 중 디자인 파우치 충전 속도 기능 타입 C타입 멀티탭 이게 타입 타입 A타입 C타입 와이파이 도시락 핸드폰 보조배터리 충전 핸드폰 충전 속도 고속충전 충전기 디자인 한몫 파우치 케이스 휴대 퀄리티 파우치 휴대 일본 불편 전기 때문 케이스 케이스 쿠션 콘센트 구멍 크기 모양 멀티어댑터 케이스 충전 파우치 디자인 파우치 성능 기능 돼지코 작동 유럽 중 콘센트 외국 고장 충전 유럽 흰색 케이스 디자인 파우치 자리 충전 파우치 일본 요고 해결 C타입 고속충전 파우치 USB포트 작동 케이스 고급 동유럽 보조배터리 충전 파우치 여러나라 부모 가실 성능 연결 케이스 세계 돼지코 듯 돼지코 파우치 안심 냄새 미국 파우치 품질 중 내 C타입 듯 내구 안정 사은품 파우치 이동 파손 우려 PD충전 C타입 충전 USB포트 충전기 실용 파우치 USB포트 C타입 작동 지역 구성품 멀티탭 일본 핸드폰 보조배터리 보조배터리 충전 충전 유선 줄 멀티탭 국가 무게 휴대 파우치 휴대 속 멀티탭 충전 케이블 충전기 무게 때문 C타입 케이블 건 무게 충전 C타입 타입 방면 실용 110V 구멍 여행지 고데기 렴 돼지코 파우치 멀티탭 고데기 연결 건 돼지코 그것 여러나라 220V C타입 케이스 성능 무게 사이즈 커버 디자인 케이스 디자인 케이스 듯 케이스 가지 USB포트 핸드폰 충전 속도 핸드폰 충전 USB포트 디자인 돼지코 고장 케이스 품질 케이스 디자인 콘센트 대박 상품 충전 핸드폰 충전 멀티탭 연결 해외여행 영국 C타입 견고 얘 건지 내 콘센트 건지 콘센트 충전 색 줄 케이스 케이스 케이스 충전 선 충전 해외여행 퓨즈 퓨즈 퓨즈 작동 파우치 케이스 사은품 케이스 내 충전 파우치 케이스 해외여행 국내 불량 단점 불량 충전 충전 속도 워치 핸드폰 보조배터리 충전 충전 포트 고데기 고데기 볼트 애플워치 보조배터리 충전 데 케이스 품질 중국 타입 충전 멀티탭 기기 충전 C타입 분 외국 일본 고장 충전 뭔가 개선 110V 충전 입구 220V 깊이 일본 입구 안쪽 개선 마감 분 아이디어 실용 정리 이게 구조 휴대 국내 외 평소 선 누가 파우치 미국 손상 국내외 케이스 사용법 부담 크기 파우치 여러나라 C타입 케이블 케이블 만능 기업 데이트 파우치 뭘 충 사이즈 타입 케이 걸 후회 일본 견고 해외여행 충전기 C타입 케이블 포트 선 동시충전 파우치 무게 세계 유럽 콘센트 케이스 휴대 앤 여행용 멀티어댑터 해외여행 콘센트 변환기 뿐 돼지코 기능 기기 동시 충전 PD C타입 안정 충전 앤 여행용 멀티어댑터 중 중 계속 멀티어댑터 미국 멀티탭 멀티탭 기기 무리 가지 해외여행 저거 대만 케이스 유럽 핸드폰 보조배터리 충전 가방 건 충전 파우치 세계 일본 가방 휴대 일본 퓨즈 퓨즈 걸 유에스비 포트 타입 포트 동시 충전 일본 충전 나름 디자인 콘센트 분 돼지코 해결 파우치 멀티탭 중 디자인 케이스 케이스 디자인 대만 전기포트 케이스 장점 케이스 케이스 충전 대로 대 충전 여러나라 호환 케이스 본체 불안감 연결 충전 케이스 콤팩트 품질 마감 안전 충전 연결 실용 케이스 케이스 다이슨 각도 각도 조절 돼지코 고속충전 케이스 케이스 해외여행 일본 이게 케이스 콘센트 C타입 단자 유에스비 단자 멀티어댑터 불편 콘센트 C타입 충전 파우치 내 휴대 충전 멀티어댑터 무게 콘센트 불편 유럽 인증 지역 커버 일본 기기 충전 전일 저녁 짐 일본 돼지코 이걸로 세계 한국인 고속충전 고속충전 아이폰 대 갤럭시 대 대 연결 충전 대만 110V 전기 충전 충전 C타입 케이스 케이스 고급 드라이기 C타입 충전 파우치 동시 충전 220V 코드 내구 국가 충전 선 파우치 디자인 컬러 고급 휴대 해외여행 멀티어댑터 포트 연결 잭 해결 듯 국가 해당 옵션 설명서 파우치 발리 신혼 다이슨 다이슨 베개 고생 뻔 의자 뻔 의자 가이드 사람 대박 C타입 동시 짐 가격대 퀄리티 장점 빛 디자인 케이스 입 개꿀 멀티탭 충전 편 멀티탭 충전 핸드폰 충전 워치 충전 드라이기 충전 파우치 파우치 실용 퓨즈 충전 케이블 명 충전 갤럭시 폰 고속충전 충전 연결 불안 일본 충전 불편 색상 흰색 그레이 포트 C타입 충전 케이스 충전 호환 불편 케이스 케이스 해외여행 C타입 최근 콘센트 자리 타입 국내 멀티탭 실용 멀티탭 연결 명 핸드폰 충전 품질 고급 케이스 콘센트 일본 명 상품 누가 충전 충전 케이스 충전 하와이 다이슨 건지 파우치 대만 태국 최고 효율 소지품 중 고속충전 짱 충전 건 접촉 불량 블로그 돼지코 동시 충전 충전 구성품 본품 설명서 파우치 비교 가격대 콘센트 현상 C타입 디자인 여러 케이블 일반 일본 배터리 충전 볼트 건지 고속충전 테두리 쪽 노란색 교환 멀티탭 대용 사이즈 랩 고장 견고 타입 충전 무게 크기 케이스 고급 베개 센스 해결 미니 고데기 그거 듯 중 케이스 디자인 파우치 견고 심플 충전 콘센트 파우치 포트 케이스 콘센트 충전 동시 충전 최대 충전 시도 미국 디자인 마트 크기 충전기 전기포트 방문 전기포트 불안 파우치 외 충전 멀티탭 220V 코드 충전 포트 뭔가 휴대 유럽 파우치 마감 C타입 포트 C타입 포트 충전 35W 최대 유럽 충전 핸드폰 수신기 충전 내 디자인 C타입 편지 사은품 호주 핸드폰 충전 USB포트 C타입 A타입 케이스 정리 듯 뭔가 핸드폰 워치 충전 간편 충전 속도 감동 케이스 재송 케이스 견고 충전 이것저것 완성도 충전 해외여행 땐 전기 코드 타입 녀석 핸드폰 충전 충전 멀티탭 충전기 불편 핸드폰 보조배터리 동시충전 손 편지 박싱 기분 케이스 디자인 파우치 코드 체결 충전 디자인 충전 포트 충전 파우치 크기 포스트잇 데 내구 의견 무게 타입 군데 최대 충전기 퓨즈 파우치 밤새 충전 유럽 충전 선 충전 홍콩 계획 콘센트 멀티어댑터 필리핀 요기 충전 보조배터리 충전 부족 국가 해외여행 배터리 정성 메모 구성품 콘센트 작동 동시 충전 속도 손 편지 감동 추가 구성품 파우치 선 정리 꽈배기 무게 콤팩트 사이즈 미국 유럽 국가 콘센트 지팅스 문자 물품 정리 줄 토요일 연결 포기 헤어 드라이기 데 바람 전압 케이스 가지 호환 충전 충전 속도 가지 기능 세 충전 고속충전 케이스 손 편지 정성 파우치 USB포트 파우치 품질 중 캐나다 멀티어댑터 파우치 변환 손 디자인 기능 사은품 쪽지 기분 케이스 건 줄 뭐 불량 불량 인증 영상 케이스 소형 세계 기기 케이스 전기 전기 상세 설명 전기 질문 설명 손 쪽지 동 케이스 멀티어댑터 메모 사은품 파우치 방법 참고 정성 손 편지 감동 구멍 고정 파우치 서유럽 방법 전화 설명 핸드폰 전기 충전 해결 포스트잇 충전기 짐 충전기 초고속 일본 충전 요건 충전 충전기 선 충전 첨 콘센트 깜놀 멀티탭 걸로 C타입 크기 휴대 USB포트 C타입 포트 고속충전 포트 용량 내장 퓨즈 퓨즈 체결 안전 성능 급속 충전 양호 파우치 C타입 개수 데 멀티탭 국내 돼지코 포트 충전기 디자인 케이스 소 조 충전 중 그거 가지 콘센트 타입 중국 파우치 퓨즈 이걸로 결정 퓨즈 적 고생 노트북 포트 코드 퓨즈 식 설명 꽈배기 모양 전기포트 케이스 고급 C타입 충전 케이스 휴대 유에스비 기본 충전기 충전 속도 선 케이스 호주 일본 고속충전 콘센트 가방 부피 수화물 무게 식구 동시 핸드폰 충전 보리 전기 사이즈 반품 코드 케이스 충전 마감 파우치 타입 일본 콘센트 중 세로 콘센트 충전 기능 볼트 볼트 변환 기능 충전 여러나 ...

# %%
# 키워드 추출
keybert_result = keybert_extract_keyword(noun_text, kw_model, top_n=5)
print(f'keybert (경량화)         result : {keybert_result}')
# Out:
# keybert (경량화)         result : ['충전기', '전기포트', '전기장판', '배터리', '트랜지스터']

# %%
keybert_result_doc_list = kw_model.extract_keywords(noun_text,top_n=30)
keybert_df = pd.DataFrame(keybert_result_doc_list, columns=['keyword','score'])
keybert_df
# Out:
#    keyword   score
# 0      충전기  0.6269
# 1     전기포트  0.5117
# 2     전기장판  0.5029
# 3      배터리  0.5004
# 4    트랜지스터  0.4854
# 5      케이블  0.4748
# 6      충전핀  0.4528
# 7    멀티어댑터  0.4449
# 8       충전  0.4238
# 9       장치  0.4032
# 10   pd45w  0.3684
# 11     커넥터  0.3632
# 12    전자제품  0.3571
# 13      전기  0.3540
# 14     태블릿  0.3405
# 15      무선  0.3305
# 16    와이파이  0.3287
# 17      포트  0.3254
# 18   pd35w  0.3234
# 19    가전제품  0.3224
# 20    안전장치  0.3162
# 21      기기  0.3089
# 22     연결선  0.2903
# 23     휴대용  0.2797
# 24      장비  0.2795
# 25   usb포트  0.2782
# 26      설계  0.2770
# 27     포트만  0.2751
# 28      용품  0.2672
# 29      펌프  0.2672

# %%
keybert_distil_result = keybert_extract_keyword(noun_text, kw_distil_model, top_n=5)
print(f'keybert (distil-based)   result : {keybert_distil_result}')
# Out:
# keybert (distil-based)   result : ['코타키나발루', '멀티어댑터', '연보라색', '전기포트', '가전제품']

# %%
keybert_multi_result = keybert_extract_keyword(noun_text, kw_multi_model, top_n=5)
print(f'keybert (multi language) result : {keybert_multi_result}')
# Out:
# keybert (multi language) result : ['코리아', 'usb포트', '국내', '멀티어댑터', '조작']

# %%
keybert_roberta_result = keybert_extract_keyword(noun_text, kw_roberta_model, top_n=5)
print(f'keybert (roberta-based)  result : {keybert_roberta_result}')
# Out:
# keybert (roberta-based)  result : ['게스트', '트랜지스터', '스마트폰', '코타키나발루', '포스트잇']

# %%
#### top10로 재확인
keybert_result_10 = keybert_extract_keyword(noun_text, kw_model, top_n=10)
print(f'keybert (경량화)         result : {keybert_result_10}')

keybert_distil_result_10 = keybert_extract_keyword(noun_text, kw_distil_model, top_n=10)
print(f'keybert (distil-based)   result : {keybert_distil_result_10}')

keybert_multi_result_10 = keybert_extract_keyword(noun_text, kw_multi_model, top_n=10)
print(f'keybert (multi language) result : {keybert_multi_result_10}')

keybert_roberta_result_10 = keybert_extract_keyword(noun_text, kw_roberta_model, top_n=10)
print(f'keybert (roberta-based)  result : {keybert_roberta_result_10}')
# Out:
# keybert (경량화)         result : ['충전기', '전기포트', '전기장판', '배터리', '트랜지스터', '케이블', '충전핀', '멀티어댑터', '충전', '장치']
# keybert (distil-based)   result : ['코타키나발루', '멀티어댑터', '연보라색', '전기포트', '가전제품', '트랜지스터', '전자제품', '전기장판', '접촉면', '뉴질랜드']
# keybert (multi language) result : ['코리아', 'usb포트', '국내', '멀티어댑터', '조작', '닌텐도', 'c타입', 'eu타입', '맥북', '무선']
# keybert (roberta-based)  result : ['게스트', '트랜지스터', '스마트폰', '코타키나발루', '포스트잇', '크로아티아', '해외여행', '전기장판', '전기포트', '콘택트']

# %%
keybert_distil_result_doc_list = kw_distil_model.extract_keywords(noun_text,top_n=30)
keybert_distil_df = pd.DataFrame(keybert_result_doc_list, columns=['keyword','score'])
keybert_distil_df
# Out:
#    keyword   score
# 0      충전기  0.6269
# 1     전기포트  0.5117
# 2     전기장판  0.5029
# 3      배터리  0.5004
# 4    트랜지스터  0.4854
# 5      케이블  0.4748
# 6      충전핀  0.4528
# 7    멀티어댑터  0.4449
# 8       충전  0.4238
# 9       장치  0.4032
# 10   pd45w  0.3684
# 11     커넥터  0.3632
# 12    전자제품  0.3571
# 13      전기  0.3540
# 14     태블릿  0.3405
# 15      무선  0.3305
# 16    와이파이  0.3287
# 17      포트  0.3254
# 18   pd35w  0.3234
# 19    가전제품  0.3224
# 20    안전장치  0.3162
# 21      기기  0.3089
# 22     연결선  0.2903
# 23     휴대용  0.2797
# 24      장비  0.2795
# 25   usb포트  0.2782
# 26      설계  0.2770
# 27     포트만  0.2751
# 28      용품  0.2672
# 29      펌프  0.2672

# %%
#### top30로 재확인
keybert_result_30 = keybert_extract_keyword(noun_text, kw_model, top_n=30)
print(f'keybert (경량화)         result : {keybert_result_30}')

keybert_distil_result_30 = keybert_extract_keyword(noun_text, kw_distil_model, top_n=30)
print(f'keybert (distil-based)   result : {keybert_distil_result_30}')

keybert_multi_result_30 = keybert_extract_keyword(noun_text, kw_multi_model, top_n=30)
print(f'keybert (multi language) result : {keybert_multi_result_30}')

keybert_roberta_result_30 = keybert_extract_keyword(noun_text, kw_roberta_model, top_n=30)
print(f'keybert (roberta-based)  result : {keybert_roberta_result_30}')
# Out:
# keybert (경량화)         result : ['충전기', '전기포트', '전기장판', '배터리', '트랜지스터', '케이블', '충전핀', '멀티어댑터', '충전', '장치', 'pd45w', '커넥터', '전자제품', '전기', '태블릿', '무선', '와이파이', '포트', 'pd35w', '가전제품', '안전장치', '기기', '연결선', '휴대용', '장비', 'usb포트', '설계', '포트만', '용품', '펌프']
# keybert (distil-based)   result : ['코타키나발루', '멀티어댑터', '연보라색', '전기포트', '가전제품', '트랜지스터', '전자제품', '전기장판', '접촉면', '뉴질랜드', '크로아티아', '오스트레일리아', '유니버설', '싱가포르', '스마트폰', '보조배터리', '콘셉트', '장바구니', '동시충전', '안전장치', '헤어드라이어', '변압기', '콤팩트', '고속충전', '만족도', '잠금장치', '산티아고', '말레이시아', '플라스틱', '디바이스']
# keybert (multi language) result : ['코리아', 'usb포트', '국내', '멀티어댑터', '조작', '닌텐도', 'c타입', 'eu타입', '맥북', '무선', '멀티탭', '에어팟', '요고', '반품', '코타키나발루', '샤오미', '연노랑', '산티아고', '오토리', 'a타입', '꽈배기', '보조배터리', '코시', '대용', 'pd충전', '외형', '배터리', '후쿠오카', '테두리', '한국인']
# keybert (roberta-based)  result : ['게스트', '트랜지스터', '스마트폰', '코타키나발루', '포스트잇', '크로아티아', '해외여행', '전기장판', '전기포트', '콘택트', '스마트', '콤팩트', '헤어드라이어', '콘셉트', '스트레스', '화이트로', '데이트', '가전제품', '클라우드', '커피포트', '오스트레일리아', '유튜브', '콘서트', '닌텐도', '멀티어댑터', '콘센트', '애틀랜타', '경향', '포트만', '선풍기']

# %%
keybert_multi_result_doc_list = kw_multi_model.extract_keywords(noun_text,top_n=30)
keybert_multi_df = pd.DataFrame(keybert_result_doc_list, columns=['keyword','score'])
keybert_multi_df
# Out:
#    keyword   score
# 0      충전기  0.6269
# 1     전기포트  0.5117
# 2     전기장판  0.5029
# 3      배터리  0.5004
# 4    트랜지스터  0.4854
# 5      케이블  0.4748
# 6      충전핀  0.4528
# 7    멀티어댑터  0.4449
# 8       충전  0.4238
# 9       장치  0.4032
# 10   pd45w  0.3684
# 11     커넥터  0.3632
# 12    전자제품  0.3571
# 13      전기  0.3540
# 14     태블릿  0.3405
# 15      무선  0.3305
# 16    와이파이  0.3287
# 17      포트  0.3254
# 18   pd35w  0.3234
# 19    가전제품  0.3224
# 20    안전장치  0.3162
# 21      기기  0.3089
# 22     연결선  0.2903
# 23     휴대용  0.2797
# 24      장비  0.2795
# 25   usb포트  0.2782
# 26      설계  0.2770
# 27     포트만  0.2751
# 28      용품  0.2672
# 29      펌프  0.2672

# %%
keybert_roberta_result_doc_list = kw_roberta_model.extract_keywords(noun_text,top_n=30)
keybert_roberta_df = pd.DataFrame(keybert_result_doc_list, columns=['keyword','score'])
keybert_roberta_df
# Out:
#    keyword   score
# 0      충전기  0.6269
# 1     전기포트  0.5117
# 2     전기장판  0.5029
# 3      배터리  0.5004
# 4    트랜지스터  0.4854
# 5      케이블  0.4748
# 6      충전핀  0.4528
# 7    멀티어댑터  0.4449
# 8       충전  0.4238
# 9       장치  0.4032
# 10   pd45w  0.3684
# 11     커넥터  0.3632
# 12    전자제품  0.3571
# 13      전기  0.3540
# 14     태블릿  0.3405
# 15      무선  0.3305
# 16    와이파이  0.3287
# 17      포트  0.3254
# 18   pd35w  0.3234
# 19    가전제품  0.3224
# 20    안전장치  0.3162
# 21      기기  0.3089
# 22     연결선  0.2903
# 23     휴대용  0.2797
# 24      장비  0.2795
# 25   usb포트  0.2782
# 26      설계  0.2770
# 27     포트만  0.2751
# 28      용품  0.2672
# 29      펌프  0.2672

# %% [markdown]
# ### 추가 분석

# %%
# intersection에 대표 속성 포함된 경우
append_keyword_df = df_sample[df_sample['word_percent']!=df_sample['word_percent_concated']]

# intersection에 대표 속성이 포함되지 않은 경우
not_appended_keyword_df = df_sample[df_sample['word_percent']==df_sample['word_percent_concated']]

# %%
append_keyword_df.head(3)
# Out:
#              Set Combination     Intersection  set_number  word_percent  \
# 14   (subset_충전, subset_어댑터)        [충전, 충전기]           2          9.99
# 19  (subset_충전, subset_고속충전)  [C타입, 고속충전, 포트]           2          6.09
# 20   (subset_충전, subset_멀티탭)        [충전, 충전기]           2          9.99
#
#    not_in_intersection   concated_word_list  word_percent_concated
# 14               [어댑터]       [충전, 충전기, 어댑터]                  12.73
# 19                [충전]  [C타입, 고속충전, 포트, 충전]                  14.89
# 20               [멀티탭]       [충전, 충전기, 멀티탭]                  11.30

# %%
len(append_keyword_df)
# Out:
# 22

# %%
sns.scatterplot(append_keyword_df, x='word_percent', y='word_percent_concated', hue='set_number')
# Out:
# <Axes: xlabel='word_percent', ylabel='word_percent_concated'>

# %%
sns.scatterplot(not_appended_keyword_df, x='word_percent', y='word_percent_concated', hue='set_number')
# Out:
# <Axes: xlabel='word_percent', ylabel='word_percent_concated'>

# %%
sns.scatterplot(append_keyword_df, x='word_percent', y='word_percent_concated', color='blue', alpha=0.7)
sns.scatterplot(not_appended_keyword_df, x='word_percent', y='word_percent_concated', color='red',alpha=0.6)
plt.legend(labels=['exclude','include'], bbox_to_anchor=(1,1))

# %%
append_keyword_df.head(3)
# Out:
#              Set Combination     Intersection  set_number  word_percent  \
# 14   (subset_충전, subset_어댑터)        [충전, 충전기]           2          9.99
# 19  (subset_충전, subset_고속충전)  [C타입, 고속충전, 포트]           2          6.09
# 20   (subset_충전, subset_멀티탭)        [충전, 충전기]           2          9.99
#
#    not_in_intersection   concated_word_list  word_percent_concated
# 14               [어댑터]       [충전, 충전기, 어댑터]                  12.73
# 19                [충전]  [C타입, 고속충전, 포트, 충전]                  14.89
# 20               [멀티탭]       [충전, 충전기, 멀티탭]                  11.30

# %%
# 자기 자신을 포함하지 않는 경우(모든 데이터) 전체 형태소에서 차지하는 비율
df_sample[['set_number','word_percent']].corr()
# Out:
#               set_number  word_percent
# set_number      1.000000     -0.422221
# word_percent   -0.422221      1.000000

# %%
# 자기 자신 포함한 경우
df_sample[['set_number','word_percent_concated']].corr()
# Out:
#                        set_number  word_percent_concated
# set_number               1.000000              -0.041253
# word_percent_concated   -0.041253               1.000000

# %%
not_appended_keyword_df[['set_number','word_percent']].corr()
# Out:
#               set_number  word_percent
# set_number      1.000000     -0.206277
# word_percent   -0.206277      1.000000

# %%
append_keyword_df[['set_number','word_percent_concated']].corr()
# Out:
#                        set_number  word_percent_concated
# set_number               1.000000               0.285536
# word_percent_concated    0.285536               1.000000

# %%
append_keyword_df[['set_number','word_percent']].corr()
# Out:
#               set_number  word_percent
# set_number      1.000000      0.047597
# word_percent    0.047597      1.000000

# %%
s2 = sum(append_keyword_df[append_keyword_df['set_number']==2]['not_in_intersection'],[])
unique_s2 = set(s2)
unique_s2
# Out:
# {'C타입', '고속충전', '멀티탭', '어댑터', '충전', '충전기', '콘센트'}

# %%
print(f"가능     : {s2.count('가능')}")
print(f"고속충전 : {s2.count('고속충전')}")
print(f"멀티탭   : {s2.count('멀티탭')}")
print(f"어댑터   : {s2.count('어댑터')}")
print(f"충전기   : {s2.count('충전기')}")
print(f"콘센트   : {s2.count('콘센트')}")
print(f"포트     : {s2.count('포트')}")
# Out:
# 가능     : 0
# 고속충전 : 1
# 멀티탭   : 4
# 어댑터   : 1
# 충전기   : 2
# 콘센트   : 2
# 포트     : 0

# %%
s3 = sum(append_keyword_df[append_keyword_df['set_number']==3]['not_in_intersection'],[])
unique_s3 = set(s3)
unique_s3
# Out:
# {'C타입', '고속충전', '멀티탭', '어댑터', '충전', '충전기', '콘센트'}

# %%
print(f"가능     : {s3.count('가능')}")
print(f"고속충전 : {s3.count('고속충전')}")
print(f"멀티탭   : {s3.count('멀티탭')}")
print(f"어댑터   : {s3.count('어댑터')}")
print(f"충전기   : {s3.count('충전기')}")
print(f"콘센트   : {s3.count('콘센트')}")
print(f"포트     : {s3.count('포트')}")
# Out:
# 가능     : 0
# 고속충전 : 1
# 멀티탭   : 5
# 어댑터   : 2
# 충전기   : 3
# 콘센트   : 3
# 포트     : 0

# %%
s4 = sum(append_keyword_df[append_keyword_df['set_number']==4]['not_in_intersection'],[])
unique_s4 = set(s4)
unique_s4
# Out:
# {'멀티탭', '어댑터', '충전기', '콘센트'}

# %%
print(f"가능     : {s4.count('가능')}")
print(f"고속충전 : {s4.count('고속충전')}")
print(f"멀티탭   : {s4.count('멀티탭')}")
print(f"어댑터   : {s4.count('어댑터')}")
print(f"충전기   : {s4.count('충전기')}")
print(f"콘센트   : {s4.count('콘센트')}")
print(f"포트     : {s4.count('포트')}")
# Out:
# 가능     : 0
# 고속충전 : 0
# 멀티탭   : 2
# 어댑터   : 1
# 충전기   : 1
# 콘센트   : 1
# 포트     : 0

# %%
s5 = sum(append_keyword_df[append_keyword_df['set_number']==5]['not_in_intersection'],[])
unique_s5 = set(s5)
unique_s5
# Out:
# set()

# %%
print(f"가능     : {s5.count('가능')}")
print(f"고속충전 : {s5.count('고속충전')}")
print(f"멀티탭   : {s5.count('멀티탭')}")
print(f"어댑터   : {s5.count('어댑터')}")
print(f"충전기   : {s5.count('충전기')}")
print(f"콘센트   : {s5.count('콘센트')}")
print(f"포트     : {s5.count('포트')}")
# Out:
# 가능     : 0
# 고속충전 : 0
# 멀티탭   : 0
# 어댑터   : 0
# 충전기   : 0
# 콘센트   : 0
# 포트     : 0

# %%
s6 = sum(append_keyword_df[append_keyword_df['set_number']==6]['not_in_intersection'],[])
unique_s6 = set(s6)
unique_s6
# Out:
# set()

# %%
print(f"가능     : {s6.count('가능')}")
print(f"고속충전 : {s6.count('고속충전')}")
print(f"멀티탭   : {s6.count('멀티탭')}")
print(f"어댑터   : {s6.count('어댑터')}")
print(f"충전기   : {s6.count('충전기')}")
print(f"콘센트   : {s6.count('콘센트')}")
print(f"포트     : {s6.count('포트')}")
# Out:
# 가능     : 0
# 고속충전 : 0
# 멀티탭   : 0
# 어댑터   : 0
# 충전기   : 0
# 콘센트   : 0
# 포트     : 0

# %%
# 대표 속성이 공통 집합에 포함되지 않은 경우 도출되는 키워드 (겹치는 개수별)
append_keyword_df.head()
# Out:
#              Set Combination          Intersection  set_number  word_percent  \
# 14   (subset_충전, subset_어댑터)             [충전, 충전기]           2          9.99
# 19  (subset_충전, subset_고속충전)       [C타입, 고속충전, 포트]           2          6.09
# 20   (subset_충전, subset_멀티탭)             [충전, 충전기]           2          9.99
# 44  (subset_어댑터, subset_멀티탭)  [어댑터, 해외여행, 충전, 충전기]           2         13.81
# 50  (subset_콘센트, subset_멀티탭)         [어댑터, 연결, 충전]           2         12.34
#
#    not_in_intersection         concated_word_list  word_percent_concated
# 14               [어댑터]             [충전, 충전기, 어댑터]                  12.73
# 19                [충전]        [C타입, 고속충전, 포트, 충전]                  14.89
# 20               [멀티탭]             [충전, 충전기, 멀티탭]                  11.30
# 44               [멀티탭]  [어댑터, 해외여행, 충전, 충전기, 멀티탭]                  15.12
# 50          [콘센트, 멀티탭]    [어댑터, 연결, 충전, 콘센트, 멀티탭]                  16.02

# %%
cumsum_keyword_충전.to_csv('C:/Users/songy/Desktop/Data/keyword_result/keyword_충전.csv', encoding='utf-8-sig')
cumsum_keyword_케이스.to_csv('C:/Users/songy/Desktop/Data/keyword_result/keyword_케이스.csv', encoding='utf-8-sig')
cumsum_keyword_여행.to_csv('C:/Users/songy/Desktop/Data/keyword_result/keyword_여행.csv', encoding='utf-8-sig')
cumsum_keyword_디자인.to_csv('C:/Users/songy/Desktop/Data/keyword_result/keyword_디자인.csv', encoding='utf-8-sig')
cumsum_keyword_어댑터.to_csv('C:/Users/songy/Desktop/Data/keyword_result/keyword_어댑터.csv', encoding='utf-8-sig')
#cumsum_keyword_콘센트.to_csv('C:/Users/songy/Desktop/Data/keyword_result/keyword_콘센트.csv', encoding='utf-8-sig')
#cumsum_keyword_파우치.to_csv('C:/Users/songy/Desktop/Data/keyword_result/keyword_파우치.csv', encoding='utf-8-sig')
#cumsum_keyword_포트.to_csv('C:/Users/songy/Desktop/Data/keyword_result/keyword_포트.csv', encoding='utf-8-sig')
#cumsum_keyword_C타입.to_csv('C:/Users/songy/Desktop/Data/keyword_result/keyword_C타입.csv', encoding='utf-8-sig')
#cumsum_keyword_가능.to_csv('C:/Users/songy/Desktop/Data/keyword_result/keyword_가능.csv', encoding='utf-8-sig')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[110], line 3
#       1 cumsum_keyword_충전.to_csv('C:/Users/songy/Desktop/Data/keyword_result/keyword_충전.csv', encoding='utf-8-sig')
#       2 cumsum_keyword_케이스.to_csv('C:/Users/songy/Desktop/Data/keyword_result/keyword_케이스.csv', encoding='utf-8-sig')
# ----> 3 cumsum_keyword_여행.to_csv('C:/Users/songy/Desktop/Data/keyword_result/keyword_여행.csv', encoding='utf-8-sig')
#       4 cumsum_keyword_디자인.to_csv('C:/Users/songy/Desktop/Data/keyword_result/keyword_디자인.csv', encoding='utf-8-sig')
#       5 cumsum_keyword_어댑터.to_csv('C:/Users/songy/Desktop/Data/keyword_result/keyword_어댑터.csv', encoding='utf-8-sig')
#
# NameError: name 'cumsum_keyword_여행' is not defined

# %%
def subset_merging_percent(subset_a, subset_b):
    subset_intersection = len(subset_a.intersection(subset_b))
    subset_union = len(subset_a.union(subset_b))
    result = round((subset_intersection / subset_union)*100,2)
    return result

# %% [markdown]
# subset_충전
# subset_케이스
# subset_여행
# subset_디자인
# subset_어댑터
# subset_콘센트
# subset_파우치
# subset_포트
# subset_C타입
# subset_가능
# subset_고속충전
# subset_멀티탭
# subset_충전기

# %%
print(subset_어댑터)
# Out:
# {'충전', '가능', '여행', '멀티탭', '해외', '연결', '플러그', '돼지코', '디자인', '여러나라', '충전기', 'USB포트', '콘센트', 'C타입', '기능', '여행용', '일본', '멀티어댑터', '해외여행', '케이스', '선', '포트'}

# %%
print(f'충전   &  케이스 겹치는 비율 : {subset_merging_percent(subset_충전,subset_케이스)} %')
print(f'충전   &  여행   겹치는 비율 : {subset_merging_percent(subset_충전,subset_여행)} %')
print(f'충전   &  디자인 겹치는 비율 : {subset_merging_percent(subset_충전,subset_디자인)} %')
print(f'충전   &  어댑터 겹치는 비율 : {subset_merging_percent(subset_충전,subset_어댑터)} %')
print(f'케이스 &  여행   겹치는 비율 : {subset_merging_percent(subset_케이스,subset_여행)} %')
print(f'케이스 &  디자인 겹치는 비율 : {subset_merging_percent(subset_케이스,subset_디자인)} %')
print(f'케이스 &  어댑터 겹치는 비율 : {subset_merging_percent(subset_케이스,subset_어댑터)} %')
print(f'여행   &  디자인 겹치는 비율 : {subset_merging_percent(subset_여행,subset_디자인)} %')
print(f'여행   &  어댑터 겹치는 비율 : {subset_merging_percent(subset_여행,subset_어댑터)} %')
# Out:
# 충전   &  케이스 겹치는 비율 : 10.0 %
# 충전   &  여행   겹치는 비율 : 27.27 %
# 충전   &  디자인 겹치는 비율 : 6.06 %
# 충전   &  어댑터 겹치는 비율 : 31.25 %
# 케이스 &  여행   겹치는 비율 : 24.32 %
# 케이스 &  디자인 겹치는 비율 : 30.0 %
# 케이스 &  어댑터 겹치는 비율 : 15.0 %
# 여행   &  디자인 겹치는 비율 : 19.35 %
# 여행   &  어댑터 겹치는 비율 : 51.72 %

# %%
def intersection_list(subset_a, subset_b):
    return subset_a.intersection(subset_b)

# %%
def set_only_list(subset_a, subset_b):
    a_result = subset_a - subset_b
    b_result = subset_b - subset_a
    return print(a_result), print(b_result)

# %%
print(intersection_list(subset_여행, subset_어댑터))
# Out:
# {'일본', '멀티어댑터', '해외여행', '충전', '가능', '멀티탭', '케이스', '충전기', 'C타입', '플러그', '여행용', '포트', '콘센트', '돼지코', '디자인'}

# %%
set_only_list(subset_여행, subset_어댑터)
# Out:
# {'고속충전', '유럽', '핸드폰', '휴대', '어댑터', '파우치', '사이즈'}
# {'여행', '여러나라', '연결', '해외', 'USB포트', '기능', '선'}
# (None, None)

# %%
print(subset_충전)
# Out:
# {'가능', '여행', '속도', '연결', '해외', '케이블', '핸드폰', '충전기', '어댑터', 'USB포트', '보조배터리', '기기', '빠르고', '콘센트', '고속충전', '빠르게', 'C타입', '동시', '일본', '포트'}

# %%
def subset_result(subset):
    subset

# %%
subset_충전.intersection(subset_케이스)
# Out:
# {'가능', '어댑터', '여행', '포트'}

# %%
cumsum_keyword_케이스
# Out:
#      형태소  빈도   퍼센트  누적_퍼센트
# 1     여행  80  8.38    8.38
# 2    디자인  61  6.39   14.77
# 3     고급  40  4.19   18.96
# 4    이쁘고  34  3.56   22.52
# 5     휴대  31  3.25   25.77
# 6    예쁘고  27  2.83   28.60
# 7     충전  23  2.41   31.01
# 8    어댑터  17  1.78   32.79
# 9     색상  17  1.78   34.57
# 10    하드  14  1.47   36.04
# 11   사이즈  12  1.26   37.30
# 12   가볍고  11  1.15   38.45
# 13  해외여행  10  1.05   39.50
# 14   귀엽고  10  1.05   40.55
# 15    가능  10  1.05   41.60
# 16    유럽   9  0.94   42.54
# 17    작고   9  0.94   43.48
# 18    견고   9  0.94   44.42
# 19     색   8  0.84   45.26
# 20    안심   8  0.84   46.10
# 21    상품   8  0.84   46.94
# 22    먼지   8  0.84   47.78
# 23    포트   8  0.84   48.62
# 24    여권   8  0.84   49.46

# %%
plt.rc('font', size = 25)
ax = plt.subplots(figsize=(25,10))
plt.title('충전 속성 결과', fontsize=20)
plt.xticks(rotation=90)
sns.barplot(data=cumsum_keyword_충전, x='형태소', y='빈도')
# Out:
# <Axes: title={'center': '충전 속성 결과'}, xlabel='형태소', ylabel='빈도'>

# %% [markdown]
# local minima 고도화 적용

# %%
cumsum_keyword_케이스
# Out:
#      형태소  빈도   퍼센트  누적_퍼센트
# 1     여행  80  8.38    8.38
# 2    디자인  61  6.39   14.77
# 3     고급  40  4.19   18.96
# 4    이쁘고  34  3.56   22.52
# 5     휴대  31  3.25   25.77
# 6    예쁘고  27  2.83   28.60
# 7     충전  23  2.41   31.01
# 8    어댑터  17  1.78   32.79
# 9     색상  17  1.78   34.57
# 10    하드  14  1.47   36.04
# 11   사이즈  12  1.26   37.30
# 12   가볍고  11  1.15   38.45
# 13  해외여행  10  1.05   39.50
# 14   귀엽고  10  1.05   40.55
# 15    가능  10  1.05   41.60
# 16    유럽   9  0.94   42.54
# 17    작고   9  0.94   43.48
# 18    견고   9  0.94   44.42
# 19     색   8  0.84   45.26
# 20    안심   8  0.84   46.10
# 21    상품   8  0.84   46.94
# 22    먼지   8  0.84   47.78
# 23    포트   8  0.84   48.62
# 24    여권   8  0.84   49.46

# %%
plt.rc('font', size = 25)
ax = plt.subplots(figsize=(25,10))
plt.title('케이스 속성 결과', fontsize=20)
plt.xticks(rotation=90)
sns.barplot(data=cumsum_keyword_케이스, x='형태소', y='빈도')
# Out:
# <Axes: title={'center': '케이스 속성 결과'}, xlabel='형태소', ylabel='빈도'>

# %%
cumsum_keyword_여행.head(50)
# Out:
#       형태소   빈도   퍼센트  누적_퍼센트
# 1      충전  186  7.56    7.56
# 2    해외여행  151  6.14   13.70
# 3     어댑터  112  4.55   18.25
# 4      일본   91  3.70   21.95
# 5     케이스   90  3.66   25.61
# 6   멀티어댑터   75  3.05   28.66
# 7     멀티탭   49  1.99   30.65
# 8      유럽   47  1.91   32.56
# 9     디자인   47  1.91   34.47
# 10    콘센트   44  1.79   36.26
# 11    돼지코   34  1.38   37.64
# 12    충전기   34  1.38   39.02
# 13   고속충전   32  1.30   40.32
# 14    파우치   31  1.26   41.58
# 15    핸드폰   31  1.26   42.84
# 16     포트   29  1.18   44.02
# 17    C타입   25  1.02   45.04
# 18     휴대   24  0.98   46.02
# 19    사이즈   24  0.98   47.00
# 20    여행용   23  0.94   47.94
# 21    플러그   23  0.94   48.88
# 22     가능   22  0.89   49.77

# %%
plt.rc('font', size = 25)
ax = plt.subplots(figsize=(25,10))
plt.title('여행 속성 결과', fontsize=20)
plt.xticks(rotation=90)
sns.barplot(data=cumsum_keyword_여행, x='형태소', y='빈도')
# Out:
# <Axes: title={'center': '여행 속성 결과'}, xlabel='형태소', ylabel='빈도'>

# %%
cumsum_keyword_디자인
# Out:
#      형태소  빈도   퍼센트  누적_퍼센트
# 1    케이스  60  7.39    7.39
# 2    이쁘고  58  7.14   14.53
# 3    예쁘고  57  7.02   21.55
# 4     여행  38  4.68   26.23
# 5    파우치  23  2.83   29.06
# 6     충전  22  2.71   31.77
# 7     기능  21  2.59   34.36
# 8     색상  21  2.59   36.95
# 9     고급  20  2.46   39.41
# 10    실용  18  2.22   41.63
# 11    성능  17  2.09   43.72
# 12   콤팩트  12  1.48   45.20
# 13    휴대  11  1.35   46.55
# 14  해외여행  10  1.23   47.78
# 15    포트  10  1.23   49.01

# %%
plt.rc('font', size = 25)
ax = plt.subplots(figsize=(25,10))
plt.title('디자인 속성 결과', fontsize=20)
plt.xticks(rotation=90)
sns.barplot(data=cumsum_keyword_디자인, x='형태소', y='빈도')
# Out:
# <Axes: title={'center': '디자인 속성 결과'}, xlabel='형태소', ylabel='빈도'>

# %%
cumsum_keyword_어댑터
# Out:
#       형태소   빈도    퍼센트  누적_퍼센트
# 1   멀티어댑터  162  11.10   11.10
# 2      여행  123   8.42   19.52
# 3      충전   65   4.45   23.97
# 4    해외여행   48   3.29   27.26
# 5     콘센트   32   2.19   29.45
# 6      해외   29   1.99   31.44
# 7     플러그   24   1.64   33.08
# 8      가능   22   1.51   34.59
# 9     충전기   22   1.51   36.10
# 10     일본   21   1.44   37.54
# 11     포트   21   1.44   38.98
# 12    C타입   20   1.37   40.35
# 13    케이스   19   1.30   41.65
# 14    여행용   17   1.16   42.81
# 15     연결   14   0.96   43.77
# 16      선   14   0.96   44.73
# 17  USB포트   13   0.89   45.62
# 18    돼지코   12   0.82   46.44
# 19    디자인   11   0.75   47.19
# 20     기능   11   0.75   47.94
# 21    멀티탭   11   0.75   48.69
# 22   여러나라   10   0.68   49.37

# %%
plt.rc('font', size = 25)
ax = plt.subplots(figsize=(25,10))
plt.title('어댑터 속성 결과', fontsize=20)
plt.xticks(rotation=90)
sns.barplot(data=cumsum_keyword_어댑터, x='형태소', y='빈도')
# Out:
# <Axes: title={'center': '어댑터 속성 결과'}, xlabel='형태소', ylabel='빈도'>

# %% [markdown]
# ### 실험 과정

# %%
df_remain_freq
# Out:
#       형태소    빈도  pos  변화량  변화량/총변화량
# 0      충전  1227  NNG    0       0.0
# 1     케이스   926  NNG  301      25.0
# 2      여행   776  NNG  150      12.0
# 3     디자인   545  NNG  231      19.0
# 4     어댑터   381  NNG  164      13.0
# ..    ...   ...  ...  ...       ...
# 961     링     1  NNG    0       0.0
# 962   그리스     1  NNP    0       0.0
# 963    두께     1  NNG    0       0.0
# 964  문제없어     1  NNG    0       0.0
# 965    도어     1  NNG    0       0.0
#
# [966 rows x 5 columns]

# %% [markdown]
# Test
