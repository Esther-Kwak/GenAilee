# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import re

from konlpy.tag import *

# %%
from konlpy.tag import Mecab

m = Mecab(dicpath = 'C:/mecab/mecab-ko-dic')
m.nouns('A타입도 좋고, PD충전 되는 것도 좋아요. C타입 여러개 있어서 좋습니다')
# Out:
# ['A타입', 'PD충전', '것', 'C타입', '개']

# %%
product = pd.read_csv("C:/Users/songy/Desktop/Data/product.csv", index_col = 0)
product
# Out:
#                              add_rule_based_split_review
# 3                               금액 차이 얼마 안 나는데 기능은 더 좋아요
# 4                             콤팩트한 디자인과 실용성에 높은 점수 주었습니다
# 8                                      전면 스크래치가 많아서 아쉽네요
# 15                               말 그대로 멀티어댑터에요 해외여행 필수 탬
# 19                                            작아서 휴대도 굿굿
# ...                                                  ...
# 18645                                       가볍고 휴대하기 좋아요
# 18646  C타입 충전이 없어서 구매를 망설이긴 했지만 좀 큰 변압기는 쳐져서 충전이 잘 안되...
# 18647                                        요 사이즈가 딱이네요
# 18649                                   켔써요 노란색이 너무 귀엽군요
# 18652           한 손에 쏙 들어오고 색이 쨍해서 여행 가서 잃어버릴 일 없을 거 같아요
#
# [8102 rows x 1 columns]

# %%
def upper_text(text):
    text = text.upper()
    return text

# %%
product['add_rule_based_split_review'] = product['add_rule_based_split_review'].apply(upper_text)

# %%
def replace_text(text):
  text = str(text)
  text = text.replace('쌈ㅎ','저렴해요')
  text = text.replace('안되는...','안됩니다')
  text = text.replace('ㅎ','')
  text = text.replace('ㅋ','')
  text = text.replace('루♡','')
  text = text.replace('♡','')
  text = text.replace('굳','굿')
  text = text.replace('ㅜ','')
  text = text.replace('중입니다)','중 입니다')
  text = text.replace('하나에요','하나예요')
  text = text.replace('있었어요','있어요')
  text = text.replace('욥','요')
  text = text.replace('오겠씀다~~ㅎㅎ/','오겠습니다')
  text = text.replace('후에~','')
  text = text.replace('개용','개요')
  text = text.replace('ㅅ','')
  text = text.replace('오ㅡ','')
  text = text.replace('여행가고싶어지네요ㅋㅋ','여행 가고 싶어지네요')
  text = text.replace('좋습니다!!!!','좋습니다')
  text = text.replace('구매확정해요','구매 확정해요')
  text = text.replace('완죤빨라요ㅋㅋ','완전 빨라요')
  text = text.replace('ㅡ','')
  text = text.replace('귀요미에요','귀여워요')
  text = text.replace('최고여요','최고예요')
  text = text.replace('사랑하여','사랑해요')
  text = text.replace('배송되었습니다','배송 되었습니다')
  text = text.replace('좋아요ㅔ','좋아요')
  text = text.replace('아니에요.','아니예요')
  text = text.replace('구매확정했습니다','구매 확정했습니다')
  text = text.replace('bbb','굿')
  text = text.replace('쓸ㄲ너ㅣㅇ르','')
  text = text.replace('같고요','같아요')
  text = text.replace('같네요','같아요')
  text = text.replace('씁니다','습니다')
  text = text.replace('넘좋와여','너무 좋아요')
  text = text.replace('굿입니다','굿')
  text = text.replace('목배게최고에요','목배게 최고예요')
  text = text.replace('감동이에요','감동이예요')
  text = text.replace('아이디어템','아이디어 탬')
  text = text.replace(':D','')
  text = text.replace('감사핮니다','감사합니다')
  text = text.replace('템','탬')
  text = text.replace('든든 합니다','든든합니다')
  text = text.replace('받아보았어요','받아봤어요')
  text = text.replace('가타용','같아요')
  text = text.replace('바랍니아','바랍니다')
  text = text.replace('사업번창하세요','사업 번창하세요')
  text = text.replace('쓸겠습니다','쓰겠습니다')
  text = text.replace('구매완료입니다','구매완료')
  text = text.replace('짱빠름','짱 빠름')
  text = text.replace('됩니닽','됩니다')
  text = text.replace('닙니다ㅛ','닙니다')
  text = text.replace('잘한듯해요','잘한듯')
  text = text.replace('가세여','가세요')
  text = text.replace('잘샀다템','잘샀어요')
  text = text.replace('좋아요좋아요좋오ㅓㅗㅇ좋아요','좋아요 좋아요')
  text = text.replace('써봐겠ㅆ네요','써봐야겠네요')
  text = text.replace('만족이에요','만족이예요')
  text = text.replace('아까워요.','아까워요')
  text = text.replace('ajjqjahaja','')
  text = text.replace('잚슬겡ㅎ','잘쓸게요')
  text = text.replace('잘했아요','잘했어요')
  text = text.replace('괜찬ㅍ아요','괜찮아요')
  text = text.replace('예쁨','예뻐요')
  text = text.replace('편하쥬','편해요')
  text = text.replace('감사함다','감사합니다')
  text = text.replace('핳핳','')
  text = text.replace('굿입니다','굿')
  text = text.replace('으흐흐','')
  text = text.replace('빨라요ㅗ','빨라요')
  text = text.replace('이븜','이쁨')
  text = text.replace('ㄹㅇ','')
  text = text.replace('되매요','되네요')
  text = text.replace('믿어보겠음다','믿어보겠습니다')
  text = text.replace('아니에요','아니예요')
  text = text.replace('만족합니다.ㅣ','만족합니다')
  text = text.replace('되고요','됩니다')
  text = text.replace('딱입니딘','딱입니다')
  text = text.replace('기대되어요','기대됩니다')
  text = text.replace('왔습디다','왔습니다')
  text = text.replace('맀어용','랐어요')
  text = text.replace('강강히','')
  text = text.replace('만족이여','만족이요')
  text = text.replace('사용했니다.','사용했습니다')
  text = text.replace('충전빨리되구죻아요','충전 빨리되고 좋아요')
  text = text.replace('잘됩니다잉','잘됩니다')
  text = text.replace('사용했답니다','사용했어요')
  text = text.replace('가타요','같아요')
  text = text.replace('최곱니다','최고입니다')
  text = text.replace('빠르네요','빠릅니다')
  text = text.replace('기릉','기를')
  text = text.replace('받았습니아','받았습니다')
  text = text.replace('ok.','ok')
  text = text.replace('가져감','가져갑니다')
  text = text.replace('익니다','입니다')
  text = text.replace('수용되오ㅡ','수용되요')
  text = text.replace('맨죡','만족')
  text = text.replace('ㄹ','')
  text = text.replace('구매예정이에요','구매 예정이예요')
  text = text.replace('좋은듓','좋은듯')
  text = text.replace('매우저롐하게잘구매했어요감사하네여','매우 저렴하게 잘 구매했어요 감사해요')
  text = text.replace('만적합니다','만족합니다')
  text = text.replace('ㅈ번창하세요','번창하세요')
  text = text.replace('전이에요','전이예요')
  text = text.replace('조어요','좋아요')
  text = text.replace('젛아요','좋아요')
  text = text.replace('됩니더','됩니다')
  text = text.replace('굿입디다','굿')
  text = text.replace('갘아어요','')
  text = text.replace('ㄷ,','')
  text = text.replace('잘되겠쥬','잘되겠죠')
  text = text.replace('쓰게습니도','쓰겠습니다')
  text = text.replace('하고요','하고')
  text = text.replace('저뇽가방도있네요','전용가방도 있네요')
  text = text.replace('sjsjsjjsjs','')
  text = text.replace('좋겠구먼요','좋겠네요')
  text = text.replace('좋아욫','좋아요')
  text = text.replace('반퓸합니다','반품합니다')
  text = text.replace('꿋꿋입니다','굿')
  text = text.replace('잘씅게용','잘쓸게요')
  text = text.replace('땡큐네요','감사합니다')
  text = text.replace('베릐굿','굿')
  text = text.replace('효오','')
  text = text.replace('☆','')
  text = text.replace('ᄒ','')
  text = text.replace('썼어ᄉ','썼어요')
  text = text.replace('사용시뉴용할듯욕','사용시 유용할 듯')
  text = text.replace('있아요','있어요')
  text = text.replace('아다아다아','')
  text = text.replace('아다 아다 아','')
  text = text.replace('감사합니다아','감사합니다')
  text = text.replace('goood','굿')
  text = text.replace('싱픔굿배소오쟈웁','상품 굿 배송')
  text = text.replace('쓸겡','쓸게요')
  text = text.replace('굿국국숙','굿굿굿')
  text = text.replace('졸아요','좋아요')
  text = text.replace('USC','USB')
  text = text.replace('A S','AS')
  text = text.replace(' ㅐ외','해외')
  text = text.replace('ᄆ','')
  text = text.replace('ᅳᄋ ᄋ','')
  text = text.replace('배슝','배송')
  text = text.replace('ᅲ','')
  text = text.replace('쓸ᄁ너ᅵᄋ르','쓸게요')
  text = text.replace(' ♥','')
  text = text.replace('ᄏ','')
  text = text.replace('강 추','강추')
  text = text.replace('★','')
  text = text.replace('■','')
  
  # text = text.replace('USB', '유에스비')
  text = text.replace('보관 백', '보관백')
  text = text.replace('TYPE', '타입')
  text = text.replace('C TO C', 'C타입')
  text = text.replace('CTOC', 'C타입')
  text = text.replace('C2C', 'C타입')
  text = text.replace('USB-C', 'USB포트 C타입')
  text = text.replace('USB-A', 'USB포트 A타입')
  text = text.replace('C TYPE', 'C타입')
  text = text.replace('C 타입','C타입')
  text = text.replace('씨타입','C타입')
  text = text.replace('씨 타입', 'C타입')
  text = text.replace('A 타입','A타입')
  text = text.replace('에이타입','A타입')
  text = text.replace('에이 타입', 'A타입')
  text = text.replace('PD 충전','PD충전')
  text = text.replace('PD 잭', 'PD잭')
  text = text.replace('급 속','급속')
  text = text.replace('포드','포트')
  text = text.replace('포드만','포트')
  text = text.replace('포드리','포트')
  text = text.replace('핸폰','핸드폰')
  text = text.replace('휴대폰', '핸드폰')
  text = text.replace('휴대전화', '핸드폰')
  text = text.replace('11볼트', '110V')
  text = text.replace('22볼트', '220V')
  text = text.replace('11V', '110V')
  text = text.replace('22V', '220V')
  # text = text.replace('35W', '35와트')
  # text = text.replace('45W', '45와트')
  # text = text.replace('65W', '65와트')
  text = text.replace('포터', '포트')
  # text = text.replace('USB', 'USB포트') 
  text = text.replace('USB 포트', 'USB포트')
  text = text.replace('동시 충전', '동시충전')
  text = text.replace('고속 충전', '고속충전')
  text = text.replace('동시 이용', '동시이용')
  text = text.replace('동시 사용', '동시사용')
  text = text.replace('여러 나라', '여러나라')
  text = text.replace('코넥터', '커넥터')
  # 1개짜리는 제외
  return text

# %%
product['add_rule_based_split_review'] = product['add_rule_based_split_review'].apply(replace_text)

# %%
def clean_text(text):
    if isinstance(text, str):
        return re.sub(r'[-=+,#/\?:^$.@*"※~&%ㆍ!』\\‘·|\(\)\[\]\<\>`\'…\"\“’]', '', text)
    else:
        return ""

# %%
product['add_rule_based_split_review'] = product['add_rule_based_split_review'].apply(clean_text)

# %%
from konlpy.tag import Mecab
m = Mecab(dicpath = 'C:/mecab/mecab-ko-dic')

# %%
def preprocess_reviews(reviews, stopwords_path, additional_stopwords=[]):
    # 불용어 파일 로드
    with open(stopwords_path, encoding='utf-8') as file:
        stopwords = file.read().splitlines()
    
    # 추가 불용어 합치기
    stopwords.extend(additional_stopwords)

    # 리뷰 전처리
    clean_sent = []
    for review in reviews:
        clean = re.sub(r'[-=+,#/\?:^$.@*"※~&%ㆍ!』\\‘·|\(\)\[\]\<\>`\'…\"\“’]', '', review)
        clean = clean.replace('\n', '').replace('\r', '')  # 줄바꿈 문자 제거
        clean_sent.append(clean)

    m = Mecab(dicpath = 'C:/mecab/mecab-ko-dic')
    
    word_list = []
    for sentences in clean_sent:
        # 정규화
        # sentences = m.normalize(sentences)
        # 토큰화
        # tokens = sentences.split()
        tokens = m.nouns(sentences)
        # tokens = okt.nouns(sentences)
        # 불용어 제거
        tokens = [token for token in tokens if token not in stopwords]
        word_list.append(tokens)
    
    return word_list

# %%
"""
stopwords_path = "C:/Users/songy/Desktop/Data/stopwords-ko.txt"
with open(stopwords_path, encoding='utf-8') as file:
    stopwords = file.read().splitlines()

print(stopwords)
"""
# Out:
# '\nstopwords_path = "C:/Users/songy/Desktop/Data/stopwords-ko.txt"\nwith open(stopwords_path, encoding=\'utf-8\') as file:\n    stopwords = file.read().splitlines()\n\nprint(stopwords)\n'

# %%
def compiled_morphs(texts, stopwords_path, additional_stopwords=[]):
    # 불용어 파일 로드
    with open(stopwords_path, encoding='utf-8') as file:
        stopwords = file.read().splitlines()

    # 추가 불용어 합치기
    stopwords.extend(additional_stopwords)

    # 리뷰 전처리
    clean = re.sub(r'[-=+,#/\?:^$.@*"※~&%ㆍ!』\\‘·|\(\)\[\]\<\>`\'…\"\“’]', '', texts)
    clean = clean.replace('\n','').replace('\r','')     # 줄바꿈 문자 제거

    # 형태소 분석기 추가
    m = Mecab(dicpath='C:/mecab/mecab-ko-dic')

    result = []
    for i in range(len(m.pos(clean))):
        word, pos = m.pos(clean)[i]
        # 형태소가 연결 어미인지 확인
        if pos in ['VA']:
            if i + 1 < len(m.pos(clean)):
                next_word, next_pos = m.pos(clean)[i + 1]
                if next_pos in ['EC', 'ETM']:           # 연결 어미 또는 관형형 전성 어미
                    result.append(word + next_word)
                else:
                    result.append(word + next_word)
        elif pos in ['NNG', 'NNP']:
            result.append(word) 
    
    # 불용어 처리
    results = [word for word in result if word not in stopwords]
    
    return results

# %%
example_sent = "퓨즈 교체가 자동이라서 신경 쓸 일이 하나 줄은 것도 장점이고요"

# %%
def find_morphs(text):
    """
    명사, 형태소 추출 함수 (형용사의 연결 어미를 반영해 추출)
    """
    result = []

    for i in range(len(m.pos(text))):
        word, pos = m.pos(text)[i]
        # 형태소가 연결 어미인지 확인
        if pos in ['VA']:
            if i + 1 < len(m.pos(text)):
                next_word, next_pos = m.pos(text)[i + 1]
                if next_pos in ['EC', 'ETM']:           # 연결 어미 또는 관형형 전성 어미
                    result.append(word + next_word)
                else:
                    #result.append(word + next_word)
                    result.append(word)
        elif pos in ['NNG', 'NNP']:                     # 명사 
            result.append(word)

    return result

# %%
find_morphs("튼튼한 것 견고한 컴팩트 케이스 테스트")
# Out:
# ['컴팩트', '케이스', '테스트']

# %%
compiled_morphs("C타입까지 USB 튼튼한 것 견고한 컴팩트 케이스 테스트 칰 USB", stopwords_path="C:/Users/songy/Desktop/Data/stopwords-ko.txt")
# Out:
# ['C타입', '컴팩트', '케이스', '테스트']

# %%
#compiled_morphs("", stopwords_path="C:/Users/songy/Desktop/Data/stopwords-ko.txt")

# %%
#product['changed_text'] = product['add_rule_based_split_review'].apply(find_morphs)
reviews = product['add_rule_based_split_review']  # 리뷰 데이터
stopwords_path = "C:/Users/songy/Desktop/Data/stopwords-ko.txt"

additional_stopwords = ['가', '가격', '가운데', '가족', '간', '감', '감비', '감사', '값', '강추', '같고', '같습니다', '같아', '같아서', '같아요', '겉'
                        '같은', '결제', '같은데', '개', '거', '거랑', '걱정', '검색', '것', '겉', '게', '게요', '결과', '결재', '경우', '고', '금액', '차이',
                        '고려', '고만', '고민', '곳', '과', '괜찮아요', '구리고', '구매', '구매평', '구비', '구성', '구입', '군더더기', '굿', '귀찮게',
                        '귀찮고', '글', '급하게', '기대', '기존', '기준', '길', '김기', '깊질', '까지', '끝', '나라', '나중', '날', '남편',
                        '냐짱', '너무', '네이버', '노브', '눈', '느낌', '느리네요', '는', '다', '다르게', '다르고', '다양', '다이소', '다행', '달',
                        '담', '답변', '대부분', '대비', '대신', '덕분', '덜렁', '도', '도착', '돈', '동봉', '동생', '동일', '돼다', '되다',
                        '되어다', '두면', '뒤', '들', '등', '디', '딸', '때', '땡', '뛰어나다', '라', '라고', '래빗', '레이', '로', 
                        '를', '리뷰', '마', '마련', '마음', '만', '만족', '많고', '많아서', '많았었', '많지만', '말', '맘', '맛', '멀티',
                        '멜리', '면', '못', '무료', '문', '문제', '물', '물건', '미', '및', '밑', '며칠', '바이', '박스', '반', '받다',
                        '발', '발송', '배', '배송', '번', '번개', '벽', '변', '별도', '별점', '보관', '복', '봉', '부분', '브레',
                        '비선', '비싸지', '비싸지만', '빌', '사나', '사서', '사실', '사요', '사용', '사장', '사진', '생각', '서', '선물', '선택',
                        '설치', '세상', '쇼퍼', '숍', '수', '숙소', '스타', '스티커', '스펙', '시', '시기', '시대', '시험', '식겁', '신랑',
                        '신행', '실사', '실사용자', '싸게', '싸구려', '싸는데', '싸진', '쌀', '써다', '쏙', '쓸모', '아들', '아무것', '아쉽네요', '아쉽습니다',
                        '아주', '아직', '안', '않다', '알차게', '앞', '애', '야지', '얇아요', '얘기', '어렵더라고요', '어머니', '언니', '언스', '엄마',
                        '업', '없겠', '없고', '없나', '없네요', '없는', '없어서', '없어요', '없었', '없으니까요', '없지만', '에', '에서', '엔', '엔코',
                        '여분', '여유', '여행', '역할', '연락', '연휴', '옆', '예비', '예전', '옛날', '오다', '오랫동안', '오전', '오케이', '오후',
                        '와', '와이프', '요', '요새', '요즘', '용', '운', '워홀', '원', '원래', '유용', '으로', '은', '을', '의',
                        '이', '이거', '이다', '이라', '이랑', '이번', '이외', '이용', '이유', '이전', '인', '인터넷', '일행', '있고', '있군요',
                        '있긴', '있네요', '있는', '있는대도', '있다', '있다는', '있던데', '있어', '있어서', '있었', '있을', '있지만', '자', '자다', '자체',
                        '잔', '잘', '장만', '잦은데', '저렴', '저번', '전', '전용', '전이', '전체', '점', '정', '정도', '제', '제공',
                        '제품', '종결', '종류', '좋겠', '좋고', '좋네요', '좋더라구요', '좋습니다', '좋아서', '좋아요', '좋았', '좋은', '좋은데요', '좋을', '주', '좋',
                        '주니', '주문', '주파', '준비', '중요', '지난번', '지네', '지원', '지인', '집', '차', '차지', '처리', '처음', '첨부',
                        '추천', '추후', '출국', '출장', '친구', '친절', '커피', '코', '크게', '크지', '큰일', '테스트', '퇴원', '튀', '트',
                        '티', '판매', '편리', '편하게', '편하고', '평', '평생', '포장', '포함', '표', '프리', '필', '필수탬', '필요', '하고', '필수', '이거', '아쉽더라구요', 
                        '하다', '하머', '하우스', '한', '한국', '한큐', '해', '형', '호텔', '확인', '활용', '회사', '효', '후', '후기', '같', '없', '당황', '목', '탬', '높은',
                        '흠', '히', '힘', '하루']

product['changed_text'] = product['add_rule_based_split_review'].apply(lambda texts : compiled_morphs(texts, stopwords_path, additional_stopwords))

# %%
product.head(3)
# Out:
#   add_rule_based_split_review    changed_text
# 3    금액 차이 얼마 안 나는데 기능은 더 좋아요            [기능]
# 4  콤팩트한 디자인과 실용성에 높은 점수 주었습니다  [콤팩트, 디자인, 실용]
# 8           전면 스크래치가 많아서 아쉽네요      [전면, 스크래치]

# %%
product.head(3)
# Out:
#   add_rule_based_split_review    changed_text
# 3    금액 차이 얼마 안 나는데 기능은 더 좋아요            [기능]
# 4  콤팩트한 디자인과 실용성에 높은 점수 주었습니다  [콤팩트, 디자인, 실용]
# 8           전면 스크래치가 많아서 아쉽네요      [전면, 스크래치]

# %%
def list_convert_comma(lst):
    return ', '.join(lst)

def list_convert_space(lst):
    return ' '.join(lst)

# %%
product['Tokenized_sentence'] = product['changed_text'].apply(list_convert_comma)
product['Tokenized_morphs'] = product['changed_text'].apply(list_convert_space)
product.head(3)
# Out:
#   add_rule_based_split_review    changed_text Tokenized_sentence  \
# 3    금액 차이 얼마 안 나는데 기능은 더 좋아요            [기능]                 기능
# 4  콤팩트한 디자인과 실용성에 높은 점수 주었습니다  [콤팩트, 디자인, 실용]       콤팩트, 디자인, 실용
# 8           전면 스크래치가 많아서 아쉽네요      [전면, 스크래치]           전면, 스크래치
#
#   Tokenized_morphs
# 3               기능
# 4       콤팩트 디자인 실용
# 8          전면 스크래치

# %%
product.to_csv('C:/Users/songy/Desktop/Data/product_morphs.csv', encoding='utf-8-sig')

# %%
#remove_stopwords = sum(preprocessed_reviews, [])
remove_stopwords2 = sum(product['changed_text'],[])
remove_stopwords2
# Out:
# ['기능',
#  '콤팩트',
#  '디자인',
#  '실용',
#  '전면',
#  '스크래치',
#  '멀티어댑터',
#  '해외여행',
#  '작아서',
#  '휴대',
#  '품질',
#  'USB형',
#  'USB형',
#  '전압',
#  '충전',
#  '느리게',
#  '충전',
#  '충전',
#  '코드',
#  '불편',
#  '파우치',
#  '같은',
#  '호환',
#  '불편',
#  '없으며',
#  '마감',
#  '아쉬우나',
#  '유럽',
#  '유럽',
#  '단자',
#  '불량',
#  'USB형',
#  '없길',
#  '성능',
#  '착하네요',
#  '콘센트',
#  '기능',
#  '일반형',
#  'USB형',
#  '좋음',
#  '겸용',
#  '충전',
#  '느리편',
#  '유럽',
#  '본체',
#  '콘센트',
#  '포트',
#  '추가',
#  '불량',
#  '포트',
#  '작동',
#  '불편',
#  '고정',
#  '무용지물',
#  '해결',
#  '가성비',
#  '불량',
#  '정상',
#  '플러그',
#  '품질',
#  '파우치',
#  '연결',
#  '연결',
#  '가능',
#  '고장',
#  '콘센트',
#  '지장',
#  '없긴',
#  '코드',
#  '괜찮은',
#  '콘센트',
#  '정상',
#  '동작',
#  '국내',
#  '기능',
#  '국가',
#  '콘센트',
#  '많은',
#  '기능',
#  'EU타입',
#  '콘센트',
#  '전원',
#  '고정',
#  'EU타입',
#  '콘센트',
#  '전원',
#  '고정',
#  '여러나라',
#  '플러그',
#  '모양',
#  '품질',
#  '버튼',
#  '많네요',
#  '유럽',
#  '어댑터',
#  '국가',
#  '퀄리티',
#  '작고',
#  '파우치',
#  '휴대',
#  '대만',
#  '충전',
#  '타입',
#  '충전',
#  '일본',
#  '돼지코',
#  '연결',
#  '멀티탭',
#  'C타입',
#  '충전',
#  '돼지코',
#  'C타입',
#  '충전기',
#  '케이블',
#  '짐',
#  '자국',
#  '마감',
#  '대만',
#  '고속충전',
#  '미국',
#  '가볍고',
#  '파우치',
#  '캐리어',
#  '유선',
#  '칸',
#  '충전',
#  '장점',
#  '있어요',
#  '상품',
#  '품질',
#  '마감',
#  '실물',
#  '여행용',
#  '멀티어댑터',
#  '해외여행',
#  '타입',
#  '휴대',
#  '멀티어댑터',
#  '디자인',
#  '파우치',
#  '충전',
#  '속도',
#  '기능',
#  '타입',
#  'C타입',
#  '멀티탭',
#  '타입',
#  '타입',
#  '가능',
#  'A타입',
#  'C타입',
#  '와이파이',
#  '도시락',
#  '핸드폰',
#  '보조배터리',
#  '충전',
#  '핸드폰',
#  '충전',
#  '속도',
#  '고속충전',
#  '충전기',
#  '디자인',
#  '한몫',
#  '파우치',
#  '좋고요',
#  '케이스',
#  '휴대',
#  '퀄리티',
#  '파우치',
#  '휴대',
#  '일본',
#  '불편',
#  '전기',
#  '케이스',
#  '케이스',
#  '쿠션',
#  '같은',
#  '콘센트',
#  '구멍',
#  '크기',
#  '모양',
#  '멀티어댑터',
#  '케이스',
#  '충전',
#  '파우치',
#  '디자인',
#  '파우치',
#  '성능',
#  '기능',
#  '돼지코',
#  '어댑터',
#  '작동',
#  '유럽',
#  '콘센트',
#  '좋더라고요',
#  '외국',
#  '고장',
#  '어댑터',
#  '충전',
#  '유럽',
#  '흰색',
#  '이쁘고',
#  '작고',
#  '케이스',
#  '디자인',
#  '파우치',
#  '자리',
#  '충전',
#  '파우치',
#  '일본',
#  '요고',
#  '해결',
#  'C타입',
#  '고속충전',
#  '파우치',
#  'USB포트',
#  '작동',
#  '케이스',
#  '고급',
#  '동유럽',
#  '보조배터리',
#  '충전',
#  '파우치',
#  '여러나라',
#  '부모',
#  '가실',
#  '성능',
#  '좋으면',
#  '연결',
#  '케이스',
#  '세계',
#  '돼지코',
#  '돼지코',
#  '파우치',
#  '안심',
#  '어댑터',
#  '냄새',
#  '미국',
#  '파우치',
#  '품질',
#  'C타입',
#  '내구',
#  '안정',
#  '가능',
#  '사은품',
#  '파우치',
#  '이동',
#  '파손',
#  '우려',
#  'PD충전',
#  'C타입',
#  '충전',
#  'USB포트',
#  '충전기',
#  '실용',
#  '파우치',
#  'USB포트',
#  'C타입',
#  '작동',
#  '지역',
#  '구성품',
#  '멀티탭',
#  '일본',
#  '핸드폰',
#  '보조배터리',
#  '보조배터리',
#  '충전',
#  '야무지게',
#  '충전',
#  '유선',
#  '멀티탭',
#  '국가',
#  '가능',
#  '무게',
#  '가볍고',
#  '휴대',
#  '파우치',
#  '휴대',
#  '속',
#  '멀티탭',
#  '충전',
#  '케이블',
#  '충전기',
#  '무게',
#  'C타입',
#  '케이블',
#  '어댑터',
#  '무게',
#  '충전',
#  'C타입',
#  '타입',
#  '실용',
#  '110V',
#  '구멍',
#  '여행지',
#  '고데기',
#  '렴',
#  '돼지코',
#  '파우치',
#  '멀티탭',
#  '고데기',
#  '어댑터',
#  '연결',
#  '돼지코',
#  '여러나라',
#  '어댑터',
#  '220V',
#  'C타입',
#  '케이스',
#  '성능',
#  '무게',
#  '사이즈',
#  '커버',
#  '디자인',
#  '이쁘고',
#  '케이스',
#  '디자인',
#  '케이스',
#  '케이스',
#  '해외',
#  'USB포트',
#  '핸드폰',
#  '충전',
#  '속도',
#  '빠르지',
#  '핸드폰',
#  '충전',
#  'USB포트',
#  '디자인',
#  '돼지코',
#  '고장',
#  '케이스',
#  '품질',
#  '케이스',
#  '어댑터',
#  '디자인',
#  '콘센트',
#  '대박',
#  '상품',
#  '충전',
#  '핸드폰',
#  '충전',
#  '멀티탭',
#  '연결',
#  '해외여행',
#  '영국',
#  'C타입',
#  '견고',
#  '콘센트',
#  '콘센트',
#  '충전',
#  '색',
#  '케이스',
#  '케이스',
#  '케이스',
#  '충전',
#  '선',
#  '충전',
#  '해외여행',
#  '크긴',
#  '문제없었',
#  '퓨즈',
#  '해외',
#  '퓨즈',
#  '퓨즈',
#  '작동',
#  '파우치',
#  '케이스',
#  '사은품',
#  '케이스',
#  '어댑터',
#  '충전',
#  '파우치',
#  '케이스',
#  '해외여행',
#  '어댑터',
#  '국내',
#  '불량',
#  '단점',
#  '불량',
#  '충전',
#  '충전',
#  '속도',
#  '느리지',
#  '워치',
#  '핸드폰',
#  '보조배터리',
#  '충전',
#  '있으면',
#  '해외',
#  '없습니다',
#  '충전',
#  '포트',
#  '고데기',
#  '고데기',
#  '볼트',
#  '어댑터',
#  '애플워치',
#  '보조배터리',
#  '충전',
#  '케이스',
#  '품질',
#  '중국',
#  '타입',
#  '충전',
#  '멀티탭',
#  '기기',
#  '충전',
#  '가능',
#  'C타입',
#  '외국',
#  '일본',
#  '고장',
#  '충전',
#  '개선',
#  '110V',
#  '충전',
#  '입구',
#  '220V',
#  '깊이',
#  '깊지',
#  '일본',
#  '많더군요',
#  '깊은',
#  '입구',
#  '안쪽',
#  '개선',
#  '마감',
#  '아이디어',
#  '실용',
#  '정리',
#  '구조',
#  '휴대',
#  '국내',
#  '평소',
#  '선',
#  '어댑터',
#  '파우치',
#  '미국',
#  '손상',
#  '국내외',
#  '케이스',
#  '사용법',
#  '작고',
#  '부담',
#  '크기',
#  '파우치',
#  '여러나라',
#  '가능',
#  'C타입',
#  '케이블',
#  '케이블',
#  '가능',
#  '만능',
#  '기업',
#  '데이트',
#  '파우치',
#  '충',
#  '사이즈',
#  '타입',
#  '케이',
#  '어댑터',
#  '후회',
#  '일본',
#  '견고',
#  '해외여행',
#  '충전기',
#  '없어',
#  'C타입',
#  '케이블',
#  '포트',
#  '선',
#  '동시충전',
#  '파우치',
#  '무게',
#  '가볍고',
#  '세계',
#  '가능',
#  '유럽',
#  '콘센트',
#  '케이스',
#  '휴대',
#  '여행용',
#  '멀티어댑터',
#  '해외여행',
#  '콘센트',
#  '변환기',
#  '돼지코',
#  '기능',
#  '기기',
#  '동시',
#  '충전',
#  'PD',
#  'C타입',
#  '빠르고',
#  '안정',
#  '충전',
#  '가능',
#  '여행용',
#  '멀티어댑터',
#  '계속',
#  '멀티어댑터',
#  '미국',
#  '멀티탭',
#  '멀티탭',
#  '기기',
#  '무리',
#  '해외여행',
#  '대만',
#  '케이스',
#  '유럽',
#  '핸드폰',
#  '보조배터리',
#  '충전',
#  '어댑터',
#  '가방',
#  '어댑터',
#  '충전',
#  '파우치',
#  '세계',
#  '가능',
#  '일본',
#  '가방',
#  '휴대',
#  '일본',
#  '퓨즈',
#  '퓨즈',
#  '유에스비',
#  '포트',
#  '타입',
#  '포트',
#  '동시',
#  '충전',
#  '일본',
#  '충전',
#  '디자인',
#  '콘센트',
#  '해외',
#  '돼지코',
#  '해결',
#  '파우치',
#  '멀티탭',
#  '좋음',
#  '디자인',
#  '케이스',
#  '케이스',
#  '디자인',
#  '대만',
#  '낯설었',
#  '전기포트',
#  '해외',
#  '케이스',
#  '장점',
#  '케이스',
#  '케이스',
#  '충전',
#  '충전',
#  '여러나라',
#  '호환',
#  '케이스',
#  '본체',
#  '같은',
#  '불안감',
#  '연결',
#  '충전',
#  '빠르게',
#  '케이스',
#  '콤팩트',
#  '품질',
#  '마감',
#  '안전',
#  '충전',
#  '연결',
#  '실용',
#  '케이스',
#  '케이스',
#  '다이슨',
#  '각도',
#  '각도',
#  '조절',
#  '돼지코',
#  '고속충전',
#  '케이스',
#  '케이스',
#  '이쁘고',
#  '해외여행',
#  '일본',
#  '케이스',
#  '콘센트',
#  'C타입',
#  '단자',
#  '유에스비',
#  '단자',
#  '빠르게',
#  '멀티어댑터',
#  '불편',
#  '콘센트',
#  '부드럽게',
#  'C타입',
#  '충전',
#  '가능',
#  '파우치',
#  '휴대',
#  '충전',
#  '해외',
#  '멀티어댑터',
#  '무게',
#  '콘센트',
#  '불편',
#  '유럽',
#  '인증',
#  '지역',
#  '커버',
#  '가능',
#  '일본',
#  '기기',
#  '충전',
#  '전일',
#  '저녁',
#  '짐',
#  '일본',
#  '돼지코',
#  '세계',
#  '한국인',
#  '고속충전',
#  '고속충전',
#  '아이폰',
#  '갤럭시',
#  '연결',
#  '충전',
#  '대만',
#  '110V',
#  '전기',
#  '충전',
#  '충전',
#  'C타입',
#  '케이스',
#  '귀엽고',
#  '케이스',
#  '고급',
#  '드라이기',
#  'C타입',
#  '충전',
#  '파우치',
#  '어댑터',
#  '동시',
#  '충전',
#  '220V',
#  '코드',
#  '내구',
#  '국가',
#  '가능',
#  '어댑터',
#  '충전',
#  '선',
#  '파우치',
#  '디자인',
#  '컬러',
#  '고급',
#  '작아서',
#  '휴대',
#  '해외여행',
#  '멀티어댑터',
#  '포트',
#  '연결',
#  '잭',
#  '해결',
#  '국가',
#  '해당',
#  '옵션',
#  '설명서',
#  '파우치',
#  '발리',
#  '신혼',
#  '다이슨',
#  '어댑터',
#  '다이슨',
#  '베개',
#  '고생',
#  '의자',
#  '의자',
#  '가이드',
#  '사람',
#  '대박',
#  'C타입',
#  '동시',
#  '해외',
#  '짐',
#  '가격대',
#  '퀄리티',
#  '가능',
#  '장점',
#  '있으면',
#  '해외',
#  '빛',
#  '디자인',
#  '케이스',
#  '입',
#  '개꿀',
#  '멀티탭',
#  '없음',
#  '충전',
#  '편',
#  '멀티탭',
#  '충전',
#  '헐겁다고',
#  '핸드폰',
#  '충전',
#  '워치',
#  '충전',
#  '드라이기',
#  '가능',
#  '좋더라고요',
#  '많은',
#  '충전',
#  '파우치',
#  '파우치',
#  '실용',
#  '퓨즈',
#  '충전',
#  '케이블',
#  '많다',
#  '예쁘게',
#  '충전',
#  '갤럭시',
#  '고속충전',
#  '충전',
#  '빠르고',
#  '무거워서',
#  '연결',
#  '불안',
#  '일본',
#  '충전',
#  '불편',
#  '색상',
#  '흰색',
#  '그레이',
#  '포트',
#  'C타입',
#  '충전',
#  '케이스',
#  '충전',
#  '호환',
#  '불편',
#  '케이스',
#  '케이스',
#  '해외여행',
#  'C타입',
#  '최근',
#  '콘센트',
#  '자리',
#  '타입',
#  '국내',
#  '멀티탭',
#  '실용',
#  '멀티탭',
#  '연결',
#  '핸드폰',
#  '충전',
#  '품질',
#  '고급',
#  '케이스',
#  '어댑터',
#  '콘센트',
#  '일본',
#  '어댑터',
#  '상품',
#  '충전',
#  '충전',
#  '케이스',
#  '충전',
#  '가능',
#  '하와이',
#  '다이슨',
#  '크기',
#  '파우치',
#  '최근',
#  '대만',
#  '태국',
#  '최고',
#  '효율',
#  '높았',
#  '소지품',
#  '고속충전',
#  '짱',
#  '충전',
#  '빠르고',
#  '접촉',
#  '불량',
#  '있다고',
#  '블로그',
#  '돼지코',
#  '동시',
#  '충전',
#  '가능',
#  '충전',
#  '구성품',
#  '어댑터',
#  '본품',
#  '설명서',
#  '파우치',
#  '어댑터',
#  '비교',
#  '가격대',
#  '콘센트',
#  '현상',
#  'C타입',
#  '적은',
#  '디자인',
#  '여러',
#  '케이블',
#  '일반',
#  '일본',
#  '배터리',
#  '충전',
#  '볼트',
#  '고속충전',
#  '테두리',
#  '노란색',
#  '교환',
#  '멀티탭',
#  '대용',
#  '사이즈',
#  '랩',
#  '고장',
#  '견고',
#  '타입',
#  '충전',
#  '빠르고',
#  '무게',
#  '크기',
#  '케이스',
#  '고급',
#  '베개',
#  '센스',
#  '많은데',
#  '해결',
#  '미니',
#  '고데기',
#  '케이스',
#  '디자인',
#  '작은',
#  '파우치',
#  '견고',
#  '심플',
#  '충전',
#  '콘센트',
#  '파우치',
#  '포트',
#  '케이스',
#  '좋고요',
#  '콘센트',
#  '충전',
#  '동시',
#  '충전',
#  '최대',
#  '충전',
#  '시도',
#  '미국',
#  '디자인',
#  '마트',
#  '크기',
#  '작았',
#  '충전기',
#  '전기포트',
#  '방문',
#  '전기포트',
#  '어댑터',
#  '어댑터',
#  '불안',
#  '파우치',
#  '어댑터',
#  '충전',
#  '괜찮았',
#  '멀티탭',
#  '220V',
#  '코드',
#  '충전',
#  '포트',
#  '같아서요',
#  '작아서',
#  '휴대',
#  '유럽',
#  '파우치',
#  '마감',
#  'C타입',
#  '포트',
#  'C타입',
#  '포트',
#  '충전',
#  '35W',
#  '최대',
#  '유럽',
#  '충전',
#  '많은데',
#  '핸드폰',
#  '수신기',
#  '충전',
#  '편하네요',
#  '디자인',
#  'C타입',
#  '편지',
#  '사은품',
#  '호주',
#  '핸드폰',
#  '충전',
#  'USB포트',
#  'C타입',
#  'A타입',
#  '케이스',
#  '정리',
#  '가능',
#  '핸드폰',
#  '워치',
#  '충전',
#  '간편',
#  '충전',
#  '속도',
#  '감동',
#  '케이스',
#  '빠르게',
#  '재송',
#  '케이스',
#  '견고',
#  '충전',
#  '이것저것',
#  '완성도',
#  '충전',
#  '해외여행',
#  '전기',
#  '코드',
#  '타입',
#  '핸드폰',
#  '충전',
#  '가능',
#  '충전',
#  '빠르고',
#  '멀티탭',
#  '충전기',
#  '불편',
#  '핸드폰',
#  '보조배터리',
#  '동시충전',
#  '손',
#  '편지',
#  '박싱',
#  '기분',
#  '케이스',
#  '디자인',
#  '파우치',
#  '코드',
#  '체결',
#  '충전',
#  '디자인',
#  '충전',
#  '포트',
#  '충전',
#  '파우치',
#  '크기',
#  '포스트잇',
#  '의견',
#  '무게',
#  '알차서',
#  'C타입',
#  '최대',
#  '있으면',
#  '해외',
#  '충전기',
#  '퓨즈',
#  '파우치',
#  '밤새',
#  '충전',
#  '유럽',
#  '충전',
#  '선',
#  '충전',
#  '어댑터',
#  '홍콩',
#  '계획',
#  '콘센트',
#  '다르다고',
#  '지',
#  '멀티어댑터',
#  '필리핀',
#  '충전',
#  '보조배터리',
#  '충전',
#  '부족',
#  '국가',
#  '가능',
#  '해외여행',
#  '배터리',
#  '없을',
#  '정성',
#  '메모',
#  '구성품',
#  '콘센트',
#  '작동',
#  '동시',
#  '충전',
#  ...]

# %%
from collections import Counter
remain_freq = Counter(remove_stopwords2).most_common()
df_remain_freq = pd.DataFrame(remain_freq, columns=['형태소', '빈도'])
df_remain_freq
# Out:
#        형태소    빈도
# 0       충전  1227
# 1      케이스   926
# 2      디자인   545
# 3      어댑터   381
# 4      콘센트   331
# ...    ...   ...
# 1381   그리스     1
# 1382    두께     1
# 1383  문제없어     1
# 1384    도어     1
# 1385  귀엽군요     1
#
# [1386 rows x 2 columns]

# %%
from pprint import pprint
print(df_remain_freq)
# Out:
#        형태소    빈도
# 0       충전  1227
# 1      케이스   926
# 2      디자인   545
# 3      어댑터   381
# 4      콘센트   331
# ...    ...   ...
# 1381   그리스     1
# 1382    두께     1
# 1383  문제없어     1
# 1384    도어     1
# 1385  귀엽군요     1
#
# [1386 rows x 2 columns]

# %%
df_remain_freq.to_csv('C:/Users/songy/Desktop/Data/product_keyword.csv', encoding = 'utf-8-sig')

# %%
df_remain_freq
# Out:
#        형태소    빈도
# 0       충전  1227
# 1      케이스   926
# 2      디자인   545
# 3      어댑터   381
# 4      콘센트   331
# ...    ...   ...
# 1381   그리스     1
# 1382    두께     1
# 1383  문제없어     1
# 1384    도어     1
# 1385  귀엽군요     1
#
# [1386 rows x 2 columns]

# %% [markdown]
# ### 키워드별 속성 추출 알고리즘 구축

# %%
product.head(3)
# Out:
#   add_rule_based_split_review    changed_text Tokenized_sentence  \
# 3    금액 차이 얼마 안 나는데 기능은 더 좋아요            [기능]                 기능
# 4  콤팩트한 디자인과 실용성에 높은 점수 주었습니다  [콤팩트, 디자인, 실용]       콤팩트, 디자인, 실용
# 8           전면 스크래치가 많아서 아쉽네요      [전면, 스크래치]           전면, 스크래치
#
#   Tokenized_morphs
# 3               기능
# 4       콤팩트 디자인 실용
# 8          전면 스크래치

# %%
# 마지막에 해당 코드 코드화하기 (누적 퍼센트, TopN개 파라미터 포함)
for i in range(len(df_remain_freq)):

    # i번째 형태소가 명사에 해당할 경우만 

    # 동적 변수명 생성해 데이터프레임 구성 
    morphs_target = df_remain_freq['형태소'][i]
    var_name = f'df_{morphs_target}'
    globals()[var_name] = product[product['add_rule_based_split_review'].str.contains(f'{df_remain_freq["형태소"][i]}')]


    # 키워드별 형태소 키워드 분석
    var_name2 = f'keyword_freq_{morphs_target}'
    globals()[var_name2] = pd.DataFrame(Counter(sum(globals()[var_name]['changed_text'],[])).most_common(), columns=['형태소', '빈도'])

    ### 앞단 키워드 상위 10개 제외 리스트 저장
    ### 제외한 키워드들만 형태소 feature에 반영될 수 있게, 퍼센트 뽑기 전에 키워드 루프 돌려야 함
    "점검 필요"
    """
    exclude_list = []   # 여기엔 앞에 등장한 키워드들 10개 포함해 누적 저장됨 
    globals()[var_name2] = globals()[var_name2][~globals()[var_name2]['형태소'].isin(exclude_list)]
    exclude_list.extend(list(globals()[var_name2]['형태소'][:10]))
    print(exclude_list)
    """
    "점검 필요 마지막 부분"
    
    # 퍼센트, 누적 퍼센트 feature 추가 
    globals()[var_name2]['퍼센트'] = round((globals()[var_name2]['빈도']/globals()[var_name2]['빈도'].sum())*100,2)
    globals()[var_name2]['누적_퍼센트'] = globals()[var_name2]['퍼센트'].cumsum()

    # 누적 퍼센트에 따른 키워드 데이터프레임 추출
    #c_value        # 누적_퍼센트 파라미터 설정
    c_value = 40
    var_name3 = f'cumsum_keyword_{morphs_target}'
    globals()[var_name3] = globals()[var_name2][globals()[var_name2]['누적_퍼센트']<c_value]    #& (globals()[var_name2]['형태소']!=morphs_target) 제외
# Out:
# ['충전', '고속충전', '충전기', '가능', '포트', '핸드폰', 'C타입', '기기', '동시', '일본']
# ['케이스', '디자인', '고급', '이쁘고', '휴대', '예쁘고', '충전', '어댑터', '색상', '하드']
# ['디자인', '케이스', '이쁘고', '예쁘고', '파우치', '충전', '기능', '색상', '고급', '실용']
# ['어댑터', '멀티어댑터', '충전', '해외여행', '콘센트', '해외', '플러그', '가능', '충전기', '일본']
# ['콘센트', '충전', '어댑터', '해외', '연결', '유럽', '가능', '플러그', '호주', '일본']
# ['파우치', '디자인', '휴대', '예쁘고', '충전', '어댑터', '사은품', '작동', '고급', '마감']
# ['포트', 'USB포트', '충전', 'C타입', '고속충전', '가능', '어댑터', '충전기', '콘센트', '핸드폰']
# ['C타입', '충전', '포트', '타입', 'USB포트', '고속충전', '가능', 'A타입', '단자', '케이블']
# ['가능', '충전', '고속충전', 'C타입', '동시', '포트', '국가', '핸드폰', '세계', '호환']
# ['고속충전', '포트', 'C타입', '충전', '가능', '핸드폰', '퓨즈', 'USB포트', '타입', '해외여행']
# ['멀티탭', '충전', '충전기', '어댑터', '해외여행', '연결', '해외', '가능', '포트', '코드']
# ['충전기', '충전', '어댑터', '선', 'C타입', '짐', '고속충전', '멀티탭', '포트', '핸드폰']
# ['멀티어댑터', '해외여행', '충전', '여행용', '해외', '플러그', '포트', '콘센트', 'C타입', '어댑터']
# ['핸드폰', '충전', '보조배터리', '동시', '가능', '연결', '워치', '고속충전', '일본', '어댑터']
# ['색상', '예쁘고', '이쁘고', '디자인', '케이스', '화이트', '예쁘네요', '블랙', '고급', '성능']
# ['일본', '충전', '돼지코', '콘센트', '어댑터', '멀티어댑터', '핸드폰', '110V', '디자인', '충전기']
# ['휴대', '케이스', '작아서', '파우치', '작고', '디자인', '크기', '사이즈', '무게', '가방']
# ['해외여행', '멀티어댑터', '충전', '어댑터', '플러그', '멀티탭', '케이스', '디자인', 'C타입', '가능']
# ['파스텔', '색상', '예쁘고', '케이스', '톤', '색감', '그린', '이쁘고', '색도', '고급']
# ['젠더', '규격', '어댑터', '미국', '220V', '국내', '안정', '가능', '고속충전', '플러그']
# ['귀마개', '안대', '베개', '택배', '상세', '설명', '기분', '케이스', '고급', '사은품']
# ['크리스털', '클라우드', 'PD', '세계', '핸드폰', '고속충전', '낮아서', '돼지코', '국가', '콘센트']
# ['크리스털', '클라우드', 'PD', '세계', '핸드폰', '고속충전', '낮아서', '돼지코', '국가', '콘센트']
# ['일반형', '고급', 'USB형', '좋음', '옆쪽', '코드', '구분', '상자', '표시', '돼지코']
# ['본체', '콘센트', '충전', '호주', '스위치', '유럽', '같은', '불안감', '연결', '빠르게']
# ['도시락', '와이파이', '충전', '핸드폰', '외국', '유럽', '고속충전', '보조배터리', '충천']
# ['이동', '케이스', '파우치', '파손', '우려', '안심', '디자인', '합격', '코트', '색깔']
# ['변환기', '콘센트', '해외여행', '같더라고요', '배터리', '충전', '안정', '멀티탭', '조합']
# ['무리', '충전', '기기', '마무리', '포트', '고속충전', '카메라', '핸드폰', '전자제품', '주파수']
# ['저녁', '충전', '전일', '동남아', '동시', '핸드폰', '보조배터리', '케이스']
# ['없음', '기능', '멀티탭', '문제없음', '해외', '작아서', '단점', '커버', '가능', '고출력']
# ['콘센트', '어댑터', '무거워서', '충전기', '연결', '충전', '본체', '같은', '브랜드', '불편']
# ['충전', '가능', '포트', '여러나라', '기기', '동시', '어댑터', '콘센트', '케이블', '충전기']
# ['충전', '케이스', '휴대', '간편', '디자인', '사용법', '가능', '성능', '사이즈', '작고']
# ['완성도', '높아', '디자인', '성능', '높고', '고급', '크기', '안전성', '뛰어나고', '의사']
# ['헤어', '드라이기', '충전', '고속충전', '바람', '약하게', '다이슨', '기기', '단독', '헤어드라이어']
# ['캐나다', '멀티어댑터', '콘센트']
# ['상세', '설명', '전기', '페이지', '괜찮은', '있단', '퓨즈', '케이스', '귀마개', '안대']
# ['첨', '불량', '콘센트', '어댑터', '일본', 'C타입', '충전', '속', '멀티탭', '인증']
# ['용량', '포트', '퓨즈', '아쉽지만', 'C타입', '고속충전', '내장', '체결', '안전', '있는데요']
# ['결정', '디자인', '퓨즈', '멀티어댑터', '있다고', '영구', '고속충전', '합리', '여러나라', '사면']
# ['쉽고', '사용법', '편하네요', '색상', '짐', '속', '모양', '케이스', '디자인', '해외']
# ['필리핀', '충전', '핀', '충전기', 'USB포트', '220V', '보조배터리', '고속충전', '어댑터', '포트']
# ['스페인', '어댑터', '콘센트', '고생', '타제품', '색상', '디자인', '빠르고', '기회', '헐겁게']
# ['비싸긴', '퀄리티', '부피', '괜찮은', '고속충전', 'C타입']
# ['은근', '케이스', '짐', '보조', '배터리', '유언비어', '캐리어', '기내', '귀찮죠', '해외']
# ['완전', '충전', '케이스', '콘센트', '충전기', '포트', '디자인', '예쁘고', '대만', '홍콩']
# ['이후', '돼지코', '충전', '국', '오랜만', '론', '타입', '헐겁고', '첫날', '일본']
# ['유저', '아이폰', '타입', '플러그', 'USB포트', 'C타입', '포트', '갤럭시', '애플워치', '수신기']
# ['검은', '색', '검은색', '흰색', '예쁘고', '파우치', '관리', '보통', '색상', '멀티탭']
# ['통신사', '공항', '어댑터', '재고', '평소', '고가', '기기', '고장', '많은', '불안']
# ['침대', '받침대', '콘센트', '서비스', '어댑터', '무게', '색', '이쁘고', '위', '없을']
# ['무용지물', '어댑터', '고정', '브랜드', '지', '크고', '무거워서', '지팅스']
# ['어댑터', '콘센트', '일본', '렴', '돼지코', '전기', '소리', '상품', '고장', '기능']
# ['안쪽', '깊은', '입구', '개선', '좋은데', '불편', '괜찮은']
# ['구조', '플러그', '버튼', '손', '속도', '사양', '있더라고요']
# ['손상', '케이스', '파우치', '미국']
# ['각도', '조절', '베개', '고생', '첨', '콘센트', '호주', '도로', '해외여행', '충전기']
# ['각도', '조절', '규격', '전압', '커넥터', 'PD', '첨', '콘센트', '호주', '도로']
# ['발리', '다이슨', '어댑터', '신혼', '일본']
# ['신혼', '다이슨', '발리', '어댑터', '일본', '계획', '멀티어댑터', '비교', '스위스', '예정']
# ['헐겁다고', '사이즈', '작네요', '상품평', '헐겁긴']
# ['충전', '많다', '케이블', 'C타입', '형식', '많다는', '단점', '이것저것', '넓다는', '디바이스']
# ['예쁘게', '충전', '검정', '케이스', '디자인', '멀티탭']
# ['하와이', '가능', '다이슨', '하와']
# ['높았', '최근', '대만', '태국', '최고', '효율', '소지품', '고속충전', '짱', '케이스']
# ['본품', '노랑', '구성품', '어댑터', '플러그', '콘셉트', '소켓', '기능', '색감', '기엽']
# ['휴대', '케이스', '대용', '무게', '파우치', '멀티탭', '크기', '휴대용', '가볍고', '작고']
# ['스마트폰', '충전', '스마트', '연결', '마트', '워치', '기기', '35W', '고속충전', '포트']
# ['방문', '어댑터', '전기포트', '여러나라', '기기', '편하네요', '크로아티아']
# ['같아서요', '충전', '포트', '코드']
# ['수신기', '충전', '핸드폰', '보조배터리', '유저', '편하네요', '이탈리아', '아이폰', '갤럭시', '애플워치']
# ['체결', '포트', '퓨즈', '코드', '충전', 'C타입', '고속충전', '용량', '내장', '안전']
# ['충전', '밤새', '유럽', '일본']
# ['충전', '케이스', '돼지코', '콘센트', '파우치', '어댑터', '디자인', '포트', 'C타입', '고속충전']
# ['안정', '정성', '손', '편지', '플러그', '메모', '구성품', '감동', '디자인', '예쁘고']
# ['메모', '정성', '구성품', '사은품', '파우치', '사람', '감동']
# ['쪽지', '작지만', '사은품', '기분', '손', '동', '케이스', '귀엽네요', '멀티탭', '탈']
# ['영상', '불량', '인증', '이미지', '실물']
# ['소형', '어댑터', '세계', '기기', '가능', '내구', '높아', '가방', '가전제품']
# ['수화물', '무게', '상관', '보관함']
# ['반품', '코드', '상자', '기분', '귀찮아서']
# ['타제품', '비교', '충전', 'USB포트', '많은', 'C타입', '포트', '스페인', '어댑터', '고생']
# ['형식', 'C타입', '충전', '많다는', '있도', '편하네요', '어댑터', '케이스', '파우치']
# ['아래쪽', '케이블', '불편', '충전', '홍콩', '모양', '사람', '해외', '포트']
# ['느리지만', '충전', '성능', '여러나라', '전기', '규격', '편하네요']
# ['고출력', '작아서', '단점', '커버', '가능', '없음', '고속충전']
# ['고심', '브랜드', '고가', '도넛', '고속충전', '속']
# ['위주', 'USB포트', '포트', '비싸고', '노트북']
# ['매끄럽고', '어댑터', '작고', '가격대', '있어도', '견고', '플러그', '교체', '방법', '비싸서']
# ['주의', '케이블', '호주', '낙하', '파손', '출력', '충전', '속도', '여행용', '국가']
# ['유격', '같은', '고속충전', '플러그', '콘센트', '사이', '충전', '전기', '고정']
# ['괌', '멀티어댑터', '준비물', '디자인', '없더라고요']
# ['어댑터', '충전', '케이스', '충전기', '돼지코', '존', 'C타입', '고속충전', '비교', '사이즈']
# ['주머니', '어댑터', '가방', '쉽게', '휴대']
# ['같음', '고데기', '어댑터', '홍콩', '일본', '케이블', '많은', '옐로', '색상', '색']
# ['실망', 'C타입', '연결', '유럽']
# ['분리', '플러그', '어댑터', '콘센트', '본체', '코드', '돼지코', '고생', '동시', '충전']
# ['파란색', '포인트', '좋고요', '이쁘네요', '전원']
# ['포인트', '파란색', '좋고요', '콤팩트', '보라색']
# ['높습니다', '크기', '작아', '휴대', '외관', '이쁘고', '케이블']
# ['신속', '품질', '보조', '배터리', '충전']
# ['보유', '케이스', '작고', '상품', '교체', '퓨즈', '여러나라', '어댑터', '정리', '멀티어댑터']
# ['충전', '베트남', '어댑터', '동남아', '일본', '콘센트', '핸드폰', '파우치', '포트', '돼지코']
# ['연수', '어학', '중국', '색', '독일', '여기저기', '페이지']
# ['연결선', '선', 'C타입', '상관', '없을', '선도', '포트']
# ['예상', '마감', '기능', '외형', '헐겁지만', '충전']
# ['부드럽고', '어댑터', '디테일', '콤팩트', '디자인', '코드', '조작', '국내', '콘센트', '돼지코']
# ['스토어', '클리', '커스', '케이블', '사은품', '불량품', '양품', '스마트', 'PD35W', '멀티어댑터']
# ['영구', '퓨즈', '반영구', '고속충전', '합리', '디자인', '결정', '해외', '괜찮은데']
# ['합리', '멀티어댑터', 'C타입', '영구', '퓨즈', '고속충전', '디자인', '결정', '상품', '구성품']
# ['부착', '충전', '해외', '220V', '전압', '국가', '멀티어댑터', 'A타입', '충전기', '타입']
# ['충전기', '해외여행', '가능', '이제', '충전', '어댑터', '멀티탭', '세계', '이것저것', '110V']
# ['샤오미', '멀티탭', '플러그', '카페', '같은', '없으니까', '어댑터']
# ['핑크', '색', '품절', '예쁘고', '사이즈', '실버', '라인', '고급', '여행용', '멀티어댑터']
# ['품절', '핑크', '색', '예쁘고', '사이즈', '흰색', '검정', '블랙', '그레이', '컬러']
# ['면세점', '참고', '할인', '전선', '무거워서', '충전기', '무게', '콘센트', '손', '불편']
# ['자동', '리스팅', '퓨즈', '매력', 'PD35W']
# ['패키징', '고급', '파우치', '타사', '비싸다는', '65W', '디자인', '돈값']
# ['무겁게', '충전기', '콤팩트', '멀티탭', '다이슨', '어댑터']
# ['충전', '어댑터', '콘센트', '속도', '디자인', '케이스', '같은', '고속충전', '고정', '플러그']
# ['준비물', '괌', 'C타입', '개수', '해외여행', '국내', '멀티탭', '충전']
# ['높아', '높아서', '높아요', '완성도', '와트', '포트', '디자인', '멀티탭', '소형', '내구']
# ['라인', '실버', '핑크', '고급', '디자인', '예쁘고', 'C타입', '많아', '온라인', '최저가']
# ['변경', '핀', '쉽습니다', '플러그', '슬라이드', '형태', '휴대', '여러나라', '가능', '하얀색']
# ['스트레스', '콘센트', '해외여행', '돼지코', '멀티탭']
# ['허용', '가능', '무게', '35W', '국가', '감안', '수준', '코시', '중국', '접지']
# ['크네요', '크기', '작은', '사이즈', '영국']
# ['콘센트', '110V', '짜리', '충전', '연결', '국내', '질', '외출', '좋다고', '크기']
# ['이탈리아', '충전', '모양', '어댑터', '없긴', '충전기', '수신기', '핸드폰', '보조배터리', '같은']
# ['많습니다', '기기', '포트', '충전', '개수']
# ['같지', '같지만', '가격대', '포트', '개수', '남', '똑같지', '충전', '속도', '없길']
# ['여행사', '고정', '어댑터', '짜증', '견고', '벽면', '현상', '불편', '많았']
# ['짜증', '충전', '여행사', '고정', '견고', '많은데', '선도', '이것저것', '선', '많아']
# ['선풍기', '보조배터리', '핸드폰', '충전', '해외여행', '여럿', '손', '무게']
# ['뛰어나고', '디자인', '추가', '많은', '도움', '안전성', '완성도', '높아', '의사', '있습니다']
# ['충천', '휴대', '고속', '색감', '무게', '고속충전', '보조배터리', '도시락']
# ['올해', '어댑터', '베트남', '같은', '220V', '유럽']
# ['감수', '불편', '플러그', '콘센트', '작아서', '추가', '어댑터', '렁', '해외', '정작']
# ['편의', '디자인', '예쁘고', '안전', '기능', '성능']
# ['빠르다고', '충전', '속', '해외여행', '해외', 'C타입', '타입']
# ['충전', '문제없고', '성능', '해외', '유에스비', '연결', '다리', '고속충전', '패키지', '동작']
# ['세팅', '퓨즈', '펌프', '수동', '교체', '자동', '입', '오토리', '베개', '힘들게']
# ['비싸서', '가격대', '슬라이드', '매끄럽고', '케이스', '고급']
# ['있어도', '가능', '멀티탭', '핸드폰', '태블릿', '워치', '보조배터리', '해결', '가격대', '견고']
# ['점검', '충전', '작동', '상태', 'C타입', '유에스비', '단자']
# ['있어야', '충전기', '무게', '면세점', '할인', '전선', '무거워서', '콘센트', '손', '불편']
# ['원활', '충전', '고속충전', '가능', '전압', '변환']
# ['모드', '고속충전', '콘센트', '해외', '포트', 'PD45W']
# ['신중', '많았', '비교', '어댑터', '고생', '멀티어댑터']
# ['뉴질랜드', '충전', '호주', '콘센트', '스위치', '버튼', '빠르고', '스마트폰']
# ['많지', '어댑터', '코드', '콘센트', '기기', '동시', '충전', '일반', '불안', '없습니다']
# ['퓨즈', '자동', '복구', '교체', '오토리', '기능']
# ['퓨즈', '오토', '오토리', '기능', '업그레이드', '버전', '급속', '충전', '세팅', '과부하']
# ['손바닥', '크기', '멀티탭', '없을', '많거나', '사이즈']
# ['작성', '드라이기', '정확', '출력', '불가', '콘센트', '단자', '충전기', '가능', '추측']
# ['높아서', '와트', '포트', '멀티탭', '미국', '귀국', '출력']
# ['경험', '콘센트', '해외', '플러그', '무게', '불편', '선', '없을', '가능', '설명']
# ['제작', '플러그', '헐겁지', '안전', '포트', '220V', '콘센트', '가늘어서']
# ['국제', '충전기', '호주', '탭', '국내', '콘센트', '헐겁네요', '중국', '멀티어댑터', '충전']
# ['카페', '멀티탭', '실용', '샤오미', '같은', '없으니까']
# ['이쁘기', '디자인', '패키지']
# ['같았', 'USB포트', '포트', '멀티탭', '어댑터', '전압', '동시', '충전']
# ['색', '그린', '어댑터', '파우치', '민트', '색상', '볼트', '옐로', '파스텔', '예쁘고']
# ['후쿠오카', '충전', '어댑터', '불편']
# ['특성', '콘센트', '멀티어댑터', '일본', '규모', '낮은', '위치', '케이스', '산티아고', '동시']
# ['제외', '220V', 'C타입', '구멍', '작동', '편', 'PD충전']
# ['가볍습니다', '작고', '크기', '이쁘고']
# ['야무지고', '실용', '디자인', '포트', '케이스']
# ['디자인', '인상', '케이스', '품질', '긍정']
# ['판매자', 'C타입', '포트', '보라색', '어댑터', '사은품']
# ['한방', '충전', '노트북', '갤럭시', '워치', '담배', '자리']
# ['고급', '케이스', '디자인', '충전', '급속', '파우치', '어댑터', '예쁘고', '골드', 'C타입']
# ['캠핑', '충전', '220V', '국내', '가능', '포트', '멀티탭']
# ['퓨즈', '오토리', '기능', '세팅', '교체', '자동', '복구', 'C타입', '고속충전', '포트']
# ['없으면', '이태리', '구멍', '작고', '스위스', '모양', '다르기에', '어댑터', '전기', '퓨즈']
# ['신뢰', '귀사', '디자인', '어댑터', '고장', '일본']
# ['완충', '워치', '핸드폰', '멀티탭', '충전기', '충전']
# ['세대', '멀티탭', '고속', '가능', '불편', '노란색', '고속충전', '파랑']
# ['호주', '회전', '플러그', '콘센트', '어댑터', '안정', '110V', '스파크', '충전기', '코시']
# ['메시지', '연결', '노트북', '충전', '손', '글씨', '감동', '스마트폰', '케이블', 'C타입']
# ['쿠폰']
# ['기능', '충실', '어댑터', '기본', '상품', '디자인', '해당', '여행지', '콘센트', '불편']
# ['수량', '어댑터', '기능', '타입', '색깔', 'C타입']
# ['주변', '충전']
# ['방지', '케이블', '플러그', '헐렁이', '파손', '완벽', '과부하', '퓨즈']
# ['과부하', '오토', '리셋', '해결', '선', '디자인', '충전', '없다는', '방지', '퓨즈']
# ['사면', '멀티어댑터', '코드', '돼지코', '지', '아깝지', '콘센트', '헐겁다는데', '사용법', '선']
# ['예쁘더라고요', '로즈', '색상', '풀', '화이트', '색깔', '고급', '골드']
# ['화재', '위험', '현지', '공항', '중국', '불량', '콘센트', '있다던데', '안심', '포트']
# ['사항', '권장', '있는데', '위아래', '충전', '많은', '상황', '국내', '위험', '취지']
# ['충전', '어댑터', '비교', '포트', 'C타입', '유에스비', '콘센트', '가성비', '멀티어댑터', '해외여행']
# ['싫어서', '불안', '해외', '블로그', '브랜드', '사은품', '첨', '사고', '깜놀', '어댑터']
# ['통일', '전선', '멀티탭']
# ['컴퓨터', '국내', '책상', '미국', '폰', '충전', '멀티탭', '사무실', '디자인']
# ['슬라이드', '초록색', '플러그', '변경', '형태', '휴대', '여러나라', '가능', '고정', '비싸서']
# ['무선', '핸드폰', '이어폰', '충전', '패드', '노트북', '멀티어댑터', '콘센트', '충전기']
# ['좋지만', '사이즈', '작아서', '부담', '패키지', '세계', '규격', '콘센트', 'USB포트', '최고']
# ['남자', '오사카', '스페이스', '그레이', '충전', '콘센트']
# ['조합', '임원', '오포', '마트', '변환기', '멀티탭']
# ['전환', '전기', '충전', 'A타입', '아쉽지만', '추가', '기능', '스위치']
# ['램프', '표시', '스위치', '맛나요', '아쉽기', '밝습니다']
# ['실용', '디자인', '충전', '실물', '예쁘고', '색상', '어댑터', '기능', '분실', '케이스']
# ['업무', '멀티어댑터', '플러그', '해외여행', '최근', '일본', '노트북', '45W', '충전', '가능']
# ['접속', '콘센트', '해외여행', '시도', '체결', '상태']
# ['외부', '충격', '괜찮은', '재질', '특징', '케이블']
# ['디자인', '이쁘고', '이쁘고요', '색상', '정상', '작동', '색']
# ['의사', '있습니다', '최고', '성능', '국내', '위험', '사항', '취지', '이해', '어렵네요']
# ['인식', '충전', '고속', '미국', '속도', '나쁘지']
# ['내부', '고정', '밴드', '신경', '케이스', '캐리어', '퓨즈', '안심']
# ['크지만', '크기', '포트', 'C타입', '포트만', '플러그', '디자인']
# ['책상', '컴퓨터', '멀티탭', '권장', '사항', '있는데', '위아래', '충전', '많은', '상황']
# ['트래블러', '키트', '충전기', '콘센트', '변환', '220V', '같은', '참고']
# ['트래블러', '키트', '충전기', '콘센트', '변환', '220V', '같은', '참고']
# ['띠', '칸', '케이블', '소리', '어댑터', '돼지코']
# ['전면', '스크래치', '불']
# ['없긴', '콘센트', '지장', '이탈리아', '모양', '어댑터', '충전기', '충전']
# ['EU타입', '콘센트', '전원', '고정']
# ['유선', '충전', '칸', '장점', '있어요', '멀티탭', '국가', '가능']
# ['한몫', '디자인', '어댑터', 'USB포트']
# ['쿠션', '케이스', '충전']
# ['동유럽', '보조배터리', '충전', '콘센트', '안심', '멀티어댑터', '좋다고', '가능', '도움']
# ['가실', '부모', '성능', '좋으면', '변압기', '해외여행']
# ['좋으면', '부모', '가실', '성능']
# ['파손', '우려', '파우치', '이동', '케이스', '적었']
# ['충전', '속도', '빠르지', '해외', 'USB포트', '핸드폰', '일반']
# ['크긴', '문제없었', '사이즈']
# ['문제없었', '충전', '크긴', '다이슨', '에어', '랩', '동시', '기기', '일본', '빠르게']
# ['개선', '입구', '110V', '충전', '220V', '깊이', '깊지', '일본', '많더군요', '깊은']
# ['깊이', '개선', '110V', '충전', '입구', '220V', '깊지', '일본', '많더군요', '해외']
# ['깊지', '호주', '개선', '110V', '충전', '입구', '220V', '깊이', '일본', '많더군요']
# ['국내외', '해외', '가능']
# ['충전', '고속충전', '충전기', '가능', '포트', '핸드폰', 'C타입', '기기', '일본', '동시']
# ['케이스', '케이블', '디자인', '충전', '고급', '이쁘고', '휴대', '예쁘고', '어댑터', '연결']
# ['불안감', '본체', '같은', '연결', '충전', '빠르게', '콘센트', '있습니다']
# ['한국인', '고속충전', '충전', '타입', '최고']
# ['의자']
# ['가이드', '작년', '공항', '돼지코', '호환', '현지', '도움', '같은', '실수', '비교']
# ['C타입', '충전', '타입', '포트', '고속충전', '어댑터', '가능', 'USB포트', 'A타입', '해외여행']
# ['충전', '케이스', '불편', '휴대', '가능', '어댑터', '편하네요', '콘센트', '디자인', '파우치']
# ['태국', '최근', '대만', '최고', '효율', '높았', '소지품', '고속충전', '짱', '일본']
# ['소지품', '최근', '대만', '태국', '최고', '효율', '높았', '고속충전', '짱', '게임']
# ['블로그', '접촉', '불량', '있다고', '돼지코', '불안', '해외', '싫어서', '브랜드', '사은품']
# ['충전', '시도', '동시', '최대', '미국', '전력', '표시', '콘센트', '접속', '해외여행']
# ['작았', '크기', '사이즈']
# ['박싱', '손', '편지', '기분', 'PD충전']
# ['포스트잇', '파우치', '크기', '좋고요']
# ['꽈배기', '선', '정리', '무게', '모양']
# ['문자', '물품', '정리', '토요일', '연결', '포기', '같은', '감동']
# ['포기', '문자', '물품', '정리', '토요일', '연결', '중국', '콘센트', '쎄게']
# ['세계', '가능', '콘센트', '충전', '케이스', '디자인', '고속충전', '타입', '포트', '케이블']
# ['작지만', '사은품', '쪽지', '기분', '콘센트', '두께', '동작']
# ['전기', '있단', '상세', '설명', '돼지코', '고속충전', '포트']
# ['질문', '귀찮을', '설명', '콘센트']
# ['헐겁다고', '헐겁다', '사이즈', '작네요', '콘센트', '헐겁다는데', '사용법', '상품평', '헐겁긴']
# ['서유럽', '어댑터', '정상', '작동', '기기', '충전', '모습']
# ['전화', '방법', '설명', '핸드폰', '전기', '충전', '해결', '전화기', '알람', '시계']
# ['깜놀', '첨', '콘센트', '어댑터', '싫어서']
# ['없다고', '성능', '다이슨', '문제없다고']
# ['양호', '상태', '콘센트', '마감', '충전', '다중', '없어', '디자인']
# ['식구', '동시', '핸드폰', '충전', '보리', '전기']
# ['사이즈', '작네요', '헐겁다고']
# ['콘센트', '세로', '일본', '있습니다', '괜찮은데', '바닥', '고정']
# ['의심', '싸서', '성능', '그렇다고', '부담', '발견']
# ['괜찮은데', '세로', '콘센트', '바닥', '고정', '퓨즈', '영구']
# ['좋지만', '콘센트', '좋지', '해외', '있어요', '보통', '검은색', '흰색', '색상', '멀티탭']
# ['어댑터', '크고', '브랜드', '지', '무거워서', '무용지물', '지팅스', '크기', '무거우니']
# ['앙증맞아요', '파우치', '케이스']
# ['충전기', '괜찮더라고요', '고장']
# ['캡', '케이스', '충전', '선', '영국', '유학', '호환']
# ['단독', '충전', '다이슨', '헤어', '기기', '몸통', '옆쪽', '핀', '고속충전']
# ['앙증맞은', '파우치', '케이블', '정리', '코일', '세심', '케이스']
# ['케이블', '정리', '코일', '앙증맞은', '파우치', '세심']
# ['버스', '참고', '미국', '110V', '콘센트', '충전']
# ['몸통', '옆쪽', '핀', '단독', '고속충전', '지팅스']
# ['충전', '고가', '통신사', '재고', '방법', '참고', '브랜드', '고심', '도넛', '고속충전']
# ['비싸고', '포트', '위주', '도넛', '모양', '유튜브', '가성비', '낫다고']
# ['어댑터', '충전기', '과정', '멀티어댑터', '연결', '선', '멀티탭', '기능', '동남아']
# ['아깝지']
# ['콘센트', '무겁지', '충전', '무게', '헐겁네요', '헐겁긴', '헐겁고', '무겁지만', '헐겁게', '멀티탭']
# ['기내', '보조', '배터리', '유언비어', '캐리어', '은근', '짐', '베개', '사은품', '안대']
# ['상관', '수화물', '연결선', '없을', '볼트', '상관없습니다', '해외', '국내외', '가능']
# ['표기', '쉽게', '케이스']
# ['벨크로', '사은품', '전선', '정리']
# ['소리', '케이스', '가요', '콘센트', '110V', '구멍', '파우치', '없던데', '코드', '없을']
# ['많을', '돼지코', '포트']
# ['파워', '존', '콘센트', '해외', '플러그', '트래블', '어댑터']
# ['높아요']
# ['스페어', '퓨즈']
# ['콘센트', '고정', '해제', '플러그', '케이스', '상태', '버튼', '작동']
# ['귀찮았', '멀티어댑터', '핸드폰', '시계', '이어폰', '충전', '가능', '멀티탭']
# ['일본', '소리', '전기', '괜찮겠', '여행용', '파우치', '사이트', '작동', '남', '그렇다는']
# ['어학', '연수', '중국', '색']
# ['좋군요', '사이즈', '파우치', '성능']
# ['어렵지', '어렵지만', '돼지코', '전력', '사용법', '콘센트', '충전기', '선', '충전', '이기']
# ['접촉면', '고장', '버튼']
# ['부실']
# ['쇠', '호주', '콘센트', '모양']
# ['국내', '있도', '돼지코', '일본', 'C타입', '충전', '불편', '형식', '편하네요', '추가']
# ['충전', '어댑터', '일본', '핸드폰', '가방', '충전기', '멀티탭', '콘센트', '부피', '포트']
# ['가전제품', '최대', '65W', '출력', '핸드폰', '고속충전', '가능', '소형']
# ['짧은', '케이블', '어댑터', '지퍼', '선', '길다고']
# ['두바이', '충전']
# ['충전', '환불', '아이패드', '불량']
# ['응대', '상담']
# ['ㄱ', 'ㄴ']
# ['부품', '전선', '괜찮네요']
# ['충전', '어댑터', '기능', '안정', '있게', '설명서', '케이스', '깊은', '입구', '안쪽']
# ['설계', '안전', '작동', '정상', '포트', '상태']
# ['사이즈', '적어', '적어서', '멀티탭', '정신없는', '작은', '가방', '공간', '디자인', '최적']
# ['늦게', '후회', '뒤늦게', '제값', '해결']
# ['콘센트', '충전', '느', '립니', '호주', '스위치', '응대', '참고', '위쪽', '있는데']
# ['나은', '고정']
# ['전원', '콘센트', '결착', '코드', '안정', '역', '포트']
# ['잦은', '충전', '해외여행', '돼지코', '스트레스', '폰', '같은', '사람', '최고']
# ['합격', '디자인', '코트', '이동', '성능']
# ['코트', '디자인', '합격', '이동', '좋은지', '포트']
# ['실버', '보라색', '핑크', '라인', '고급']
# ['적어서', '디자인', '사이즈', '최적', '짐', '케이스', '파손']
# ['케이스', '쉽습니다', '마감', '공간', '핀', '변경', '무게', '국내', '없다는', 'USB포트']
# ['인도', '콘서트', '디자인', '휴대', '좋은데', '설명서', '쉽게', '이해']
# ['어댑터', '비싸게', '지속']
# ['지속', '자분', '어댑터', '비싸게', '문의', '톡', '진행', '빠르게', '참고', '해외']
# ['차원', '무게', '다르네요']
# ['무게', '가능', '감안', '35W', '국가', '허용', '수준', '급속', '충전']
# ['가능', '수준', '무게', '35W', '국가', '감안', '허용', '멀티탭', '불편']
# ['말레이시아', '일본', '휴대', '220V', '코드', '모양']
# ['단자', '충전', '케이스', 'C타입', '디자인', '단점', '파우치', '고속충전', '작동', '어댑터']
# ['퓨즈', '조건', '자동', '진심']
# ['양품', '스토어', '불량품']
# ['홍콩', '마카오', '세부', '멀티탭', '고속충전', '헤어', '드라이기', '동시']
# ['충전', '한쪽', '해외여행', '핸드폰', '불편', '케이블', '어댑터']
# ['예쁘기', '오색', '케이스']
# ['다용도', '다용', '코드', '장점', '공간', '적게', '멀티탭', '많은', '일본', '멀티어댑터']
# ['호주', '위쪽', '스위치', '콘센트', '있는데', '포트', '본체', '해외', '구멍', 'USB포트']
# ['제값', '뒤늦게', '충전', '포트', '비싸도']
# ['사이판', '콘센트', '접촉', '110V', '속도']
# ['낮아서', '일본', '전압', '충전', '핸드폰', '고속충전', '크리스털', '클라우드']
# ['그렇다고', '돼지코', '싸서', '성능', '의심', '부담', '발견']
# ['첫날', '고주파', '음', '헐겁고', '이후']
# ['고주파', '첫날', '음', 'A타입', '충전', '소리']
# ['시중', '이것저것', '비교', '출력', '같더라고요', '어댑터', 'USB포트', '많은']
# ['같더라고요', '이것저것', '비교', '시중', '출력', '변환기', '일본', '45W', '업그레이드', '똑같더라고요']
# ['무겁습니다']
# ['대접', '케이스', '고급', '화이트', '골드', '색상']
# ['불빛', '실용', 'USB포트', '강하네요']
# ['흔하지', '케이스', '블랙', '색상', '색']
# ['세계', '가든', '한국인', '고속충전', '어댑터', '해외', '없음', '파우치', '돼지', '멀티탭']
# ['돼지코', '일본', '충전', '연결', '어댑터', '작동', '국내', '콘센트', '충전기', '플러그']
# ['국내', '없지', '기능', '포트', '장점', '디자인', '크기', '방법', '일본', '돼지코']
# ['몰디브', '디자인']
# ['앙증맞게', '작은', '파우치', '예쁘고요', '색상']
# ['충전', '다리', '없을', '가능', '해외', '유에스비', '연결', '문제없고', '권장', '사항']
# ['최신', '나이스', '폰', '사양']
# ['나이스', '최신', '포트']
# ['수동', '버튼', '퓨즈', '교체', '자동', '세팅', '입', '불편']
# ['사양', '최신', '폰', '구조', '속도', '있더라고요']
# ['충전', '디바이스', '많다면']
# ['없기', '고장']
# ['면세점', '참고', '면세', '할인', '전선', '무거워서', '충전기', '무게', '콘센트', '손']
# ['같다는', 'C타입', '없는데', '아쉬움', '파우치', '색', '개인']
# ['매력', '자동', '리스팅', '퓨즈', 'PD35W', '국가', '가능', '기기', '충전']
# ['괜찮아서', '디자인', '여자', '퀄리티']
# ['소장', '가치', '케이스']
# ['가치', '소장', '있다고']
# ['무겁다', '고정', '가능', '좋은데', '호주', '콘센트', '형태', '접촉', '물통']
# ['여행사', '어댑터', '고정', '행사', '여권', '케이스', '짜증', '견고', '필수품', '충전']
# ['상품', '똑같아요', '페이지']
# ['강하네요', '고속충전', '크기', '작은', '메리트', 'USB포트', '불빛']
# ['무적', '동남아', '만능']
# ['도중', '일본', '110V', '멀티탭', '발견', '작동', '내구']
# ['일자', '모양', '원형', '부피', '적게', '드라이버']
# ['원형', '일자', '모양', '부피', '적게', '플러그', '간섭']
# ['적게', '일자', '모양', '원형', '부피', '공간', '다용', '멀티탭', '많은']
# ['장비', '충전', '해외', '국내']
# ['다용도', '다용', '코드', '장점', '공간', '적게', '멀티탭', '많은', '일본', '멀티어댑터']
# ['좋다는', '휴대']
# ['충전', '띠', '돼지코', '지금', '칸', '케이블', '소리', '어댑터', '불량', '인증']
# ['부피', '적고', '효율', '없고요', '용도']
# ['케이스', 'C타입', '충전', '고정', '콘센트', '괜찮은데', '쉽네요', '없다는', '국내', '퓨즈']
# ['나머지', '헐겁고', '장점', '있습니다']
# ['새롭게', '타입']
# ['퓨즈', '차단', '포트', 'C타입', '고속충전', '오토리', '전력', '누전', '차단기', '기능']
# ['추측', '기기', '출력', '멀티어댑터', '없을', '단자', '충전기', '드라이기', '가능', '퓨즈']
# ['성능', '발휘', '이것저것', '해외']
# ['무겁고', '멀티탭', '워치', '폰', '에어팟', '보조배터리', '충전', '부피']
# ['절약', '공간', '멀티탭', '디자인', '충전']
# ['유니버설', '멀티탭', '해외', '돼지코', '콘센트', 'C타입', '고속충전', '동작']
# ['슈퍼', '베이글', '표시', '화이트', '핸드폰', '갤럭시', 'C타입', '고속충전', '충전']
# ['발생', '아웃렛', '스위치', '현상', '불편', '보조', '충전기', '충전', '사고', '이후']
# ['소켓', '플러그', '본품', '콘셉트', '기능']
# ['기능', '비싸다는', '디테일', '좋다면', '살', '타사', '65W', '디자인', '패키징', '돈값']
# ['콘센트', '다중', '호주', '멀티탭', '스위치', '마감', '충전', '상태', '없어']
# ['다르기', '전자제품', '주파수', '무리', '이태리', '구멍', '작고', '스위스', '모양', '다르기에']
# ['유럽', '충전', '포트', '콘센트', 'C타입', '유에스비', '어댑터', '케이스', '가능', '고속충전']
# ['귀염', '색상', '사이즈']
# ['칼라', '케이스', '이쁘고', '실용', '예쁘고', '성능']
# ['실용', '디자인', '이쁘고', 'USB포트', '충전', '실용성', '요즈음', '해외여행', '콤팩트', '충전기']
# ['취향', '민트', '색상', '색']
# ['장바구니', '멀티탭', '할인', '이벤트']
# ['레몬색', '이쁘고', '단점', '사이즈', '하드']
# ['덤', 'C타입']
# ['배송굿', '퀄리티', '디자인']
# ['컴포트', '사이즈', '색감']
# ['쓰임새']
# ['밴드', '고정', '케이스', '내부', '신경']
# ['비싸서', '싸서', '케이스', '가격대', '없고요', '성능', '의심', '그렇다고', '부담', '발견']
# ['품목', '어댑터', '좋다고', '충전', '속도', '느리고']
# ['보완', '케이스', '충격']
# ['규모', '콘센트', '일본', '특성', '낮은', '위치', '케이스', '유럽', '작은', '지역']
# ['낮은', '일본', '규모', '특성', '콘센트', '위치', '케이스', '전력', '성능', '헤어']
# ['귀엽고', '케이스', '파우치', '귀엽네요', '사이즈', '디자인', '색감', '색상', '귀마개', '어댑터']
# ['같긴', '귀엽고', '인테리어', '효과', '케이스', '자크']
# ['커플', '색상']
# ['보코', '하드', '케이스', '색상', '소', '렴', '멀티어댑터']
# ['같지만', '충전', '속도', '없길', '케이스']
# ['하늘색', '콤팩트']
# ['색상', '밝아서', '성능', '기분', '비싸도']
# ['케이스', '자크', '휴대', '좋은데', '같긴']
# ['양쪽', '글씨', '불량']
# ...
# ['충전', '동행', '비교', '제거']
# ['알리', '비싸네요']
# ['전반', '무게', '디자인', '품질']
# ['헐겁지만', '충전', '예상']
# ['위아래', '콘센트', '권장', '사항', '있는데', '충전', '많은', '상황', '좋은데', '부피']
# ['두껍고', '괜찮은', '케이스', '이쁘고']
# ['파스텔', '톤', '색도', '컬러']
# ['야무지고', '야무', '케이스', '보조배터리', '충전', '야무지게', '사이즈', '파우치', '좋군요', '실용']
# ['반영구', '해외']
# ['게임', '세계', '호환', '가능', '멀티어댑터', '소지품']
# ['설명서', '어르신', '쉽게', '세계', '각국', '충전', '가능', '플러그', '기계', '안내']
# ['받침대', '서비스', '콘센트', '어댑터', '무게']
# ['충전', '케이스', '충전기', '기능', '크기', '휴대', '어댑터', '기기', '디자인', '포트']
# ['펌프', '베개', '힘들게', '세팅']
# ['삽입', '깊게', '국내', '플러그', '헐겁습니다']
# ['기간', '일본', '기기', '충전', '해외여행', '돼지코', '고정', 'USB포트', '부족']
# ['두렵지']
# ['좋은지', '불량', '어렵네요', '코트', '포트']
# ['어렵네요', '불량', '좋은지', '국내', '위험', '사항', '취지', '이해']
# ['직구', '최근', '돼지코', '얇은', '코드', '커버', '싱가포르', '전압', '잭', '진행']
# ['구매처', '어댑터', '제거', '좋다고']
# ['투명', '라이브', '해외여행', '어댑터', '설정', '멀티어댑터', '알람']
# ['투명', '라이브', '해외여행', '어댑터', '설정', '멀티어댑터', '알람']
# ['어댑터', '와중', '호주', '발견']
# ['케이스', '충전', '디자인', '고급', '콘센트', '이쁘고', '어댑터', '예쁘고', '휴대', '포트']
# ['알람', '설정', '투명', '멀티어댑터', '라이브', '전화기', '시계']
# ['사이즈', '콤팩트', '작고', '작아서', '케이스', '작은', '휴대', '디자인', '충전', '가방']
# ['구분', '상자', '표시', '일반형', '전압', '멀티어댑터']
# ['비싸다고', '돼지코', '포트', '케이스']
# ['외형', '예상', '기능', '마감', '고급']
# ['색', '퍼플', '디자인', '예쁘고', '고급', '돼지코', '짐', '색상', '보통', '트렌디']
# ['해외', '잦아서', '평소', '어댑터', '멀티어댑터', '괜찮고', '발견']
# ['재고', '공항', '통신사', '하얀색', '블랙', '변경']
# ['실감', '가능', '고속충전', '동시', '충전', '기술', '발전']
# ['선', '충전', '케이블', '길어서', '휴대', '케이스', '선도', '서비스', '정리', '파우치']
# ['임원', '오포', '조합', '마트']
# ['임원', '오포', '조합', '마트']
# ['초록색', '슬라이드', '고정']
# ['환경', '어댑터', '전압', '고장']
# ['오염', '작고', '가방', '사이즈', '파우치', '짐', '사이', '세계', '가능', '안전']
# ['귀국', '멀티탭', '미국', '포트', '출력', '높아서']
# ['아쉽기', '연결', '부위', '램프', '표시', '규격', '위', '콘센트', '아쉽긴']
# ['파우치', '역시', '품질', '해외여행', '멀티어댑터', '흰색', '예쁘네요', '돈값', '퀄리티', '중국']
# ['코리아']
# ['어댑터', '창', '유럽', '콘센트', '겁', '안정', '장치', '여행지', '케이블', '추가']
# ['완료', '오토', '퓨즈', '기능', '일본']
# ['소재', '충격', '고급', '마감', '케이스']
# ['콘센트', '없으니까', '멀티탭', '버튼', '안심', '좋더라고요', '샤오미', '카페', '같은', '퓨즈']
# ['철물점', '어렵습니다', '산']
# ['덥', '터', '잭', '단자', '없어']
# ['담날', '불량']
# ['천재', '사람']
# ['행복', '필수품', '콘센트']
# ['측정', '성능', '전압', '품질']
# ['충전', '저속', '케이블', '속', '보조배터리', '같은', 'C타입', '구멍', '고속충전', '핸드폰']
# ['무게', '경향', '플러그', '케이블', '연결']
# ['스페이스', '남자', '그레이', '매트', '블랙', '화이트']
# ['무겁긴', '무겁', '퀄리티', '디자인', '예쁘고']
# ['똑같은', '같은', '상품', '어댑터', '기능', '예쁘니깐']
# ['밀착', '가볍고', '성능', '콘센트']
# ['빠름', '색상']
# ['무광', '색상', '로즈', '디자인', '블랙', '버튼', '부드럽게', '어댑터', '변환']
# ['매트', '블랙', '스페이스', '화이트', '미니', '코드']
# ['영국', '파리', '충전', '빠르고', '스위스', '멀티탭']
# ['짐', '충전기', '케이스', '충전', '어댑터', '콘센트', '포트', '부피', 'USB포트', '멀티탭']
# ['괜찮습니다', '성급', '마감', '나쁘지']
# ['문제없습니다', '스위치', '없습니다', '외관']
# ['휴대', '케이스', '무게', '파우치', '크기', '휴대용', '가볍고', '작고', '배터리', '충전']
# ['동반자', '충전', '포트', '해외여행', '트래블']
# ['너모', '유럽', '변압', '멀티탭', '대용', '색깔']
# ['케이스', '충전', '있으니까', '연결', '아깝지', '손쉽게', '많은', '기기', '속도', '무게']
# ['모습', '서유럽', '정상', '작동', '기기', '충전']
# ['C타입', 'USB포트', '개인', '디자인', '단자', '아쉽긴', '멀티탭', '핸드폰', '타입', '포트']
# ['단계', '고급', '허접', '초고속', '없을', '중간']
# ['사무실', '디자인', '컴퓨터', '책상', '멀티탭']
# ['전기', '용품', '기기', '콘센트', '멀티탭']
# ['깜장', '파우치', '어댑터', '키', '링']
# ['불편', '없으며']
# ['마감', '아쉬우나']
# ['성능', '착하네요']
# []
# ['콘센트', '지장', '없긴']
# ['자국', '마감']
# ['충전', '일본', '요고', '해결', '많은데']
# ['보조배터리', '충전', '야무지게']
# ['충전', '느리지만', '속도', '느리지', '워치', '핸드폰', '성능', '여러나라', '전기', '규격']
# ['개선', '110V', '충전', '입구', '220V', '깊이', '깊지', '일본', '많더군요']
# ['깊은', '입구', '안쪽', '개선']
# ['기업', '데이트']
# ['기업', '데이트']
# ['케이블', '전기', '고정', '계속', '사람', '대박', '멀티어댑터', '아깝지', '충전', '불안']
# ['대만', '낯설었', '전기포트', '해외']
# ['전일', '저녁']
# ['입', '개꿀']
# ['빠르게', '재송']
# ['의견']
# ['무게', '알차서']
# ['홍콩', '계획', '콘센트', '다르다고']
# ['문자', '물품', '정리', '토요일', '연결', '포기']
# ['헤어', '드라이기', '바람', '약하게']
# ['귀찮을', '질문', '설명']
# ['충전', '작동', '동시', '가능', '어댑터', '콘센트', '포트', '파우치', '핸드폰', '케이스']
# ['포트', '퓨즈', 'C타입', '고속충전', '용량', '내장', '체결', '안전', '있는데요']
# ['충전', '보조배터리', '핸드폰', '콘센트', '보조', '포트', '어댑터', '배터리', '폰', '동시']
# ['전기포트', '멀어서']
# ['식구', '동시', '핸드폰', '충전', '보리', '전기']
# ['폰', 'C타입', '보조', '터너', '타입', '동시충전']
# ['충전', '속도', '길지']
# ['포켓', '많은', '홈', '먼지', '보호', '빠르게']
# ['파우치', '없던데']
# ['C타입', '형식', '충전', '많다는']
# ['케이블', '정리', '코일', '앙증맞은', '파우치', '세심']
# ['해외', '없어선', '어댑터']
# ['가성비', '최고', '콘센트', 'C타입', '기능', '사이즈', '디자인', '포트', '고속충전', '해결']
# ['케이스', '사이즈', '작으며']
# ['C타입', '충전기', '많음']
# ['낙하', '파손', '주의']
# ['돼지코', '고정', '유럽', '괜찮으려나']
# ['디자인', '작고', '앙증맞으며', '파우치']
# ['어댑터', '입', '개꿀', '꿀', '해외', '콘센트', '플러그', '있는데']
# ['보조', '배터리', '유언비어', '캐리어', '기내', '은근', '짐']
# []
# ['콘센트', '헐겁다는데', '사용법']
# ['매뉴얼', '있어요']
# ['제품력']
# ['좋다고', '어댑터', '충전기', '좋다는', '기능', '35W', '65W', '국내', '돼지코', '포트']
# ['일본', '소리', '전기', '여행용', '파우치', '사이트', '작동', '남', '괜찮겠', '그렇다는']
# ['시끄럽지']
# ['충전', '국', '이후', '오랜만', '돼지코', '론', '타입', '호환', '초고속', '출력']
# ['핸드폰', '충전', '코드', '가능', '드라이기', '보조배터리', '케이스', '어댑터', '콘센트', '고속충전']
# ['좋죠']
# ['220V', '콘센트', '힘드네요']
# ['어댑터', '없대도']
# ['케이스', '파우치', '충전', '크기', '해외여행', '어댑터', '사이즈', '디자인', '작아서', '휴대']
# ['충전', '일본', '콘센트', '어댑터', '멀티어댑터', '핸드폰', '멀티탭', '예쁘고', '파우치', '해외여행']
# ['무겁지만', '65W', '그렇겠']
# ['문제없겠']
# ['안심', '안전', '퓨즈', '가능', '케이스', '인증', '타사', '타입', '전압', '작동']
# ['수정']
# ['비싸고', '포트', '위주', '파우치', '싸고', '콘센트', '도넛', '모양', '유튜브', '가성비']
# ['ㄱ', 'ㄴ']
# ['해외여행', '멀티어댑터', '없죠']
# ['C타입', '어댑터', '고속충전', '하나라', '충전', '방식', '구멍', 'USB포트', '좋은데', '전기']
# ['불편', '멀티탭', '상품', '손', '타입', '디자인', '케이스', '좋있', '있답니다']
# ['불편', '멀티탭', '상품', '손', '타입', '디자인', '케이스', '좋있', '있답니다']
# ['물음', '드림']
# ['물음', '드림']
# ['멀티탭', '정신없는', '작은', '사이즈', '가방', '공간', '적어']
# ['부피', '틈', '플러그', '어댑터']
# ['케이스', '견고', '아이디어', '실용', '정리', '타사', '기능', '작동', '호환', '충전']
# ['돼지코', '헤드', '선', '번거롭고']
# ['기능', '문제없음']
# ['아무렇게', '아무렇게나', '고장', '보관함']
# ['초고속', '충전', '부아']
# ['바람', '세기', '단']
# ['스토어', '불량품', '양품']
# ['포트', '충전기', '케이스', '줌']
# ['발열', '심하지']
# ['퓨즈', '충전', '멀티탭', '콘센트', '설명', '있는지', '콤팩트', '무겁게', '단점', '헐겁고']
# ['빠르나']
# ['뒤늦게', '제값']
# ['USB포트', '다량', '충전', '가능']
# ['자동', '퓨즈', '조건', '진심']
# ['미극']
# ['충전', '포트', '없더군요']
# ['디자인', '케이스', '충전', '좋음', '어댑터', '콘센트', '색상', '파우치', 'C타입', '기능']
# ['이틀', '소리']
# ['단점', '이것저것', '많다', '넓다는']
# ['일본', '110V', '충전', '콘센트', '작기']
# ['임원', '오포', '조합', '로마', '충전', '마트']
# ['도움', '콘센트', 'C타입', '포트', '아쉬움', '무게', '어댑터', '고급', '디자인', '많은']
# ['전고', '업그레이드', '버전', '고속충전', '단자', '추가', '아쉽더라고요']
# ['콘센트', '충전', '멀티탭', '해외', '연결', '충전기', '포트', '플러그', '불편', '퓨즈']
# ['220V', '110V', '트랜지스터', '예정']
# ['케이스', '어댑터', '고급', '충전', '파우치', '디자인', '멀티탭', '콘센트', '해외여행', '충전기']
# ['손쉽게', '많은', '기기', '속도', '충전']
# ['색상', '원가']
# ['업그레이드', '버전', '고속충전', '단자', '추가', '아쉽더라고요']
# ['보츠', '버전']
# ['변환', '스위치', '부드럽진', '기능', '많으니']
# ['크기', '포트', '콤팩트', '같단']
# ['케이스', '크기', '타입', '충전기', '작동', '해외', '빛', '안심', '콘센트', '있겠']
# ['빠르진']
# ['낮아서', '일본', '전압', '충전', '해외', '전원', '콘센트', '깊이', '낮아', '핸드폰']
# ['유저', '어댑터', '세계', '일주', '가능', '아이폰', '갤럭시', '애플워치', '수신기', '보조배터리']
# ['국가', '잘습니다']
# ['무겁지', '무게', '무겁지만', '크기', '무겁게', '멀티탭', '충전', '디자인', '휴대', '파우치']
# ['비싸요']
# ['충전', '보조배터리', '케이스', '콘센트', '어댑터', '퀄리티', '핸드폰', '디자인', '포트', 'C타입']
# ['선', '길다고', '짧은']
# ['바르고', '품질']
# ['현지', '콘센트', '탓', '충전', '남']
# ['경쟁력', '사이즈', '디자인', '없으니']
# ['부피', '작으면서', '기능']
# ['높네요']
# ['빨간색', '버튼', '아래', '코드']
# ['일자', '드라이버']
# ['콘센트', '해외', '포트', '퓨즈', '연결', '충전', 'C타입', '고속충전', '용량', '내장']
# ['사이즈', '작고', '가볍네요']
# ['아웃렛', '스위치', '현상', '발생', '불편']
# ['크기', '작어서', '좋고요']
# ['플러그', '본품', '콘셉트', '소켓', '기능']
# ['편하기']
# ['가격대', '높지만', '무겁지']
# ['기능', '디테일', '비싸다는', '좋다면', '살']
# ['콘센트', '일본', '어댑터', '멀티탭', '무게', '파우치', '작동', '소리', '호주', '포트']
# ['충전', '케이스', '무게', '디자인', '어댑터', '파우치', '가능', '콘센트', '포트', '색상']
# ['플라스틱', '재질', '같은', '내구']
# ['잦고', '콘센트', '부족', '해결']
# ['성능', '디자인', '휴대', '실용', '가성비', '케이스', '내구', 'C타입', '기능', '충전']
# ['해외', '어댑터', '있으면', '빛', '외출', '좋다고', '크기', '좋음', '국가', '평소']
# ['볼트', '상관없습니다']
# ['콘센트', '유럽', '220V', '스페인', '같은', '돼지코', '헐겁네요', '멀티탭', '코드', '이탈리아']
# ['충전', '해외', '가능', '해외여행', '어댑터', '있는데', '세계', '메리트', '최고', '볼트']
# ['전자제품', '주파수', '다르기', '무리']
# ['색상', '레몬옐로']
# ['남', '똑같지']
# ['월요일', '출고', '불가']
# ['월요일', '출고', '불가']
# ['연결', '충전', '선', '케이블', 'C타입', '콘센트', '핸드폰', '가능', '어댑터', '멀티탭']
# ['없다는', '함정']
# ['노랑', '색감', '기엽', '케이스', '본품', '연노랑']
# ['노랑', '색감', '기엽', '케이스', '본품', '연노랑']
# ['어댑터', '있나요']
# ['품목', '어댑터', '좋다고', '충전', '속도', '느리고']
# ['생김새', '귀엽고', '작아서', '휴대', '볼트', '세계', '전압', '색도', '생김', '디자인']
# ['귀엽지']
# ['퀄리티', '마감', '좋거나', '고급', '없고요']
# ['디자인', '예쁘니', '기분', '똑같은', '어댑터', '기능', '예쁘니깐']
# ['잠금장치', '방법']
# ['성능', '좋길', '좋길래']
# ['보호', '고장', '흠집', '위험', '적을']
# ['버튼', '매끄럽진']
# ['색', '밝게', '실물', '예쁘고', '파우치', '좋은데', 'USB포트']
# ['오색', '예쁘기', '케이스']
# ['콘센트', '타이트']
# ['색상', '아름답습니다']
# ['스피커', '보조', '배터리', '동시', '충전']
# ['헤어드라이어']
# ['이것저것', '신상품', '같기', '타입', '많은', '고속충전', '버전']
# ['이것저것', '신상품', '같기', '타입', '많은', '고속충전', '버전']
# ['오스트레일리아', '편하셨']
# ['충전', '포트', '가능', '동시', '충전기', '케이블', '콘센트', 'USB포트', 'C타입', '연결']
# ['같은', '220V', '없는데도']
# ['위치', '가깝게', '개선']
# ['많기']
# ['불편', '멀티탭', '충전기', '휴대', '편하여', '돼지코']
# ['해외', '충전', '늦으면', '고속']
# ['고무줄']
# ['편하다', '외국', '편하다고']
# ['이태리', '구멍', '작고', '스위스', '모양', '다르기에', '어댑터', '없으면', '전기']
# ['광고', '다르지']
# ['플러그', '동작', '부드럽네요']
# ['없게', '충전']
# ['은근', '귀찮죠']
# ['포트', '제작', '220V', '콘센트', '가늘어서']
# ['자분', '사은품', '문의', '톡', '진행', '빠르게', '참고', '해외', '돼지코', '지속']
# ['드라이기', '충전', '가능', '핸드폰', '헤어', '포트', '고속충전', '해외', '디자인', '다이슨']
# ['색상', '밝고', '없을']
# ['하와이', '가능', '다이슨', '하와']
# ['실생활']
# ['퓨즈', '개수', '세계', '파우치', '봄', '해외여행', '계획', '돼지코', '불편', 'C타입']
# ['세', '뛰어나서']
# ['멋지고', '효율']
# ['충전', '일본', '놀러', '케이스', '외국']
# ['연결', '콘센트', '어댑터', '출력', '약하긴']
# ['일본', '모양', '다르니']
# ['카타르', '공항', '충전']
# ['애플워치', '충전', '보조배터리', 'C타입', '핸드폰', '갤럭시', '유저', '포트', '케이스', '같은']
# ['USB포트', 'A타입', 'C타입', '많게', '전기', '연결']
# ['충전', 'C타입', '파우치', '콘센트', '디자인', '케이스', '어댑터', '가능', '마감', '계획']
# ['충전', '디바이스', '많다면']
# ['산티아고', '동시', '알베르', '특성', '콘센트', '골치', '부피', '작고', '멀티어댑터']
# ['산티아고', '동시', '알베르', '특성', '콘센트', '골치', '부피', '작고', '멀티어댑터']
# ['베이글', '모양', '특이']
# ['콘센트', '가능', '멀티어댑터', '높고요']
# ['작은데', '기능', '놀랍습니다']
# ['불량', '빠르게', '케이스', '국내', '금지', '폰', '충전기', '있을까', '견고']
# ['선', '길고', '케이스', '휴대', '편하네요']
# ['케이블', '플러그', '헐렁이', '방지']
# ['충전', '북유럽', '핸드폰', '기기', '없을']
# ['보조배터리', '충전', '기기', '많더라고요']
# ['드라이기', '닌텐도', '충전']
# ['안전', '내장', '콘센트', '어린이', '사용자', '누전', '사고']
# ['디자인', '뛰어나고', '추가', '많은', '도움', '안전', '내장', '콘센트', '어린이', '사용자']
# ['없을', '많거나', '크기', '손바닥']
# ['전력', '소모량']
# ['화요일']
# ['애틀랜타']
# ['케이스', '위탁', '수하물']
# ['케이스', '위탁', '수하물']
# ['안전장치']
# ['알리', '비싸네요']
# ['현지', '공항', '중국', '불량', '콘센트', '화재', '있다던데', '안심']
# ['문제없네요']
# ['USB포트', '포트', '핸드폰', '보조배터리', '카메라', '카봉', '충전기']
# ['단점', '크기', '크다는']
# ['권장', '사항', '있는데', '위아래', '충전', '많은', '상황']
# ['콘센트', '얇아서', '헐겁게', '유럽', '구멍', '좁아서', '괜찮았']
# ['담배', '한방', '충전', '자리']
# ['고정', '무겁다', '물통']
# ['충전', '충전기', '어댑터', '포트', '용도', '선', '컬러', '다용도', '기기', '속도']
# ['사은품', '센스', '좋으시']
# ['보라돌이', '보라색', '색감', '사고', '실물', '이쁘고', '충전']
# ['부족', '없군요']
# ['알차다']
# ['베개', '부피', '작아서', '좋으셨']
# ['충전', '케이스', '콘센트', '멀티탭', 'USB포트', '핸드폰', '국내', '해외여행', '다이슨', '돼지코']
# ['센스', '있으신지']
# ['고속충전', '초고속', '충전', '포트', '가능', 'C타입', '멀티어댑터', '해외여행', '세계', '퓨즈']
# ['펌프', '베개', '힘들게', '세팅']
# ['편하네요', '충전', '케이스', '휴대', '가능', '어댑터', '충전기', '핸드폰', '사용법', 'C타입']
# ['깊게', '삽입']
# ['글로벌', '콘센트', '가능']
# ['콘센트', '충전', '선', '충전기', '무게', '불편', '있어요', '일본', '단자', '면세점']
# ['폰', '충전', '여러나라', '적용']
# ['충전', '중간', '불량', '매끄럽게', '연결', '불편']
# ['도쿄', '충전', '급속']
# ['시애틀']
# ['급하신', '자제']
# ['최근', '직구', '돼지코', '얇은', '코드', '커버']
# ['싱가포르', '시드니', '코드']
# ['설정', '투명', '멀티어댑터', '라이브', '알람']
# ['해결', '관리', '경제', '이득']
# ['해결', '관리', '경제', '이득']
# ['해외여행', '충전기', '어댑터', '충전', '있다는데']
# []
# ['휴대', '충전', '케이스', '디자인', '어댑터', '멀티탭', '콘센트', '가능', '파우치', '작아서']
# ['멀티탭', '어댑터', '충전', '케이스', '핸드폰', '멀티어댑터', '포트', '고급', '일반형', 'USB형']
# ['C타입', '이렇게', '충전', '빠르더라고요']
# ['비싸요', '싸요']
# ['있으니깐', '해결']
# ['아이패드', '고맙다고']
# ['멀티어댑터', '심하다는']
# ['색상', '보통', '트렌디', '여자']
# ['충전', '멀티탭', '틀리고', '잭']
# ['온라인', '최저가']
# ['온라인', '최저가']
# ['충전핀', '많아']
# ['스위치', '램프', '표시', '맛나요']
# ['이동식', '역시', '돼지코']
# ['플러그', '옆면']
# ['뉴욕', '충전']
# ['어댑터', 'C타입', '슈퍼', '베이글', '표시', '브랜드', '지', '크고', '무거워서', '무용지물']
# ['해외', '무섭지']
# ['퓨즈', 'C타입', '고속충전', '포트', '오토리', '전력', '누전', '차단기', '기능']
# ['파우치', '없는걸요']
# ['중국', '중화']
# ['일본', '45W', '업그레이드', '똑같더라고요']
# ['일본', '돼지코', '고데기', '미니', '나아요']
# ['일본', '괜찮다고']
# ['가습', '기디', '110V', '전기', '변환', '어댑터', '코드']
# ['가습', '기디', '110V', '전기', '변환', '어댑터', '코드']
# ['있는데도', '어댑터', '내장', '퓨즈', '있는데']
# ['철물점', '어렵습니다']
# ['외국인', '게스트']
# ['외국인', '게스트']
# ['좋다며']
# ['플러그', 'USB포트', '아이폰', '유저', 'C타입', '포트', '케이스', '있다니', '충전']
# ['코타키나발루', '충전', '빠르고']
# ['전화기', '알람', '시계']
# ['케이스', '와전']
# ['케이스', '후대']
# ['크로아티아', '방문']
# ['유럽', '아시아', '국가', '가능', '무게']
# ['상품', '좋은데', '테두리', '로즈', '골드', '화이트로', '고급', '충전', '기기', '호환']
# ['중국', '충전', '멀티어댑터', '콘센트', '디자인', '멀티탭', '충전기', '어댑터', '화이트', '색상']
# ['디자인', '예쁘고', '가볍기', '가볍고', '작고', '휴대']
# ['같에요']
# ['디자인', '룸', '인테리어']
# ['기능', '문제없어서']
# ['케이스', '파손', '우려', '적었']
# ['문제없아요']
# ['기능', '설명', '다기능', '포트', '여행용', '사이즈']
# ['크기', '케이스', '충전', '휴대', '작고', '파우치', '디자인', '충전기', '어댑터', '콘센트']
# ['만듦새', '케이스', '퀄리티', '아깝다는']
# ['광고', '좋을지']
# ['여자', '퀄리티', '괜찮아서', '주려', '추가']
# ['발열', '충전', '케이스', '콤팩트', '지퍼', '고급', '상품', '사이즈', '심하고', '품질']
# ['다이슨', '문제없다고']
# ['필리핀', '세부', '높게']
# ['보조', '충전기', '충전', '사고', '발생', '이후', '조심']
# ['출장지']
# ['낫겠']
# ['충전', '콘센트', '어댑터', '케이스', '국가', '충전기', '포트', '돼지코', '개별', '짐']
# ['아프리카']
# ['색상', '똑같습니다']
# ['일본', '나고야', '돼지코', '안정', '핀', '충전']
# ['충전', '기기', '많으신', '최고']
# ['디자인', '예쁘고', '일당백']
# ['색상', '해외여행', '밝은', '부드럽게', '버튼']
# ['충전', '좋고요', '케이스', '콘센트', '어댑터', '좋더라고요', '충전기', '디자인', '가능', '고속충전']
# ['C타입', '낮았']
# ['기술', '발전', '실감']
# ['기술', '발전', '실감']
# ['단점', '크기', '크다는', '몸체', '크다', '콘센트', '위치']
# ['디자인', '브랜드', '고심', '고가', '도넛', '고속충전', '속', '뛰어나고', '추가', '많은']
# ['보조', '데리', '충전']
# ['드라이기', '충전', '가능', '핸드폰', '헤어', '고속충전', '다이슨', '110V', '작성', '충전기']
# ['충전', '콘센트', '워치', '케이스', '어댑터', '고급', '핸드폰', '보조배터리', '작고', '파우치']
# ['핸드폰', '충전', '충만']
# ['퓨즈', '없으면', '플러스']
# ['지역', '국내', '포트', '충전기', '돼지코', '파우치', '어댑터', '충전', '멀티탭', '콘센트']
# ['일본', '콘센트', '얕아서']
# ['충장']
# ['뛰어나네요']
# ['연결', '탭', '줄', '들것', '충전']
# ['소문']
# ['외부', '재질', '특징', '케이블']
# ['압축', '파우치', '공간', '정리', '편하더라고요']
# ['현지', '전기', '콘센트', '적은데', '선', '동시']
# ['주말', '케이스', '휴대']
# ['오래도록']
# ['고속충전', '급속도']
# ['멀티어댑터', '호주', '콘센트', '다르기', '낭패']
# ['고속충전', '플러그', '정상', '없잖아요']
# ['참고', '미국', '버스', '110V', '콘센트', '충전기', '충전', '속도', '많은', '있더군요']
# ['높아요', '높습니다', '케이스', '만족도', '높았', '충전', '최고']
# ['크기', '크고', '무거우니', '무거우니까', '충전', '고생']
# ['아무렇게', '아무렇게나', '고장', '보관함']
# ['일본', '소리', '전기', '그렇다고', '여행용', '파우치', '사이트', '작동', '남', '괜찮겠']
# ['성급', '괜찮습니다']
# ['해외', '잦아서', '평소', '어댑터', '멀티어댑터', '괜찮고', '발견', '잦아']
# ['콘센트', '단점', '부위', '공간', '많아', '힘들어요']
# ['여기저기', '편하게요']
# ['편하다고']
# ['도넛', '모양', '유튜브', '비싸고', '가성비', '낫다고']
# ['디자인', '아깝습니다']
# ['깜놀', '어댑터', '싫어서', '사기']
# ['좋길래']
# ['국내', '위험', '사항', '취지', '이해', '어렵네요']
# ['유럽', '중남미', '핸드폰', '패드']
# ['은근', '파우치', '귀찮은데']
# ['C타입', '포트', '아쉽다']
# ['택배', '늦긴']
# ['C타입', '포트', 'USB포트', 'A타입', '좋다고', '고장', '일부', '작동', '어댑터', '타입']
# ['화이트', '색', '블랙', '나쁘진']
# ['충전', '청소기']
# ['불량', '길요']
# ['색상', '예쁘고', '넓고']
# ['국가', '콘센트', '덜하네요']
# ['휴대용', '인덕션']
# ['여행사', '어댑터', '벽면', '고정', '현상', '불편', '많았']
# ['중국', '콘센트', '포기', '쎄게']
# ['충전', '발열', '심하진']
# ['고속충전', 'C타입', 'A타입', '알맞아요']
# ['콘센트', '연결', '없어야']
# ['색감', '분홍색', '유', '멀티어댑터']
# ['노란색', '고속충전', '파랑', '세대']
# ['무거우니까', '충전', '고생']
# ['아이폰', '220V', '충전', '불량', '세게', '힘세게', '코드']
# ['똑같은', '어댑터', '기능', '예쁘니깐']
# ['파우치', '많아도', '흠집']
# ['배달']
# ['충전', '칠레', '포트']
# ['없진']
# ['힘들지만', '색', '예쁘고', '포트', '개수']
# ['무거우면', '코드', '현상', '있다고', '좋던데요']
# ['무거우면', '코드', '현상', '있다고', '좋던데요']
# ['돼지코', '이쁘면서', '기능', '충실']
# ['포트', '충전', 'USB포트', 'C타입', '가능', '편하네요', '세대', '고속', '불편', '초고속']
# ['성능', '조으리라']
# ['힘세게', '코드']
# ['좁은', '공간']
# ['아쉽지만', '국내', '용량', 'C타입', '디자인', '중국', '무게', '작아', '불량', '색']
# ['톡', '고맙습니다']
# ['충전', '케이스', '어댑터', '콘센트', '파우치', '충전기', '포트', 'C타입', '멀티탭', '타입']
# ['안전', '설계', '안전성', '뛰어나고', '완성도', '높아', '의사', '있습니다']
# ['케이스', '멋지네요']
# ['인증', '고용량', '용량']
# ['유에스비', '같네']
# ['성능', '좋기']
# ['쿠바', '충전']
# ['110V', '짜리', '아깝네요']
# ['육안']
# ['늦어서', '해외', '휴가']
# ['220V', '콘센트', '콘택트', '헐겁습니다']
# ['케냐']
# ['파우치', '없던데', '없던']
# ['특수', '젠더']
# ['주황색']
# ['램프', '밝습니다']
# ['안정', '툴']
# ['해외', '정작', '아쉽고', '충전', '불편', '감수']
# ['해외', '정작', '아쉽고', '충전', '불편', '감수']
# ['만듦새', '케이스', '같은데요']
# ['무게', '무겁네요']
# ['색도', '블랙', '변색', '조작']
# ['충전', '패키지', '패키징', '트래블러', '키트', '고급', '파우치', '포트', '충전기', '콘센트']
# ['깜장', '구매처', '파우치', '어댑터', '키', '링']
# ['그리스']
# ['콘센트', '두께', '작지만', '동작']
# ['기능', '문제없어서', '충전', '문제없어']
# ['이쁘고', '충전', '도어']
# ['노란색', '귀엽군요']

# %%
cumsum_keyword_충전
# Out:
#     형태소    빈도    퍼센트  누적_퍼센트
# 0    충전  1227  27.44   27.44
# 1  고속충전   239   5.34   32.78
# 2   충전기   165   3.69   36.47
# 3    가능   129   2.88   39.35

# %%
keyword_freq_콘센트
# Out:
#       형태소   빈도    퍼센트  누적_퍼센트
# 0     콘센트  331  29.55   29.55
# 1      충전   35   3.12   32.67
# 2     어댑터   21   1.88   34.55
# 3      해외   17   1.52   36.07
# 4      연결   15   1.34   37.41
# ..    ...  ...    ...     ...
# 333  전기장판    1   0.09   99.92
# 334    두께    1   0.09  100.01
# 335   작지만    1   0.09  100.10
# 336    기본    1   0.09  100.19
# 337   이쁘고    1   0.09  100.28
#
# [338 rows x 4 columns]

# %%
#df_충전.head(3)

# %%
keyword_freq_충전.head(20)
# Out:
#       형태소    빈도    퍼센트  누적_퍼센트
# 0      충전  1227  27.44   27.44
# 1    고속충전   239   5.34   32.78
# 2     충전기   165   3.69   36.47
# 3      가능   129   2.88   39.35
# 4      포트   115   2.57   41.92
# 5     핸드폰   108   2.42   44.34
# 6     C타입   105   2.35   46.69
# 7      기기    67   1.50   48.19
# 8      동시    65   1.45   49.64
# 9      일본    64   1.43   51.07
# 10  보조배터리    61   1.36   52.43
# 11     속도    60   1.34   53.77
# 12    어댑터    58   1.30   55.07
# 13    빠르고    50   1.12   56.19
# 14    콘센트    44   0.98   57.17
# 15     연결    39   0.87   58.04
# 16    빠르게    39   0.87   58.91
# 17  USB포트    36   0.81   59.72
# 18    케이블    34   0.76   60.48
# 19     해외    34   0.76   61.24

# %% [markdown]
# ### 실험 과정

# %%
pd.DataFrame(Counter(sum(globals()[var_name]['changed_text'],[])).most_common(), columns=['형태소', '빈도'])
# Out:
#     형태소  빈도
# 0   노란색   1
# 1  귀엽군요   1

# %%
test_freq = Counter(remove_stopwords2).most_common()
test_remain_freq = pd.DataFrame(test_freq, columns=['형태소', '빈도'])
test_remain_freq['퍼센트']=round((test_remain_freq['빈도']/test_remain_freq['빈도'].sum())*100,2)
test_remain_freq['누적_퍼센트'] = test_remain_freq['퍼센트'].cumsum()
test_remain_freq
# Out:
#        형태소    빈도   퍼센트  누적_퍼센트
# 0       충전  1227  7.55    7.55
# 1      케이스   926  5.70   13.25
# 2      디자인   545  3.36   16.61
# 3      어댑터   381  2.35   18.96
# 4      콘센트   331  2.04   21.00
# ...    ...   ...   ...     ...
# 1381   그리스     1  0.01  100.71
# 1382    두께     1  0.01  100.72
# 1383  문제없어     1  0.01  100.73
# 1384    도어     1  0.01  100.74
# 1385  귀엽군요     1  0.01  100.75
#
# [1386 rows x 4 columns]

# %%
test_remain_freq[(test_remain_freq['누적_퍼센트']<30) & (test_remain_freq['형태소']!='충전')]
# Out:
#     형태소   빈도   퍼센트  누적_퍼센트
# 1   케이스  926  5.70   13.25
# 2   디자인  545  3.36   16.61
# 3   어댑터  381  2.35   18.96
# 4   콘센트  331  2.04   21.00
# 5   파우치  313  1.93   22.93
# 6    포트  310  1.91   24.84
# 7   C타입  299  1.84   26.68
# 8    가능  258  1.59   28.27
# 9  고속충전  239  1.47   29.74

# %%
df_remain_freq
# Out:
#        형태소    빈도
# 0       충전  1227
# 1      케이스   926
# 2      디자인   545
# 3      어댑터   381
# 4      콘센트   331
# ...    ...   ...
# 1381   그리스     1
# 1382    두께     1
# 1383  문제없어     1
# 1384    도어     1
# 1385  귀엽군요     1
#
# [1386 rows x 2 columns]

# %%
# top Key 저장 코드
test_list = list(df_remain_freq['형태소'][:10])
test_append_target_list = ['케이스','디자인','어댑터']
test_list.extend(test_append_target_list)
test_list = list(set(test_list))
test_list
# Out:
# ['콘센트', '충전', 'C타입', '가능', '디자인', '어댑터', '케이스', '파우치', '포트', '고속충전']
