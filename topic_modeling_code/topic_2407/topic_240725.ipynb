# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import re

from konlpy.tag import *

# %%
from konlpy.tag import Mecab

m = Mecab(dicpath = 'C:/mecab/mecab-ko-dic')
m.nouns('A타입도 좋고, PD충전 되는 것도 좋아요. C타입 여러개 있어서 좋습니다')
# Out:
# ['A타입', 'PD충전', '것', 'C타입', '개']

# %%
product = pd.read_csv("C:/Users/songy/Desktop/Data/product.csv", index_col = 0)
product
# Out:
#                              add_rule_based_split_review
# 3                               금액 차이 얼마 안 나는데 기능은 더 좋아요
# 4                             콤팩트한 디자인과 실용성에 높은 점수 주었습니다
# 8                                      전면 스크래치가 많아서 아쉽네요
# 18                              말 그대로 멀티 어댑터에요 해외여행 필수 탬
# 22                                            작아서 휴대도 굿굿
# ...                                                  ...
# 17702                                       가볍고 휴대하기 좋아요
# 17703  C 타입 충전이 없어서 구매를 망설이긴 했지만 좀 큰 변압기는 쳐져서 충전이 잘 안...
# 17704                                        요 사이즈가 딱이네요
# 17706                                   켔써요 노란색이 너무 귀엽군요
# 17709           한 손에 쏙 들어오고 색이 쨍해서 여행 가서 잃어버릴 일 없을 거 같아요
#
# [7785 rows x 1 columns]

# %%
def upper_text(text):
    text = text.upper()
    return text

# %%
product['add_rule_based_split_review'] = product['add_rule_based_split_review'].apply(upper_text)

# %%
def replace_text(text):
  text = str(text)
  text = text.replace('습ㄴ지다','습니다')
  text = text.replace('쌈ㅎ','저렴해요')
  text = text.replace('안되는...','안됩니다')
  text = text.replace('ㅎ','')
  text = text.replace('ㄱㅅ함다','감사합니다')
  text = text.replace('ㅋ','')
  text = text.replace('루♡','')
  text = text.replace('♡','')
  text = text.replace('굳','굿')
  text = text.replace('뻈어요','뺏어요')
  text = text.replace('ㅜ','')
  text = text.replace('0','')
  text = text.replace('좋음.','좋음')
  text = text.replace('중입니다♥?)','중 입니다')
  text = text.replace('하나에요','하나예요')
  text = text.replace('됩니다><','됩니다')
  text = text.replace('있었어요','있어요')
  text = text.replace('_','')
  text = text.replace('욥','요')
  text = text.replace('ㆍ','')
  text = text.replace('오겠씀다~~ㅎㅎ/','오겠습니다')
  text = text.replace('/',' ')
  text = text.replace('듯.','듯')
  text = text.replace('후에~','')
  text = text.replace('개용','개요')
  text = text.replace('.?','')
  text = text.replace('ㅅ','')
  text = text.replace('오ㅡ','')
  text = text.replace('여행가고싶어지네요ㅋㅋ','여행 가고 싶어지네요')
  text = text.replace('좋습니다!!!!','좋습니다')
  text = text.replace('...','')
  text = text.replace('구매확정해요','구매 확정해요')
  text = text.replace('완죤빨라요ㅋㅋ','완전 빨라요')
  text = text.replace('ㅡ','')
  text = text.replace('귀요미에요','귀여워요')
  text = text.replace('최고여요','최고예요')
  text = text.replace('-',' ')
  text = text.replace('사랑하여','사랑해요')
  text = text.replace('배송되었습니다','배송 되었습니다')
  text = text.replace('좋아요ㅔ','좋아요')
  text = text.replace('아니에요.','아니예요')
  text = text.replace('구매확정했습니다','구매 확정했습니다')
  text = text.replace('bbb','굿')
  text = text.replace('쓸ㄲ너ㅣㅇ르','')
  text = text.replace(';','')
  text = text.replace('같고요','같아요')
  text = text.replace('같네요','같아요')
  text = text.replace('씁니다','습니다')
  text = text.replace('넘좋와여','너무 좋아요')
  text = text.replace('굿입니다','굿')
  text = text.replace('목배게최고에요','목배게 최고예요')
  text = text.replace('감동이에요','감동이예요')
  text = text.replace(',.','')
  text = text.replace('아이디어템','아이디어 탬')
  text = text.replace(':D','')
  text = text.replace('..','')
  text = text.replace('감사핮니다','감사합니다')
  text = text.replace('템','탬')
  text = text.replace('든든 합니다','든든합니다')
  text = text.replace('받아보았어요','받아봤어요')
  text = text.replace('가타용','같아요')
  text = text.replace('바랍니아','바랍니다')
  text = text.replace('사업번창하세요','사업 번창하세요')
  text = text.replace('쓸겠습니다','쓰겠습니다')
  text = text.replace('구매완료입니다','구매완료')
  text = text.replace('짱빠름','짱 빠름')
  text = text.replace('됩니닽','됩니다')
  text = text.replace('닙니다ㅛ','닙니다')
  text = text.replace('잘한듯해요','잘한듯')
  text = text.replace('가세여','가세요')
  text = text.replace('잘샀다템','잘샀어요')
  text = text.replace('좋아요좋아요좋오ㅓㅗㅇ좋아요','좋아요 좋아요')
  text = text.replace('@@','')
  text = text.replace('써봐겠ㅆ네요','써봐야겠네요')
  text = text.replace('만족이에요','만족이예요')
  text = text.replace('아까워요.','아까워요')
  text = text.replace('ajjqjahaja','')
  text = text.replace('잚슬겡ㅎ','잘쓸게요')
  text = text.replace('잘했아요','잘했어요')
  text = text.replace('괜찬ㅍ아요','괜찮아요')
  text = text.replace('><','')
  text = text.replace('예쁨','예뻐요')
  text = text.replace('편하쥬','편해요')
  text = text.replace('감사함다','감사합니다')
  text = text.replace('*','')
  text = text.replace('핳핳','')
  text = text.replace('굿입니다','굿')
  text = text.replace('으흐흐','')
  text = text.replace('빨라요ㅗ','빨라요')
  text = text.replace('이븜','이쁨')
  text = text.replace('ㄹㅇ','')
  text = text.replace('되매요','되네요')
  text = text.replace('믿어보겠음다','믿어보겠습니다')
  text = text.replace('아니에요','아니예요')
  text = text.replace('만족합니다.ㅣ','만족합니다')
  text = text.replace('되고요','됩니다')
  text = text.replace('딱입니딘','딱입니다')
  text = text.replace('기대되어요','기대됩니다')
  text = text.replace('왔습디다','왔습니다')
  text = text.replace('맀어용','랐어요')
  text = text.replace('강강히','')
  text = text.replace('만족이여','만족이요')
  text = text.replace('사용했니다.','사용했습니다')
  text = text.replace('충전빨리되구죻아요','충전 빨리되고 좋아요')
  text = text.replace('잘됩니다잉','잘됩니다')
  text = text.replace('사용했답니다','사용했어요')
  text = text.replace('가타요','같아요')
  text = text.replace('최곱니다','최고입니다')
  text = text.replace('빠르네요','빠릅니다')
  text = text.replace('기릉','기를')
  text = text.replace('받았습니아','받았습니다')
  text = text.replace('ok.','ok')
  text = text.replace('가져감','가져갑니다')
  text = text.replace('익니다','입니다')
  text = text.replace('수용되오ㅡ','수용되요')
  text = text.replace('맨죡','만족')
  text = text.replace('`','')
  text = text.replace(',,,','')
  text = text.replace('ㄹ','')
  text = text.replace('구매예정이에요','구매 예정이예요')
  text = text.replace('좋은듓','좋은듯')
  text = text.replace('매우저롐하게잘구매했어요감사하네여','매우 저렴하게 잘 구매했어요 감사해요')
  text = text.replace('만적합니다','만족합니다')
  text = text.replace('ㅈ번창하세요','번창하세요')
  text = text.replace('전이에요','전이예요')
  text = text.replace('조어요','좋아요')
  text = text.replace('젛아요','좋아요')
  text = text.replace('됩니더','됩니다')
  text = text.replace('굿입디다','굿')
  text = text.replace('갘아어요','')
  text = text.replace('ㄷ,','')
  text = text.replace('잘되겠쥬','잘되겠죠')
  text = text.replace('쓰게습니도','쓰겠습니다')
  text = text.replace('하고요','하고')
  text = text.replace('저뇽가방도있네요','전용가방도 있네요')
  text = text.replace('sjsjsjjsjs','')
  text = text.replace('좋겠구먼요','좋겠네요')
  text = text.replace('좋아욫','좋아요')
  text = text.replace('반퓸합니다','반품합니다')
  text = text.replace('꿋꿋입니다','굿')
  text = text.replace('잘씅게용','잘쓸게요')
  text = text.replace('땡큐네요','감사합니다')
  text = text.replace('베릐굿','굿')
  text = text.replace('효오','')
  text = text.replace('☆','')
  text = text.replace('ᄒ','')
  text = text.replace('썼어ᄉ','썼어요')
  text = text.replace('ㄱ','')
  text = text.replace('사용시뉴용할듯욕','사용시 유용할 듯')
  text = text.replace('있아요','있어요')
  text = text.replace('아다아다아','')
  text = text.replace('아다 아다 아','')
  text = text.replace('감사합니다아','감사합니다')
  text = text.replace('goood','굿')
  text = text.replace('싱픔굿배소오쟈웁','상품 굿 배송')
  text = text.replace('쓸겡','쓸게요')
  text = text.replace('굿국국숙','굿굿굿')
  text = text.replace('졸아요','좋아요')
  text = text.replace(': ','')
  text = text.replace(':','')
  text = text.replace('근데,','')
  text = text.replace('USC','usb')
  text = text.replace('A S','AS')
  text = text.replace('※','')
  text = text.replace(' ㅐ외','해외')
  text = text.replace('ᄆ','')
  text = text.replace('ᅳᄋ ᄋ','')
  text = text.replace('배슝','배송')
  text = text.replace('@ % @ @ @','')
  text = text.replace('@','')
  text = text.replace('ᅲ','')
  text = text.replace('쓸ᄁ너ᅵᄋ르','쓸게요')
  text = text.replace(' ♥','')
  text = text.replace('ᄏ','')
  text = text.replace('강 추','강추')
  text = text.replace('★','')
  text = text.replace('■','')
  text = text.replace('C 타입','C타입')
  text = text.replace('씨타입','C타입')
  text = text.replace('A 타입','A타입')
  text = text.replace('에이타입','A타입')
  text = text.replace('PD 충전','PD충전')

  # 1개짜리는 제외
  return text

# %%
product['add_rule_based_split_review'] = product['add_rule_based_split_review'].apply(replace_text)

# %%
def clean_text(text):
    if isinstance(text, str):
        return re.sub(r'[-=+,#/\?:^$.@*"※~&%ㆍ!』\\‘·|\(\)\[\]\<\>`\'…\"\“’]', '', text)
    else:
        return ""

# %%
product['add_rule_based_split_review'] = product['add_rule_based_split_review'].apply(clean_text)

# %%
from konlpy.tag import Mecab
m = Mecab(dicpath = 'C:/mecab/mecab-ko-dic')

# %%
def preprocess_reviews(reviews, stopwords_path, additional_stopwords=[]):
    # 불용어 파일 로드
    with open(stopwords_path, encoding='utf-8') as file:
        stopwords = file.read().splitlines()
    
    # 추가 불용어 합치기
    stopwords.extend(additional_stopwords)

    # 리뷰 전처리
    clean_sent = []
    for review in reviews:
        clean = re.sub(r'[-=+,#/\?:^$.@*"※~&%ㆍ!』\\‘·|\(\)\[\]\<\>`\'…\"\“’]', '', review)
        clean = clean.replace('\n', '').replace('\r', '')  # 줄바꿈 문자 제거
        clean_sent.append(clean)

    m = Mecab(dicpath = 'C:/mecab/mecab-ko-dic')
    
    word_list = []
    for sentences in clean_sent:
        # 정규화
        # sentences = m.normalize(sentences)
        # 토큰화
        # tokens = sentences.split()
        tokens = m.nouns(sentences)
        # tokens = okt.nouns(sentences)
        # 불용어 제거
        tokens = [token for token in tokens if token not in stopwords]
        word_list.append(tokens)
    
    return word_list

# %%
"""
stopwords_path = "C:/Users/songy/Desktop/Data/stopwords-ko.txt"
with open(stopwords_path, encoding='utf-8') as file:
    stopwords = file.read().splitlines()

print(stopwords)
"""
# Out:
# '\nstopwords_path = "C:/Users/songy/Desktop/Data/stopwords-ko.txt"\nwith open(stopwords_path, encoding=\'utf-8\') as file:\n    stopwords = file.read().splitlines()\n\nprint(stopwords)\n'

# %%
def compiled_morphs(texts, stopwords_path, additional_stopwords=[]):
    # 불용어 파일 로드
    with open(stopwords_path, encoding='utf-8') as file:
        stopwords = file.read().splitlines()

    # 추가 불용어 합치기
    stopwords.extend(additional_stopwords)

    # 리뷰 전처리
    clean = re.sub(r'[-=+,#/\?:^$.@*"※~&%ㆍ!』\\‘·|\(\)\[\]\<\>`\'…\"\“’]', '', texts)
    clean = clean.replace('\n','').replace('\r','')     # 줄바꿈 문자 제거

    # 형태소 분석기 추가
    m = Mecab(dicpath='C:/mecab/mecab-ko-dic')

    result = []
    for i in range(len(m.pos(clean))):
        word, pos = m.pos(clean)[i]
        # 형태소가 연결 어미인지 확인
        if pos in ['VA']:
            if i + 1 < len(m.pos(clean)):
                next_word, next_pos = m.pos(clean)[i + 1]
                if next_pos in ['EC', 'ETM']:           # 연결 어미 또는 관형형 전성 어미
                    result.append(word + next_word)
                else:
                    result.append(word + next_word)
        elif pos in ['NNG', 'NNP']:
            result.append(word) 
    
    # 불용어 처리
    results = [word for word in result if word not in stopwords]
    
    return results

# %%
example_sent = "퓨즈 교체가 자동이라서 신경 쓸 일이 하나 줄은 것도 장점이고요"

# %%
def find_morphs(text):
    """
    명사, 형태소 추출 함수 (형용사의 연결 어미를 반영해 추출)
    """
    result = []

    for i in range(len(m.pos(text))):
        word, pos = m.pos(text)[i]
        # 형태소가 연결 어미인지 확인
        if pos in ['VA']:
            if i + 1 < len(m.pos(text)):
                next_word, next_pos = m.pos(text)[i + 1]
                if next_pos in ['EC', 'ETM']:           # 연결 어미 또는 관형형 전성 어미
                    result.append(word + next_word)
                else:
                    #result.append(word + next_word)
                    result.append(word)
        elif pos in ['NNG', 'NNP']:                     # 명사 
            result.append(word)

    return result

# %%
find_morphs("튼튼한 것 견고한 컴팩트 케이스 테스트")
# Out:
# ['컴팩트', '케이스', '테스트']

# %%
compiled_morphs("튼튼한 것 견고한 컴팩트 케이스 테스트 칰", stopwords_path="C:/Users/songy/Desktop/Data/stopwords-ko.txt")
# Out:
# ['컴팩트', '케이스', '테스트']

# %%
#product['changed_text'] = product['add_rule_based_split_review'].apply(find_morphs)
reviews = product['add_rule_based_split_review']  # 리뷰 데이터
stopwords_path = "C:/Users/songy/Desktop/Data/stopwords-ko.txt"

additional_stopwords = ['의','가','이','은','들','는','과','서', '있다','자다','라고', '이라', '되다', '제', 'ㅎ', 'ㅋㅋ',
                        '도','를','으로','자','에','와','한','하다','등' ,'및', '것', '에서', '거', '면', '오다', '용', '요',
                        '잘','다','수','개','달', '게요', '전', '변','이거','시', '하다', '자다', '있다', '도', '이', '에', '써다', '때', '너무', '가', '것' ,'에서', '거',
                        '서', '수', '요','오다','아직','으로','을','은','아주','안','를','로','되어다', '다','하고',
                        '이다','않다','받다','고','는','게','이번','만','전','돼다','까지','용','라','번','달','시','못',
                        ]

"""
additional_stopwords = ['의','가','이','은','들','는','과','서', '있다','자다','라고', '이라', '되다', '제', 'ㅎ', 'ㅋㅋ',
                        '도','를','으로','자','에','와','한','하다','등' ,'및', '것', '에서', '거', '면', '오다', '용', '요',
                        '잘','다','수','개','달','해외여행','해외','여행', '게요', '전', '변','이거','시', 
                        '하다', '자다', '.', '있다', '도', '이', '에', '써다', '때', '너무', '가', '것' ,'에서', '거',
                        '서', '수', ',', '요','오다','아직','으로','을','은','아주','안','를','로','되어다', '다','하고',
                        '이다','않다','받다','고','는','게','이번','만','전','돼다','까지','용','라','번','달','시','못',
                        '지만','중','사','들','해봤다','인데','나','문제','..','다음','면','이라','과','제','여','라서',
                        '잘','적','맘','의','기','꼭','또','에서도','싶다','진짜','듯','마다','?','내','어느','해','에는',
                        '저','후','곳','나다','산','때문','에도','네','선','빨','일이','그냥','한','덕분','와','줄','랑',
                        '두','인','함','건','성','그리고','에서는','등','보','여서','동안','딱','모든','따로','짐','가면',
                        '이랑','데','하지만','대비','굿굿','간','니','이네','아','별','주','이고','든','가기','걸','감',
                        '이에요','이예요','자주','아무','그래서','나오다','그래도','예요','구','v','잇다','이용','우선',
                        '살짝','내내','기다','분','바','유','가든','어','일','+','엔','처음','래','듭니','세','만큼','빼다',
                        '미리','지금','기존','계속','약간','오','바로','혹시','사은','구요','꽉','지','으로도','그','이나',
                        '하니'',자꾸','꼽','실','V','대가','에선','에게','훨씬','별로','야','처럼','땐','뭐','품','무엇',
                        '별도','꽤','한데','W','명','에스','하','쪽','온','첫','탈','중이','짱','지고','행','...','라고',
                        '단','외','죠','.?','날','위','재','허다','수가','언스','가성','너','그런데','아이','모','겠다',
                        '굿굿굿','뿐','분들','사려','및','여기','안해','대신','음','에서나','이예','대해','습니','...','자',
                        '터','자마자','타','사가','테','티스','소','스비','으로는','왜','한테','텐데','대로','이제','그거',
                        '즈','대요','젠','장','젠장','영','대','반','속','각','신행','꺼','ㅜㅜ','임','준','곳도','리','년',
                        '법도','','히','아무래도','그대로','어서','엇','님','김','서도','로서','됫','난','휴','정','에드',
                        '대박','만약','연','트','좋아','편','애','이라는','이랑은','스럽게','모로','껏','통해','동','다가',
                        'ㅏㅁㄴ해','이라고','곤','.???','*','평','이니','뮤','녀석',"'", '뻔','콘','놈','ㅜ','겹','십','께',
                        'to','충','라는','으로만','예','구가','탓','덜','☆','흠','째',',','편이','이만','무','디지다','치',
                        '만의','극','작','겟네','뻐','햇','며','끗','쩝','팅','◡̈','다기','??','>','<','짜리','암튼','국',
                        '어요','치네다','그레','겨우','그러니까','밑','하므다','나니','안나','풍','평이','움','♥︎',';','식',
                        '남','진','신','인거','_','ㅇㅅ','료','와는','이지','니까','언','어쪄','싰는데','누','오지','뿌네',
                        '담','긍','등등','친','구거','삐','부턴','원체','득','능이','햇으','됫네','만을','아직','당','몀',
                        '거란','뿌','에서든지','어찌어찌','장안','땜','떼','곡','다다','디음','인가요','줄줄','천후','쭉',
                        '에요','다용','딜','우레','D','이든','던','요런','시나','라도','한다는','족','지네','뭘','값임',
                        '찌다','에다','에나','역','뇨','디테','로움','뽀옹','원주고','격','박','향가','안고','※','대한',
                        '데리','그랬는데','앙증','탬이','씨','**','디','방','넉','얼','바나','썻','림','더군요','뭥',
                        '가렵니','이면','버여','숩니','모해','노','꾹','이기','쿄','습','룸','ㄴ','차무','부아','아앙','스',
                        '았','쑤다','예여','쥬','접','젤','싰습니','여도','위져','녀','원쁠','겸','사시','로만','ㄷㄷㄷ','|',
                        'ㅣ','규','개사','퍽','나기','바봬','즇으','왕사','욜','으','에서만','보다도','번만','꽈','니깐',
                        '터너','홈','건가','꼿는','스레','젠데','땨','여요','디어','이니까','만으로','..,','드','지는',
                        '바듯','삿','오오','옹','ㅗ','바이','햤어','ㅍ','욤해','이며','조아','걱욧','꼐서는','께서는',
                        '너므','어보','권','됗거','구여','으론','게요','없이','1','도','이','하다','자다','여행','좋다','부아아앙',
                        '씸플','신기방기','쭉','때','것','해외','거','수','아주','개','안','요','유럽','이번','전',
                        '정말','용','게','번','시','이','달','타요','이로', '여행', '때', '것', '해외', '거', '수', 
                        '거립니','다시','듬새','개도','아주','간혹','잠깐','사나','헐렁거리','비도','다자','봄','누나','신랑','친구',
                        '맞춰','생가','어쩜','개', '안', '요', '유럽', '이번', '전', '정말', '묘','용', '게', '번', '시', '이', '달', 
                        '더', '중', '하나로', '좀', '다음', '조금', '매우', '제', '맘', '고', '꼭', '또', '기', '도', '듯', '여', '굿', 
                        '해', '후', '곳', '그냥', '함', '건', '등', '보', '모든', '외국', '데', '호텔', '굿굿', '만', '가기', '걸', '감', 
                        '나', '아무', '이용', '주', '우선', '내내', '저', '바', '유', '가든', '일', '구', '듭니', '분', '다만', '미리', '지금', 
                        '계속', '바로', '혹시', '사은', '꽉', '하니', '자꾸', '제일', '꼽', '그', '부디', '현지', '제대로', '간', '내', '몇',
                        '훨씬씬', '감비앤코', '니', '별로', '세', '땐', '실', '뭐', '품', '무엇', '별도', '다음주', '꽤', '강', '로', '명', '쪽', 
                        '사서', '온', '다행', '오', '탈', '행', '굳이', '질', '뒤', '단', '외', '하자', '수가', '언스', '가성', '거의', '전혀', '모', 
                        '둘', '무조건', '가장', '기도', '조만간', '더욱', '이예', '서든', '굿굿굿', '뻑뻑', '및', '안해', '대신', '옆', '전부', '신경', '어뎁터', 
                        '음', '대해', '얼른', '여기저기', '터', '드네', '자마자', '해도', '짱', '사가', '살', '테', '티스', '군데', '스비', 
                        '왜', '우리나라', '은', '이제', '그거', '글', '대요', '갓', '타', '각', '신행', '얼마', '깜짝', '임', '절대', '의', '뿐', '리', 
                        '법도', '어서', '마다', '자', '김', '서도', '비앤코', '로서', '됫', '위주', '경우', '정', '에드', '만약', '대박', '트', '편', '애', '영', '금방', 
                        '모로', '껏', '통해', '면', '다가', '가요', '만해', '깨끝', '젠', '곤', '충천', '평', '낭패', '뮤', '뻔', '그게', '콘', '놈', '상', '두루', '장', 
                        '가야', '겹', '안타', '무슨', '일부러', '군더더기', '시기', '사실', '큰일', '크게', '평소', '충', '개꿀', '기분', '구가', '탓', '덜', '흠', '를', 
                        '언제', '구성은', '반', '잠시', '인', '편이', '감안', '이만', '무', '치', '우려', '요새', '뻐', '햇', '할걸', '각자', '갑자기', '종', 
                        '나이스', '느슷', '팅', '다기', '사두', '조', '입', '국', '어요', '워낙', '그레',  '내일', '오히려', '밑', '미니', '엇', '었어', 
                        '햇습니', '나니', '안나', '비엔', '누가', '평이', '대로', '움', '전일', '가까스로', '백이', '삿는데', '다소', '빡빡', '외로', '식', '남', '진', 
                        '짤', '난', '료', '늘', '일부', '처럼', '무척', '포드', '지장', '주렁주렁', '이지', '하와', '진심', '어쪄', '싰는데', '했어', 
                        '저희', '한층', '똑바로', '위로', '누', '오지', '두서', '이후', '필', '싶슺니', '지난', '담', '긍', '등등', '친', '삐', '협소하', '득', '능이', 
                        '하류', '햇으', '됐네', '당', '몀', '강츄합니', '뿌', '글쎄요', '즉시', '땜', '부쩍', '떼', '뜻', '다다', '있겄다', '이나', '줄줄', '텐데', '다용', 
                        '일도', '기우', '보임', '또한', '종종', '오케이','요런', '시나', '족', '지네', '일간', '뭘', '값임', '뇨', '디테', '일이', '어탭터', '로움', 
                        '꿀', '뽀용', '원주고', '안건', '조마', '리조트', '휴양', '대한', '데리', '유언비어', '했슴돠', '씨', '가라', '대서', '탭터', '대합', '담달', '디', '급', '얼', 
                        '바나', '썻', '네', '림', '무어', '젠장', '이면', '스페어', '숩니', '버여','칸', '만요', '구비', '반신반의', '모해', '노', '이기', '이제야', '절찬',
                        '케리', '라뷷호', '이븜', '습', '특', '오기', '해당', '대폭', '부아', '아앙', '지라', '줌', '다량', '았', '달래', '쥬', '덴마크', '접', 
                        '젤', '싰습니', '일주', '씸플하', '히', '지난번', '작', '위져', '녀', '핸폰', '삿포로', '것일', '촉', '쓰시', '적격입니', '달리', '속', '부', '겸', '로만', '규',
                        '향', '투', '아예', '처', '연', '과', '감히', '퍽', '바봬', '쉬', '왕사', '직', '용한', '욜', '겨', '삿네', '깜놀', '덜렁', '마저', '번만', '꽈', '에어비앤비',
                        '아고다', '낼', '휴양도시', '바기오', '관강객', '일절', '어차피', '싸가지', '감쟈함니', '하여튼', '싶엇구', '어찌', '낭', '나로', '워', '사욤할', 
                        '괴어', '건가', '몰디브', '렁거리', '번가', '맀었습니', '세심', '스레', '겐트', '젠데', '땨', '다꼽고', '며칠', '여서', '디어', '탄자니아', '이집트', '드', 
                        '툴', '어쨌는', '백', '중인', '신기', '방기', '아보', '요요', '예', '바듯', '저뇽', '오오', '옹', '런던', '햤어', '뽁뽁', '젭굼', '와우', '욤해', 
                        '울', '타숍', '깨끝해', '쭈욱', '이어도', '넉', '쫀득쫀득', '봉', '걱욧', '너므', '그간', '어보', '럭', '듬직', '미주', '됗거','만족'
                        '여행','차이','앞','동생','곳','마음','출국','사용','신경','생각','느낌','부피','어딜','뭔가','주','테스트','느']   #하나만 => '하나'
"""

product['changed_text'] = product['add_rule_based_split_review'].apply(lambda texts : compiled_morphs(texts, stopwords_path, additional_stopwords))

# %%
product.head(3)
# Out:
#   add_rule_based_split_review           changed_text
# 3    금액 차이 얼마 안 나는데 기능은 더 좋아요      [금액, 차이, 기능, 좋아요]
# 4  콤팩트한 디자인과 실용성에 높은 점수 주었습니다     [콤팩트, 디자인, 실용, 높은]
# 8           전면 스크래치가 많아서 아쉽네요  [전면, 스크래치, 많아서, 아쉽네요]

# %%
product.head(3)
# Out:
#   add_rule_based_split_review           changed_text
# 3    금액 차이 얼마 안 나는데 기능은 더 좋아요      [금액, 차이, 기능, 좋아요]
# 4  콤팩트한 디자인과 실용성에 높은 점수 주었습니다     [콤팩트, 디자인, 실용, 높은]
# 8           전면 스크래치가 많아서 아쉽네요  [전면, 스크래치, 많아서, 아쉽네요]

# %%
def list_convert_comma(lst):
    return ', '.join(lst)

def list_convert_space(lst):
    return ' '.join(lst)

# %%
product['Tokenized_sentence'] = product['changed_text'].apply(list_convert_comma)
product['Tokenized_morphs'] = product['changed_text'].apply(list_convert_space)
product.head(3)
# Out:
#   add_rule_based_split_review           changed_text   Tokenized_sentence  \
# 3    금액 차이 얼마 안 나는데 기능은 더 좋아요      [금액, 차이, 기능, 좋아요]      금액, 차이, 기능, 좋아요
# 4  콤팩트한 디자인과 실용성에 높은 점수 주었습니다     [콤팩트, 디자인, 실용, 높은]     콤팩트, 디자인, 실용, 높은
# 8           전면 스크래치가 많아서 아쉽네요  [전면, 스크래치, 많아서, 아쉽네요]  전면, 스크래치, 많아서, 아쉽네요
#
#    Tokenized_morphs
# 3      금액 차이 기능 좋아요
# 4     콤팩트 디자인 실용 높은
# 8  전면 스크래치 많아서 아쉽네요

# %%
#remove_stopwords = sum(preprocessed_reviews, [])
remove_stopwords2 = sum(product['changed_text'],[])
remove_stopwords2
# Out:
# ['금액',
#  '차이',
#  '기능',
#  '좋아요',
#  '콤팩트',
#  '디자인',
#  '실용',
#  '높은',
#  '전면',
#  '스크래치',
#  '많아서',
#  '아쉽네요',
#  '말',
#  '멀티',
#  '어댑터',
#  '해외여행',
#  '필수',
#  '탬',
#  '작아서',
#  '휴대',
#  '굿',
#  '굿',
#  '배송',
#  '좋은',
#  '품질',
#  '감사',
#  'USB형',
#  '후기',
#  '형',
#  '사용',
#  '좋았',
#  '해외',
#  '여유',
#  '같아요',
#  '나라',
#  '전압',
#  '충전',
#  '나라',
#  '있고',
#  '느리게',
#  '충전',
#  '경우',
#  '있고',
#  '충전',
#  '코드',
#  '불편',
#  '호텔',
#  '있어서',
#  '파우치',
#  '같은',
#  '밑',
#  '사용',
#  '같아요',
#  '충전',
#  '충전',
#  '속도',
#  '많이',
#  '사용',
#  '불편',
#  '없었',
#  '호환',
#  '나라',
#  '많아서',
#  '좋아요',
#  '마감',
#  '아쉬우나',
#  '맛',
#  '유럽',
#  '여행',
#  '구매',
#  '유럽',
#  '나라',
#  '얇아요',
#  '단자',
#  '있어',
#  '유용',
#  '불량',
#  '사용',
#  '좋겠',
#  'USB형',
#  '성능',
#  '대비',
#  '가격',
#  '착하네요',
#  '물건',
#  '멀티',
#  '콘센트',
#  '몸통',
#  '단점',
#  '있어요',
#  '필요',
#  '기능',
#  '좋았',
#  '일반',
#  'USB형',
#  '구매',
#  '여행',
#  '좋음',
#  '겸용',
#  '같아요',
#  '센스',
#  '파우치',
#  '보관',
#  '쉽네요',
#  '충전',
#  '느리편',
#  '괜찮아요',
#  '유럽',
#  '본체',
#  '콘센트',
#  '결과',
#  '구성',
#  '편리',
#  '만족',
#  '한국',
#  '포트',
#  '좋을',
#  '같아서',
#  '구매',
#  '여행',
#  '구매',
#  '사용',
#  '사용',
#  '불안',
#  '있지만',
#  '제품',
#  '추가',
#  '구매',
#  '불량',
#  '구매',
#  '포트',
#  '많아서',
#  '활용',
#  '좋고',
#  '작동',
#  '장기',
#  '해외',
#  '출장',
#  '급하게',
#  '구매',
#  '고장',
#  '여유',
#  '구매',
#  '완료',
#  '기대',
#  '배송',
#  '다이소',
#  '불편',
#  '고정',
#  '무용지물',
#  '해결',
#  '편리',
#  '성비',
#  '좋습니다',
#  '주문',
#  '불량',
#  '정상',
#  '다행',
#  '플러그',
#  '형식',
#  '편리',
#  '같아요',
#  '품질',
#  '좋습니다',
#  '보관',
#  '파우치',
#  '연결',
#  '연결',
#  '가능',
#  '고장',
#  '같아서',
#  '주문',
#  '주문',
#  '콘센트',
#  '느낌',
#  '사용',
#  '지장',
#  '없긴',
#  '코드',
#  '괜찮은',
#  '같아요',
#  '이외',
#  '멀티',
#  '사용',
#  '부분',
#  '좋습니다',
#  '제품',
#  '같아요',
#  '생각',
#  '콘센트',
#  '정상',
#  '동작',
#  '국내',
#  '기능',
#  '확인',
#  '국가',
#  '콘센트',
#  '가격',
#  '많은',
#  '기능',
#  '만족',
#  '여행',
#  '필요',
#  '물건',
#  '구매',
#  '타입',
#  '집',
#  '콘센트',
#  '전원',
#  '고정',
#  '타입',
#  '집',
#  '콘센트',
#  '전원',
#  '고정',
#  '나라',
#  '플러그',
#  '모양',
#  '좋아요',
#  '지인',
#  '품질',
#  '좋았',
#  '좋겠',
#  '버튼',
#  '부분',
#  '많네요',
#  '유럽',
#  '여행',
#  '어댑터',
#  '구입',
#  '국가',
#  '편리',
#  '가격',
#  '구매',
#  '여행',
#  '제품',
#  '퀄리티',
#  '좋네요',
#  '사용',
#  '작고',
#  '파우치',
#  '있어서',
#  '휴대',
#  '같아요',
#  '대만',
#  '여행',
#  '충전',
#  '타입',
#  '있어서',
#  '좋았',
#  '해외',
#  '다이슨',
#  '구매',
#  '충전',
#  '좋아요',
#  '저번',
#  '일본',
#  '여행',
#  '맛',
#  '돼지코',
#  '연결',
#  '멀티탭',
#  '맘',
#  '걱정',
#  '필요',
#  '타입',
#  '충전',
#  '좋았',
#  '기존',
#  '돼지코',
#  '구매',
#  '점',
#  '맘',
#  '타입',
#  '부분',
#  '있어서',
#  '좋네요',
#  '별도',
#  '충전기',
#  '케이블',
#  '짐',
#  '굿',
#  '대만',
#  '고속',
#  '충전',
#  '동생',
#  '미국',
#  '출장',
#  '연락',
#  '가볍고',
#  '전용',
#  '파우치',
#  '보관',
#  '캐리어',
#  '좋아요',
#  '유선',
#  '칸',
#  '많아서',
#  '충전',
#  '장점',
#  '있어요',
#  '상품',
#  '품질',
#  '마감',
#  '실물',
#  '좋네요',
#  '예쁘고',
#  '감',
#  '코',
#  '여행',
#  '멀티',
#  '어댑터',
#  '해외여행',
#  '미국',
#  '여행',
#  '사용',
#  '사용',
#  '타입',
#  '다양',
#  '다양',
#  '같아요',
#  '휴대',
#  '편리',
#  '동일',
#  '스펙',
#  '멀티',
#  '어댑터',
#  '디자인',
#  '파우치',
#  '있고',
#  '충전',
#  '속도',
#  '여행',
#  '기능',
#  '편리',
#  '타입',
#  '타입',
#  '있어서',
#  '유용',
#  '멀티탭',
#  '대신',
#  '여행',
#  '필수',
#  '탬',
#  '강추',
#  '좋네요',
#  '용도',
#  '다양',
#  '물건',
#  '사진',
#  '좋습니다',
#  '타입',
#  '타입',
#  '가능',
#  '가격',
#  '좋은',
#  '같습니다',
#  'A타입',
#  '타입',
#  '유용',
#  '사용',
#  '손',
#  '선풍기',
#  '와이파이',
#  '도시락',
#  '핸드폰',
#  '보조',
#  '배터리',
#  '충전',
#  '좋았',
#  '핸드폰',
#  '충전',
#  '속도',
#  '고속',
#  '충전',
#  '사용',
#  '충전기',
#  '좋았',
#  '디자인',
#  '한몫',
#  '생각',
#  '여행',
#  '좋네요',
#  '파우치',
#  '보관',
#  '좋고요',
#  '케이스',
#  '있어서',
#  '휴대',
#  '좋아서',
#  '여행',
#  '사용',
#  '같습니다',
#  '퀄리티',
#  '좋아요',
#  '파우치',
#  '좋아요',
#  '구매',
#  '평',
#  '휴대',
#  '편하고',
#  '일본',
#  '불편',
#  '업',
#  '사용',
#  '같아요',
#  '별점',
#  '이유',
#  '전기',
#  '제품',
#  '배송',
#  '케이스',
#  '감사',
#  '케이스',
#  '쿠션',
#  '없고',
#  '박스',
#  '같은',
#  '스티커',
#  '출국',
#  '물건',
#  '테스트',
#  '한국',
#  '콘센트',
#  '구멍',
#  '크기',
#  '모양',
#  '멀티',
#  '어댑터',
#  '사용',
#  '점',
#  '좋아요',
#  '케이스',
#  '맘',
#  '배송',
#  '충전',
#  '덕분',
#  '사진',
#  '여행',
#  '편하게',
#  '사용',
#  '보관',
#  '파우',
#  '좋아요',
#  '디자인',
#  '파우치',
#  '마음',
#  '여행',
#  '전이',
#  '성능',
#  '기능',
#  '나라',
#  '여행',
#  '일본',
#  '여행지',
#  '사용',
#  '구입',
#  '여분',
#  '돼지코',
#  '없었',
#  '큰일',
#  '날',
#  '정도',
#  '어댑터',
#  '작동',
#  '유럽',
#  '여행',
#  '이용',
#  '제품',
#  '콘센트',
#  '좋더라고요',
#  '외국',
#  '같아요',
#  '고장',
#  '같아요',
#  '신행',
#  '준비',
#  '어댑터',
#  '좋겠',
#  '충전',
#  '좋아요',
#  '유럽',
#  '여행',
#  '흰색',
#  '이쁘고',
#  '작고',
#  '케이스',
#  '있어서',
#  '좋아요',
#  '리뷰',
#  '구매',
#  '디자인',
#  '맘',
#  '좋아요',
#  '파우치',
#  '좋아요',
#  '자리',
#  '차지',
#  '충전',
#  '여행',
#  '파우치',
#  '좋아요',
#  '일본',
#  '여행',
#  '요고',
#  '해결',
#  'C타입',
#  '고속',
#  '충전',
#  '맘',
#  '파우치',
#  '좋아요',
#  '포트',
#  '만족',
#  '여행',
#  '사용',
#  '작동',
#  '케이스',
#  '고급',
#  '동유럽',
#  '필요',
#  '없었',
#  '보조',
#  '배터리',
#  '충전',
#  '사용',
#  '파우치',
#  '좋아요',
#  '나라',
#  '사용',
#  '좋은',
#  '같아요',
#  '부모',
#  '여행',
#  '가실',
#  '성능',
#  '좋으면',
#  '좋겠',
#  '연결',
#  '좋았',
#  '케이스',
#  '보관',
#  '돼지코',
#  '준비',
#  '돼지코',
#  '없었',
#  '파우치',
#  '안심',
#  '여행',
#  '언니',
#  '어댑터',
#  '제품',
#  '구매',
#  '냄새',
#  '미국',
#  '출장',
#  '차',
#  '급하게',
#  '구입',
#  '파우치',
#  '마음',
#  '후기',
#  '품질',
#  '문제',
#  '사용',
#  '생각',
#  'C타입',
#  '좋네요',
#  '내구',
#  '안정',
#  '사용',
#  '가능',
#  '사은품',
#  '파우치',
#  '덕분',
#  '이동',
#  '파손',
#  '우려',
#  '없었',
#  'PD충전',
#  'C타입',
#  '충전',
#  '필',
#  '포트',
#  '있어',
#  '굿',
#  '충전기',
#  '필요',
#  '없는',
#  '점',
#  '실용',
#  '좋았',
#  '비싸지만',
#  '구매',
#  '파우치',
#  '생각',
#  '좋네요',
#  '작동',
#  '지역',
#  '사용',
#  '편리',
#  '구성',
#  '품',
#  '맘',
#  '멀티탭',
#  '덕분',
#  '일본',
#  '여행',
#  '핸드폰',
#  '보조',
#  '배터리',
#  '친구',
#  '보조',
#  '배터리',
#  '충전',
#  '야무지게',
#  '덕분',
#  '사진',
#  '좋은',
#  '부분',
#  '충전',
#  '유선',
#  '곳',
#  '많고',
#  '멀티탭',
#  '국가',
#  '사용',
#  '가능',
#  '좋아요',
#  '무게',
#  '생각',
#  '가볍고',
#  '구매',
#  '휴대',
#  '파우',
#  '휴대',
#  '사진',
#  '동일',
#  '여행',
#  '속',
#  '멀티탭',
#  '사진',
#  '첨부',
#  '다이소',
#  '충전',
#  '케이블',
#  '충전기',
#  '무게',
#  '벽',
#  '설치',
#  '밑',
#  'C타입',
#  '케이블',
#  '곳',
#  '편리',
#  '어댑터',
#  '전체',
#  '만족',
#  '제품',
#  '무게',
#  '정도',
#  '충전',
#  '타입',
#  '타입',
#  '있어서',
#  '실용',
#  '구멍',
#  '여행',
#  '여행지',
#  '고데기',
#  '사용',
#  '필수',
#  '렴',
#  '돼지코',
#  '파우치',
#  '제품',
#  '구입',
#  '곳',
#  '많아서',
#  '멀티탭',
#  '대신',
#  '사용',
#  '좋았',
#  '고데기',
#  '어댑터',
#  '연결',
#  '돼지코',
#  '사용',
#  '나라',
#  '어댑터',
#  '사용',
#  '같아요',
#  '고정',
#  '좋은',
#  '같아요',
#  '형태',
#  '충전',
#  '가능',
#  '좋네요',
#  '처음',
#  '곳',
#  '없나',
#  '식겁',
#  'C타입',
#  '좋아요',
#  '케이스',
#  '있어서',
#  '좋고',
#  '성능',
#  '만족',
#  '생각',
#  '느낌',
#  '무게',
#  '있군요',
#  '사이즈',
#  '크지',
#  '커버',
#  '있어서',
#  '좋아요',
#  '편하지만',
#  '느리네요',
#  '디자인',
#  '이쁘고',
#  '케이스',
#  '좋아요',
#  '디자인',
#  '군더더기',
#  '없고',
#  '좋아요',
#  '케이스',
#  '있는',
#  '좋은',
#  '여행',
#  '사용',
#  '케이스',
#  '좋아요',
#  '제품',
#  '많지만',
#  '구멍',
#  '많아서',
#  '좋은',
#  '같아요',
#  '미',
#  '사용',
#  '활용',
#  '높을',
#  '같아',
#  '좋아요',
#  '해외',
#  '호텔',
#  '포트',
#  '이용',
#  '핸드폰',
#  '충전',
#  '속도',
#  '빠르지',
#  '집',
#  '드라이',
#  '사용',
#  '핸드폰',
#  '충전',
#  '호텔',
#  '포트',
#  '디자인',
#  '만족',
#  '돼지코',
#  '여행',
#  '고장',
#  '후기',
#  '케이스',
#  '제품',
#  '가격',
#  '품질',
#  '배송',
#  '만족',
#  '상품',
#  '케이스',
#  '좋아요',
#  '어댑터',
#  '구성',
#  '좋습니다',
#  '디자인',
#  '멀티',
#  '콘센트',
#  '좋네요',
#  '커피',
#  '대신',
#  '물',
#  '쓸모',
#  '대박',
#  '상품',
#  '충전',
#  '핸드폰',
#  '충전',
#  '멀티탭',
#  '연결',
#  '해외여행',
#  '필수',
#  '탬',
#  '덕분',
#  '영국',
#  '출장',
#  '구매',
#  '다이소',
#  '타입',
#  '이랑',
#  '구성',
#  '견고',
#  '나라',
#  '좋아요',
#  '콘센트',
#  '콘센트',
#  '충전',
#  '여행',
#  '활용',
#  '색',
#  '케이스',
#  '케이스',
#  '있어서',
#  '좋아요',
#  '결제',
#  '케이스',
#  '있어',
#  '사용',
#  '좋을',
#  '같아요',
#  '충전',
#  '여행',
#  '사용',
#  '선',
#  '충전',
#  '해외여행',
#  '생각',
#  '크긴',
#  '점',
#  '문제없었',
#  '퓨즈',
#  '해외',
#  '사용',
#  '퓨즈',
#  '여분',
#  '퓨즈',
#  '작동',
#  '사용',
#  '파우치',
#  '케이스',
#  '좋아요',
#  '사은품',
#  '케이스',
#  '배송',
#  '포장',
#  '만족',
#  '호텔',
#  '어댑터',
#  '있었',
#  '충전',
#  '여행',
#  '좋은',
#  '마음',
#  '주문',
#  '파우치',
#  '맘',
#  '후대',
#  '일본',
#  '편하게',
#  '케이스',
#  '좋아요',
#  '해외여행',
#  '어댑터',
#  '국내',
#  '확인',
#  '불량',
#  '단점',
#  '불량',
#  '충전',
#  '충전',
#  '속도',
#  '느리지',
#  '워치',
#  '핸드폰',
#  '보조',
#  '배터리',
#  '충전',
#  '좋았',
#  '있으면',
#  '해외',
#  '걱정',
#  '없습니다',
#  '충전',
#  '포트',
#  '걱정',
#  '고데기',
#  '고데기',
#  '프리',
#  '볼트',
#  '제품',
#  '앞',
#  '여행',
#  '어댑터',
#  '걱정',
#  '없겠',
#  '무료',
#  '배송',
#  '나중',
#  '가족',
#  '글',
#  '주문',
#  '애플',
#  '워치',
#  '보조',
#  '배터리',
#  '충전',
#  '대부분',
#  '사용',
#  '케이스',
#  '보관',
#  '편리',
#  '제품',
#  '상',
#  '품평',
#  '구매',
#  '품질',
#  '좋네요',
#  '중국',
#  '기대',
#  '좋습니다',
#  '타입',
#  '한국',
#  '형',
#  '충전',
#  '사용',
#  '같아요',
#  '멀티탭',
#  '기기',
#  '충전',
#  '가능',
#  '같습니다',
#  '타입',
#  '여유',
#  '좋네요',
#  '외국',
#  '사용',
#  '구성',
#  '좋고',
#  '맘',
#  '일본',
#  '여행',
#  '고장',
#  '충전',
#  '사용',
#  '개선',
#  '좋을',
#  '충전',
#  '입구',
#  '깊이',
#  '깊지',
#  '일본',
#  '많더군요',
#  '깊은',
#  '입구',
#  '안쪽',
#  '개선',
#  '좋을',
#  '같습니다',
#  '곳',
#  '많고',
#  '만족',
#  '마감',
#  '처리',
#  '아쉽습니다',
#  '사용',
#  '좋아서',
#  '값',
#  '비싸지만',
#  '걱정',
#  '글',
#  '아이디어',
#  '실용',
#  '정리',
#  '구조',
#  '같아요',
#  '휴대',
#  '편하고',
#  '국내',
#  '필요',
#  '사용',
#  '하머',
#  '구입',
#  '사용',
#  '고장',
#  '평소',
#  '감',
#  '엔',
#  '코',
#  '선',
#  '어댑터',
#  '사나',
#  '파우치',
#  '미국',
#  '여행',
#  ...]

# %%
from collections import Counter
remain_freq = Counter(remove_stopwords2).most_common()
df_remain_freq = pd.DataFrame(remain_freq, columns=['형태소', '빈도'])
df_remain_freq
# Out:
#        형태소    빈도
# 0       충전  1488
# 1       사용  1038
# 2      케이스   927
# 3       여행   872
# 4      좋아요   720
# ...    ...   ...
# 1649    두께     1
# 1650  문제없어     1
# 1651   편하셨     1
# 1652    도어     1
# 1653  귀엽군요     1
#
# [1654 rows x 2 columns]

# %%
from pprint import pprint
print(df_remain_freq)
# Out:
#        형태소    빈도
# 0       충전  1488
# 1       사용  1038
# 2      케이스   927
# 3       여행   872
# 4      좋아요   720
# ...    ...   ...
# 1649    두께     1
# 1650  문제없어     1
# 1651   편하셨     1
# 1652    도어     1
# 1653  귀엽군요     1
#
# [1654 rows x 2 columns]

# %%
df_remain_freq.to_csv('C:/Users/songy/Desktop/Data/product_keyword.csv', encoding = 'utf-8-sig')

# %%
df_remain_freq
# Out:
#        형태소    빈도
# 0       충전  1488
# 1       사용  1038
# 2      케이스   927
# 3       여행   872
# 4      좋아요   720
# ...    ...   ...
# 1649    두께     1
# 1650  문제없어     1
# 1651   편하셨     1
# 1652    도어     1
# 1653  귀엽군요     1
#
# [1654 rows x 2 columns]
