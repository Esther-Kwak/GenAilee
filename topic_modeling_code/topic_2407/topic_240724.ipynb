# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import re

from konlpy.tag import *

# %%
from konlpy.tag import Mecab

m = Mecab(dicpath = 'C:/mecab/mecab-ko-dic')
m.nouns('A타입도 좋고, PD충전 되는 것도 좋아요. C타입 여러개 있어서 좋습니다')
# Out:
# ['A타입', 'PD충전', '것', 'C타입', '개']

# %%
product = pd.read_csv("C:/Users/shopperhouse/Code/GEN_Ailee\product.csv", index_col = 0)
product
# Out:
#                              add_rule_based_split_review
# 3                               금액 차이 얼마 안 나는데 기능은 더 좋아요
# 4                             콤팩트한 디자인과 실용성에 높은 점수 주었습니다
# 8                                      전면 스크래치가 많아서 아쉽네요
# 18                              말 그대로 멀티 어댑터에요 해외여행 필수 탬
# 22                                            작아서 휴대도 굿굿
# ...                                                  ...
# 17702                                       가볍고 휴대하기 좋아요
# 17703  C 타입 충전이 없어서 구매를 망설이긴 했지만 좀 큰 변압기는 쳐져서 충전이 잘 안...
# 17704                                        요 사이즈가 딱이네요
# 17706                                   켔써요 노란색이 너무 귀엽군요
# 17709           한 손에 쏙 들어오고 색이 쨍해서 여행 가서 잃어버릴 일 없을 거 같아요
#
# [7785 rows x 1 columns]

# %%
def upper_text(text):
    text = text.upper()
    return text

# %%
product['add_rule_based_split_review'] = product['add_rule_based_split_review'].apply(upper_text)

# %%
def replace_text(text):
  text = str(text)
  text = text.replace('습ㄴ지다','습니다')
  text = text.replace('쌈ㅎ','저렴해요')
  text = text.replace('안되는...','안됩니다')
  text = text.replace('ㅎ','')
  text = text.replace('ㄱㅅ함다','감사합니다')
  text = text.replace('ㅋ','')
  text = text.replace('루♡','')
  text = text.replace('♡','')
  text = text.replace('굳','굿')
  text = text.replace('뻈어요','뺏어요')
  text = text.replace('ㅜ','')
  text = text.replace('0','')
  text = text.replace('좋음.','좋음')
  text = text.replace('중입니다♥?)','중 입니다')
  text = text.replace('하나에요','하나예요')
  text = text.replace('됩니다><','됩니다')
  text = text.replace('있었어요','있어요')
  text = text.replace('_','')
  text = text.replace('욥','요')
  text = text.replace('ㆍ','')
  text = text.replace('오겠씀다~~ㅎㅎ/','오겠습니다')
  text = text.replace('/',' ')
  text = text.replace('듯.','듯')
  text = text.replace('후에~','')
  text = text.replace('개용','개요')
  text = text.replace('.?','')
  text = text.replace('ㅅ','')
  text = text.replace('오ㅡ','')
  text = text.replace('여행가고싶어지네요ㅋㅋ','여행 가고 싶어지네요')
  text = text.replace('좋습니다!!!!','좋습니다')
  text = text.replace('...','')
  text = text.replace('구매확정해요','구매 확정해요')
  text = text.replace('완죤빨라요ㅋㅋ','완전 빨라요')
  text = text.replace('ㅡ','')
  text = text.replace('귀요미에요','귀여워요')
  text = text.replace('최고여요','최고예요')
  text = text.replace('-',' ')
  text = text.replace('사랑하여','사랑해요')
  text = text.replace('배송되었습니다','배송 되었습니다')
  text = text.replace('좋아요ㅔ','좋아요')
  text = text.replace('아니에요.','아니예요')
  text = text.replace('구매확정했습니다','구매 확정했습니다')
  text = text.replace('bbb','굿')
  text = text.replace('쓸ㄲ너ㅣㅇ르','')
  text = text.replace(';','')
  text = text.replace('같고요','같아요')
  text = text.replace('같네요','같아요')
  text = text.replace('씁니다','습니다')
  text = text.replace('넘좋와여','너무 좋아요')
  text = text.replace('굿입니다','굿')
  text = text.replace('목배게최고에요','목배게 최고예요')
  text = text.replace('감동이에요','감동이예요')
  text = text.replace(',.','')
  text = text.replace('아이디어템','아이디어 탬')
  text = text.replace(':D','')
  text = text.replace('..','')
  text = text.replace('감사핮니다','감사합니다')
  text = text.replace('템','탬')
  text = text.replace('든든 합니다','든든합니다')
  text = text.replace('받아보았어요','받아봤어요')
  text = text.replace('가타용','같아요')
  text = text.replace('바랍니아','바랍니다')
  text = text.replace('사업번창하세요','사업 번창하세요')
  text = text.replace('쓸겠습니다','쓰겠습니다')
  text = text.replace('구매완료입니다','구매완료')
  text = text.replace('짱빠름','짱 빠름')
  text = text.replace('됩니닽','됩니다')
  text = text.replace('닙니다ㅛ','닙니다')
  text = text.replace('잘한듯해요','잘한듯')
  text = text.replace('가세여','가세요')
  text = text.replace('잘샀다템','잘샀어요')
  text = text.replace('좋아요좋아요좋오ㅓㅗㅇ좋아요','좋아요 좋아요')
  text = text.replace('@@','')
  text = text.replace('써봐겠ㅆ네요','써봐야겠네요')
  text = text.replace('만족이에요','만족이예요')
  text = text.replace('아까워요.','아까워요')
  text = text.replace('ajjqjahaja','')
  text = text.replace('잚슬겡ㅎ','잘쓸게요')
  text = text.replace('잘했아요','잘했어요')
  text = text.replace('괜찬ㅍ아요','괜찮아요')
  text = text.replace('><','')
  text = text.replace('예쁨','예뻐요')
  text = text.replace('편하쥬','편해요')
  text = text.replace('감사함다','감사합니다')
  text = text.replace('*','')
  text = text.replace('핳핳','')
  text = text.replace('굿입니다','굿')
  text = text.replace('으흐흐','')
  text = text.replace('빨라요ㅗ','빨라요')
  text = text.replace('이븜','이쁨')
  text = text.replace('ㄹㅇ','')
  text = text.replace('되매요','되네요')
  text = text.replace('믿어보겠음다','믿어보겠습니다')
  text = text.replace('아니에요','아니예요')
  text = text.replace('만족합니다.ㅣ','만족합니다')
  text = text.replace('되고요','됩니다')
  text = text.replace('딱입니딘','딱입니다')
  text = text.replace('기대되어요','기대됩니다')
  text = text.replace('왔습디다','왔습니다')
  text = text.replace('맀어용','랐어요')
  text = text.replace('강강히','')
  text = text.replace('만족이여','만족이요')
  text = text.replace('사용했니다.','사용했습니다')
  text = text.replace('충전빨리되구죻아요','충전 빨리되고 좋아요')
  text = text.replace('잘됩니다잉','잘됩니다')
  text = text.replace('사용했답니다','사용했어요')
  text = text.replace('가타요','같아요')
  text = text.replace('최곱니다','최고입니다')
  text = text.replace('빠르네요','빠릅니다')
  text = text.replace('기릉','기를')
  text = text.replace('받았습니아','받았습니다')
  text = text.replace('ok.','ok')
  text = text.replace('가져감','가져갑니다')
  text = text.replace('익니다','입니다')
  text = text.replace('수용되오ㅡ','수용되요')
  text = text.replace('맨죡','만족')
  text = text.replace('`','')
  text = text.replace(',,,','')
  text = text.replace('ㄹ','')
  text = text.replace('구매예정이에요','구매 예정이예요')
  text = text.replace('좋은듓','좋은듯')
  text = text.replace('매우저롐하게잘구매했어요감사하네여','매우 저렴하게 잘 구매했어요 감사해요')
  text = text.replace('만적합니다','만족합니다')
  text = text.replace('ㅈ번창하세요','번창하세요')
  text = text.replace('전이에요','전이예요')
  text = text.replace('조어요','좋아요')
  text = text.replace('젛아요','좋아요')
  text = text.replace('됩니더','됩니다')
  text = text.replace('굿입디다','굿')
  text = text.replace('갘아어요','')
  text = text.replace('ㄷ,','')
  text = text.replace('잘되겠쥬','잘되겠죠')
  text = text.replace('쓰게습니도','쓰겠습니다')
  text = text.replace('하고요','하고')
  text = text.replace('저뇽가방도있네요','전용가방도 있네요')
  text = text.replace('sjsjsjjsjs','')
  text = text.replace('좋겠구먼요','좋겠네요')
  text = text.replace('좋아욫','좋아요')
  text = text.replace('반퓸합니다','반품합니다')
  text = text.replace('꿋꿋입니다','굿')
  text = text.replace('잘씅게용','잘쓸게요')
  text = text.replace('땡큐네요','감사합니다')
  text = text.replace('베릐굿','굿')
  text = text.replace('효오','')
  text = text.replace('☆','')
  text = text.replace('ᄒ','')
  text = text.replace('썼어ᄉ','썼어요')
  text = text.replace('ㄱ','')
  text = text.replace('사용시뉴용할듯욕','사용시 유용할 듯')
  text = text.replace('있아요','있어요')
  text = text.replace('아다아다아','')
  text = text.replace('아다 아다 아','')
  text = text.replace('감사합니다아','감사합니다')
  text = text.replace('goood','굿')
  text = text.replace('싱픔굿배소오쟈웁','상품 굿 배송')
  text = text.replace('쓸겡','쓸게요')
  text = text.replace('굿국국숙','굿굿굿')
  text = text.replace('졸아요','좋아요')
  text = text.replace(': ','')
  text = text.replace(':','')
  text = text.replace('근데,','')
  text = text.replace('USC','usb')
  text = text.replace('A S','AS')
  text = text.replace('※','')
  text = text.replace(' ㅐ외','해외')
  text = text.replace('ᄆ','')
  text = text.replace('ᅳᄋ ᄋ','')
  text = text.replace('배슝','배송')
  text = text.replace('@ % @ @ @','')
  text = text.replace('@','')
  text = text.replace('ᅲ','')
  text = text.replace('쓸ᄁ너ᅵᄋ르','쓸게요')
  text = text.replace(' ♥','')
  text = text.replace('ᄏ','')
  text = text.replace('강 추','강추')
  text = text.replace('★','')
  text = text.replace('■','')
  text = text.replace('C 타입','C타입')
  text = text.replace('씨타입','C타입')
  text = text.replace('A 타입','A타입')
  text = text.replace('에이타입','A타입')
  text = text.replace('PD 충전','PD충전')

  # 1개짜리는 제외
  return text

# %%
product['add_rule_based_split_review'] = product['add_rule_based_split_review'].apply(replace_text)

# %%
def clean_text(text):
    if isinstance(text, str):
        return re.sub(r'[-=+,#/\?:^$.@*"※~&%ㆍ!』\\‘·|\(\)\[\]\<\>`\'…\"\“’]', '', text)
    else:
        return ""

# %%
product['add_rule_based_split_review'] = product['add_rule_based_split_review'].apply(clean_text)

# %%
def preprocess_reviews(reviews, stopwords_path, additional_stopwords=[]):
    # 불용어 파일 로드
    with open(stopwords_path, encoding='utf-8') as file:
        stopwords = file.read().splitlines()
    
    # 추가 불용어 합치기
    stopwords.extend(additional_stopwords)

    # 리뷰 전처리
    clean_sent = []
    for review in reviews:
        clean = re.sub(r'[-=+,#/\?:^$.@*"※~&%ㆍ!』\\‘·|\(\)\[\]\<\>`\'…\"\“’]', '', review)
        clean = clean.replace('\n', '').replace('\r', '')  # 줄바꿈 문자 제거
        clean_sent.append(clean)

    m = Mecab(dicpath = 'C:/mecab/mecab-ko-dic')
    
    word_list = []
    for sentences in clean_sent:
        # 정규화
        # sentences = m.normalize(sentences)
        # 토큰화
        # tokens = sentences.split()
        tokens = m.nouns(sentences)
        # tokens = okt.nouns(sentences)
        # 불용어 제거
        tokens = [token for token in tokens if token not in stopwords]
        word_list.append(tokens)
    
    return word_list

# %%
reviews = product['add_rule_based_split_review']  # 리뷰 데이터
stopwords_path = "C:/Users/shopperhouse/Downloads/stopwords-ko.txt"
additional_stopwords = ['의','가','이','은','들','는','과','서', 'c', '있다','자다','라고', '이라', '되다', '제', 'ㅎ', 'ㅋㅋ',
                        '도','를','으로','자','에','와','한','하다','등' ,'및', '것', '에서', '거', '면', '오다', '용', '요',
                        '잘','다','수','개','달','해외여행','해외','여행', '게요', '전', '변','이거','시', 
                        '하다', '자다', '.', '있다', '도', '이', '에', '써다', '때', '너무', '가', '것' ,'에서', '거',
                        '서', '수', ',', '요','오다','아직','으로','을','은','아주','안','를','로','되어다', '다','하고',
                        '이다','않다','받다','고','는','게','이번','만','전','돼다','까지','용','라','번','달','시','못',
                        '지만','중','사','들','해봤다','인데','나','문제','..','다음','면','이라','과','제','여','라서',
                        '잘','적','맘','의','기','꼭','또','에서도','싶다','진짜','듯','마다','?','내','어느','해','에는',
                        '저','후','곳','나다','산','때문','에도','네','선','빨','일이','그냥','한','덕분','와','줄','랑',
                        '두','인','함','건','성','그리고','에서는','등','보','여서','동안','딱','모든','따로','짐','가면',
                        '이랑','데','하지만','대비','굿굿','간','니','이네','아','별','주','이고','든','가기','걸','감',
                        '이에요','이예요','자주','아무','그래서','나오다','그래도','예요','구','v','잇다','이용','우선',
                        '살짝','내내','기다','분','바','유','가든','어','일','+','엔','처음','래','듭니','세','만큼','빼다',
                        '미리','지금','기존','계속','약간','오','바로','혹시','사은','구요','꽉','지','으로도','그','이나',
                        '하니'',자꾸','꼽','실','V','대가','에선','에게','훨씬','별로','야','처럼','땐','뭐','품','무엇',
                        '별도','꽤','한데','W','명','에스','하','쪽','온','첫','탈','중이','짱','지고','행','...','라고',
                        '단','외','죠','.?','날','위','재','허다','수가','언스','가성','너','그런데','아이','모','겠다',
                        '굿굿굿','뿐','분들','사려','및','여기','안해','대신','음','에서나','이예','대해','습니','...','자',
                        '터','자마자','타','사가','테','티스','소','스비','으로는','왜','한테','텐데','대로','이제','그거',
                        '즈','대요','젠','장','젠장','영','대','반','속','각','신행','꺼','ㅜㅜ','임','준','곳도','리','년',
                        '법도','','히','아무래도','그대로','어서','엇','님','김','서도','로서','됫','난','휴','정','에드',
                        '대박','만약','연','트','좋아','편','애','이라는','이랑은','스럽게','모로','껏','통해','동','다가',
                        'ㅏㅁㄴ해','이라고','곤','.???','*','평','이니','뮤','녀석',"'", '뻔','콘','놈','ㅜ','겹','십','께',
                        'to','충','라는','으로만','예','구가','탓','덜','☆','흠','째',',,,','편이','이만','무','디지다','치',
                        '만의','극','작','겟네','뻐','햇','며','끗','쩝','팅','◡̈','다기','??','>','<','짜리','암튼','국',
                        '어요','치네다','그레','겨우','그러니까','밑','하므다','나니','안나','풍','평이','움','♥︎',';','식',
                        '남','진','신','인거','_','ㅇㅅ','료','와는','이지','니까','언','어쪄','싰는데','누','오지','뿌네',
                        '담','긍','등등','친','구거','삐','부턴','원체','득','능이','햇으','됫네','만을','아직','당','몀',
                        '거란','뿌','에서든지','어찌어찌','장안','땜','떼','곡','다다','디음','인가요','줄줄','천후','쭉',
                        '에요','다용','딜','우레','D','이든','던','요런','시나','라도','한다는','족','지네','뭘','값임',
                        '찌다','에다','에나','역','뇨','디테','로움','뽀옹','원주고','격','박','향가','안고','※','대한',
                        '데리','그랬는데','앙증','탬이','씨','**','디','방','넉','얼','바나','썻','림','더군요','뭥',
                        '가렵니','이면','버여','숩니','모해','노','꾹','이기','쿄','습','룸','ㄴ','차무','부아','아앙','스',
                        '았','쑤다','예여','쥬','접','젤','싰습니','여도','위져','녀','원쁠','겸','사시','로만','ㄷㄷㄷ','|',
                        'ㅣ','규','개사','퍽','나기','바봬','즇으','왕사','욜','으','에서만','보다도','번만','꽈','니깐',
                        '터너','홈','건가','꼿는','스레','젠데','땨','여요','디어','이니까','만으로','..,','드','지는',
                        '바듯','삿','오오','옹','ㅗ','바이','햤어','ㅍ','욤해','이며','조아','걱욧','꼐서는','께서는',
                        '너므','어보','권','됗거','구여','으론','게요','없이','1','도','이','하다','자다','여행','좋다','부아아앙',
                        '씸플','신기방기','쭉','때','것','일본','해외','거','수','아주','개','안','요','유럽','이번','전',
                        '정말','용','게','번','시','이','달','타요','이로', '여행', '때', '것', '일본', '해외', '거', '수', 
                        '거립니','다시','듬새','개도','아주','간혹','잠깐','사나','헐렁거리','비도','다자','봄','누나','신랑','친구','맞춰','생가','어쩜','개', '안', '요', '유럽', '이번', '전', '정말', '묘','용', '게', '번', '시', '이', '달', '더', '중', '하나로', '좀', '다음', '조금', '매우', '제', '맘', '고', '꼭', '또', '기', '도', '듯', '여', '굿', '해', '후', '곳', '그냥', '베트남', '함', '건', '홍콩', '등', '보', '모든', '외국', '데', '호텔', '굿굿', '만', '가기', '걸', '감', '나', '아무', '이용', '주', '우선', '내내', '저', '바', '유', '가든', '일', '구', '듭니', '분', '영국', '스위스', '다만', '미리', '지금', '계속', '바로', '혹시', '사은', '꽉', '하니', '자꾸', '제일', '꼽', '그', '부디', '중국', '현지', '제대로', '간', '내', '몇', '뉴질랜드', '훨씬씬', '싱가포르', '감비앤코', '니', '별로', '세', '필리핀', '땐', '실', '뭐', '품', '무엇', '별도', '다음주', '꽤', '강', '로', '명', '쪽', '사서', '온', '다행', '오', '탈', '행', '굳이', '질', '뒤', '하와이', '도쿄', '단', '외', '하자', '수가', '언스', '가성', '거의', '전혀', '모', '둘', '무조건', '가장', '기도', '조만간', '더욱', '괌', '이예', '서든', '굿굿굿', '뻑뻑', '및', '안해', '대신', '옆', '전부', '신경', '어뎁터', '음', '대해', '얼른', '여기저기', '터', '드네', '말레이시아', '자마자', '해도', '짱', '사가', '살', '테', '티스', '군데', '오사카', '스비', '두바이', '왜', '우리나라', '은', '이제', '그거', '글', '대요', '갓', '타', '각', '신행', '얼마', '깜짝', '임', '절대', '뉴욕', '의', '뿐', '리', '법도', '어서', '마다', '자', '김', '서도', '비앤코', '로서', '됫', '위주', '경우', '정', '에드', '만약', '대박', '트', '편', '애', '영', '금방', '모로', '껏', '통해', '면', '다가', '가요', '만해', '깨끝', '젠', '곤', '충천', '평', '낭패', '뮤', '뻔', '그게', '콘', '놈', '상', '두루', '장', '가야', '겹', '안타', '무슨', '일부러', '군더더기', '시기', '사실', '큰일', '크게', '평소', '충', '개꿀', '기분', '구가', '탓', '덜', '흠', '를', '언제', '구성은', '반', '잠시', '인', '편이', '감안', '이만', '무', '서유럽', '치', '우려', '요새', '뻐', '햇', '할걸', '각자', '갑자기', '종', '나이스', '느슷', '팅', '다기', '사두', '조', '입', '국', '어요', '워낙', '그레', '세부', '내일', '오히려', '스페인', '밑', '미니', '엇', '었어', '햇습니', '나니', '안나', '비엔', '누가', '평이', '대로', '움', '전일', '가까스로', '백이', '삿는데', '다소', '빡빡', '외로', '식', '남', '진', '짤', '난', '료', '마카오', '캐나다', '늘', '일부', '처럼', '무척', '포드', '지장', '주렁주렁', '이지', '하와', '진심', '어쪄', '싰는데', '했어', '저희', '한층', '똑바로', '위로', '누', '오지', '두서', '이후', '필', '싶슺니', '지난', '담', '긍', '등등', '친', '삐', '협소하', '득', '로마', '능이', '하류', '햇으', '됐네', '당', '몀', '강츄합니', '뿌', '글쎄요', '즉시', '땜', '부쩍', '떼', '뜻', '다다', '있겄다', '이나', '줄줄', '텐데', '다용', '타이베이', '일도', '기우', '보임', '또한', '종종', '오케이', '체코', '오스트리아', '요런', '시나', '족', '지네', '일간', '뭘', '값임', '뇨', '디테', '일이', '어탭터', '로움', '꿀', '뽀용', '원주고', '안건', '조마', '리조트', '휴양', '대한', '데리', '유언비어', '했슴돠', '씨', '가라', '대서', '탭터', '대합', '담달', '디', '급', '얼', '바나', '썻', '네', '림', '무어', '젠장', '이면', '스페어', '숩니', '버여', '동남아', '칸', '만요', '구비', '반신반의', '모해', '노', '이기', '이제야', '절찬', '케리', '라뷷호', '이븜', '습', '특', '오기', '해당', '대폭', '남유럽', '북아프리카', '부아', '아앙', '지라', '줌', '다량', '았', '달래', '쥬', '덴마크', '접', '젤', '싰습니', '일주', '씸플하', '히', '지난번', '작', '위져', '녀', '핸폰', '삿포로', '것일', '촉', '쓰시', '적격입니', '달리', '속', '부', '겸', '로만', '규', '향', '투', '아예', '처', '연', '과', '감히', '퍽', '바봬', '쉬', '왕사', '직', '용한', '욜', '겨', '삿네', '깜놀', '덜렁', '마저', '번만', '꽈', '에어비앤비', '아고다', '낼', '휴양도시', '바기오', '마닐라', '관강객', '일절', '어차피', '싸가지', '감쟈함니', '하여튼', '싶엇구', '어찌', '낭', '나로', '워', '사욤할', '괴어', '건가', '몰디브', '렁거리', '번가', '맀었습니', '세심', '스레', '겐트', '젠데', '땨', '다꼽고', '며칠', '여서', '디어', '탄자니아', '이집트', '드', '툴', '어쨌는', '백', '중인', '신기', '방기', '아보', '요요', '예', '바듯', '저뇽', '오오', '옹', '런던', '햤어', '칠레', '뽁뽁', '젭굼', '와우', '욤해', '울', '독일', '타숍', '깨끝해', '쭈욱', '이어도', '넉', '쫀득쫀득', '봉', '걱욧', '너므', '그간', '어보', '럭', '듬직', '동북아시아', '미주', '됗거']

preprocessed_reviews = preprocess_reviews(reviews, stopwords_path, additional_stopwords)
# print(preprocessed_reviews)

# %%
preprocessed_reviews
# Out:
# [['금액', '차이', '기능'],
#  ['콤팩트', '디자인', '실용'],
#  ['전면', '스크래치'],
#  ['말', '멀티', '어댑터', '필수', '탬'],
#  ['휴대'],
#  ['배송', '품질', '감사'],
#  ['USB형', '후기'],
#  ['형', '사용'],
#  ['여유'],
#  ['나라', '전압', '충전', '나라', '충전', '충전', '코드', '불편', '파우', '걸로', '사용'],
#  ['충전', '충전', '속도', '사용', '불편'],
#  ['호환', '나라'],
#  ['마감', '맛'],
#  [],
#  ['구매', '나라'],
#  ['단자', '유용', '불량', '사용'],
#  ['USB형'],
#  ['성능', '가격'],
#  ['물건'],
#  ['멀티', '콘센트'],
#  ['몸통', '단점'],
#  ['필요', '기능'],
#  ['일반', 'USB형', '구매'],
#  ['가지', '겸용'],
#  ['센스', '우치', '보관'],
#  ['충전'],
#  [],
#  ['본체', '콘센트'],
#  ['결과'],
#  ['구성', '편리', '만족'],
#  ['한국'],
#  ['포트', '구매'],
#  ['볼트', '구매'],
#  ['사용', '뭔가', '사용', '불안'],
#  ['제품', '추가', '구매'],
#  ['불량'],
#  ['구매'],
#  ['포트', '활용', '작동'],
#  ['장기', '출장', '구매'],
#  ['고장', '여유', '구매', '완료'],
#  ['기대', '배송'],
#  ['다이소'],
#  ['불편'],
#  ['고정', '무용지물'],
#  ['해결', '편리', '성비'],
#  ['주문', '불량'],
#  ['정상'],
#  ['가지', '플러그'],
#  ['형식', '편리'],
#  ['품질'],
#  ['보관', '파우', '연결', '연결', '가능'],
#  ['고장', '주문', '주문'],
#  ['콘센트', '느낌', '사용'],
#  ['코드'],
#  ['이외', '멀티', '사용', '부분'],
#  ['제품'],
#  ['생각'],
#  ['콘센트', '정상', '동작'],
#  ['국내', '기능', '확인', '국가', '콘센트'],
#  ['가격', '기능', '만족'],
#  [],
#  ['필요', '물건', '구매'],
#  ['타입', '집', '콘센트', '전원', '고정'],
#  ['타입', '집', '콘센트', '전원', '고정'],
#  ['나라', '플러그', '모양'],
#  ['지인'],
#  ['품질'],
#  ['버튼', '부분'],
#  ['어댑터', '구입', '국가', '편리', '가격', '구매'],
#  ['제품', '퀄리티'],
#  ['사용', '파우', '휴대'],
#  ['대만', '충전', '타입'],
#  ['다이슨', '구매'],
#  ['충전'],
#  ['저번', '맛', '돼지코', '연결'],
#  ['멀티탭', '걱정', '필요'],
#  ['타입', '충전'],
#  ['돼지코', '구매'],
#  ['점', '타입', '부분'],
#  ['충전기', '케이블'],
#  [],
#  ['대만', '고속', '충전', '동생', '미국', '출장', '연락'],
#  ['전용', '파우', '보관', '캐리어'],
#  ['유선', '충전', '장점'],
#  ['상품', '품질', '마감', '실물'],
#  [],
#  ['앤', '코', '멀티', '어댑터'],
#  ['미국', '사용', '사용'],
#  ['타입', '다양', '다양'],
#  ['휴대', '편리'],
#  ['동일', '스펙', '멀티', '어댑터', '디자인'],
#  ['파우', '충전', '속도'],
#  ['기능', '편리'],
#  ['타입', '타입', '유용'],
#  ['멀티탭', '필수', '탬', '강추'],
#  [],
#  ['용도', '다양'],
#  ['물건', '사진'],
#  ['이게', '타입', '타입', '가능', '가격'],
#  ['A타입', '타입', '유용', '사용'],
#  ['손', '선풍기', '파이', '도시락', '핸드폰', '보조', '배터리', '충전'],
#  ['핸드폰', '충전', '속도', '고속', '충전', '사용'],
#  ['충전기', '디자인', '한몫', '생각'],
#  ['우치', '보관'],
#  ['케이스', '휴대', '사용'],
#  ['퀄리티'],
#  ['파우'],
#  ['구매'],
#  ['휴대', '불편', '업', '사용'],
#  [],
#  ['별점', '이유', '전기', '제품', '배송'],
#  ['케이스', '감사', '케이스', '쿠션', '박스', '스티커'],
#  ['출국', '물건', '테스트', '한국', '콘센트', '구멍', '크기', '모양'],
#  ['멀티', '어댑터', '사용', '점'],
#  ['케이스'],
#  ['배송'],
#  ['충전', '사진'],
#  [],
#  ['사용', '보관', '파우'],
#  ['디자인', '우치', '마음'],
#  ['전이', '성능'],
#  ['기능', '나라'],
#  ['여행지', '사용', '구입', '여분', '돼지코', '정도', '어댑터', '작동'],
#  ['제품'],
#  ['콘센트'],
#  [],
#  ['고장'],
#  ['준비', '어댑터'],
#  ['충전'],
#  ['흰색', '케이스'],
#  ['리뷰', '구매', '디자인'],
#  ['파우'],
#  ['자리', '차지', '충전'],
#  ['우치'],
#  ['요고', '해결'],
#  ['C타입', '고속', '충전'],
#  ['파우'],
#  ['포트', '만족'],
#  ['사용'],
#  ['작동', '케이스', '고급'],
#  ['동유럽', '필요', '보조', '배터리', '충전', '사용'],
#  ['파우'],
#  ['나라', '사용'],
#  ['부모', '가실', '성능'],
#  ['연결'],
#  ['케이스', '보관'],
#  [],
#  ['돼지코', '준비', '돼지코'],
#  ['파우', '안심', '언니', '어댑터', '제품', '구매', '냄새'],
#  ['미국', '출장', '차', '구입', '파우', '마음', '후기', '품질', '사용'],
#  ['생각'],
#  ['C타입'],
#  [],
#  ['내구', '안정', '사용', '가능'],
#  ['사은품'],
#  ['파우', '이동', '파손'],
#  ['PD충전', 'C타입', '충전', '포트', '충전기', '필요', '점', '실용'],
#  ['구매'],
#  ['파우', '생각'],
#  ['작동'],
#  ['지역', '사용', '편리'],
#  ['구성'],
#  ['멀티탭', '핸드폰', '보조', '배터리', '보조', '배터리', '충전'],
#  ['사진'],
#  ['부분', '충전', '유선', '멀티탭', '국가', '사용', '가능'],
#  ['무게', '생각', '구매', '휴대', '파우', '휴대'],
#  ['사진', '동일', '멀티탭', '사진', '첨부'],
#  ['다이소'],
#  ['충전', '케이블', '충전기'],
#  ['무게', '벽', '설치'],
#  ['C타입', '케이블', '편리'],
#  ['어댑터'],
#  ['전체', '만족', '제품'],
#  ['무게', '정도'],
#  ['충전', '타입', '타입'],
#  ['실용'],
#  ['구멍'],
#  [],
#  ['여행지', '고데', '사용', '필수', '렴', '돼지코'],
#  ['파우', '제품', '구입'],
#  ['멀티탭', '사용'],
#  ['데기', '어댑터', '연결', '돼지코', '사용', '그것'],
#  ['나라', '어댑터', '사용'],
#  ['고정'],
#  ['형태', '충전', '가능'],
#  [],
#  ['식겁'],
#  ['C타입'],
#  ['케이스', '성능', '만족'],
#  ['생각', '느낌', '무게'],
#  ['사이즈', '커버'],
#  ['나름'],
#  ['디자인', '케이스'],
#  ['디자인'],
#  ['케이스'],
#  ['사용', '케이스'],
#  ['가지', '제품'],
#  ['구멍'],
#  ['미', '사용', '활용'],
#  ['포트', '핸드폰', '충전', '속도'],
#  ['집', '사용', '핸드폰', '충전', '포트'],
#  ['디자인', '만족'],
#  ['돼지코', '고장', '후기'],
#  ['케이스', '제품'],
#  ['가격', '품질', '배송', '만족'],
#  ['상품'],
#  ['케이스'],
#  ['어댑터', '구성'],
#  ['디자인', '멀티', '콘센트'],
#  ['커피', '물'],
#  ['쓸모', '상품'],
#  ['충전', '핸드폰', '충전'],
#  ['멀티탭', '연결', '필수', '탬'],
#  ['출장', '구매', '다이소', '타입', '구성'],
#  ['견고'],
#  ['나라'],
#  ['얘', '건지', '콘센트', '건지', '콘센트', '충전', '활용'],
#  ['색', '케이스'],
#  ['케이스'],
#  ['결제'],
#  ['케이스', '사용'],
#  ['충전', '사용'],
#  ['충전'],
#  [],
#  ['생각', '점'],
#  ['퓨즈', '사용', '퓨즈', '여분'],
#  ['퓨즈', '작동'],
#  ['사용', '우치'],
#  ['케이스'],
#  ['사은품', '배송', '포장', '만족'],
#  ['어댑터', '충전'],
#  ['마음', '주문', '파우'],
#  ['후대'],
#  ['케이스'],
#  ['어댑터', '국내', '확인', '불량', '단점', '불량', '충전'],
#  ['충전', '속도', '워치', '핸드폰', '보조', '배터리', '충전'],
#  ['걱정'],
#  [],
#  ['충전', '포트', '걱정', '고데'],
#  ['데기', '프리', '볼트', '제품'],
#  ['앞', '어댑터', '걱정'],
#  ['무료', '배송', '나중', '가족', '주문'],
#  ['애플', '워치', '보조', '배터리', '충전', '대부분', '사용', '케이스', '보관', '편리'],
#  ['제품', '품평', '구매', '품질'],
#  ['기대'],
#  [],
#  ['타입', '한국', '형', '충전'],
#  ['사용'],
#  ['멀티탭', '기기', '충전', '가능'],
#  ['타입', '여유'],
#  ['사용', '구성'],
#  ['고장', '충전', '사용'],
#  ['뭔가', '개선', '충전', '입구', '깊이'],
#  ['입구', '안쪽', '개선'],
#  ['만족'],
#  ['마감', '처리'],
#  ['사용'],
#  ['값'],
#  ['걱정'],
#  ['아이디어', '실용', '정리'],
#  ['이게', '구조'],
#  ['휴대', '국내', '필요', '사용', '구입', '사용'],
#  ['고장'],
#  ['비', '코'],
#  ['어댑터'],
#  ['파우', '미국', '손상', '걱정', '사용'],
#  ['국내외'],
#  ['케이스'],
#  ['사용법', '부담', '크기', '사용'],
#  ['전용', '파우', '제공'],
#  ['나라', '사용', '가능', '타입', '케이블', '케이블', '사용', '가능', '만능'],
#  ['파우'],
#  [],
#  ['배송', '사이즈'],
#  ['타입', '사용'],
#  ['케이', '어댑터', '제품'],
#  ['구매', '후회'],
#  ['주문', '견고'],
#  [],
#  ['물건'],
#  ['다이소', '원', '요거', '요거', '요거', '충전기', '필요', '사용'],
#  ['케이블'],
#  ['고정', '장치'],
#  ['제품', '포트', '동시', '충전', '테스트'],
#  ['파우'],
#  ['무게', '세계', '사용', '가능'],
#  ['콘센트', '구매', '라이브', '가격', '구매'],
#  [],
#  ['동봉', '케이스', '휴대'],
#  ['사용', '앤', '코', '멀티', '어댑터', '편리'],
#  ['필요', '콘센트', '변환기', '국가', '사용', '플러그', '제공', '효율'],
#  ['돼지코', '기능', '기기', '동시', '충전', '편리'],
#  ['타입', '지원'],
#  ['안정', '충전', '가능', '나라', '사용', '발생'],
#  ['필요', '기기', '앤', '코', '멀티', '어댑터', '탬'],
#  ['멀티', '어댑터', '구입'],
#  ['이전', '미국', '다이소', '멀티탭', '생각', '구매'],
#  ['멀티탭'],
#  ['편안', '기기', '무리'],
#  ['가지', '중요'],
#  ['저거'],
#  ['대만', '사용', '보관', '케이스'],
#  ['핸드폰', '보조', '배터리', '충전', '어댑터', '고민', '인터넷', '후기', '구입', '포장', '어댑터', '만족'],
#  ['겉', '제품', '실사', '추천', '제품', '구매'],
#  ['충전'],
#  ['파우', '가족', '구매'],
#  ['사용', '구입', '가방', '휴대'],
#  ['퓨즈'],
#  ['여분', '여분', '퓨즈'],
#  ['고민', '생각'],
#  ['유에스비', '포트', '타입', '포트', '말'],
#  ['동시', '충전'],
#  ['검색', '선택', '구매'],
#  ['충전'],
#  [],
#  ['사용', '구매', '나름', '디자인'],
#  ['추천', '구매', '지원'],
#  ['콘센트'],
#  ['돼지코', '해결'],
#  ['사용', '파우'],
#  ['사용', '집', '멀티탭', '사용'],
#  ['디자인', '케이스', '마음'],
#  ['사용', '케이스', '보관', '디자인', '만족'],
#  ['대만', '전기', '포트'],
#  [],
#  ['제품', '나중'],
#  ['케이스', '장점'],
#  ['케이스'],
#  [],
#  ['필요', '제품'],
#  ['케이스', '편리'],
#  ['충전', '충전'],
#  ['나라', '호환'],
#  ['케이스'],
#  [],
#  ['본체', '느낌', '불안감', '연결', '충전', '앞'],
#  [],
#  ['케이스', '콤팩트'],
#  ['제품', '품질', '마감', '처리', '안전', '제품', '느낌'],
#  ['배송', '충전', '연결', '실용'],
#  [],
#  ['케이스'],
#  ['케이스'],
#  ['세상', '사장', '복'],
#  ['다이슨'],
#  ['부분', '각도', '당황', '각도', '조절'],
#  ['돼지코', '필요'],
#  ['고속', '충전', '편리'],
#  ['보관', '케이스', '마련', '사용', '제품'],
#  ['유용'],
#  ['케이스', '걱정'],
#  ['검색', '이게', '주문'],
#  ['케이스'],
#  ['멀티', '콘센트', '편리'],
#  ['C타입', '단자', '유에스비', '단자', '마음'],
#  ['발송'],
#  ['구매', '멀티', '어댑터', '사용', '불편', '콘센트', '부분', '힘'],
#  ['타입', '충전', '가능', '유용'],
#  ['파우', '마음'],
#  ['구매', '휴대'],
#  ['종류', '다양', '충전'],
#  ['비', '코', '멀티', '어댑터'],
#  ['무게', '콘센트', '불편'],
#  ['구매', '인증'],
#  ['필요'],
#  ['지역', '커버', '가능'],
#  ['기기', '충전'],
#  ['저녁'],
#  ['동생', '필요', '느낌'],
#  ['전용', '보관'],
#  ['돼지코', '필요', '이걸로'],
#  ['세계', '나라', '요거', '끝'],
#  ['나라', '한국인', '고속', '충전', '구매'],
#  ['사용', '집', '고속', '충전기', '사용'],
#  ['아이폰', '갤럭시', '연결', '충전', '대만', '전기', '사용'],
#  ['생각', '충전'],
#  [],
#  ['충전', '타입'],
#  ['만족'],
#  ['케이스', '마음'],
#  ['케이스'],
#  ['고급'],
#  ['시험', '사용', '드라', '타입', '충전'],
#  ['파우', '어댑터'],
#  ['부분', '동시', '충전'],
#  ['코드', '발'],
#  ['발', '내구'],
#  ['국가', '사용', '가능', '어댑터', '필요', '충전', '선망'],
#  ['파우', '디자인', '컬러', '제품', '고급'],
#  ['휴대'],
#  ['출장', '사용', '멀티', '어댑터', '네이버', '검색', '구매', '판매', '이유'],
#  ['포트', '연결', '잭', '해결'],
#  ['국가', '옵션', '설명서', '유용', '우치'],
#  ['발리', '신혼', '다이슨', '주문', '어댑터', '다이슨', '사용'],
#  ['목', '의자', '하루', '의자', '목'],
#  ['가이드'],
#  ['사람', '정도', '활용'],
#  ['C타입', '동시', '사용'],
#  ['가격대', '퀄리티', '제품', '생각'],
#  ['구매', '만족'],
#  ['출장', '빛'],
#  ['디자인', '케이스', '만족'],
#  [],
#  ['멀티탭', '필요'],
#  ['준비', '충전'],
#  ['멀티탭', '필요'],
#  ['충전'],
#  [],
#  [],
#  ['핸드폰', '충전', '워치', '충전', '드라이', '가능'],
#  ['충전'],
#  ['우치'],
#  ['돈', '유용'],
#  ['다이소', '천', '원', '이건', '믿음'],
#  [],
#  ['파우', '실용'],
#  [],
#  ['구매'],
#  ['예비', '퓨즈'],
#  ['충전', '케이블', '사용', '정도'],
#  ['충전'],
#  ['갤럭시', '폰', '고속', '충전'],
#  ['물건'],
#  ['충전'],
#  ['연결'],
#  ['돈', '연결', '불안'],
#  ['사용', '충전', '불편'],
#  ['색상', '흰색'],
#  ['포트'],
#  ['타입', '충전', '사용'],
#  ['케이스', '보관', '편리'],
#  ['충전', '호환', '불편', '사용'],
#  ['케이스'],
#  ['케이스'],
#  ['C타입', '최근', '집', '콘센트', '자리', '타입', '사용'],
#  ['국내', '멀티탭', '사용', '가능'],
#  ['물건'],
#  ['사용', '편리', '실용'],
#  ['제품', '한국', '멀티탭', '연결', '휴대폰', '충전'],
#  ['배송', '품질', '감사'],
#  ['고급', '케이스', '어댑터'],
#  ['콘센트', '활용'],
#  ['어댑터', '유용', '사용'],
#  ['전이', '상품', '구성', '만족'],
#  ['충전'],
#  ['충전'],
#  ['보관', '케이스', '사용'],
#  ['충전'],
#  ['사용', '가능', '다이슨', '사용'],
#  ['건지', '참고'],
#  ['크기', '파우'],
#  ['최근', '대만', '태국', '최고', '효율', '소지품'],
#  ['고속', '충전'],
#  ['충전'],
#  ['접촉', '불량', '블로그', '추천', '돼지코'],
#  ['동시', '정도', '충전', '가능', '유용'],
#  ['충전'],
#  ['구성', '어댑터', '본품', '설명서', '파우'],
#  ['다이소', '어댑터', '비교'],
#  ['가격대', '콘센트', '현상'],
#  ['점', 'C타입'],
#  ['커버', '보관'],
#  ['디자인'],
#  ['이전', '구매'],
#  ['케이블'],
#  ['일반'],
#  ['배터리', '충전'],
#  ['프리', '볼트', '건지'],
#  ['고속', '충전'],
#  ['테두리', '끝', '노란색'],
#  ['교환', '물건', '사용'],
#  ['멀티탭', '대용', '유용'],
#  ['사이즈'],
#  ['견고'],
#  ['앞', '타입', '고민'],
#  ['충전'],
#  ['무게', '크기', '만족'],
#  ['사용', '기대'],
#  ['케이스', '고급', '목', '베개', '센스'],
#  ['해결'],
#  ['종류'],
#  ['데기', '사용'],
#  ['값'],
#  ['케이스'],
#  ['사용', '사용', '후기'],
#  ['디자인', '보관', '파우'],
#  ['견고', '심플'],
#  ['충전'],
#  ['콘센트', '파우'],
#  ['포트'],
#  [],
#  ['케이스'],
#  ['보관'],
#  ['사용'],
#  ['구매'],
#  ['제품', '자체', '콘센트', '충전', '확인'],
#  ['동시', '충전', '최대', '충전', '시도', '미국', '사용'],
#  ['디자인', '마트', '제품'],
#  ['크기'],
#  ['만족', '제품'],
#  ['제품'],
#  ['충전기', '후기', '구매'],
#  ['마감', '사용'],
#  ['전기', '포트', '방문', '전기', '포트', '어댑터'],
#  ['어댑터', '불안'],
#  ['값'],
#  ['파우', '길'],
#  ['어댑터', '여분'],
#  ['생각', '충전'],
#  ['멀티탭', '나라', '코드'],
#  ['충전', '포트', '활용'],
#  ['뭔가'],
#  [],
#  ['휴대', '사용'],
#  ['파우', '마감'],
#  ['C타입', '포트'],
#  ['C타입', '포트', '충전', '최대'],
#  ['남편', '충전'],
#  ['핸드폰', '수신기', '충전'],
#  ['구성'],
#  ['디자인', '타입'],
#  ['편지', '사은품', '만족'],
#  ['호주', '휴대폰', '충전', '고민', '인터넷', '사용'],
#  ['포트', '타입', '타입'],
#  ['케이스', '정리', '가능', '뭔가'],
#  ['핸드폰', '워치', '충전'],
#  ['충전', '속도'],
#  ['물건'],
#  ['감동'],
#  ['케이스'],
#  ['케이스', '편리'],
#  [],
#  ['제품', '견고'],
#  ['충전'],
#  ['이것저것', '필요'],
#  ['구매'],
#  ['완성도'],
#  ['충전', '필수', '탬'],
#  ['세상'],
#  ['예전', '나라', '전기', '코드', '타입', '확인', '준비', '걱정', '핸드폰', '충전', '가능', '세상'],
#  ['충전'],
#  ['멀티탭', '충전기', '불편', '구매'],
#  ['애플', '워치', '담배', '핸드폰', '보조', '배터리', '동시', '충전'],
#  ['손', '편지', '박싱'],
#  ['케이스'],
#  ['디자인'],
#  ['파우', '만족'],
#  ['코드', '체결', '싸구려', '충전'],
#  ['디자인'],
#  ['만족',
#   '점',
#   '만족',
#   '점',
#   '만족',
#   '점',
#   '만족',
#   '점',
#   '만족',
#   '점',
#   '만족',
#   '점',
#   '만족',
#   '점',
#   '만족',
#   '점',
#   '만족',
#   '점',
#   '만족',
#   '점',
#   '만족',
#   '점',
#   '만족',
#   '점'],
#  ['걱정', '충전', '포트', '충전', '사용'],
#  ['파우', '크기', '포스트잇', '사용', '편리', '생각'],
#  ['구성', '사용', '추후', '의견'],
#  ['무게', '구성'],
#  ['C타입', '유용'],
#  ['최대'],
#  ['충전기', '걱정'],
#  ['여분', '퓨즈', '파우', '만족'],
#  ['저번', '밤새', '충전', '구매'],
#  ['충전', '선망', '충전', '어댑터'],
#  ['제품', '돈'],
#  ['필요'],
#  ['계획', '한국', '콘센트', '구매'],
#  ['목', '멀티', '어댑터', '구매'],
#  ['요기', '테스트', '걱정', '충전', '보조', '배터리', '충전', '부족'],
#  ['국가', '사용', '가능', '앞', '배터리', '걱정'],
#  ['배송', '정성', '메모', '구성', '만족'],
#  ['한국', '콘센트', '작동'],
#  ['동시', '충전', '속도'],
#  ['배송',
#   '손',
#   '편지',
#   '감동',
#   '추가',
#   '구성',
#   '파우',
#   '정리',
#   '꽈배기',
#   '무게',
#   '콤팩트',
#   '사이즈',
#   '미국',
#   '국가',
#   '사용',
#   '가능',
#   '콘센트',
#   '지원'],
#  ['배송', '문자', '물품', '정리', '물건', '연락', '토요일', '연결', '포기', '물건'],
#  ['필요', '전압'],
#  ['전용', '케이스'],
#  ['가지', '호환'],
#  ['느낌', '충전'],
#  ['충전', '속도'],
#  [],
#  ['물건', '가지', '기능'],
#  [],
#  ['충전', '만족'],
#  ['배송', '집', '고속', '충전', '케이스'],
#  ['친절', '손', '편지'],
#  ['정성'],
#  ['파우'],
#  ['포트', '편리'],
#  ['유용', '사용', '구매', '어댑터', '파우', '마음'],
#  ['품질'],
#  ['워홀', '멀티', '어댑터', '구매'],
#  ['파우'],
#  ['변환', '손'],
#  ['디자인', '기능', '만족'],
#  ['사은품', '쪽지', '구매'],
#  ['전용', '케이스', '보관', '배송'],
#  ['만족'],
#  [],
#  ['불량'],
#  ['불량', '인증', '첨부', '영상'],
#  ['케이스'],
#  ['소형', '어댑터', '세계', '기기', '사용', '가능', '기대'],
#  ['사용', '가능'],
#  ['케이스', '마음'],
#  ['사장', '전기', '전기', '눈', '상세', '설명'],
#  ['전기'],
#  ['세상', '질문', '친절', '설명'],
#  ['손', '쪽지', '케이스'],
#  [],
#  ['멀티', '어댑터', '야지', '야지', '생각'],
#  ['메모', '사은품', '파우'],
#  ['이것저것', '테스트'],
#  ['정성', '손', '편지', '감동'],
#  ['끝'],
#  ['구멍', '앞'],
#  [],
#  ['고정', '느낌'],
#  ['파우', '보관'],
#  ['남편', '어댑터', '사용'],
#  ['사용', '방법', '전화', '설명', '핸드폰', '전기', '충전', '해결'],
#  ['포스트잇'],
#  ['저번', '구매', '동생'],
#  ['충전기'],
#  ['한국', '사용'],
#  ['충전기', '필요'],
#  ['초고속'],
#  ['어댑터', '충전', '요건', '충전'],
#  ['충전기', '충전', '편리'],
#  ['선물', '구매'],
#  ['첨', '집', '사용', '콘센트', '사용', '설명서', '국내', '사용', '가능', '이해'],
#  ['멀티탭', '리뷰', '걸로', '구매'],
#  ['C타입', '사용', '가능'],
#  [],
#  ['크기', '휴대'],
#  ['포트',
#   'C타입',
#   '포트',
#   '고속',
#   '충전',
#   '포트',
#   '용량',
#   '내장',
#   '퓨즈',
#   '여분',
#   '퓨즈',
#   '체결',
#   '안전',
#   '정도'],
#  ['성능', '생각'],
#  ['급속', '충전'],
#  ['물건', '양호', '정도', '박스'],
#  ['파우', '타입', '개수'],
#  [],
#  ['멀티탭'],
#  ['제품', '이유'],
#  ['어댑터', '종결'],
#  ['국내', '돼지코', '포트', '충전기', '역할', '생각'],
#  ['디자인', '케이스'],
#  ['충전'],
#  [],
#  ['가지', '콘센트', '타입', '멀티'],
#  ['파우', '주문'],
#  [],
#  ['여분', '퓨즈', '이걸로', '결정'],
#  ['예전', '어댑터', '퓨즈', '당황'],
#  ['말', '어댑터', '고생', '구매'],
#  ['출장', '노트북', '포트'],
#  ['코드', '여분', '퓨즈', '사용', '설명'],
#  ['꽈배기', '모양'],
#  ['전기', '포트', '구매', '구매'],
#  ['제품', '케이스', '고급'],
#  ['사용', '타입'],
#  ['충전'],
#  ['케이스', '휴대'],
#  ['유에스비', '기본', '충전기', '점', '충전', '속도'],
#  ['준비'],
#  ['케이스', '호주', '사용'],
#  ['고속', '충전'],
#  ['콘센트', '가방', '부피', '선물'],
#  ['수화물', '무게'],
#  ['식구', '동시', '휴대폰', '충전', '보리', '전기'],
#  ['사요'],
#  ['별점'],
#  ['사이즈', '생각'],
#  ['반품', '코드'],
#  ['케이스'],
#  ['충전', '마감', '처리', '파우', '만족'],
#  ['타입'],
#  ['생각'],
#  ['콘센트', '벽', '세로', '콘센트'],
#  ['이것저것'],
#  ['자체', '충전', '기능', '볼트', '볼트', '변환', '기능'],
#  ['충전', '어댑터', '집', '나라', '충전', '어댑터', '기능', '구매'],
#  ['만족'],
#  ['제품', '허접'],
#  ['사용', '여분', '퓨즈', '포트', '만족'],
#  ['충전'],
#  ['충전기', '만족'],
#  ['집', '사용', '이건', '휴대폰', '충전', '주문'],
#  ['고장'],
#  ['폰', '타입', '보조', '배', '타입', '동시', '충전', '충전', '속도'],
#  ['타입', '이걸로'],
#  ['파우'],
#  ['시험', '작동'],
#  ['걱정', '안정', '연결', '충전'],
#  ['효과'],
#  ['케이스'],
#  ['편리'],
#  ['타제품', '비교', '정도', '충전'],
#  ['의심', '정도'],
#  ['어댑터', '요즘', '타입', '준비'],
#  ['가족', '동시', '사용', '가능'],
#  ['구성', '보관', '포켓', '먼지', '보호'],
#  ['케이스'],
#  ['파우', '건가요'],
#  ['배송', '케이스', '용량', '타사', '비교', '구입'],
#  ['호주', '구입', '랩', '사용', '가능', '핸드폰', '와이파이', '도시락', '보조', '배터리', '충전', '사용'],
#  ['요즘', '타입', '형식', '충전'],
#  ['C타입'],
#  ['케이스', '안심'],
#  ['제품', '그건'],
#  ['사용'],
#  ['출국', '고민', '배송', '케이스'],
#  ['변환기'],
#  ['충전', '기능'],
#  ['나라', '콘센트', '모양', '방식'],
#  ['케이스', '휴대'],
#  ['파우'],
#  ['케이스', '이동', '안심'],
#  ['콘센트', '구멍', '어댑터', '무게'],
#  ['세로', '콘센트', '바닥', '고정'],
#  ['퓨즈', '편리'],
#  ['상품', '콤팩트', '사이즈', '만족', '케이스', '만족'],
#  ['어댑터', '흠집', '재질'],
#  ['뭔가', '충전'],
#  ['자체', '콘센트'],
#  ['브랜드', '어댑터', '그건', '무용지물', '지팅스', '어댑터'],
#  ['이것저것', '파우'],
#  ['C타입', '포트', '선택'],
#  ['파우'],
#  ['상세', '페이지', '구매'],
#  ['사용', '견고'],
#  ['출장', '사용', '충전기', '충전'],
#  ['사용', '케이스'],
#  ['멀티탭', '필요'],
#  ['포트', 'C타입', '충전', '포트', '휴대폰', '충전', '카메라', '충전', '걱정'],
#  ['한국', '충전기', '고장', '사용', '충전기'],
#  ['케이스', '충전', '캡', '구입', '출력'],
#  ['디자인'],
#  [],
#  ['느낌', '포트', '가족', '장점'],
#  ['생각', '휴대'],
#  ['충전'],
#  ['사용', '충전', '만족', '다이슨', '헤어', '기기', '단독', '사용'],
#  ['사용', '케이블', '작동'],
#  ['포트', '당황'],
#  ['어댑터', '첨'],
#  ['후기', '판매', '개수', '세계', '파우'],
#  ['타입', '타입', '충전', '걱정'],
#  ['충전기', '자체', '고정', '불편'],
#  ['보관', '파우', '케이블', '정리', '코일'],
#  ['충전'],
#  ['물건'],
#  ['사용', '어댑터'],
#  ['충전', '나라'],
#  ['생각'],
#  ['모양', '케이블', '아래쪽', '불편', '사람', '케이블', '가지', '충전'],
#  ['사용', '비교', '제품'],
#  ['케이스'],
#  ['사용', '전체', '마감', '파우'],
#  ['케이블', '정리', '코일'],
#  ['쪽지', '멀티탭', '출장'],
#  ['폰', '워치', '태블릿', '카메라', '충전', '가능', '데기', '필수', '고데', '사용'],
#  ['전용', '케이스', '휴대'],
#  ['지팅스', '멀티', '어댑터', '타입', '초고속', '세계'],
#  ['우치'],
#  ['어댑터', '점'],
#  ['나라', '사용', '가능'],
#  ['콘센트', '플러그'],
#  ['참고', '미국', '버스', '콘센트'],
#  ['전기', '어댑터', '편리'],
#  ['해결'],
#  ['국내', '플러그', '사이즈'],
#  [],
#  ['포트', '목', '베개'],
#  ['멀티', '어댑터', '핸드폰', '충전', '국내', '드라이'],
#  ['기기', '충전', '구매'],
#  [],
#  [],
#  ['사이즈', '퓨즈', '불편', '성비', '가격'],
#  ['C타입'],
#  ['보관', '케이스', '사이즈', '사용', '편리', '구매', '선물'],
#  ['어댑터', '배송'],
#  [],
#  ['충전', '몸통', '옆쪽', '핀', '단독', '사용', '고속', '충전'],
#  ['만족'],
#  ['충전', '케이블', '지팅스', '몸통'],
#  ['출장', '사용', '어댑터', '구매'],
#  ['충전', '단자', '여유', '사용'],
#  ['파우'],
#  ['기능', '확인'],
#  ['선물'],
#  ['사용', '편리'],
#  ['크기', '호환'],
#  [],
#  ['핸드폰', '동시', '충전', '편리'],
#  ['실용'],
#  ['국내', '다양'],
#  ['사용', '기기'],
#  ['기능'],
#  ['다양', '고속', '충전', '사용'],
#  ['케이스'],
#  ['국내', '사용', '가능', '사이즈'],
#  ['스펙', '만족'],
#  ['포트', '초고속'],
#  ['느낌', '집', '충전', '실험'],
#  ['케이스'],
#  ['지인', '선물'],
#  ['충전기', '고민', '충전', '걸로'],
#  ['충전'],
#  ['고생', '선물', '구매'],
#  ['고출력', '시대', '타입', '충전기'],
#  ['제품', '고장', '걸로'],
#  ['C타입', '동시', '충전', '멀티탭', '필요'],
#  ['보관', '파우'],
#  ['생각', '휴대'],
#  ['문', '답변'],
#  ['케이스'],
#  ['시험', '불'],
#  ['브랜드', '고심'],
#  ['고가',
#   '사용',
#   '편리',
#   '생각',
#   '도넛',
#   '고속',
#   '충전',
#   '포트',
#   '포트',
#   '고심',
#   '고심',
#   '고속',
#   '충전',
#   '가능',
#   '국내',
#   '디자인',
#   '고려',
#   '퓨즈',
#   '교체',
#   '배송',
#   '추가',
#   '퓨즈',
#   '어댑터',
#   '내장',
#   '핀',
#   '교체'],
#  [],
#  [],
#  ['후기', '사이즈'],
#  ['벽', '콘센트'],
#  ['보관', '케이스', '편리', '사용'],
#  ['구매', '타입', '충전', '구성', '사용', '불편', '사용'],
#  [],
#  [],
#  ['타입', '만족'],
#  ['어댑터'],
#  ['기능', '사용'],
#  ['디자인', '케이스'],
#  ['케이스'],
#  ['충전'],
#  ['충전'],
#  ['배송', '케이스'],
#  ['생각', '사이즈', '만족'],
#  ['사진', '충전기', '어댑터', '크기', '비교'],
#  ['사용', '나라'],
#  ['충전기', '사용', '멀티', '어댑터', '연결', '어댑터', '숙소', '과정', '어댑터', '멀티탭', '기능', '사용'],
#  ['일반', '멀티탭', '부피', '만족'],
#  ['유격', '고속', '충전', '부분'],
#  ['타입', '포트', '만족'],
#  ['케이스'],
#  ['불'],
#  ['렴', '돼지코', '위험', '생각'],
#  ['휴대폰', '태블릿', '워치', '보조', '배터리', '해결', '가능'],
#  ['나라', '돼지코', '멀티', '포트'],
#  ['한국', '돼지코', '벽', '고정'],
#  ['타사', '제품', '타입', '전압', '안심', '사용'],
#  ['파우', '보관'],
#  ['심플', '포트', '유용'],
#  ['케이스', '완벽', '자체'],
#  ['다이소', '검정', '돼지코', '구매'],
#  ['멀티탭', '코드'],
#  ['멀티탭'],
#  ['사용', '디자인'],
#  ['디자인', '타입', '사용'],
#  ['타입', '가격', '퀄리티'],
#  ['가격', '케이스'],
#  ['유용'],
#  ['디자인', '전용', '파우'],
#  ['사용', '편리', '잭', '연결', '휴대폰', '충전', '불'],
#  ['디자인'],
#  ['멀티', '어댑터', '타입', '포트', '결제'],
#  ['포트', '어댑터', '케이블'],
#  ['충전', '속도', '이게'],
#  ['포트'],
#  ['돈'],
#  ['충전', '이것저것'],
#  ['타입', '전압', '코드'],
#  ['선물', '유학', '필요'],
#  ['작년', '필요', '구매'],
#  ['충전'],
#  ['한국'],
#  ['다이소', '불안'],
#  ['제품', '구성'],
#  ['케이스'],
#  ['동작', '확인', '가능'],
#  ['사용', '타입', '연결', '개수', '유용'],
#  ['고정'],
#  ['고정'],
#  ['고속', '충전', '포트', '유용', '사용'],
#  ['품질'],
#  ['싸구려', '저번', '콘센트', '겁', '돈', '안정', '장치', '구매'],
#  ['케이스', '상자'],
#  ['상품'],
#  ['C타입'],
#  ['돼지코', '한국', '어댑터', '불편'],
#  ['한국', '테스트', '불'],
#  ['충전', '불편'],
#  ['돼지코', '사고', '나중'],
#  [],
#  ['어댑터', '전이', '사용', '국가', '사용', '유용'],
#  ['국내', '작동', '확인', '빛', '확인', '빛'],
#  ['작동', '빛', '안심'],
#  ['케이스'],
#  ['충전', '가능'],
#  ['디자인', '사용', '사용'],
#  ['디자인', '안정'],
#  [],
#  ['멀티', '어댑터', '리뷰', '주문'],
#  ['사이즈', '보관함'],
#  ['가방'],
#  ['사이즈', '생각'],
#  ['제품', '후기', '구매'],
#  ['사용법', '편리'],
#  ['구성', '사용'],
#  ['어댑터', '콘센트', '플러그', '어댑터'],
#  ['어댑터', '콘센트', '한국', '플러그', '어댑터', '끝', '느낌'],
#  ['디자인'],
#  ['케이스', '파손', '걱정'],
#  ['테스트', '제품', '느낌'],
#  ['유에스비', '어댑터'],
#  ['보조', '배터리', '캐리어', '은근', '수화물', '상관'],
#  ['화이트'],
#  ['C타입'],
#  ['보관', '케이스', '최고'],
#  ['최근', '보조', '배터리', '구입', '화이트', '화이트', '케이스', '뭔가', '마음', '불편'],
#  ['올인원', '해결'],
#  ['파우'],
#  ['기능'],
#  ['사용', '구매'],
#  ['케이스'],
#  ['어댑터', '가족', '추가', '구매', '건데', '케이스', '고속', '충전', '타입'],
#  ['질문', '답변'],
#  ['어댑터', '충전', '휴대'],
#  ['케이스', '사용', '편리'],
#  ['C타입'],
#  ['볼트'],
#  ['타입', '필요'],
#  [],
#  ['차별'],
#  ['요즘'],
#  ['고속', '충전'],
#  ['지팅스', '멀티', '어댑터'],
#  ['충전', '사용', '편리'],
#  ['사용'],
#  ['계획', '장만', '견고', '구매'],
#  ['상담', '친절'],
#  ['파우', '사이', '부분', '만족'],
#  ['케이스', '보관'],
#  ['충전'],
#  ['가지', '동시', '충전'],
#  ['필수', '탬', '충전'],
#  ['사람', '핸드폰', '보조', '배터리', '충전', '카메라', '배터리', '충전', '동시'],
#  ['케이스', '고급', '가능'],
#  ['제품'],
#  ['기능', '확인', '디자인', '마음'],
#  ['제품'],
#  ['케이스'],
#  ['어댑터'],
#  ['최고'],
#  ['멀티탭', '필요', '활용', '만족'],
#  ['포트', '가지', '충전'],
#  ['효율'],
#  ['휴대폰', '충전'],
#  ['포트'],
#  ['블랙'],
#  ['표기'],
#  ['배송', '물건'],
#  ['포트', '타입', '포트', '충전', '걱정'],
#  ['사이즈'],
#  ['퓨즈', '동봉'],
#  ['콤팩트', '디자인'],
#  ['퀄리티'],
#  [],
#  ['포트', '걱정'],
#  ['보호', '케이스'],
#  ['멀티', '어댑터'],
#  ['생각'],
#  ['케이스'],
#  ['어댑터', '사용'],
#  ['제품', '어댑터', '편리'],
#  [],
#  ['마감'],
#  ['배송', '최고', '유용', '구성'],
#  ['배송'],
#  ['가격', '물건'],
#  ['콘센트', '부분', '이건', '사용법'],
#  ['생각'],
#  ['콤팩트', '사이즈', '추천'],
#  ['멀티',
#   '어댑터',
#   '플러그',
#   '멀티',
#   '어댑터',
#   '플러그',
#   '멀티',
#   '어댑터',
#   '플러그',
#   '멀티',
#   '어댑터',
#   '플러그',
#   '멀티',
#   '어댑터',
#   '플러그',
#   '멀티',
#   '어댑터',
#   '플러그'],
#  ['파우'],
#  ['케이스', '설명서'],
#  ['테스트', '충전'],
#  ['이게', '소리', '코드', '소리'],
#  ['휴대', '케이스', '보관'],
#  ['이놈'],
#  ['충전'],
#  ['멀티', '어댑터', '필요', '구매'],
#  ['가지', '형태', '파우'],
#  ['한국', '충전', '사용', '기대'],
#  [],
#  ['앞', '돼지코', '구매', '만족'],
#  ['앞', '유용'],
#  ['마감', '외관', '고급'],
#  ['배송', '검수', '콘센트', '유에스비', 'C타입', '포트', '정상', '작동'],
#  ['전용', '파우', '쿠션'],
#  ['동일', '규격', '상품', '브랜드', '콘센트', '파워', '존'],
#  ['충전'],
#  ['포트'],
#  ['물건'],
#  ['멀티탭', '엄마', '편리', '제품'],
#  ['케이스', '배송'],
#  ...]

# %%
remove_stopwords = sum(preprocessed_reviews, [])

# %%
from collections import Counter
remain_freq = Counter(remove_stopwords).most_common()
df_remain_freq = pd.DataFrame(remain_freq, columns=['형태소', '빈도'])
df_remain_freq
# Out:
#      형태소    빈도
# 0     충전  1488
# 1     사용  1039
# 2    케이스   926
# 3     구매   556
# 4    디자인   546
# ..   ...   ...
# 995  주황색     1
# 996   북미     1
# 997   변색     1
# 998  고주파     1
# 999   두께     1
#
# [1000 rows x 2 columns]

# %%
from pprint import pprint
print(df_remain_freq)
# Out:
#      형태소    빈도
# 0     충전  1488
# 1     사용  1039
# 2    케이스   926
# 3     구매   556
# 4    디자인   546
# ..   ...   ...
# 995  주황색     1
# 996   북미     1
# 997   변색     1
# 998  고주파     1
# 999   두께     1
#
# [1000 rows x 2 columns]

# %%
df_remain_freq.to_csv('C:/Users/shopperhouse/Code/GEN_Ailee/product_keyword.csv', encoding = 'utf-8-sig')
